# %%
import sys, os
import doc_index.Document_Index as docIndex

import struct

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

print docIndex.getID('http://www.reuters.com/news/archive/businessNews')
# Out:
# 0

# %%
status = 0#unparsed
repoPointer = 0
docchecksum = 0
docinfopointer, url_len = docIndex.setUrlInList('http://www.reuters.com/news/archive/businessNews')
title_len = 0
chunk = struct.pack('BIIIHH', status, repoPointer, docchecksum, docinfopointer, url_len, title_len)
docIndex.setDocIndex(0, chunk)

# %%
import crawlers.Crawlers as crawler

crawler.run(0)
# Out:
# 0

# %%
import indexer.Parser as parser

parser.run(0)
#lex.save() Do this if you need to
# Out:
# (/finance): Business
# (/finance): Business Home
# (/legal): Legal
# (/finance/deals): Deals
# (/subjects/aerospace-and-defense): Aerospace Defense
# (/subjects/banks): Finance
# (/subjects/autos): Autos
# (/finance/summits): Reuters Summits
# (/news/subjects/ADventures): ADventures
# (/data-dive): Data Dive
# (/finance/markets): Markets
# (/finance/markets): Markets Home
# (/finance/markets/us): U S Markets
# (/finance/markets/europe): European Markets
# (/finance/markets/asia): Asian Markets
# (/finance/global-market-data): Global Market Data
# (/finance/markets/indices): Indices
# (/finance/stocks): Stocks
# (/finance/bonds): Bonds
# (/finance/currencies): Currencies
# (/finance/commodities): Comm Energy
# (/finance/futures): Futures
# (/finance/funds): Funds
# (/finance/EarningsUS): Earnings
# (/finance/markets/dividends): Dividends
# (/news/world): World
# (/news/world): World Home
# (/news/us): U S
# (/subjects/specialReports): Special Reports
# (http://www.reuters.com/investigates/): Reuters Investigates
# (/subjects/euro-zone): Euro Zone
# (/subjects/middle-east): Middle East
# (/places/china): China
# (/places/japan): Japan
# (/places/mexico): Mexico
# (/places/brazil): Brazil
# (/places/africa): Africa
# (/places/russia): Russia
# (/places/india): India
# (/politics): Politics
# (/politics): Politics Home
# (/politics/election2016): Election 2016
# (http://polling.reuters.com): Polling Explorer
# (http://live.reuters.com/Event/Election_2016): Just In Election 2016
# (http://www.reuters.com/election2016/the-undecided/): What Voters Want
# (/subjects/supreme-court): Supreme Court
# (/news/technology): Tech
# (/news/technology): Technology Home
# (/news/science): Science
# (/bizfinance/technology/Top100Innovators): Top 100 Global Innovators
# (/news/environment): Environment
# (/innovation): Innovation
# (/commentary): Commentary
# (/commentary): Commentary Home
# (/tools/podcasts/): Podcasts
# (/breakingviews): Breakingviews
# (/breakingviews): Breakingviews Home
# (/video/breakingviews): Breakingviews Video
# (/finance/personal-finance): Money
# (/finance/personal-finance): Money Home
# (/finance/personal-finance/retirement): Retirement
# (/subjects/us-lipper-awards): Lipper Awards
# (/finance/personal-finance/analyst-research): Analyst Research
# (http://stockscreener.us.reuters.com/Stock/US/Index?quickscreen=gaarp): Stock Screener
# (http://funds.us.reuters.com/US/screener/screener.asp): Fund Screener
# (/news/lifestyle): Life
# (/news/health): Health
# (/news/sports): Sports
# (/news/entertainment/arts): Arts
# (/news/entertainment): Entertainment
# (/news/oddlyEnough): Oddly Enough
# (/news/pictures): Pictures Home
# (http://widerimage.reuters.com): The Wider Image
# (http://widerimage.reuters.com/photographer): Photographers
# (/focus-360/): Focus 360
# (http://af.reuters.com): Africa
# (http://lta.reuters.com): Amrica Latina
# (http://ar.reuters.com): Argentina
# (http://br.reuters.com): Brasil
# (http://ca.reuters.com): Canada
# (http://de.reuters.com): Deutschland
# (http://es.reuters.com): Espaa
# (http://fr.reuters.com): France
# (http://in.reuters.com): India
# (http://it.reuters.com): Italia
# (http://mx.reuters.com): Mxico
# (http://uk.reuters.com): United Kingdom
# (http://www.reuters.com): United States
# (/article/us-global-markets-idUSKBN13D040): Dollar charges to 14 year high bond tantrum in full swing
# (/article/us-opec-talks-iran-idUSKBN13D140): OPEC moves closer to oil output deal as Iran gets new offer
# (/article/us-volkswagen-costs-idUSKBN13D0UJ): Volkswagen to cut 30 000 jobs at VW brand by 2020
# (/article/us-usa-trump-coal-idUSKBN13D17J): Can Trump make coal great again At least some companies think so
# (/article/us-russia-linkedin-diplomacy-idUSKBN13D0ST): U S says concerned over Russia blocking access to LinkedIn
# (/article/us-abercrombie-results-idUSKBN13D1I1): Abercrombie Fitch quarterly sales miss estimates shares skid
# (/article/us-apec-summit-idUSKBN13D0R5): Pacific rim leaders to debate future of trade post Trump
# (/article/us-snapchat-ipo-analysis-idUSKBN13D0HG): Snap s youthful founders show no fear in race to IPO
# (/article/us-jpmorgan-succession-idUSKBN13D0HO): JPMorgan has clutch of CEO understudies people guessing on winner
# (/article/us-rio-tinto-guinea-legal-idUSKBN13D1L2): Rio Tinto in spotlight as Australia fraud police targets resources industry
# (?view=page&page=2&pageSize=10):  Next Page
# (/news/video?videoChannel=1003):  Politics Video
# (/news/video/story?videoId=370493940&videoChannel=1003): Trump meets Japan s Abe in NYC
# (/news/video/story?videoId=370493890&videoChannel=1003): Trump has offered national security adviser job to Flynn
# (/news/video/story?videoId=370491996&videoChannel=1003): Top spy Clapper set to move on
# (/news/video/story?videoId=370490049&videoChannel=1003): Pence humbled by enthusiasm on Capitol Hill
# (/news/video?videoChannel=1003):  More Politics Video
# (http://www.reuters.com/politics):  Politics News
# (/article/us-usa-trump-idUSKBN13D1JE): Trump taps Sessions for attorney general Pompeo for CIA transition official
# (/article/us-obama-germany-idUSKBN13D1F6): Obama EU leaders agree to maintain cooperation via NATO after Trump victory
# (/article/us-usa-trump-flynn-idUSKBN13D0AD): With Trump victory blunt U S general gets second chance
# (/article/us-usa-trump-democratic-states-idUSKBN13D17M):  First line of defense Democratic states vow to fight Trump in court
# (http://www.reuters.com/politics):  More
# (http://www.reuters.com/tools/rss): Feeds
# (http://newslink.reuters.com/join/subscribe): Newsletters
# (/tools/podcasts): Podcasts
# (/tools/mobile): Apps
# (http://agency.reuters.com): Reuters News Agency
# (http://agency.reuters.com/en/platforms-delivery/reuters-brand-attribution-guidelines.html): Brand Attribution Guidelines
# (http://thomsonreuters.com/): Thomson Reuters
# (/info/disclaimer): See here for a complete list
# (http://reuters.zendesk.com/): Site Feedback
# (https://reuters.zendesk.com/anonymous_requests/new): Corrections
# (http://sales.reuters.com/): Advertise With Us
# (/advertising-guidelines): Advertising Guidelines
# (/terms-of-use): Terms of Use
# (/privacy-policy): Privacy Policy
# adding hit...
# �
# adding hit...
# �
# adding hit...
# �
# adding hit...
# �
# {'business': '\x00\xf1',
#  'headlines': '\x02\xf1',
#  'news': '\x01\xf1',
#  'reuters': '\x03\xf1'}

# %%
import URLResolver.URLResolver as urlresolver
urlresolver.run()
# Out:
# url:  http://www.reuters.com/finance
# Making docIndex: [1] http://www.reuters.com/finance
# putting Business for docID 1 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/finance
# putting Business Home for docID 1 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://www.reuters.com/legal
# Making docIndex: [2] http://www.reuters.com/legal
# putting Legal for docID 2 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/finance/deals
# Making docIndex: [3] http://www.reuters.com/finance/deals
# putting Deals for docID 3 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/subjects/aerospace-and-defense
# Making docIndex: [4] http://www.reuters.com/subjects/aerospace-and-defense
# putting Aerospace Defense for docID 4 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://www.reuters.com/subjects/banks
# Making docIndex: [5] http://www.reuters.com/subjects/banks
# putting Finance for docID 5 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/subjects/autos
# Making docIndex: [6] http://www.reuters.com/subjects/autos
# putting Autos for docID 6 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/finance/summits
# Making docIndex: [7] http://www.reuters.com/finance/summits
# putting Reuters Summits for docID 7 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://www.reuters.com/news/subjects/ADventures
# Making docIndex: [8] http://www.reuters.com/news/subjects/ADventures
# putting ADventures for docID 8 in forward index
# adding hit...
# P�
# LEN HITS: 1
# url:  http://www.reuters.com/data-dive
# Making docIndex: [9] http://www.reuters.com/data-dive
# putting Data Dive for docID 9 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://www.reuters.com/finance/markets
# Making docIndex: [10] http://www.reuters.com/finance/markets
# putting Markets for docID 10 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/finance/markets
# putting Markets Home for docID 10 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://www.reuters.com/finance/markets/us
# Making docIndex: [11] http://www.reuters.com/finance/markets/us
# putting U S Markets for docID 11 in forward index
# adding hit...
# 2�
# adding hit...
# 1�
# adding hit...
# 0�
# LEN HITS: 3
# url:  http://www.reuters.com/finance/markets/europe
# Making docIndex: [12] http://www.reuters.com/finance/markets/europe
# putting European Markets for docID 12 in forward index
# adding hit...
# q�
# adding hit...
# p�
# LEN HITS: 2
# url:  http://www.reuters.com/finance/markets/asia
# Making docIndex: [13] http://www.reuters.com/finance/markets/asia
# putting Asian Markets for docID 13 in forward index
# adding hit...
# �
# adding hit...
# �
# LEN HITS: 2
# url:  http://www.reuters.com/finance/global-market-data
# Making docIndex: [14] http://www.reuters.com/finance/global-market-data
# putting Global Market Data for docID 14 in forward index
# adding hit...
# ��
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 3
# url:  http://www.reuters.com/finance/markets/indices
# Making docIndex: [15] http://www.reuters.com/finance/markets/indices
# putting Indices for docID 15 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/finance/stocks
# Making docIndex: [16] http://www.reuters.com/finance/stocks
# putting Stocks for docID 16 in forward index
# adding hit...
# �
# LEN HITS: 1
# url:  http://www.reuters.com/finance/bonds
# Making docIndex: [17] http://www.reuters.com/finance/bonds
# putting Bonds for docID 17 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/finance/currencies
# Making docIndex: [18] http://www.reuters.com/finance/currencies
# putting Currencies for docID 18 in forward index
# adding hit...
# @�
# LEN HITS: 1
# url:  http://www.reuters.com/finance/commodities
# Making docIndex: [19] http://www.reuters.com/finance/commodities
# putting Comm Energy for docID 19 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://www.reuters.com/finance/futures
# Making docIndex: [20] http://www.reuters.com/finance/futures
# putting Futures for docID 20 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/finance/funds
# Making docIndex: [21] http://www.reuters.com/finance/funds
# putting Funds for docID 21 in forward index
# adding hit...
# @�
# LEN HITS: 1
# url:  http://www.reuters.com/finance/EarningsUS
# Making docIndex: [22] http://www.reuters.com/finance/EarningsUS
# putting Earnings for docID 22 in forward index
# adding hit...
#  �
# LEN HITS: 1
# url:  http://www.reuters.com/finance/markets/dividends
# Making docIndex: [23] http://www.reuters.com/finance/markets/dividends
# putting Dividends for docID 23 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/news/world
# Making docIndex: [24] http://www.reuters.com/news/world
# putting World for docID 24 in forward index
# adding hit...
# p�
# LEN HITS: 1
# url:  http://www.reuters.com/news/world
# putting World Home for docID 24 in forward index
# adding hit...
# p�
# adding hit...
# q�
# LEN HITS: 2
# url:  http://www.reuters.com/news/us
# Making docIndex: [25] http://www.reuters.com/news/us
# putting U S  for docID 25 in forward index
# adding hit...
# b�
# adding hit...
# a�
# adding hit...
# `�
# LEN HITS: 3
# url:  http://www.reuters.com/subjects/specialReports
# Making docIndex: [26] http://www.reuters.com/subjects/specialReports
# putting Special Reports for docID 26 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://www.reuters.com/investigates/
# Making docIndex: [27] http://www.reuters.com/investigates/
# putting Reuters Investigates for docID 27 in forward index
# adding hit...
# �
# adding hit...
# �
# LEN HITS: 2
# url:  http://www.reuters.com/subjects/euro-zone
# Making docIndex: [28] http://www.reuters.com/subjects/euro-zone
# putting Euro Zone for docID 28 in forward index
# adding hit...
# �
# adding hit...
# �
# LEN HITS: 2
# url:  http://www.reuters.com/subjects/middle-east
# Making docIndex: [29] http://www.reuters.com/subjects/middle-east
# putting Middle East for docID 29 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://www.reuters.com/places/china
# Making docIndex: [30] http://www.reuters.com/places/china
# putting China for docID 30 in forward index
# adding hit...
# 0�
# LEN HITS: 1
# url:  http://www.reuters.com/places/japan
# Making docIndex: [31] http://www.reuters.com/places/japan
# putting Japan for docID 31 in forward index
# adding hit...
# �
# LEN HITS: 1
# url:  http://www.reuters.com/places/mexico
# Making docIndex: [32] http://www.reuters.com/places/mexico
# putting Mexico for docID 32 in forward index
# adding hit...
# �
# LEN HITS: 1
# url:  http://www.reuters.com/places/brazil
# Making docIndex: [33] http://www.reuters.com/places/brazil
# putting Brazil for docID 33 in forward index
# adding hit...
# P�
# LEN HITS: 1
# url:  http://www.reuters.com/places/africa
# Making docIndex: [34] http://www.reuters.com/places/africa
# putting Africa for docID 34 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/places/russia
# Making docIndex: [35] http://www.reuters.com/places/russia
# putting Russia for docID 35 in forward index
# adding hit...
# 0�
# LEN HITS: 1
# url:  http://www.reuters.com/places/india
# Making docIndex: [36] http://www.reuters.com/places/india
# putting India for docID 36 in forward index
# adding hit...
# p�
# LEN HITS: 1
# url:  http://www.reuters.com/politics
# Making docIndex: [37] http://www.reuters.com/politics
# putting Politics for docID 37 in forward index
# adding hit...
# �
# LEN HITS: 1
# url:  http://www.reuters.com/politics
# putting Politics Home for docID 37 in forward index
# adding hit...
# �
# adding hit...
# �
# LEN HITS: 2
# url:  http://www.reuters.com/politics/election2016
# Making docIndex: [38] http://www.reuters.com/politics/election2016
# putting Election 2016 for docID 38 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://polling.reuters.com
# Making docIndex: [39] http://polling.reuters.com
# putting Polling Explorer for docID 39 in forward index
# adding hit...
# A�
# adding hit...
# @�
# LEN HITS: 2
# url:  http://live.reuters.com/Event/Election_2016
# Making docIndex: [40] http://live.reuters.com/Event/Election_2016
# putting Just In Election 2016 for docID 40 in forward index
# adding hit...
# ��
# adding hit...
# ��
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 4
# url:  http://www.reuters.com/election2016/the-undecided/
# Making docIndex: [41] http://www.reuters.com/election2016/the-undecided/
# putting What Voters Want for docID 41 in forward index
# adding hit...
# ��
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 3
# url:  http://www.reuters.com/subjects/supreme-court
# Making docIndex: [42] http://www.reuters.com/subjects/supreme-court
# putting Supreme Court for docID 42 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://www.reuters.com/news/technology
# Making docIndex: [43] http://www.reuters.com/news/technology
# putting Tech for docID 43 in forward index
# adding hit...
# `�
# LEN HITS: 1
# url:  http://www.reuters.com/news/technology
# putting Technology Home for docID 43 in forward index
# adding hit...
# a�
# adding hit...
# `�
# LEN HITS: 2
# url:  http://www.reuters.com/news/science
# Making docIndex: [44] http://www.reuters.com/news/science
# putting Science for docID 44 in forward index
# adding hit...
# 0�
# LEN HITS: 1
# url:  http://www.reuters.com/bizfinance/technology/Top100Innovators
# Making docIndex: [45] http://www.reuters.com/bizfinance/technology/Top100Innovators
# putting Top 100 Global Innovators for docID 45 in forward index
# adding hit...
# ��
# adding hit...
# ��
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 4
# url:  http://www.reuters.com/news/environment
# Making docIndex: [46] http://www.reuters.com/news/environment
# putting Environment for docID 46 in forward index
# adding hit...
# P�
# LEN HITS: 1
# url:  http://www.reuters.com/innovation
# Making docIndex: [47] http://www.reuters.com/innovation
# putting Innovation for docID 47 in forward index
# adding hit...
# p�
# LEN HITS: 1
# url:  http://www.reuters.com/commentary
# Making docIndex: [48] http://www.reuters.com/commentary
# putting Commentary for docID 48 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/commentary
# putting Commentary Home  for docID 48 in forward index
# adding hit...
# ��
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 3
# url:  http://www.reuters.com/tools/podcasts/
# Making docIndex: [49] http://www.reuters.com/tools/podcasts/
# putting Podcasts for docID 49 in forward index
# adding hit...
# P�
# LEN HITS: 1
# url:  http://www.reuters.com/breakingviews
# Making docIndex: [50] http://www.reuters.com/breakingviews
# putting Breakingviews for docID 50 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/breakingviews
# putting Breakingviews Home for docID 50 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://www.reuters.com/video/breakingviews
# Making docIndex: [51] http://www.reuters.com/video/breakingviews
# putting Breakingviews Video for docID 51 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://www.reuters.com/finance/personal-finance
# Making docIndex: [52] http://www.reuters.com/finance/personal-finance
# putting Money for docID 52 in forward index
# adding hit...
# P�
# LEN HITS: 1
# url:  http://www.reuters.com/finance/personal-finance
# putting Money Home for docID 52 in forward index
# adding hit...
# P�
# adding hit...
# Q�
# LEN HITS: 2
# url:  http://www.reuters.com/finance/personal-finance/retirement
# Making docIndex: [53] http://www.reuters.com/finance/personal-finance/retirement
# putting Retirement for docID 53 in forward index
# adding hit...
# `�
# LEN HITS: 1
# url:  http://www.reuters.com/subjects/us-lipper-awards
# Making docIndex: [54] http://www.reuters.com/subjects/us-lipper-awards
# putting Lipper Awards for docID 54 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://www.reuters.com/finance/personal-finance/analyst-research
# Making docIndex: [55] http://www.reuters.com/finance/personal-finance/analyst-research
# putting Analyst Research for docID 55 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://stockscreener.us.reuters.com/Stock/US/Index?quickscreen=gaarp
# Making docIndex: [56] http://stockscreener.us.reuters.com/Stock/US/Index?quickscreen=gaarp
# putting Stock Screener for docID 56 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://funds.us.reuters.com/US/screener/screener.asp
# Making docIndex: [57] http://funds.us.reuters.com/US/screener/screener.asp
# putting Fund Screener for docID 57 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://www.reuters.com/news/lifestyle
# Making docIndex: [58] http://www.reuters.com/news/lifestyle
# putting Life for docID 58 in forward index
# adding hit...
# �
# LEN HITS: 1
# url:  http://www.reuters.com/news/health
# Making docIndex: [59] http://www.reuters.com/news/health
# putting Health for docID 59 in forward index
# adding hit...
# �
# LEN HITS: 1
# url:  http://www.reuters.com/news/sports
# Making docIndex: [60] http://www.reuters.com/news/sports
# putting Sports for docID 60 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/news/entertainment/arts
# Making docIndex: [61] http://www.reuters.com/news/entertainment/arts
# putting Arts for docID 61 in forward index
# adding hit...
# �
# LEN HITS: 1
# url:  http://www.reuters.com/news/entertainment
# Making docIndex: [62] http://www.reuters.com/news/entertainment
# putting Entertainment for docID 62 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/news/oddlyEnough
# Making docIndex: [63] http://www.reuters.com/news/oddlyEnough
# putting Oddly Enough for docID 63 in forward index
# adding hit...
# a�
# adding hit...
# `�
# LEN HITS: 2
# url:  http://www.reuters.com/news/pictures
# Making docIndex: [64] http://www.reuters.com/news/pictures
# putting Pictures Home for docID 64 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://widerimage.reuters.com
# Making docIndex: [65] http://widerimage.reuters.com
# putting The Wider Image for docID 65 in forward index
# adding hit...
# A�
# adding hit...
# @�
# adding hit...
# B�
# LEN HITS: 3
# url:  http://widerimage.reuters.com/photographer
# Making docIndex: [66] http://widerimage.reuters.com/photographer
# putting Photographers for docID 66 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/focus-360/
# Making docIndex: [67] http://www.reuters.com/focus-360/
# putting Focus 360 for docID 67 in forward index
# adding hit...
# @�
# adding hit...
# A�
# LEN HITS: 2
# url:  http://af.reuters.com
# Making docIndex: [68] http://af.reuters.com
# putting Africa for docID 68 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://lta.reuters.com
# Making docIndex: [69] http://lta.reuters.com
# putting Amrica Latina for docID 69 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://ar.reuters.com
# Making docIndex: [70] http://ar.reuters.com
# putting Argentina for docID 70 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://br.reuters.com
# Making docIndex: [71] http://br.reuters.com
# putting Brasil for docID 71 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://ca.reuters.com
# Making docIndex: [72] http://ca.reuters.com
# putting Canada for docID 72 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://de.reuters.com
# Making docIndex: [73] http://de.reuters.com
# putting Deutschland for docID 73 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://es.reuters.com
# Making docIndex: [74] http://es.reuters.com
# putting Espaa for docID 74 in forward index
# adding hit...
# @�
# LEN HITS: 1
# url:  http://fr.reuters.com
# Making docIndex: [75] http://fr.reuters.com
# putting France for docID 75 in forward index
# adding hit...
# P�
# LEN HITS: 1
# url:  http://in.reuters.com
# Making docIndex: [76] http://in.reuters.com
# putting India for docID 76 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://it.reuters.com
# Making docIndex: [77] http://it.reuters.com
# putting Italia for docID 77 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://mx.reuters.com
# Making docIndex: [78] http://mx.reuters.com
# putting Mxico for docID 78 in forward index
# adding hit...
# @�
# LEN HITS: 1
# url:  http://uk.reuters.com
# Making docIndex: [79] http://uk.reuters.com
# putting United Kingdom for docID 79 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://www.reuters.com
# Making docIndex: [80] http://www.reuters.com
# putting United States for docID 80 in forward index
# adding hit...
# q�
# adding hit...
# p�
# LEN HITS: 2
# url:  http://www.reuters.com/article/us-global-markets-idUSKBN13D040
# Making docIndex: [81] http://www.reuters.com/article/us-global-markets-idUSKBN13D040
# putting Dollar charges to 14 year high bond tantrum in full swing for docID 81 in forward index
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# LEN HITS: 11
# url:  http://www.reuters.com/article/us-opec-talks-iran-idUSKBN13D140
# Making docIndex: [82] http://www.reuters.com/article/us-opec-talks-iran-idUSKBN13D140
# putting OPEC moves closer to oil output deal as Iran gets new offer for docID 82 in forward index
# adding hit...
# "r
# adding hit...
# $r
# adding hit...
# (�
# adding hit...
# &r
# adding hit...
# #r
# adding hit...
# +r
# adding hit...
#  �
# adding hit...
# 'r
# adding hit...
# *r
# adding hit...
# %r
# adding hit...
# !r
# adding hit...
# )r
# LEN HITS: 12
# url:  http://www.reuters.com/article/us-volkswagen-costs-idUSKBN13D0UJ
# Making docIndex: [83] http://www.reuters.com/article/us-volkswagen-costs-idUSKBN13D0UJ
# putting Volkswagen to cut 30 000 jobs at VW brand by 2020 for docID 83 in forward index
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# �r
# LEN HITS: 11
# url:  http://www.reuters.com/article/us-usa-trump-coal-idUSKBN13D17J
# Making docIndex: [84] http://www.reuters.com/article/us-usa-trump-coal-idUSKBN13D17J
# putting Can Trump make coal great again At least some companies think so for docID 84 in forward index
# adding hit...
# Ur
# adding hit...
# Tr
# adding hit...
# Q�
# adding hit...
# Yr
# adding hit...
# Rr
# adding hit...
# Xr
# adding hit...
# Wr
# adding hit...
# Sr
# adding hit...
# [r
# adding hit...
# P�
# adding hit...
# Zr
# adding hit...
# V�
# LEN HITS: 12
# url:  http://www.reuters.com/article/us-russia-linkedin-diplomacy-idUSKBN13D0ST
# Making docIndex: [85] http://www.reuters.com/article/us-russia-linkedin-diplomacy-idUSKBN13D0ST
# putting U S says concerned over Russia blocking access to LinkedIn for docID 85 in forward index
# adding hit...
# r
# adding hit...
# r
# adding hit...
# �
# adding hit...
# �
# adding hit...
# r
# adding hit...
# r
# adding hit...
# �
# adding hit...
# �
# adding hit...
# r
# adding hit...
# r
# LEN HITS: 10
# url:  http://www.reuters.com/article/us-abercrombie-results-idUSKBN13D1I1
# Making docIndex: [86] http://www.reuters.com/article/us-abercrombie-results-idUSKBN13D1I1
# putting Abercrombie Fitch quarterly sales miss estimates shares skid for docID 86 in forward index
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# �r
# LEN HITS: 8
# url:  http://www.reuters.com/article/us-apec-summit-idUSKBN13D0R5
# Making docIndex: [87] http://www.reuters.com/article/us-apec-summit-idUSKBN13D0R5
# putting Pacific rim leaders to debate future of trade post Trump for docID 87 in forward index
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# LEN HITS: 10
# url:  http://www.reuters.com/article/us-snapchat-ipo-analysis-idUSKBN13D0HG
# Making docIndex: [88] http://www.reuters.com/article/us-snapchat-ipo-analysis-idUSKBN13D0HG
# putting Snap s youthful founders show no fear in race to IPO for docID 88 in forward index
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# �r
# LEN HITS: 11
# url:  http://www.reuters.com/article/us-jpmorgan-succession-idUSKBN13D0HO
# Making docIndex: [89] http://www.reuters.com/article/us-jpmorgan-succession-idUSKBN13D0HO
# putting JPMorgan has clutch of CEO understudies people guessing on winner for docID 89 in forward index
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# LEN HITS: 10
# url:  http://www.reuters.com/article/us-rio-tinto-guinea-legal-idUSKBN13D1L2
# Making docIndex: [90] http://www.reuters.com/article/us-rio-tinto-guinea-legal-idUSKBN13D1L2
# putting Rio Tinto in spotlight as Australia fraud police targets resources industry for docID 90 in forward index
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# LEN HITS: 11
# url:  http://www.reuters.com/news/archive/businessNews?view=page&page=2&pageSize=10
# Making docIndex: [91] http://www.reuters.com/news/archive/businessNews?view=page&page=2&pageSize=10
# putting  Next Page  for docID 91 in forward index
# adding hit...
# ����
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 3
# url:  http://www.reuters.com/news/video?videoChannel=1003
# Making docIndex: [92] http://www.reuters.com/news/video?videoChannel=1003
# putting  Politics Video for docID 92 in forward index
# adding hit...
# P�
# adding hit...
# Q�
# adding hit...
# R�
# LEN HITS: 3
# url:  http://www.reuters.com/news/video/story?videoId=370493940&videoChannel=1003
# Making docIndex: [93] http://www.reuters.com/news/video/story?videoId=370493940&videoChannel=1003
# putting Trump meets Japan s Abe in NYC for docID 93 in forward index
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 7
# url:  http://www.reuters.com/news/video/story?videoId=370493890&videoChannel=1003
# Making docIndex: [94] http://www.reuters.com/news/video/story?videoId=370493890&videoChannel=1003
# putting Trump has offered national security adviser job to Flynn for docID 94 in forward index
# adding hit...
# r
# adding hit...
# �
# adding hit...
# r
# adding hit...
# r
# adding hit...
# r
# adding hit...
# r
# adding hit...
# r
# adding hit...
# r
# adding hit...
# �
# LEN HITS: 9
# url:  http://www.reuters.com/news/video/story?videoId=370491996&videoChannel=1003
# Making docIndex: [95] http://www.reuters.com/news/video/story?videoId=370491996&videoChannel=1003
# putting Top spy Clapper set to move on for docID 95 in forward index
# adding hit...
# !r
# adding hit...
# #r
# adding hit...
# &r
# adding hit...
# "�
# adding hit...
#  �
# adding hit...
# %r
# adding hit...
# $r
# LEN HITS: 7
# url:  http://www.reuters.com/news/video/story?videoId=370490049&videoChannel=1003
# Making docIndex: [96] http://www.reuters.com/news/video/story?videoId=370490049&videoChannel=1003
# putting Pence humbled by enthusiasm on Capitol Hill for docID 96 in forward index
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# ��
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# �r
# LEN HITS: 7
# url:  http://www.reuters.com/news/video?videoChannel=1003
# putting  More Politics Video for docID 92 in forward index
# adding hit...
# P�
# adding hit...
# R�
# adding hit...
# S�
# adding hit...
# Q�
# LEN HITS: 4
# url:  http://www.reuters.com/politics
# putting  Politics News for docID 37 in forward index
# adding hit...
# �
# adding hit...
# �
# adding hit...
# �
# LEN HITS: 3
# url:  http://www.reuters.com/article/us-usa-trump-idUSKBN13D1JE
# Making docIndex: [97] http://www.reuters.com/article/us-usa-trump-idUSKBN13D1JE
# putting Trump taps Sessions for attorney general Pompeo for CIA transition official for docID 97 in forward index
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# �r�r
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 10
# url:  http://www.reuters.com/article/us-obama-germany-idUSKBN13D1F6
# Making docIndex: [98] http://www.reuters.com/article/us-obama-germany-idUSKBN13D1F6
# putting Obama EU leaders agree to maintain cooperation via NATO after Trump victory for docID 98 in forward index
# adding hit...
# r
# adding hit...
# r
# adding hit...
# �
# adding hit...
# r
# adding hit...
# r
# adding hit...
# r
# adding hit...
# �
# adding hit...
# r
# adding hit...
# r
# adding hit...
# �
# adding hit...
# r
# adding hit...
# �
# LEN HITS: 12
# url:  http://www.reuters.com/article/us-usa-trump-flynn-idUSKBN13D0AD
# Making docIndex: [99] http://www.reuters.com/article/us-usa-trump-flynn-idUSKBN13D0AD
# putting With Trump victory blunt U S general gets second chance for docID 99 in forward index
# adding hit...
# r
# adding hit...
# �
# adding hit...
# �
# adding hit...
# r
# adding hit...
# r
# adding hit...
# �
# adding hit...
# �
# adding hit...
# r
# adding hit...
# r
# adding hit...
# r
# LEN HITS: 10
# url:  http://www.reuters.com/article/us-usa-trump-democratic-states-idUSKBN13D17M
# Making docIndex: [100] http://www.reuters.com/article/us-usa-trump-democratic-states-idUSKBN13D17M
# putting  First line of defense Democratic states vow to fight Trump in court for docID 100 in forward index
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 13
# url:  http://www.reuters.com/politics
# putting  More for docID 37 in forward index
# adding hit...
# �
# adding hit...
# �
# LEN HITS: 2
# url:  http://www.reuters.com/tools/rss
# Making docIndex: [101] http://www.reuters.com/tools/rss
# putting Feeds for docID 101 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://newslink.reuters.com/join/subscribe
# Making docIndex: [102] http://newslink.reuters.com/join/subscribe
# putting Newsletters for docID 102 in forward index
# adding hit...
# 0�
# LEN HITS: 1
# url:  http://www.reuters.com/tools/podcasts
# Making docIndex: [103] http://www.reuters.com/tools/podcasts
# putting Podcasts for docID 103 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://www.reuters.com/tools/mobile
# Making docIndex: [104] http://www.reuters.com/tools/mobile
# putting Apps for docID 104 in forward index
# adding hit...
# ��
# LEN HITS: 1
# url:  http://agency.reuters.com
# Making docIndex: [105] http://agency.reuters.com
# putting Reuters News Agency for docID 105 in forward index
# adding hit...
# a�
# adding hit...
# `�
# adding hit...
# b�
# LEN HITS: 3
# url:  http://agency.reuters.com/en/platforms-delivery/reuters-brand-attribution-guidelines.html
# Making docIndex: [106] http://agency.reuters.com/en/platforms-delivery/reuters-brand-attribution-guidelines.html
# putting Brand Attribution Guidelines for docID 106 in forward index
# adding hit...
# ��
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 3
# url:  http://thomsonreuters.com/
# Making docIndex: [107] http://thomsonreuters.com/
# putting Thomson Reuters for docID 107 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2
# url:  http://www.reuters.com/info/disclaimer
# Making docIndex: [108] http://www.reuters.com/info/disclaimer
# putting See here for a complete list for docID 108 in forward index
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# �r
# adding hit...
# ��
# LEN HITS: 6
# url:  http://reuters.zendesk.com/
# Making docIndex: [109] http://reuters.zendesk.com/
# putting Site Feedback for docID 109 in forward index
# adding hit...
#  �
# adding hit...
# !�
# LEN HITS: 2
# url:  https://reuters.zendesk.com/anonymous_requests/new
# Making docIndex: [110] https://reuters.zendesk.com/anonymous_requests/new
# putting Corrections for docID 110 in forward index
# adding hit...
# 0�
# LEN HITS: 1
# url:  http://sales.reuters.com/
# Making docIndex: [111] http://sales.reuters.com/
# putting Advertise With Us for docID 111 in forward index
# adding hit...
# �
# adding hit...
# �
# adding hit...
# �
# LEN HITS: 3
# url:  http://www.reuters.com/advertising-guidelines
# Making docIndex: [112] http://www.reuters.com/advertising-guidelines
# putting Advertising Guidelines for docID 112 in forward index
# adding hit...
# a�
# adding hit...
# `�
# LEN HITS: 2
# url:  http://www.reuters.com/terms-of-use
# Making docIndex: [113] http://www.reuters.com/terms-of-use
# putting Terms of Use for docID 113 in forward index
# adding hit...
# �r
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 3
# url:  http://www.reuters.com/privacy-policy
# Making docIndex: [114] http://www.reuters.com/privacy-policy
# putting Privacy Policy for docID 114 in forward index
# adding hit...
# ��
# adding hit...
# ��
# LEN HITS: 2

# %%
i = 0
docI = docIndex.getDocIndex(i)
while docI is not None:
    print docIndex.getUrlFromList(docI[3], docI[4])
    i += 1
    docI = docIndex.getDocIndex(i)
# Out:
# http://www.reuters.com/news/archive/businessNews
# http://www.reuters.com/finance
# http://www.reuters.com/legal
# http://www.reuters.com/finance/deals
# http://www.reuters.com/subjects/aerospace-and-defense
# http://www.reuters.com/subjects/banks
# http://www.reuters.com/subjects/autos
# http://www.reuters.com/finance/summits
# http://www.reuters.com/news/subjects/ADventures
# http://www.reuters.com/data-dive
# http://www.reuters.com/finance/markets
# http://www.reuters.com/finance/markets/us
# http://www.reuters.com/finance/markets/europe
# http://www.reuters.com/finance/markets/asia
# http://www.reuters.com/finance/global-market-data
# http://www.reuters.com/finance/markets/indices
# http://www.reuters.com/finance/stocks
# http://www.reuters.com/finance/bonds
# http://www.reuters.com/finance/currencies
# http://www.reuters.com/finance/commodities
# http://www.reuters.com/finance/futures
# http://www.reuters.com/finance/funds
# http://www.reuters.com/finance/EarningsUS
# http://www.reuters.com/finance/markets/dividends
# http://www.reuters.com/news/world
# http://www.reuters.com/news/us
# http://www.reuters.com/subjects/specialReports
# http://www.reuters.com/investigates/
# http://www.reuters.com/subjects/euro-zone
# http://www.reuters.com/subjects/middle-east
# http://www.reuters.com/places/china
# http://www.reuters.com/places/japan
# http://www.reuters.com/places/mexico
# http://www.reuters.com/places/brazil
# http://www.reuters.com/places/africa
# http://www.reuters.com/places/russia
# http://www.reuters.com/places/india
# http://www.reuters.com/politics
# http://www.reuters.com/politics/election2016
# http://polling.reuters.com
# http://live.reuters.com/Event/Election_2016
# http://www.reuters.com/election2016/the-undecided/
# http://www.reuters.com/subjects/supreme-court
# http://www.reuters.com/news/technology
# http://www.reuters.com/news/science
# http://www.reuters.com/bizfinance/technology/Top100Innovators
# http://www.reuters.com/news/environment
# http://www.reuters.com/innovation
# http://www.reuters.com/commentary
# http://www.reuters.com/tools/podcasts/
# http://www.reuters.com/breakingviews
# http://www.reuters.com/video/breakingviews
# http://www.reuters.com/finance/personal-finance
# http://www.reuters.com/finance/personal-finance/retirement
# http://www.reuters.com/subjects/us-lipper-awards
# http://www.reuters.com/finance/personal-finance/analyst-research
# http://stockscreener.us.reuters.com/Stock/US/Index?quickscreen=gaarp
# http://funds.us.reuters.com/US/screener/screener.asp
# http://www.reuters.com/news/lifestyle
# http://www.reuters.com/news/health
# http://www.reuters.com/news/sports
# http://www.reuters.com/news/entertainment/arts
# http://www.reuters.com/news/entertainment
# http://www.reuters.com/news/oddlyEnough
# http://www.reuters.com/news/pictures
# http://widerimage.reuters.com
# http://widerimage.reuters.com/photographer
# http://www.reuters.com/focus-360/
# http://af.reuters.com
# http://lta.reuters.com
# http://ar.reuters.com
# http://br.reuters.com
# http://ca.reuters.com
# http://de.reuters.com
# http://es.reuters.com
# http://fr.reuters.com
# http://in.reuters.com
# http://it.reuters.com
# http://mx.reuters.com
# http://uk.reuters.com
# http://www.reuters.com
# http://www.reuters.com/article/us-global-markets-idUSKBN13D040
# http://www.reuters.com/article/us-opec-talks-iran-idUSKBN13D140
# http://www.reuters.com/article/us-volkswagen-costs-idUSKBN13D0UJ
# http://www.reuters.com/article/us-usa-trump-coal-idUSKBN13D17J
# http://www.reuters.com/article/us-russia-linkedin-diplomacy-idUSKBN13D0ST
# http://www.reuters.com/article/us-abercrombie-results-idUSKBN13D1I1
# http://www.reuters.com/article/us-apec-summit-idUSKBN13D0R5
# http://www.reuters.com/article/us-snapchat-ipo-analysis-idUSKBN13D0HG
# http://www.reuters.com/article/us-jpmorgan-succession-idUSKBN13D0HO
# http://www.reuters.com/article/us-rio-tinto-guinea-legal-idUSKBN13D1L2
# http://www.reuters.com/news/archive/businessNews?view=page&page=2&pageSize=10
# http://www.reuters.com/news/video?videoChannel=1003
# http://www.reuters.com/news/video/story?videoId=370493940&videoChannel=1003
# http://www.reuters.com/news/video/story?videoId=370493890&videoChannel=1003
# http://www.reuters.com/news/video/story?videoId=370491996&videoChannel=1003
# http://www.reuters.com/news/video/story?videoId=370490049&videoChannel=1003
# http://www.reuters.com/article/us-usa-trump-idUSKBN13D1JE
# http://www.reuters.com/article/us-obama-germany-idUSKBN13D1F6
# http://www.reuters.com/article/us-usa-trump-flynn-idUSKBN13D0AD
# http://www.reuters.com/article/us-usa-trump-democratic-states-idUSKBN13D17M
# http://www.reuters.com/tools/rss
# http://newslink.reuters.com/join/subscribe
# http://www.reuters.com/tools/podcasts
# http://www.reuters.com/tools/mobile
# http://agency.reuters.com
# http://agency.reuters.com/en/platforms-delivery/reuters-brand-attribution-guidelines.html
# http://thomsonreuters.com/
# http://www.reuters.com/info/disclaimer
# http://reuters.zendesk.com/
# https://reuters.zendesk.com/anonymous_requests/new
# http://sales.reuters.com/
# http://www.reuters.com/advertising-guidelines
# http://www.reuters.com/terms-of-use
# http://www.reuters.com/privacy-policy

# %%
def is_valid_wordID(wordIDBytes):
    for i in wordIDBytes:
        if i != 0:
            return True
    return False

def forward_index_review():
    with open('barrels/forward_index.bin', 'r+b') as fp:
        fp.seek(0, 2)
        size = fp.tell()
        fp.seek(0, 0)
        while(fp.tell() < size):
            docID = struct.unpack("I", fp.read(4))[0]
            print "DOC ID: ", docID
            while is_valid_wordID(struct.unpack("BBB", fp.read(3))):
                fp.seek(-3, 1)
                hit_data = struct.unpack("I", fp.read(4))[0]
                num_hits = hit_data & 0xFF
                wordID = hit_data >> 8 & 0xFFFFFF
                print "WordID: ", wordID
                print "num_hits: ", num_hits
                print ""
                fp.seek(num_hits*2, 1)
            print "======================="

forward_index_review()
# Out:
# DOC ID:  0
# WordID:  1
# num_hits:  1
#
# WordID:  2
# num_hits:  1
#
# WordID:  3
# num_hits:  1
#
# WordID:  4
# num_hits:  1
#
# =======================
# DOC ID:  1
# WordID:  4
# num_hits:  1
#
# =======================
# DOC ID:  1
# WordID:  5
# num_hits:  1
#
# WordID:  4
# num_hits:  1
#
# =======================
# DOC ID:  2
# WordID:  6
# num_hits:  1
#
# =======================
# DOC ID:  3
# WordID:  7
# num_hits:  1
#
# =======================
# DOC ID:  4
# WordID:  8
# num_hits:  1
#
# WordID:  9
# num_hits:  1
#
# =======================
# DOC ID:  5
# WordID:  10
# num_hits:  1
#
# =======================
# DOC ID:  6
# WordID:  11
# num_hits:  1
#
# =======================
# DOC ID:  7
# WordID:  3
# num_hits:  1
#
# WordID:  12
# num_hits:  1
#
# =======================
# DOC ID:  8
# WordID:  13
# num_hits:  1
#
# =======================
# DOC ID:  9
# WordID:  14
# num_hits:  1
#
# WordID:  15
# num_hits:  1
#
# =======================
# DOC ID:  10
# WordID:  16
# num_hits:  1
#
# =======================
# DOC ID:  10
# WordID:  5
# num_hits:  1
#
# WordID:  16
# num_hits:  1
#
# =======================
# DOC ID:  11
# WordID:  16
# num_hits:  1
#
# WordID:  17
# num_hits:  1
#
# WordID:  18
# num_hits:  1
#
# =======================
# DOC ID:  12
# WordID:  16
# num_hits:  1
#
# WordID:  19
# num_hits:  1
#
# =======================
# DOC ID:  13
# WordID:  16
# num_hits:  1
#
# WordID:  20
# num_hits:  1
#
# =======================
# DOC ID:  14
# WordID:  21
# num_hits:  1
#
# WordID:  15
# num_hits:  1
#
# WordID:  22
# num_hits:  1
#
# =======================
# DOC ID:  15
# WordID:  23
# num_hits:  1
#
# =======================
# DOC ID:  16
# WordID:  24
# num_hits:  1
#
# =======================
# DOC ID:  17
# WordID:  25
# num_hits:  1
#
# =======================
# DOC ID:  18
# WordID:  26
# num_hits:  1
#
# =======================
# DOC ID:  19
# WordID:  27
# num_hits:  1
#
# WordID:  28
# num_hits:  1
#
# =======================
# DOC ID:  20
# WordID:  29
# num_hits:  1
#
# =======================
# DOC ID:  21
# WordID:  30
# num_hits:  1
#
# =======================
# DOC ID:  22
# WordID:  31
# num_hits:  1
#
# =======================
# DOC ID:  23
# WordID:  32
# num_hits:  1
#
# =======================
# DOC ID:  24
# WordID:  33
# num_hits:  1
#
# =======================
# DOC ID:  24
# WordID:  33
# num_hits:  1
#
# WordID:  5
# num_hits:  1
#
# =======================
# DOC ID:  25
# WordID:  0
# num_hits:  1
#
# WordID:  17
# num_hits:  1
#
# WordID:  18
# num_hits:  1
#
# =======================
# DOC ID:  26
# WordID:  34
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# =======================
# DOC ID:  27
# WordID:  3
# num_hits:  1
#
# WordID:  36
# num_hits:  1
#
# =======================
# DOC ID:  28
# WordID:  37
# num_hits:  1
#
# WordID:  38
# num_hits:  1
#
# =======================
# DOC ID:  29
# WordID:  39
# num_hits:  1
#
# WordID:  40
# num_hits:  1
#
# =======================
# DOC ID:  30
# WordID:  41
# num_hits:  1
#
# =======================
# DOC ID:  31
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  32
# WordID:  43
# num_hits:  1
#
# =======================
# DOC ID:  33
# WordID:  44
# num_hits:  1
#
# =======================
# DOC ID:  34
# WordID:  45
# num_hits:  1
#
# =======================
# DOC ID:  35
# WordID:  46
# num_hits:  1
#
# =======================
# DOC ID:  36
# WordID:  47
# num_hits:  1
#
# =======================
# DOC ID:  37
# WordID:  48
# num_hits:  1
#
# =======================
# DOC ID:  37
# WordID:  48
# num_hits:  1
#
# WordID:  5
# num_hits:  1
#
# =======================
# DOC ID:  38
# WordID:  49
# num_hits:  1
#
# WordID:  50
# num_hits:  1
#
# =======================
# DOC ID:  39
# WordID:  51
# num_hits:  1
#
# WordID:  52
# num_hits:  1
#
# =======================
# DOC ID:  40
# WordID:  49
# num_hits:  1
#
# WordID:  50
# num_hits:  1
#
# WordID:  53
# num_hits:  1
#
# WordID:  54
# num_hits:  1
#
# =======================
# DOC ID:  41
# WordID:  55
# num_hits:  1
#
# WordID:  56
# num_hits:  1
#
# WordID:  57
# num_hits:  1
#
# =======================
# DOC ID:  42
# WordID:  58
# num_hits:  1
#
# WordID:  59
# num_hits:  1
#
# =======================
# DOC ID:  43
# WordID:  60
# num_hits:  1
#
# =======================
# DOC ID:  43
# WordID:  5
# num_hits:  1
#
# WordID:  61
# num_hits:  1
#
# =======================
# DOC ID:  44
# WordID:  62
# num_hits:  1
#
# =======================
# DOC ID:  45
# WordID:  63
# num_hits:  1
#
# WordID:  64
# num_hits:  1
#
# WordID:  21
# num_hits:  1
#
# WordID:  65
# num_hits:  1
#
# =======================
# DOC ID:  46
# WordID:  66
# num_hits:  1
#
# =======================
# DOC ID:  47
# WordID:  67
# num_hits:  1
#
# =======================
# DOC ID:  48
# WordID:  68
# num_hits:  1
#
# =======================
# DOC ID:  48
# WordID:  0
# num_hits:  1
#
# WordID:  68
# num_hits:  1
#
# WordID:  5
# num_hits:  1
#
# =======================
# DOC ID:  49
# WordID:  69
# num_hits:  1
#
# =======================
# DOC ID:  50
# WordID:  70
# num_hits:  1
#
# =======================
# DOC ID:  50
# WordID:  5
# num_hits:  1
#
# WordID:  70
# num_hits:  1
#
# =======================
# DOC ID:  51
# WordID:  70
# num_hits:  1
#
# WordID:  71
# num_hits:  1
#
# =======================
# DOC ID:  52
# WordID:  72
# num_hits:  1
#
# =======================
# DOC ID:  52
# WordID:  72
# num_hits:  1
#
# WordID:  5
# num_hits:  1
#
# =======================
# DOC ID:  53
# WordID:  73
# num_hits:  1
#
# =======================
# DOC ID:  54
# WordID:  74
# num_hits:  1
#
# WordID:  75
# num_hits:  1
#
# =======================
# DOC ID:  55
# WordID:  76
# num_hits:  1
#
# WordID:  77
# num_hits:  1
#
# =======================
# DOC ID:  56
# WordID:  78
# num_hits:  1
#
# WordID:  79
# num_hits:  1
#
# =======================
# DOC ID:  57
# WordID:  80
# num_hits:  1
#
# WordID:  78
# num_hits:  1
#
# =======================
# DOC ID:  58
# WordID:  81
# num_hits:  1
#
# =======================
# DOC ID:  59
# WordID:  82
# num_hits:  1
#
# =======================
# DOC ID:  60
# WordID:  83
# num_hits:  1
#
# =======================
# DOC ID:  61
# WordID:  84
# num_hits:  1
#
# =======================
# DOC ID:  62
# WordID:  85
# num_hits:  1
#
# =======================
# DOC ID:  63
# WordID:  86
# num_hits:  1
#
# WordID:  87
# num_hits:  1
#
# =======================
# DOC ID:  64
# WordID:  88
# num_hits:  1
#
# WordID:  5
# num_hits:  1
#
# =======================
# DOC ID:  65
# WordID:  89
# num_hits:  1
#
# WordID:  90
# num_hits:  1
#
# WordID:  91
# num_hits:  1
#
# =======================
# DOC ID:  66
# WordID:  92
# num_hits:  1
#
# =======================
# DOC ID:  67
# WordID:  93
# num_hits:  1
#
# WordID:  94
# num_hits:  1
#
# =======================
# DOC ID:  68
# WordID:  45
# num_hits:  1
#
# =======================
# DOC ID:  69
# WordID:  95
# num_hits:  1
#
# WordID:  96
# num_hits:  1
#
# =======================
# DOC ID:  70
# WordID:  97
# num_hits:  1
#
# =======================
# DOC ID:  71
# WordID:  98
# num_hits:  1
#
# =======================
# DOC ID:  72
# WordID:  99
# num_hits:  1
#
# =======================
# DOC ID:  73
# WordID:  100
# num_hits:  1
#
# =======================
# DOC ID:  74
# WordID:  101
# num_hits:  1
#
# =======================
# DOC ID:  75
# WordID:  102
# num_hits:  1
#
# =======================
# DOC ID:  76
# WordID:  47
# num_hits:  1
#
# =======================
# DOC ID:  77
# WordID:  103
# num_hits:  1
#
# =======================
# DOC ID:  78
# WordID:  104
# num_hits:  1
#
# =======================
# DOC ID:  79
# WordID:  105
# num_hits:  1
#
# WordID:  106
# num_hits:  1
#
# =======================
# DOC ID:  80
# WordID:  107
# num_hits:  1
#
# WordID:  106
# num_hits:  1
#
# =======================
# DOC ID:  81
# WordID:  108
# num_hits:  1
#
# WordID:  109
# num_hits:  1
#
# WordID:  110
# num_hits:  1
#
# WordID:  111
# num_hits:  1
#
# WordID:  54
# num_hits:  1
#
# WordID:  112
# num_hits:  1
#
# WordID:  113
# num_hits:  1
#
# WordID:  114
# num_hits:  1
#
# WordID:  115
# num_hits:  1
#
# WordID:  116
# num_hits:  1
#
# WordID:  117
# num_hits:  1
#
# =======================
# DOC ID:  82
# WordID:  118
# num_hits:  1
#
# WordID:  119
# num_hits:  1
#
# WordID:  120
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# WordID:  115
# num_hits:  1
#
# WordID:  122
# num_hits:  1
#
# WordID:  123
# num_hits:  1
#
# WordID:  124
# num_hits:  1
#
# WordID:  125
# num_hits:  1
#
# WordID:  126
# num_hits:  1
#
# WordID:  127
# num_hits:  1
#
# WordID:  128
# num_hits:  1
#
# =======================
# DOC ID:  83
# WordID:  129
# num_hits:  1
#
# WordID:  130
# num_hits:  1
#
# WordID:  131
# num_hits:  1
#
# WordID:  132
# num_hits:  1
#
# WordID:  133
# num_hits:  1
#
# WordID:  115
# num_hits:  1
#
# WordID:  134
# num_hits:  1
#
# WordID:  135
# num_hits:  1
#
# WordID:  136
# num_hits:  1
#
# WordID:  137
# num_hits:  1
#
# WordID:  138
# num_hits:  1
#
# =======================
# DOC ID:  84
# WordID:  139
# num_hits:  1
#
# WordID:  140
# num_hits:  1
#
# WordID:  141
# num_hits:  1
#
# WordID:  142
# num_hits:  1
#
# WordID:  143
# num_hits:  1
#
# WordID:  144
# num_hits:  1
#
# WordID:  145
# num_hits:  1
#
# WordID:  146
# num_hits:  1
#
# WordID:  147
# num_hits:  1
#
# WordID:  148
# num_hits:  1
#
# WordID:  149
# num_hits:  1
#
# WordID:  136
# num_hits:  1
#
# =======================
# DOC ID:  85
# WordID:  150
# num_hits:  1
#
# WordID:  151
# num_hits:  1
#
# WordID:  152
# num_hits:  1
#
# WordID:  46
# num_hits:  1
#
# WordID:  153
# num_hits:  1
#
# WordID:  115
# num_hits:  1
#
# WordID:  17
# num_hits:  1
#
# WordID:  18
# num_hits:  1
#
# WordID:  154
# num_hits:  1
#
# WordID:  155
# num_hits:  1
#
# =======================
# DOC ID:  86
# WordID:  156
# num_hits:  1
#
# WordID:  157
# num_hits:  1
#
# WordID:  158
# num_hits:  1
#
# WordID:  159
# num_hits:  1
#
# WordID:  160
# num_hits:  1
#
# WordID:  161
# num_hits:  1
#
# WordID:  162
# num_hits:  1
#
# WordID:  163
# num_hits:  1
#
# =======================
# DOC ID:  87
# WordID:  164
# num_hits:  1
#
# WordID:  165
# num_hits:  1
#
# WordID:  166
# num_hits:  1
#
# WordID:  167
# num_hits:  1
#
# WordID:  168
# num_hits:  1
#
# WordID:  115
# num_hits:  1
#
# WordID:  169
# num_hits:  1
#
# WordID:  170
# num_hits:  1
#
# WordID:  171
# num_hits:  1
#
# WordID:  141
# num_hits:  1
#
# =======================
# DOC ID:  88
# WordID:  115
# num_hits:  1
#
# WordID:  172
# num_hits:  1
#
# WordID:  173
# num_hits:  1
#
# WordID:  174
# num_hits:  1
#
# WordID:  175
# num_hits:  1
#
# WordID:  17
# num_hits:  1
#
# WordID:  176
# num_hits:  1
#
# WordID:  54
# num_hits:  1
#
# WordID:  177
# num_hits:  1
#
# WordID:  178
# num_hits:  1
#
# WordID:  179
# num_hits:  1
#
# =======================
# DOC ID:  89
# WordID:  180
# num_hits:  1
#
# WordID:  181
# num_hits:  1
#
# WordID:  182
# num_hits:  1
#
# WordID:  183
# num_hits:  1
#
# WordID:  184
# num_hits:  1
#
# WordID:  185
# num_hits:  1
#
# WordID:  186
# num_hits:  1
#
# WordID:  165
# num_hits:  1
#
# WordID:  187
# num_hits:  1
#
# WordID:  188
# num_hits:  1
#
# =======================
# DOC ID:  90
# WordID:  189
# num_hits:  1
#
# WordID:  190
# num_hits:  1
#
# WordID:  191
# num_hits:  1
#
# WordID:  192
# num_hits:  1
#
# WordID:  193
# num_hits:  1
#
# WordID:  124
# num_hits:  1
#
# WordID:  194
# num_hits:  1
#
# WordID:  54
# num_hits:  1
#
# WordID:  195
# num_hits:  1
#
# WordID:  196
# num_hits:  1
#
# WordID:  197
# num_hits:  1
#
# =======================
# DOC ID:  91
# WordID:  0
# num_hits:  2
#
# WordID:  198
# num_hits:  1
#
# WordID:  199
# num_hits:  1
#
# =======================
# DOC ID:  92
# WordID:  0
# num_hits:  1
#
# WordID:  48
# num_hits:  1
#
# WordID:  71
# num_hits:  1
#
# =======================
# DOC ID:  93
# WordID:  200
# num_hits:  1
#
# WordID:  201
# num_hits:  1
#
# WordID:  17
# num_hits:  1
#
# WordID:  54
# num_hits:  1
#
# WordID:  202
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# WordID:  141
# num_hits:  1
#
# =======================
# DOC ID:  94
# WordID:  203
# num_hits:  1
#
# WordID:  141
# num_hits:  1
#
# WordID:  204
# num_hits:  1
#
# WordID:  115
# num_hits:  1
#
# WordID:  205
# num_hits:  1
#
# WordID:  206
# num_hits:  1
#
# WordID:  187
# num_hits:  1
#
# WordID:  207
# num_hits:  1
#
# WordID:  208
# num_hits:  1
#
# =======================
# DOC ID:  95
# WordID:  209
# num_hits:  1
#
# WordID:  210
# num_hits:  1
#
# WordID:  181
# num_hits:  1
#
# WordID:  211
# num_hits:  1
#
# WordID:  64
# num_hits:  1
#
# WordID:  212
# num_hits:  1
#
# WordID:  115
# num_hits:  1
#
# =======================
# DOC ID:  96
# WordID:  181
# num_hits:  1
#
# WordID:  213
# num_hits:  1
#
# WordID:  214
# num_hits:  1
#
# WordID:  215
# num_hits:  1
#
# WordID:  216
# num_hits:  1
#
# WordID:  217
# num_hits:  1
#
# WordID:  138
# num_hits:  1
#
# =======================
# DOC ID:  92
# WordID:  0
# num_hits:  1
#
# WordID:  48
# num_hits:  1
#
# WordID:  71
# num_hits:  1
#
# WordID:  218
# num_hits:  1
#
# =======================
# DOC ID:  37
# WordID:  0
# num_hits:  1
#
# WordID:  48
# num_hits:  1
#
# WordID:  1
# num_hits:  1
#
# =======================
# DOC ID:  97
# WordID:  219
# num_hits:  1
#
# WordID:  220
# num_hits:  1
#
# WordID:  141
# num_hits:  1
#
# WordID:  221
# num_hits:  2
#
# WordID:  222
# num_hits:  1
#
# WordID:  223
# num_hits:  1
#
# WordID:  224
# num_hits:  1
#
# WordID:  225
# num_hits:  1
#
# WordID:  226
# num_hits:  1
#
# WordID:  227
# num_hits:  1
#
# =======================
# DOC ID:  98
# WordID:  228
# num_hits:  1
#
# WordID:  164
# num_hits:  1
#
# WordID:  141
# num_hits:  1
#
# WordID:  229
# num_hits:  1
#
# WordID:  115
# num_hits:  1
#
# WordID:  230
# num_hits:  1
#
# WordID:  231
# num_hits:  1
#
# WordID:  232
# num_hits:  1
#
# WordID:  233
# num_hits:  1
#
# WordID:  234
# num_hits:  1
#
# WordID:  235
# num_hits:  1
#
# WordID:  236
# num_hits:  1
#
# =======================
# DOC ID:  99
# WordID:  237
# num_hits:  1
#
# WordID:  141
# num_hits:  1
#
# WordID:  238
# num_hits:  1
#
# WordID:  239
# num_hits:  1
#
# WordID:  225
# num_hits:  1
#
# WordID:  17
# num_hits:  1
#
# WordID:  18
# num_hits:  1
#
# WordID:  232
# num_hits:  1
#
# WordID:  128
# num_hits:  1
#
# WordID:  240
# num_hits:  1
#
# =======================
# DOC ID:  100
# WordID:  0
# num_hits:  1
#
# WordID:  59
# num_hits:  1
#
# WordID:  141
# num_hits:  1
#
# WordID:  165
# num_hits:  1
#
# WordID:  241
# num_hits:  1
#
# WordID:  242
# num_hits:  1
#
# WordID:  107
# num_hits:  1
#
# WordID:  115
# num_hits:  1
#
# WordID:  8
# num_hits:  1
#
# WordID:  54
# num_hits:  1
#
# WordID:  243
# num_hits:  1
#
# WordID:  244
# num_hits:  1
#
# WordID:  245
# num_hits:  1
#
# =======================
# DOC ID:  37
# WordID:  0
# num_hits:  1
#
# WordID:  218
# num_hits:  1
#
# =======================
# DOC ID:  101
# WordID:  246
# num_hits:  1
#
# =======================
# DOC ID:  102
# WordID:  247
# num_hits:  1
#
# =======================
# DOC ID:  103
# WordID:  69
# num_hits:  1
#
# =======================
# DOC ID:  104
# WordID:  248
# num_hits:  1
#
# =======================
# DOC ID:  105
# WordID:  1
# num_hits:  1
#
# WordID:  3
# num_hits:  1
#
# WordID:  249
# num_hits:  1
#
# =======================
# DOC ID:  106
# WordID:  131
# num_hits:  1
#
# WordID:  250
# num_hits:  1
#
# WordID:  251
# num_hits:  1
#
# =======================
# DOC ID:  107
# WordID:  3
# num_hits:  1
#
# WordID:  252
# num_hits:  1
#
# =======================
# DOC ID:  108
# WordID:  253
# num_hits:  1
#
# WordID:  254
# num_hits:  1
#
# WordID:  221
# num_hits:  1
#
# WordID:  255
# num_hits:  1
#
# WordID:  256
# num_hits:  1
#
# WordID:  257
# num_hits:  1
#
# =======================
# DOC ID:  109
# WordID:  258
# num_hits:  1
#
# WordID:  259
# num_hits:  1
#
# =======================
# DOC ID:  110
# WordID:  260
# num_hits:  1
#
# =======================
# DOC ID:  111
# WordID:  261
# num_hits:  1
#
# WordID:  238
# num_hits:  1
#
# WordID:  262
# num_hits:  1
#
# =======================
# DOC ID:  112
# WordID:  250
# num_hits:  1
#
# WordID:  263
# num_hits:  1
#
# =======================
# DOC ID:  113
# WordID:  165
# num_hits:  1
#
# WordID:  264
# num_hits:  1
#
# WordID:  265
# num_hits:  1
#
# =======================
# DOC ID:  114
# WordID:  266
# num_hits:  1
#
# WordID:  267
# num_hits:  1
#
# =======================

# %%
import barrels.Sorter as sorter
import lexicon.Lexicon as lexicon

sorter.sort()
# Out:
# Doc ID [25] Num Hits[1]
# Inverted Hit Data:  0b1100100001
# Doc ID [48] Num Hits[1]
# Inverted Hit Data:  0b11000000001
# Doc ID [91] Num Hits[2]
# Inverted Hit Data:  0b101101100010
# Doc ID [92] Num Hits[1]
# Inverted Hit Data:  0b101110000001
# Doc ID [92] Num Hits[1]
# Inverted Hit Data:  0b101110000001
# Doc ID [37] Num Hits[1]
# Inverted Hit Data:  0b10010100001
# Doc ID [100] Num Hits[1]
# Inverted Hit Data:  0b110010000001
# Doc ID [37] Num Hits[1]
# Inverted Hit Data:  0b10010100001
# Adding wordID[0] pos[0]
# Doc ID [0] Num Hits[1]
# Inverted Hit Data:  0b1
# Doc ID [37] Num Hits[1]
# Inverted Hit Data:  0b10010100001
# Doc ID [105] Num Hits[1]
# Inverted Hit Data:  0b110100100001
# Adding wordID[1] pos[41]
# Doc ID [0] Num Hits[1]
# Inverted Hit Data:  0b1
# Adding wordID[2] pos[56]
# Doc ID [0] Num Hits[1]
# Inverted Hit Data:  0b1
# Doc ID [7] Num Hits[1]
# Inverted Hit Data:  0b11100001
# Doc ID [27] Num Hits[1]
# Inverted Hit Data:  0b1101100001
# Doc ID [105] Num Hits[1]
# Inverted Hit Data:  0b110100100001
# Doc ID [107] Num Hits[1]
# Inverted Hit Data:  0b110101100001
# Adding wordID[3] pos[61]
# Doc ID [0] Num Hits[1]
# Inverted Hit Data:  0b1
# Doc ID [1] Num Hits[1]
# Inverted Hit Data:  0b100001
# Doc ID [1] Num Hits[1]
# Inverted Hit Data:  0b100001
# Adding wordID[4] pos[86]
# Doc ID [1] Num Hits[1]
# Inverted Hit Data:  0b100001
# Doc ID [10] Num Hits[1]
# Inverted Hit Data:  0b101000001
# Doc ID [24] Num Hits[1]
# Inverted Hit Data:  0b1100000001
# Doc ID [37] Num Hits[1]
# Inverted Hit Data:  0b10010100001
# Doc ID [43] Num Hits[1]
# Inverted Hit Data:  0b10101100001
# Doc ID [48] Num Hits[1]
# Inverted Hit Data:  0b11000000001
# Doc ID [50] Num Hits[1]
# Inverted Hit Data:  0b11001000001
# Doc ID [52] Num Hits[1]
# Inverted Hit Data:  0b11010000001
# Doc ID [64] Num Hits[1]
# Inverted Hit Data:  0b100000000001
# Adding wordID[5] pos[101]
# Doc ID [2] Num Hits[1]
# Inverted Hit Data:  0b1000001
# Adding wordID[6] pos[146]
# Doc ID [3] Num Hits[1]
# Inverted Hit Data:  0b1100001
# Adding wordID[7] pos[151]
# Doc ID [4] Num Hits[1]
# Inverted Hit Data:  0b10000001
# Doc ID [100] Num Hits[1]
# Inverted Hit Data:  0b110010000001
# Adding wordID[8] pos[156]
# Doc ID [4] Num Hits[1]
# Inverted Hit Data:  0b10000001
# Adding wordID[9] pos[166]
# Doc ID [5] Num Hits[1]
# Inverted Hit Data:  0b10100001
# Adding wordID[10] pos[171]
# Doc ID [6] Num Hits[1]
# Inverted Hit Data:  0b11000001
# Adding wordID[11] pos[176]
# Doc ID [7] Num Hits[1]
# Inverted Hit Data:  0b11100001
# Adding wordID[12] pos[181]
# Doc ID [8] Num Hits[1]
# Inverted Hit Data:  0b100000001
# Adding wordID[13] pos[186]
# Doc ID [9] Num Hits[1]
# Inverted Hit Data:  0b100100001
# Adding wordID[14] pos[191]
# Doc ID [9] Num Hits[1]
# Inverted Hit Data:  0b100100001
# Doc ID [14] Num Hits[1]
# Inverted Hit Data:  0b111000001
# Adding wordID[15] pos[196]
# Doc ID [10] Num Hits[1]
# Inverted Hit Data:  0b101000001
# Doc ID [10] Num Hits[1]
# Inverted Hit Data:  0b101000001
# Doc ID [11] Num Hits[1]
# Inverted Hit Data:  0b101100001
# Doc ID [12] Num Hits[1]
# Inverted Hit Data:  0b110000001
# Doc ID [13] Num Hits[1]
# Inverted Hit Data:  0b110100001
# Adding wordID[16] pos[206]
# Doc ID [11] Num Hits[1]
# Inverted Hit Data:  0b101100001
# Doc ID [25] Num Hits[1]
# Inverted Hit Data:  0b1100100001
# Doc ID [85] Num Hits[1]
# Inverted Hit Data:  0b101010100001
# Doc ID [88] Num Hits[1]
# Inverted Hit Data:  0b101100000001
# Doc ID [93] Num Hits[1]
# Inverted Hit Data:  0b101110100001
# Doc ID [99] Num Hits[1]
# Inverted Hit Data:  0b110001100001
# Adding wordID[17] pos[231]
# Doc ID [11] Num Hits[1]
# Inverted Hit Data:  0b101100001
# Doc ID [25] Num Hits[1]
# Inverted Hit Data:  0b1100100001
# Doc ID [85] Num Hits[1]
# Inverted Hit Data:  0b101010100001
# Doc ID [99] Num Hits[1]
# Inverted Hit Data:  0b110001100001
# Adding wordID[18] pos[261]
# Doc ID [12] Num Hits[1]
# Inverted Hit Data:  0b110000001
# Adding wordID[19] pos[281]
# Doc ID [13] Num Hits[1]
# Inverted Hit Data:  0b110100001
# Adding wordID[20] pos[286]
# Doc ID [14] Num Hits[1]
# Inverted Hit Data:  0b111000001
# Doc ID [45] Num Hits[1]
# Inverted Hit Data:  0b10110100001
# Adding wordID[21] pos[291]
# Doc ID [14] Num Hits[1]
# Inverted Hit Data:  0b111000001
# Adding wordID[22] pos[301]
# Doc ID [15] Num Hits[1]
# Inverted Hit Data:  0b111100001
# Adding wordID[23] pos[306]
# Doc ID [16] Num Hits[1]
# Inverted Hit Data:  0b1000000001
# Adding wordID[24] pos[311]
# Doc ID [17] Num Hits[1]
# Inverted Hit Data:  0b1000100001
# Adding wordID[25] pos[316]
# Doc ID [18] Num Hits[1]
# Inverted Hit Data:  0b1001000001
# Adding wordID[26] pos[321]
# Doc ID [19] Num Hits[1]
# Inverted Hit Data:  0b1001100001
# Adding wordID[27] pos[326]
# Doc ID [19] Num Hits[1]
# Inverted Hit Data:  0b1001100001
# Adding wordID[28] pos[331]
# Doc ID [20] Num Hits[1]
# Inverted Hit Data:  0b1010000001
# Adding wordID[29] pos[336]
# Doc ID [21] Num Hits[1]
# Inverted Hit Data:  0b1010100001
# Adding wordID[30] pos[341]
# Doc ID [22] Num Hits[1]
# Inverted Hit Data:  0b1011000001
# Adding wordID[31] pos[346]
# Doc ID [23] Num Hits[1]
# Inverted Hit Data:  0b1011100001
# Adding wordID[32] pos[351]
# Doc ID [24] Num Hits[1]
# Inverted Hit Data:  0b1100000001
# Doc ID [24] Num Hits[1]
# Inverted Hit Data:  0b1100000001
# Adding wordID[33] pos[356]
# Doc ID [26] Num Hits[1]
# Inverted Hit Data:  0b1101000001
# Adding wordID[34] pos[366]
# Doc ID [26] Num Hits[1]
# Inverted Hit Data:  0b1101000001
# Adding wordID[35] pos[371]
# Doc ID [27] Num Hits[1]
# Inverted Hit Data:  0b1101100001
# Adding wordID[36] pos[376]
# Doc ID [28] Num Hits[1]
# Inverted Hit Data:  0b1110000001
# Adding wordID[37] pos[381]
# Doc ID [28] Num Hits[1]
# Inverted Hit Data:  0b1110000001
# Adding wordID[38] pos[386]
# Doc ID [29] Num Hits[1]
# Inverted Hit Data:  0b1110100001
# Adding wordID[39] pos[391]
# Doc ID [29] Num Hits[1]
# Inverted Hit Data:  0b1110100001
# Adding wordID[40] pos[396]
# Doc ID [30] Num Hits[1]
# Inverted Hit Data:  0b1111000001
# Adding wordID[41] pos[401]
# Doc ID [31] Num Hits[1]
# Inverted Hit Data:  0b1111100001
# Doc ID [93] Num Hits[1]
# Inverted Hit Data:  0b101110100001
# Adding wordID[42] pos[406]
# Doc ID [32] Num Hits[1]
# Inverted Hit Data:  0b10000000001
# Adding wordID[43] pos[416]
# Doc ID [33] Num Hits[1]
# Inverted Hit Data:  0b10000100001
# Adding wordID[44] pos[421]
# Doc ID [34] Num Hits[1]
# Inverted Hit Data:  0b10001000001
# Doc ID [68] Num Hits[1]
# Inverted Hit Data:  0b100010000001
# Adding wordID[45] pos[426]
# Doc ID [35] Num Hits[1]
# Inverted Hit Data:  0b10001100001
# Doc ID [85] Num Hits[1]
# Inverted Hit Data:  0b101010100001
# Adding wordID[46] pos[436]
# Doc ID [36] Num Hits[1]
# Inverted Hit Data:  0b10010000001
# Doc ID [76] Num Hits[1]
# Inverted Hit Data:  0b100110000001
# Adding wordID[47] pos[446]
# Doc ID [37] Num Hits[1]
# Inverted Hit Data:  0b10010100001
# Doc ID [37] Num Hits[1]
# Inverted Hit Data:  0b10010100001
# Doc ID [92] Num Hits[1]
# Inverted Hit Data:  0b101110000001
# Doc ID [92] Num Hits[1]
# Inverted Hit Data:  0b101110000001
# Doc ID [37] Num Hits[1]
# Inverted Hit Data:  0b10010100001
# Adding wordID[48] pos[456]
# Doc ID [38] Num Hits[1]
# Inverted Hit Data:  0b10011000001
# Doc ID [40] Num Hits[1]
# Inverted Hit Data:  0b10100000001
# Adding wordID[49] pos[481]
# Doc ID [38] Num Hits[1]
# Inverted Hit Data:  0b10011000001
# Doc ID [40] Num Hits[1]
# Inverted Hit Data:  0b10100000001
# Adding wordID[50] pos[491]
# Doc ID [39] Num Hits[1]
# Inverted Hit Data:  0b10011100001
# Adding wordID[51] pos[501]
# Doc ID [39] Num Hits[1]
# Inverted Hit Data:  0b10011100001
# Adding wordID[52] pos[506]
# Doc ID [40] Num Hits[1]
# Inverted Hit Data:  0b10100000001
# Adding wordID[53] pos[511]
# Doc ID [40] Num Hits[1]
# Inverted Hit Data:  0b10100000001
# Doc ID [81] Num Hits[1]
# Inverted Hit Data:  0b101000100001
# Doc ID [88] Num Hits[1]
# Inverted Hit Data:  0b101100000001
# Doc ID [90] Num Hits[1]
# Inverted Hit Data:  0b101101000001
# Doc ID [93] Num Hits[1]
# Inverted Hit Data:  0b101110100001
# Doc ID [100] Num Hits[1]
# Inverted Hit Data:  0b110010000001
# Adding wordID[54] pos[516]
# Doc ID [41] Num Hits[1]
# Inverted Hit Data:  0b10100100001
# Adding wordID[55] pos[546]
# Doc ID [41] Num Hits[1]
# Inverted Hit Data:  0b10100100001
# Adding wordID[56] pos[551]
# Doc ID [41] Num Hits[1]
# Inverted Hit Data:  0b10100100001
# Adding wordID[57] pos[556]
# Doc ID [42] Num Hits[1]
# Inverted Hit Data:  0b10101000001
# Adding wordID[58] pos[561]
# Doc ID [42] Num Hits[1]
# Inverted Hit Data:  0b10101000001
# Doc ID [100] Num Hits[1]
# Inverted Hit Data:  0b110010000001
# Adding wordID[59] pos[566]
# Doc ID [43] Num Hits[1]
# Inverted Hit Data:  0b10101100001
# Adding wordID[60] pos[576]
# Doc ID [43] Num Hits[1]
# Inverted Hit Data:  0b10101100001
# Adding wordID[61] pos[581]
# Doc ID [44] Num Hits[1]
# Inverted Hit Data:  0b10110000001
# Adding wordID[62] pos[586]
# Doc ID [45] Num Hits[1]
# Inverted Hit Data:  0b10110100001
# Adding wordID[63] pos[591]
# Doc ID [45] Num Hits[1]
# Inverted Hit Data:  0b10110100001
# Doc ID [95] Num Hits[1]
# Inverted Hit Data:  0b101111100001
# Adding wordID[64] pos[596]
# Doc ID [45] Num Hits[1]
# Inverted Hit Data:  0b10110100001
# Adding wordID[65] pos[606]
# Doc ID [46] Num Hits[1]
# Inverted Hit Data:  0b10111000001
# Adding wordID[66] pos[611]
# Doc ID [47] Num Hits[1]
# Inverted Hit Data:  0b10111100001
# Adding wordID[67] pos[616]
# Doc ID [48] Num Hits[1]
# Inverted Hit Data:  0b11000000001
# Doc ID [48] Num Hits[1]
# Inverted Hit Data:  0b11000000001
# Adding wordID[68] pos[621]
# Doc ID [49] Num Hits[1]
# Inverted Hit Data:  0b11000100001
# Doc ID [103] Num Hits[1]
# Inverted Hit Data:  0b110011100001
# Adding wordID[69] pos[631]
# Doc ID [50] Num Hits[1]
# Inverted Hit Data:  0b11001000001
# Doc ID [50] Num Hits[1]
# Inverted Hit Data:  0b11001000001
# Doc ID [51] Num Hits[1]
# Inverted Hit Data:  0b11001100001
# Adding wordID[70] pos[641]
# Doc ID [51] Num Hits[1]
# Inverted Hit Data:  0b11001100001
# Doc ID [92] Num Hits[1]
# Inverted Hit Data:  0b101110000001
# Doc ID [92] Num Hits[1]
# Inverted Hit Data:  0b101110000001
# Adding wordID[71] pos[656]
# Doc ID [52] Num Hits[1]
# Inverted Hit Data:  0b11010000001
# Doc ID [52] Num Hits[1]
# Inverted Hit Data:  0b11010000001
# Adding wordID[72] pos[671]
# Doc ID [53] Num Hits[1]
# Inverted Hit Data:  0b11010100001
# Adding wordID[73] pos[681]
# Doc ID [54] Num Hits[1]
# Inverted Hit Data:  0b11011000001
# Adding wordID[74] pos[686]
# Doc ID [54] Num Hits[1]
# Inverted Hit Data:  0b11011000001
# Adding wordID[75] pos[691]
# Doc ID [55] Num Hits[1]
# Inverted Hit Data:  0b11011100001
# Adding wordID[76] pos[696]
# Doc ID [55] Num Hits[1]
# Inverted Hit Data:  0b11011100001
# Adding wordID[77] pos[701]
# Doc ID [56] Num Hits[1]
# Inverted Hit Data:  0b11100000001
# Doc ID [57] Num Hits[1]
# Inverted Hit Data:  0b11100100001
# Adding wordID[78] pos[706]
# Doc ID [56] Num Hits[1]
# Inverted Hit Data:  0b11100000001
# Adding wordID[79] pos[716]
# Doc ID [57] Num Hits[1]
# Inverted Hit Data:  0b11100100001
# Adding wordID[80] pos[721]
# Doc ID [58] Num Hits[1]
# Inverted Hit Data:  0b11101000001
# Adding wordID[81] pos[726]
# Doc ID [59] Num Hits[1]
# Inverted Hit Data:  0b11101100001
# Adding wordID[82] pos[731]
# Doc ID [60] Num Hits[1]
# Inverted Hit Data:  0b11110000001
# Adding wordID[83] pos[736]
# Doc ID [61] Num Hits[1]
# Inverted Hit Data:  0b11110100001
# Adding wordID[84] pos[741]
# Doc ID [62] Num Hits[1]
# Inverted Hit Data:  0b11111000001
# Adding wordID[85] pos[746]
# Doc ID [63] Num Hits[1]
# Inverted Hit Data:  0b11111100001
# Adding wordID[86] pos[751]
# Doc ID [63] Num Hits[1]
# Inverted Hit Data:  0b11111100001
# Adding wordID[87] pos[756]
# Doc ID [64] Num Hits[1]
# Inverted Hit Data:  0b100000000001
# Adding wordID[88] pos[761]
# Doc ID [65] Num Hits[1]
# Inverted Hit Data:  0b100000100001
# Adding wordID[89] pos[766]
# Doc ID [65] Num Hits[1]
# Inverted Hit Data:  0b100000100001
# Adding wordID[90] pos[771]
# Doc ID [65] Num Hits[1]
# Inverted Hit Data:  0b100000100001
# Adding wordID[91] pos[776]
# Doc ID [66] Num Hits[1]
# Inverted Hit Data:  0b100001000001
# Adding wordID[92] pos[781]
# Doc ID [67] Num Hits[1]
# Inverted Hit Data:  0b100001100001
# Adding wordID[93] pos[786]
# Doc ID [67] Num Hits[1]
# Inverted Hit Data:  0b100001100001
# Adding wordID[94] pos[791]
# Doc ID [69] Num Hits[1]
# Inverted Hit Data:  0b100010100001
# Adding wordID[95] pos[796]
# Doc ID [69] Num Hits[1]
# Inverted Hit Data:  0b100010100001
# Adding wordID[96] pos[801]
# Doc ID [70] Num Hits[1]
# Inverted Hit Data:  0b100011000001
# Adding wordID[97] pos[806]
# Doc ID [71] Num Hits[1]
# Inverted Hit Data:  0b100011100001
# Adding wordID[98] pos[811]
# Doc ID [72] Num Hits[1]
# Inverted Hit Data:  0b100100000001
# Adding wordID[99] pos[816]
# Doc ID [73] Num Hits[1]
# Inverted Hit Data:  0b100100100001
# Adding wordID[100] pos[821]
# Doc ID [74] Num Hits[1]
# Inverted Hit Data:  0b100101000001
# Adding wordID[101] pos[826]
# Doc ID [75] Num Hits[1]
# Inverted Hit Data:  0b100101100001
# Adding wordID[102] pos[831]
# Doc ID [77] Num Hits[1]
# Inverted Hit Data:  0b100110100001
# Adding wordID[103] pos[836]
# Doc ID [78] Num Hits[1]
# Inverted Hit Data:  0b100111000001
# Adding wordID[104] pos[841]
# Doc ID [79] Num Hits[1]
# Inverted Hit Data:  0b100111100001
# Adding wordID[105] pos[846]
# Doc ID [79] Num Hits[1]
# Inverted Hit Data:  0b100111100001
# Doc ID [80] Num Hits[1]
# Inverted Hit Data:  0b101000000001
# Adding wordID[106] pos[851]
# Doc ID [80] Num Hits[1]
# Inverted Hit Data:  0b101000000001
# Doc ID [100] Num Hits[1]
# Inverted Hit Data:  0b110010000001
# Adding wordID[107] pos[861]
# Doc ID [81] Num Hits[1]
# Inverted Hit Data:  0b101000100001
# Adding wordID[108] pos[871]
# Doc ID [81] Num Hits[1]
# Inverted Hit Data:  0b101000100001
# Adding wordID[109] pos[876]
# Doc ID [81] Num Hits[1]
# Inverted Hit Data:  0b101000100001
# Adding wordID[110] pos[881]
# Doc ID [81] Num Hits[1]
# Inverted Hit Data:  0b101000100001
# Adding wordID[111] pos[886]
# Doc ID [81] Num Hits[1]
# Inverted Hit Data:  0b101000100001
# Adding wordID[112] pos[891]
# Doc ID [81] Num Hits[1]
# Inverted Hit Data:  0b101000100001
# Adding wordID[113] pos[896]
# Doc ID [81] Num Hits[1]
# Inverted Hit Data:  0b101000100001
# Adding wordID[114] pos[901]
# Doc ID [81] Num Hits[1]
# Inverted Hit Data:  0b101000100001
# Doc ID [82] Num Hits[1]
# Inverted Hit Data:  0b101001000001
# Doc ID [83] Num Hits[1]
# Inverted Hit Data:  0b101001100001
# Doc ID [85] Num Hits[1]
# Inverted Hit Data:  0b101010100001
# Doc ID [87] Num Hits[1]
# Inverted Hit Data:  0b101011100001
# Doc ID [88] Num Hits[1]
# Inverted Hit Data:  0b101100000001
# Doc ID [94] Num Hits[1]
# Inverted Hit Data:  0b101111000001
# Doc ID [95] Num Hits[1]
# Inverted Hit Data:  0b101111100001
# Doc ID [98] Num Hits[1]
# Inverted Hit Data:  0b110001000001
# Doc ID [100] Num Hits[1]
# Inverted Hit Data:  0b110010000001
# Adding wordID[115] pos[906]
# Doc ID [81] Num Hits[1]
# Inverted Hit Data:  0b101000100001
# Adding wordID[116] pos[956]
# Doc ID [81] Num Hits[1]
# Inverted Hit Data:  0b101000100001
# Adding wordID[117] pos[961]
# Doc ID [82] Num Hits[1]
# Inverted Hit Data:  0b101001000001
# Adding wordID[118] pos[966]
# Doc ID [82] Num Hits[1]
# Inverted Hit Data:  0b101001000001
# Adding wordID[119] pos[971]
# Doc ID [82] Num Hits[1]
# Inverted Hit Data:  0b101001000001
# Adding wordID[120] pos[976]
# Doc ID [82] Num Hits[1]
# Inverted Hit Data:  0b101001000001
# Adding wordID[121] pos[981]
# Doc ID [82] Num Hits[1]
# Inverted Hit Data:  0b101001000001
# Adding wordID[122] pos[986]
# Doc ID [82] Num Hits[1]
# Inverted Hit Data:  0b101001000001
# Adding wordID[123] pos[991]
# Doc ID [82] Num Hits[1]
# Inverted Hit Data:  0b101001000001
# Doc ID [90] Num Hits[1]
# Inverted Hit Data:  0b101101000001
# Adding wordID[124] pos[996]
# Doc ID [82] Num Hits[1]
# Inverted Hit Data:  0b101001000001
# Adding wordID[125] pos[1006]
# Doc ID [82] Num Hits[1]
# Inverted Hit Data:  0b101001000001
# Adding wordID[126] pos[1011]
# Doc ID [82] Num Hits[1]
# Inverted Hit Data:  0b101001000001
# Adding wordID[127] pos[1016]
# Doc ID [82] Num Hits[1]
# Inverted Hit Data:  0b101001000001
# Doc ID [99] Num Hits[1]
# Inverted Hit Data:  0b110001100001
# Adding wordID[128] pos[1021]
# Doc ID [83] Num Hits[1]
# Inverted Hit Data:  0b101001100001
# Adding wordID[129] pos[1031]
# Doc ID [83] Num Hits[1]
# Inverted Hit Data:  0b101001100001
# Adding wordID[130] pos[1036]
# Doc ID [83] Num Hits[1]
# Inverted Hit Data:  0b101001100001
# Doc ID [106] Num Hits[1]
# Inverted Hit Data:  0b110101000001
# Adding wordID[131] pos[1041]
# Doc ID [83] Num Hits[1]
# Inverted Hit Data:  0b101001100001
# Adding wordID[132] pos[1051]
# Doc ID [83] Num Hits[1]
# Inverted Hit Data:  0b101001100001
# Adding wordID[133] pos[1056]
# Doc ID [83] Num Hits[1]
# Inverted Hit Data:  0b101001100001
# Adding wordID[134] pos[1061]
# Doc ID [83] Num Hits[1]
# Inverted Hit Data:  0b101001100001
# Adding wordID[135] pos[1066]
# Doc ID [83] Num Hits[1]
# Inverted Hit Data:  0b101001100001
# Doc ID [84] Num Hits[1]
# Inverted Hit Data:  0b101010000001
# Adding wordID[136] pos[1071]
# Doc ID [83] Num Hits[1]
# Inverted Hit Data:  0b101001100001
# Adding wordID[137] pos[1081]
# Doc ID [83] Num Hits[1]
# Inverted Hit Data:  0b101001100001
# Doc ID [96] Num Hits[1]
# Inverted Hit Data:  0b110000000001
# Adding wordID[138] pos[1086]
# Doc ID [84] Num Hits[1]
# Inverted Hit Data:  0b101010000001
# Adding wordID[139] pos[1096]
# Doc ID [84] Num Hits[1]
# Inverted Hit Data:  0b101010000001
# Adding wordID[140] pos[1101]
# Doc ID [84] Num Hits[1]
# Inverted Hit Data:  0b101010000001
# Doc ID [87] Num Hits[1]
# Inverted Hit Data:  0b101011100001
# Doc ID [93] Num Hits[1]
# Inverted Hit Data:  0b101110100001
# Doc ID [94] Num Hits[1]
# Inverted Hit Data:  0b101111000001
# Doc ID [97] Num Hits[1]
# Inverted Hit Data:  0b110000100001
# Doc ID [98] Num Hits[1]
# Inverted Hit Data:  0b110001000001
# Doc ID [99] Num Hits[1]
# Inverted Hit Data:  0b110001100001
# Doc ID [100] Num Hits[1]
# Inverted Hit Data:  0b110010000001
# Adding wordID[141] pos[1106]
# Doc ID [84] Num Hits[1]
# Inverted Hit Data:  0b101010000001
# Adding wordID[142] pos[1146]
# Doc ID [84] Num Hits[1]
# Inverted Hit Data:  0b101010000001
# Adding wordID[143] pos[1151]
# Doc ID [84] Num Hits[1]
# Inverted Hit Data:  0b101010000001
# Adding wordID[144] pos[1156]
# Doc ID [84] Num Hits[1]
# Inverted Hit Data:  0b101010000001
# Adding wordID[145] pos[1161]
# Doc ID [84] Num Hits[1]
# Inverted Hit Data:  0b101010000001
# Adding wordID[146] pos[1166]
# Doc ID [84] Num Hits[1]
# Inverted Hit Data:  0b101010000001
# Adding wordID[147] pos[1171]
# Doc ID [84] Num Hits[1]
# Inverted Hit Data:  0b101010000001
# Adding wordID[148] pos[1176]
# Doc ID [84] Num Hits[1]
# Inverted Hit Data:  0b101010000001
# Adding wordID[149] pos[1181]
# Doc ID [85] Num Hits[1]
# Inverted Hit Data:  0b101010100001
# Adding wordID[150] pos[1186]
# Doc ID [85] Num Hits[1]
# Inverted Hit Data:  0b101010100001
# Adding wordID[151] pos[1191]
# Doc ID [85] Num Hits[1]
# Inverted Hit Data:  0b101010100001
# Adding wordID[152] pos[1196]
# Doc ID [85] Num Hits[1]
# Inverted Hit Data:  0b101010100001
# Adding wordID[153] pos[1201]
# Doc ID [85] Num Hits[1]
# Inverted Hit Data:  0b101010100001
# Adding wordID[154] pos[1206]
# Doc ID [85] Num Hits[1]
# Inverted Hit Data:  0b101010100001
# Adding wordID[155] pos[1211]
# Doc ID [86] Num Hits[1]
# Inverted Hit Data:  0b101011000001
# Adding wordID[156] pos[1216]
# Doc ID [86] Num Hits[1]
# Inverted Hit Data:  0b101011000001
# Adding wordID[157] pos[1221]
# Doc ID [86] Num Hits[1]
# Inverted Hit Data:  0b101011000001
# Adding wordID[158] pos[1226]
# Doc ID [86] Num Hits[1]
# Inverted Hit Data:  0b101011000001
# Adding wordID[159] pos[1231]
# Doc ID [86] Num Hits[1]
# Inverted Hit Data:  0b101011000001
# Adding wordID[160] pos[1236]
# Doc ID [86] Num Hits[1]
# Inverted Hit Data:  0b101011000001
# Adding wordID[161] pos[1241]
# Doc ID [86] Num Hits[1]
# Inverted Hit Data:  0b101011000001
# Adding wordID[162] pos[1246]
# Doc ID [86] Num Hits[1]
# Inverted Hit Data:  0b101011000001
# Adding wordID[163] pos[1251]
# Doc ID [87] Num Hits[1]
# Inverted Hit Data:  0b101011100001
# Doc ID [98] Num Hits[1]
# Inverted Hit Data:  0b110001000001
# Adding wordID[164] pos[1256]
# Doc ID [87] Num Hits[1]
# Inverted Hit Data:  0b101011100001
# Doc ID [89] Num Hits[1]
# Inverted Hit Data:  0b101100100001
# Doc ID [100] Num Hits[1]
# Inverted Hit Data:  0b110010000001
# Doc ID [113] Num Hits[1]
# Inverted Hit Data:  0b111000100001
# Adding wordID[165] pos[1266]
# Doc ID [87] Num Hits[1]
# Inverted Hit Data:  0b101011100001
# Adding wordID[166] pos[1286]
# Doc ID [87] Num Hits[1]
# Inverted Hit Data:  0b101011100001
# Adding wordID[167] pos[1291]
# Doc ID [87] Num Hits[1]
# Inverted Hit Data:  0b101011100001
# Adding wordID[168] pos[1296]
# Doc ID [87] Num Hits[1]
# Inverted Hit Data:  0b101011100001
# Adding wordID[169] pos[1301]
# Doc ID [87] Num Hits[1]
# Inverted Hit Data:  0b101011100001
# Adding wordID[170] pos[1306]
# Doc ID [87] Num Hits[1]
# Inverted Hit Data:  0b101011100001
# Adding wordID[171] pos[1311]
# Doc ID [88] Num Hits[1]
# Inverted Hit Data:  0b101100000001
# Adding wordID[172] pos[1316]
# Doc ID [88] Num Hits[1]
# Inverted Hit Data:  0b101100000001
# Adding wordID[173] pos[1321]
# Doc ID [88] Num Hits[1]
# Inverted Hit Data:  0b101100000001
# Adding wordID[174] pos[1326]
# Doc ID [88] Num Hits[1]
# Inverted Hit Data:  0b101100000001
# Adding wordID[175] pos[1331]
# Doc ID [88] Num Hits[1]
# Inverted Hit Data:  0b101100000001
# Adding wordID[176] pos[1336]
# Doc ID [88] Num Hits[1]
# Inverted Hit Data:  0b101100000001
# Adding wordID[177] pos[1341]
# Doc ID [88] Num Hits[1]
# Inverted Hit Data:  0b101100000001
# Adding wordID[178] pos[1346]
# Doc ID [88] Num Hits[1]
# Inverted Hit Data:  0b101100000001
# Adding wordID[179] pos[1351]
# Doc ID [89] Num Hits[1]
# Inverted Hit Data:  0b101100100001
# Adding wordID[180] pos[1356]
# Doc ID [89] Num Hits[1]
# Inverted Hit Data:  0b101100100001
# Doc ID [95] Num Hits[1]
# Inverted Hit Data:  0b101111100001
# Doc ID [96] Num Hits[1]
# Inverted Hit Data:  0b110000000001
# Adding wordID[181] pos[1361]
# Doc ID [89] Num Hits[1]
# Inverted Hit Data:  0b101100100001
# Adding wordID[182] pos[1376]
# Doc ID [89] Num Hits[1]
# Inverted Hit Data:  0b101100100001
# Adding wordID[183] pos[1381]
# Doc ID [89] Num Hits[1]
# Inverted Hit Data:  0b101100100001
# Adding wordID[184] pos[1386]
# Doc ID [89] Num Hits[1]
# Inverted Hit Data:  0b101100100001
# Adding wordID[185] pos[1391]
# Doc ID [89] Num Hits[1]
# Inverted Hit Data:  0b101100100001
# Adding wordID[186] pos[1396]
# Doc ID [89] Num Hits[1]
# Inverted Hit Data:  0b101100100001
# Doc ID [94] Num Hits[1]
# Inverted Hit Data:  0b101111000001
# Adding wordID[187] pos[1401]
# Doc ID [89] Num Hits[1]
# Inverted Hit Data:  0b101100100001
# Adding wordID[188] pos[1411]
# Doc ID [90] Num Hits[1]
# Inverted Hit Data:  0b101101000001
# Adding wordID[189] pos[1416]
# Doc ID [90] Num Hits[1]
# Inverted Hit Data:  0b101101000001
# Adding wordID[190] pos[1421]
# Doc ID [90] Num Hits[1]
# Inverted Hit Data:  0b101101000001
# Adding wordID[191] pos[1426]
# Doc ID [90] Num Hits[1]
# Inverted Hit Data:  0b101101000001
# Adding wordID[192] pos[1431]
# Doc ID [90] Num Hits[1]
# Inverted Hit Data:  0b101101000001
# Adding wordID[193] pos[1436]
# Doc ID [90] Num Hits[1]
# Inverted Hit Data:  0b101101000001
# Adding wordID[194] pos[1441]
# Doc ID [90] Num Hits[1]
# Inverted Hit Data:  0b101101000001
# Adding wordID[195] pos[1446]
# Doc ID [90] Num Hits[1]
# Inverted Hit Data:  0b101101000001
# Adding wordID[196] pos[1451]
# Doc ID [90] Num Hits[1]
# Inverted Hit Data:  0b101101000001
# Adding wordID[197] pos[1456]
# Doc ID [91] Num Hits[1]
# Inverted Hit Data:  0b101101100001
# Adding wordID[198] pos[1461]
# Doc ID [91] Num Hits[1]
# Inverted Hit Data:  0b101101100001
# Adding wordID[199] pos[1466]
# Doc ID [93] Num Hits[1]
# Inverted Hit Data:  0b101110100001
# Adding wordID[200] pos[1471]
# Doc ID [93] Num Hits[1]
# Inverted Hit Data:  0b101110100001
# Adding wordID[201] pos[1476]
# Doc ID [93] Num Hits[1]
# Inverted Hit Data:  0b101110100001
# Adding wordID[202] pos[1481]
# Doc ID [94] Num Hits[1]
# Inverted Hit Data:  0b101111000001
# Adding wordID[203] pos[1486]
# Doc ID [94] Num Hits[1]
# Inverted Hit Data:  0b101111000001
# Adding wordID[204] pos[1491]
# Doc ID [94] Num Hits[1]
# Inverted Hit Data:  0b101111000001
# Adding wordID[205] pos[1496]
# Doc ID [94] Num Hits[1]
# Inverted Hit Data:  0b101111000001
# Adding wordID[206] pos[1501]
# Doc ID [94] Num Hits[1]
# Inverted Hit Data:  0b101111000001
# Adding wordID[207] pos[1506]
# Doc ID [94] Num Hits[1]
# Inverted Hit Data:  0b101111000001
# Adding wordID[208] pos[1511]
# Doc ID [95] Num Hits[1]
# Inverted Hit Data:  0b101111100001
# Adding wordID[209] pos[1516]
# Doc ID [95] Num Hits[1]
# Inverted Hit Data:  0b101111100001
# Adding wordID[210] pos[1521]
# Doc ID [95] Num Hits[1]
# Inverted Hit Data:  0b101111100001
# Adding wordID[211] pos[1526]
# Doc ID [95] Num Hits[1]
# Inverted Hit Data:  0b101111100001
# Adding wordID[212] pos[1531]
# Doc ID [96] Num Hits[1]
# Inverted Hit Data:  0b110000000001
# Adding wordID[213] pos[1536]
# Doc ID [96] Num Hits[1]
# Inverted Hit Data:  0b110000000001
# Adding wordID[214] pos[1541]
# Doc ID [96] Num Hits[1]
# Inverted Hit Data:  0b110000000001
# Adding wordID[215] pos[1546]
# Doc ID [96] Num Hits[1]
# Inverted Hit Data:  0b110000000001
# Adding wordID[216] pos[1551]
# Doc ID [96] Num Hits[1]
# Inverted Hit Data:  0b110000000001
# Adding wordID[217] pos[1556]
# Doc ID [92] Num Hits[1]
# Inverted Hit Data:  0b101110000001
# Doc ID [37] Num Hits[1]
# Inverted Hit Data:  0b10010100001
# Adding wordID[218] pos[1561]
# Doc ID [97] Num Hits[1]
# Inverted Hit Data:  0b110000100001
# Adding wordID[219] pos[1571]
# Doc ID [97] Num Hits[1]
# Inverted Hit Data:  0b110000100001
# Adding wordID[220] pos[1576]
# Doc ID [97] Num Hits[2]
# Inverted Hit Data:  0b110000100010
# Doc ID [108] Num Hits[1]
# Inverted Hit Data:  0b110110000001
# Adding wordID[221] pos[1581]
# Doc ID [97] Num Hits[1]
# Inverted Hit Data:  0b110000100001
# Adding wordID[222] pos[1592]
# Doc ID [97] Num Hits[1]
# Inverted Hit Data:  0b110000100001
# Adding wordID[223] pos[1597]
# Doc ID [97] Num Hits[1]
# Inverted Hit Data:  0b110000100001
# Adding wordID[224] pos[1602]
# Doc ID [97] Num Hits[1]
# Inverted Hit Data:  0b110000100001
# Doc ID [99] Num Hits[1]
# Inverted Hit Data:  0b110001100001
# Adding wordID[225] pos[1607]
# Doc ID [97] Num Hits[1]
# Inverted Hit Data:  0b110000100001
# Adding wordID[226] pos[1617]
# Doc ID [97] Num Hits[1]
# Inverted Hit Data:  0b110000100001
# Adding wordID[227] pos[1622]
# Doc ID [98] Num Hits[1]
# Inverted Hit Data:  0b110001000001
# Adding wordID[228] pos[1627]
# Doc ID [98] Num Hits[1]
# Inverted Hit Data:  0b110001000001
# Adding wordID[229] pos[1632]
# Doc ID [98] Num Hits[1]
# Inverted Hit Data:  0b110001000001
# Adding wordID[230] pos[1637]
# Doc ID [98] Num Hits[1]
# Inverted Hit Data:  0b110001000001
# Adding wordID[231] pos[1642]
# Doc ID [98] Num Hits[1]
# Inverted Hit Data:  0b110001000001
# Doc ID [99] Num Hits[1]
# Inverted Hit Data:  0b110001100001
# Adding wordID[232] pos[1647]
# Doc ID [98] Num Hits[1]
# Inverted Hit Data:  0b110001000001
# Adding wordID[233] pos[1657]
# Doc ID [98] Num Hits[1]
# Inverted Hit Data:  0b110001000001
# Adding wordID[234] pos[1662]
# Doc ID [98] Num Hits[1]
# Inverted Hit Data:  0b110001000001
# Adding wordID[235] pos[1667]
# Doc ID [98] Num Hits[1]
# Inverted Hit Data:  0b110001000001
# Adding wordID[236] pos[1672]
# Doc ID [99] Num Hits[1]
# Inverted Hit Data:  0b110001100001
# Adding wordID[237] pos[1677]
# Doc ID [99] Num Hits[1]
# Inverted Hit Data:  0b110001100001
# Doc ID [111] Num Hits[1]
# Inverted Hit Data:  0b110111100001
# Adding wordID[238] pos[1682]
# Doc ID [99] Num Hits[1]
# Inverted Hit Data:  0b110001100001
# Adding wordID[239] pos[1692]
# Doc ID [99] Num Hits[1]
# Inverted Hit Data:  0b110001100001
# Adding wordID[240] pos[1697]
# Doc ID [100] Num Hits[1]
# Inverted Hit Data:  0b110010000001
# Adding wordID[241] pos[1702]
# Doc ID [100] Num Hits[1]
# Inverted Hit Data:  0b110010000001
# Adding wordID[242] pos[1707]
# Doc ID [100] Num Hits[1]
# Inverted Hit Data:  0b110010000001
# Adding wordID[243] pos[1712]
# Doc ID [100] Num Hits[1]
# Inverted Hit Data:  0b110010000001
# Adding wordID[244] pos[1717]
# Doc ID [100] Num Hits[1]
# Inverted Hit Data:  0b110010000001
# Adding wordID[245] pos[1722]
# Doc ID [101] Num Hits[1]
# Inverted Hit Data:  0b110010100001
# Adding wordID[246] pos[1727]
# Doc ID [102] Num Hits[1]
# Inverted Hit Data:  0b110011000001
# Adding wordID[247] pos[1732]
# Doc ID [104] Num Hits[1]
# Inverted Hit Data:  0b110100000001
# Adding wordID[248] pos[1737]
# Doc ID [105] Num Hits[1]
# Inverted Hit Data:  0b110100100001
# Adding wordID[249] pos[1742]
# Doc ID [106] Num Hits[1]
# Inverted Hit Data:  0b110101000001
# Doc ID [112] Num Hits[1]
# Inverted Hit Data:  0b111000000001
# Adding wordID[250] pos[1747]
# Doc ID [106] Num Hits[1]
# Inverted Hit Data:  0b110101000001
# Adding wordID[251] pos[1757]
# Doc ID [107] Num Hits[1]
# Inverted Hit Data:  0b110101100001
# Adding wordID[252] pos[1762]
# Doc ID [108] Num Hits[1]
# Inverted Hit Data:  0b110110000001
# Adding wordID[253] pos[1767]
# Doc ID [108] Num Hits[1]
# Inverted Hit Data:  0b110110000001
# Adding wordID[254] pos[1772]
# Doc ID [108] Num Hits[1]
# Inverted Hit Data:  0b110110000001
# Adding wordID[255] pos[1777]
# Doc ID [108] Num Hits[1]
# Inverted Hit Data:  0b110110000001
# Adding wordID[256] pos[1782]
# Doc ID [108] Num Hits[1]
# Inverted Hit Data:  0b110110000001
# Adding wordID[257] pos[1787]
# Doc ID [109] Num Hits[1]
# Inverted Hit Data:  0b110110100001
# Adding wordID[258] pos[1792]
# Doc ID [109] Num Hits[1]
# Inverted Hit Data:  0b110110100001
# Adding wordID[259] pos[1797]
# Doc ID [110] Num Hits[1]
# Inverted Hit Data:  0b110111000001
# Adding wordID[260] pos[1802]
# Doc ID [111] Num Hits[1]
# Inverted Hit Data:  0b110111100001
# Adding wordID[261] pos[1807]
# Doc ID [111] Num Hits[1]
# Inverted Hit Data:  0b110111100001
# Adding wordID[262] pos[1812]
# Doc ID [112] Num Hits[1]
# Inverted Hit Data:  0b111000000001
# Adding wordID[263] pos[1817]
# Doc ID [113] Num Hits[1]
# Inverted Hit Data:  0b111000100001
# Adding wordID[264] pos[1822]
# Doc ID [113] Num Hits[1]
# Inverted Hit Data:  0b111000100001
# Adding wordID[265] pos[1827]
# Doc ID [114] Num Hits[1]
# Inverted Hit Data:  0b111001000001
# Adding wordID[266] pos[1832]
# Doc ID [114] Num Hits[1]
# Inverted Hit Data:  0b111001000001
# Adding wordID[267] pos[1837]

# %%
import searcher.Searcher as searcher

searcher.search('news')
# Out:
# Word Position: 86
# 0b100000000000000000000000000
# 0b1000000000000000000000
# NUM HITS: 0
# DOC ID: 2097152
