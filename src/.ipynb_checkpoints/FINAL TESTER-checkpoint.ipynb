# %%
import sys, os
import doc_index.Document_Index as docIndex

import struct

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

print docIndex.getID('http://stackoverflow.com/')
# Out:
# 0

# %%
status = 0#unparsed
repoPointer = 0
docchecksum = 0
docinfopointer, url_len = docIndex.setUrlInList('http://stackoverflow.com/')
title_len = 0
chunk = struct.pack('BIIIHH', status, repoPointer, docchecksum, docinfopointer, url_len, title_len)
docIndex.setDocIndex(0, chunk)

# %%
import crawlers.Crawlers as crawler

crawler.run(0)
# Out:
# 0

# %%
import indexer.Parser as parser

parser.run(0)
#lex.save() Do this if you need to
# Out:
# (//stackoverflow.com): current community
# (http://chat.stackoverflow.com): chat
# (https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent&amp;utm_source=stackoverflow.com&amp;utm_medium=dev-story&amp;utm_campaign=signup-redirect): Sign up
# (https://stackoverflow.com/users/login?ssrc=site_switcher&returnurl=http%3a%2f%2fstackoverflow.com%2f): log in
# (//stackexchange.com/sites): more stack exchange communities
# (http://stackoverflow.blog): company blog
# (https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent&utm_source=stackoverflow.com&utm_medium=dev-story&utm_campaign=signup-redirect): sign up
# (https://stackoverflow.com/users/login?ssrc=head&returnurl=http%3a%2f%2fstackoverflow.com%2f): log in
# (/tour): tour
# (#):  help
# (/tour):  Tour
# (/help):  Help Center
# (//meta.stackoverflow.com):  Meta
# (http://stackoverflow.com/company/about):  About Us
# (http://business.stackoverflow.com/?ref=topbar_help):  Business
# (/):  Stack Overflow
# (/questions):  Questions
# (/jobs?med=site-ui&ref=jobs-tab):  Jobs
# (/documentation):  Documentation
# (/tags):  Tags
# (/users):  Users
# (/help/badges):  Badges
# (/questions/ask): Ask Question
# (/users/story/join): Check out Developer Story
# (?tab=interesting):  interesting
# (?tab=hot):  hot
# (?tab=week):  week
# (?tab=month):  month
# (/questions/40867963/how-to-print-sorted-data-on-json-load): How to print sorted data on json load
# (/questions/tagged/python): python
# (/questions/tagged/json): json
# (/questions/tagged/sorting): sorting
# (/questions/40867963/how-to-print-sorted-data-on-json-load): asked
# (/users/7009113/tonemgub): tonemgub
# (/questions/40867959/how-to-install-a-program-from-github-only-using-terminal-linux): How to install a program from github only using terminal linux
# (/questions/tagged/selenium): selenium
# (/questions/tagged/firefox): firefox
# (/questions/tagged/geckodriver): geckodriver
# (/questions/40867959/how-to-install-a-program-from-github-only-using-terminal-linux): asked
# (/questions/40867956/readthedocs-is-there-a-way-to-autodoc-same-model-functions-separately-in-the-on): Readthedocs Is there a way to autodoc same model functions separately in the one file
# (/questions/tagged/python): python
# (/questions/tagged/sphinx): sphinx
# (/questions/tagged/restructuredtext): restructuredtext
# (/questions/tagged/read-the-docs): read the docs
# (/questions/40867956/readthedocs-is-there-a-way-to-autodoc-same-model-functions-separately-in-the-on): asked
# (/users/2677101/joab-mendes): Joab Mendes
# (/questions/40867955/do-i-need-to-call-require-method-each-time-i-create-new-combobox): Do I need to call require method each time I create new combobox
# (/questions/tagged/combobox): combobox
# (/questions/tagged/dojo): dojo
# (/questions/40867955/do-i-need-to-call-require-method-each-time-i-create-new-combobox): asked
# (/users/7119647/eniss): Eniss
# (/questions/40867954/prestashop-multistore-local-store-prices-are-overwritten-with-price-from-defau): Prestashop Multistore local store prices are overwritten with price from default shop
# (/questions/tagged/prestashop): prestashop
# (/questions/tagged/prestashop-1.6): prestashop 1 6
# (/questions/tagged/multistore): multistore
# (/questions/40867954/prestashop-multistore-local-store-prices-are-overwritten-with-price-from-defau): asked
# (/users/3656266/larsd): larsd
# (/questions/40867951/custom-tableviewcell): Custom tableViewCell
# (/questions/tagged/ios): ios
# (/questions/tagged/arrays): arrays
# (/questions/tagged/uitableview): uitableview
# (/questions/tagged/swift3): swift3
# (/questions/tagged/cell): cell
# (/questions/40867951/custom-tableviewcell): asked
# (/users/7135257/fatemeh): fatemeh
# (/questions/40864945/rails-is-confusing-params-after-adding-locale-to-the-url): Rails is confusing params after adding locale to the url
# (/questions/tagged/ruby-on-rails-4): ruby on rails 4
# (/questions/tagged/parameters): parameters
# (/questions/tagged/routes): routes
# (/questions/tagged/internationalization): internationalization
# (/questions/tagged/locale): locale
# (/questions/40864945/rails-is-confusing-params-after-adding-locale-to-the-url): modified
# (/users/3665315/syk): Syk
# (/questions/40867947/unauthorized-response-from-rest-call-to-crm-using-adal-js): Unauthorized response from Rest call to CRM using adal js
# (/questions/tagged/javascript): javascript
# (/questions/tagged/dynamics-crm): dynamics crm
# (/questions/tagged/single-page-application): single page application
# (/questions/tagged/adal): adal
# (/questions/tagged/adal.js): adal js
# (/questions/40867947/unauthorized-response-from-rest-call-to-crm-using-adal-js): asked
# (/users/7225815/dom): Dom
# (/questions/40867946/how-to-find-mt2002-offending-dll): How to find MT2002 Offending DLL
# (/questions/tagged/c%23): c
# (/questions/tagged/xamarin): xamarin
# (/questions/tagged/xamarin.ios): xamarin ios
# (/questions/tagged/vsts-build): vsts build
# (/questions/40867946/how-to-find-mt2002-offending-dll): asked
# (/users/4539/noah): Noah
# (/questions/40867944/how-to-find-the-size-of-a-document-in-icloud-before-picking-it-and-downloading-t): how to find the size of a document in iCloud before picking it and downloading to device using UIDocumentPickerViewController
# (/questions/tagged/ios): ios
# (/questions/tagged/icloud): icloud
# (/questions/tagged/uidocumentpickervc): uidocumentpickervc
# (/questions/40867944/how-to-find-the-size-of-a-document-in-icloud-before-picking-it-and-downloading-t): asked
# (/users/499174/sujith1406): sujith1406
# (/questions/40867879/excel-len-search-and-find-double-space-bug): Excel LEN SEARCH and FIND Double Space Bug
# (/questions/tagged/excel): excel
# (/questions/tagged/excel-2010): excel 2010
# (/questions/40867879/excel-len-search-and-find-double-space-bug): modified
# (/users/6613600/nullarbor): Nullarbor
# (/questions/40867943/what-is-the-recommended-approach-to-have-less-contrived-code-in-the-function-of): What is the recommended approach to have less contrived code in the function of my component that reacts on data changed from the store
# (/questions/tagged/reactjs): reactjs
# (/questions/tagged/flux): flux
# (/questions/tagged/reactjs-flux): reactjs flux
# (/questions/40867943/what-is-the-recommended-approach-to-have-less-contrived-code-in-the-function-of): asked
# (/users/215553/ibiza): ibiza
# (/questions/40867942/unity-does-not-inject-dependency-after-configuring-oauth): Unity does not inject dependency after configuring OAuth
# (/questions/tagged/c%23): c
# (/questions/tagged/oauth): oauth
# (/questions/tagged/dependency-injection): dependency injection
# (/questions/tagged/asp.net-web-api2): asp net web api2
# (/questions/tagged/unity-container): unity container
# (/questions/40867942/unity-does-not-inject-dependency-after-configuring-oauth): asked
# (/users/1505521/user1505521): user1505521
# (/questions/40867941/devise-subdomains-from-www-appname-com-admin-login-to-admin-appname-com-login): Devise subdomains from www appname com admin login to admin appname com login
# (/questions/tagged/ruby-on-rails): ruby on rails
# (/questions/tagged/devise): devise
# (/questions/tagged/routes): routes
# (/questions/40867941/devise-subdomains-from-www-appname-com-admin-login-to-admin-appname-com-login): asked
# (/users/1301037/user1301037): user1301037
# (/questions/40867723/swift-3-0-bool-to-int-issue): Swift 3 0 Bool to Int issue
# (/questions/tagged/ios): ios
# (/questions/tagged/swift): swift
# (/questions/tagged/swift3): swift3
# (/questions/40867723/swift-3-0-bool-to-int-issue/?lastactivity): answered
# (/users/3514372/artem-novichkov): Artem Novichkov
# (/questions/40867937/regex-looping-through-a-foreach-to-find-a-certain-pattern): Regex looping through a foreach to find a certain pattern
# (/questions/tagged/c%23): c
# (/questions/tagged/xml): xml
# (/questions/40867937/regex-looping-through-a-foreach-to-find-a-certain-pattern): asked
# (/users/5993382/craig-gallagher): Craig Gallagher
# (/questions/40867934/split-delimited-string-and-store-values-in-json-object-using-dataweave): Split delimited string and store values in JSON object using dataweave
# (/questions/tagged/json): json
# (/questions/tagged/mule): mule
# (/questions/tagged/datamapper): datamapper
# (/questions/tagged/anypoint-studio): anypoint studio
# (/questions/tagged/dataweave): dataweave
# (/questions/40867934/split-delimited-string-and-store-values-in-json-object-using-dataweave): asked
# (/users/3165854/user3165854): user3165854
# (/questions/40867862/mvc-display-text-after-post-and-keep-data-in-form): mvc display text after post and keep data in form
# (/questions/tagged/asp.net-mvc): asp net mvc
# (/questions/tagged/asp.net-mvc-partialview): asp net mvc partialview
# (/questions/40867862/mvc-display-text-after-post-and-keep-data-in-form): modified
# (/users/4141606/antoinedelia): antoinedelia
# (/questions/25300557/toast-notifications-in-asp-net-mvc-4): Toast notifications in ASP NET MVC 4
# (/questions/tagged/javascript): javascript
# (/questions/tagged/jquery): jquery
# (/questions/tagged/asp.net-mvc-4): asp net mvc 4
# (/questions/tagged/toastr): toastr
# (/questions/25300557/toast-notifications-in-asp-net-mvc-4/?lastactivity): answered
# (/users/4219451/fatih-b%c3%9clb%c3%9cl): Fatih B LB L
# (/questions/40867928/how-to-set-oracle-apex-application-language-as-bi-publisher-report-language): How to set Oracle APEX application language as BI publisher report language
# (/questions/tagged/oracle-apex): oracle apex
# (/questions/tagged/oracle-bi): oracle bi
# (/questions/40867928/how-to-set-oracle-apex-application-language-as-bi-publisher-report-language): asked
# (/users/4091311/amol): Amol
# (/questions/40864219/ssms-2008-sql-how-to-extract-specific-string-of-text): SSMS 2008 SQL how to extract specific string of text
# (/questions/tagged/sql): sql
# (/questions/tagged/ssms): ssms
# (/questions/40864219/ssms-2008-sql-how-to-extract-specific-string-of-text/?lastactivity): modified
# (/users/5085719/rdkells): RDKells
# (/questions/40862955/having-dns-probe-finished-domainnx-regularly-on-a-domain): Having dns probe finished domainnx regularly on a domain
# (/questions/tagged/heroku): heroku
# (/questions/tagged/dns): dns
# (/questions/tagged/ovh): ovh
# (/questions/40862955/having-dns-probe-finished-domainnx-regularly-on-a-domain): modified
# (/users/1717031/mathrobin): MathRobin
# (/questions/596481/simulate-javascript-key-events): Simulate JavaScript Key Events
# (/questions/tagged/javascript): javascript
# (/questions/tagged/javascript-events): javascript events
# (/questions/596481/simulate-javascript-key-events/?lastactivity): modified
# (/users/6290027/monami): monami
# (/questions/40867921/when-i-use-jekyll-template-if-page-title-category-first-get-fal): when i use jekyll template if page title category first get false
# (/questions/tagged/templates): templates
# (/questions/tagged/jekyll): jekyll
# (/questions/tagged/liquid): liquid
# (/questions/40867921/when-i-use-jekyll-template-if-page-title-category-first-get-fal): asked
# (/users/4910220/silence): silence
# (/questions/40867918/select-upload-history-from-oracle-table): Select upload history from Oracle table
# (/questions/tagged/oracle): oracle
# (/questions/tagged/plsql): plsql
# (/questions/tagged/dense-rank): dense rank
# (/questions/tagged/partition-by): partition by
# (/questions/40867918/select-upload-history-from-oracle-table): asked
# (/users/549903/robin-clave): Robin clave
# (/questions/40867917/how-to-sign-old-ios-version): How to sign old iOS version
# (/questions/tagged/ios): ios
# (/questions/tagged/iphone): iphone
# (/questions/tagged/testing): testing
# (/questions/tagged/ios-ipsw-file): ios ipsw file
# (/questions/40867917/how-to-sign-old-ios-version): asked
# (/users/382788/mm24): mm24
# (/questions/40867783/how-to-set-a-different-image-for-each-pin-xamarin-ios): How to set a different image for each pin Xamarin iOS
# (/questions/tagged/ios): ios
# (/questions/tagged/xamarin): xamarin
# (/questions/tagged/xamarin.ios): xamarin ios
# (/questions/40867783/how-to-set-a-different-image-for-each-pin-xamarin-ios): modified
# (/users/6484526/don): Don
# (/questions/40867914/salesforce-report-exports-as-html-workaround): Salesforce report exports as html workaround
# (/questions/tagged/salesforce): salesforce
# (/questions/tagged/html-xml-utils): html xml utils
# (/questions/40867914/salesforce-report-exports-as-html-workaround): asked
# (/users/7178871/adam-mcdermott): Adam McDermott
# (/questions/40867645/undefined-reference-to-symbol-sem-closeglibc-2-2-5): undefined reference to symbol sem close GLIBC 2 2 5
# (/questions/tagged/c%2b%2b): c
# (/questions/tagged/linux): linux
# (/questions/tagged/cmake): cmake
# (/questions/tagged/activemq): activemq
# (/questions/tagged/activemq-cpp): activemq cpp
# (/questions/40867645/undefined-reference-to-symbol-sem-closeglibc-2-2-5/?lastactivity): answered
# (/users/6533075/sch%c3%bctze): Sch tze
# (/questions/37471440/js-surroundcontents-only-retains-highlight-on-text-about-20-of-the-highlight): JS surroundContents only retains highlight on text about 20 of the highlight attempts
# (/questions/tagged/javascript): javascript
# (/questions/tagged/highlighting): highlighting
# (/questions/37471440/js-surroundcontents-only-retains-highlight-on-text-about-20-of-the-highlight/?lastactivity): answered
# (/users/1544886/k-scandrett): K Scandrett
# (/questions/40867515/excel-connect-to-mssql-returns-login-failed-for-user): Excel connect to MSSQL returns Login failed for user
# (/questions/tagged/sql-server): sql server
# (/questions/tagged/excel): excel
# (/questions/tagged/connection): connection
# (/questions/40867515/excel-connect-to-mssql-returns-login-failed-for-user): modified
# (/users/121260/eric-darchis): Eric Darchis
# (/questions/40867902/including-geofire-calls-in-a-firebase-transaction): Including GeoFire calls in a Firebase transaction
# (/questions/tagged/firebase-database): firebase database
# (/questions/tagged/geofire): geofire
# (/questions/40867902/including-geofire-calls-in-a-firebase-transaction): asked
# (/users/682778/crocodile): Crocodile
# (/questions/40867900/perl-extract-substring-to-a-character-with-count-zero-or-more): perl extract substring to a character with count zero or more
# (/questions/tagged/regex): regex
# (/questions/tagged/string): string
# (/questions/tagged/perl): perl
# (/questions/40867900/perl-extract-substring-to-a-character-with-count-zero-or-more): asked
# (/users/278910/ontherocks): ontherocks
# (/questions/40867897/how-do-i-ask-for-the-input-of-a-variable-when-needed-instead-of-typing-input-b): How do I ask for the input of a variable when needed instead of typing input before every line
# (/questions/tagged/python-3.x): python 3 x
# (/questions/40867897/how-do-i-ask-for-the-input-of-a-variable-when-needed-instead-of-typing-input-b): asked
# (/users/7164679/dave-matthew): Dave Matthew
# (/questions/40867894/using-javascript-to-loop-through-nodes-of-an-xml-feed): Using javascript to loop through Nodes of an XML Feed
# (/questions/tagged/javascript): javascript
# (/questions/tagged/xml): xml
# (/questions/tagged/xml-parsing): xml parsing
# (/questions/40867894/using-javascript-to-loop-through-nodes-of-an-xml-feed): asked
# (/users/1555453/tim-cadieux): Tim Cadieux
# (/questions/40867893/creating-a-custom-video-similar-to-facebook-birthday-videos-programmatically): Creating a custom video similar to Facebook birthday videos programmatically
# (/questions/tagged/javascript): javascript
# (/questions/tagged/java): java
# (/questions/tagged/video): video
# (/questions/tagged/webpage): webpage
# (/questions/40867893/creating-a-custom-video-similar-to-facebook-birthday-videos-programmatically): asked
# (/users/5621098/robin-abishek): robin abishek
# (/questions/40867892/different-menu-level-with-same-viewcontroller): different menu level with same viewcontroller
# (/questions/tagged/ios): ios
# (/questions/tagged/swift): swift
# (/questions/40867892/different-menu-level-with-same-viewcontroller): asked
# (/users/6267839/chris): Chris
# (/questions/40867889/sapui5-multiple-vizframes-in-view): SAPUI5 multiple VizFrames in View
# (/questions/tagged/javascript): javascript
# (/questions/tagged/sapui5): sapui5
# (/questions/tagged/openui5): openui5
# (/questions/40867889/sapui5-multiple-vizframes-in-view): asked
# (/users/1191056/alexander-fuchs): Alexander Fuchs
# (/questions/40867885/jsonschema2pojo-make-private-classes-from-definitions): jsonschema2pojo make private classes from definitions
# (/questions/tagged/java): java
# (/questions/tagged/jsonschema): jsonschema
# (/questions/tagged/jsonschema2pojo): jsonschema2pojo
# (/questions/40867885/jsonschema2pojo-make-private-classes-from-definitions): asked
# (/users/3392595/forepick): Forepick
# (/questions/40865592/lapply-function-in-r): lapply function in R
# (/questions/tagged/r): r
# (/questions/tagged/for-loop): for loop
# (/questions/tagged/lapply): lapply
# (/questions/40865592/lapply-function-in-r): modified
# (/users/6019081/neha-sharma): Neha Sharma
# (/questions/40867878/loading-routers-paths-from-external-files): Loading router s paths from external files
# (/questions/tagged/angular2): angular2
# (/questions/tagged/angular2-routing): angular2 routing
# (/questions/40867878/loading-routers-paths-from-external-files): asked
# (/users/2203299/tom): Tom
# (/questions/40867875/account-kit-with-ionic-v-1-3): Account kit with ionic v 1 3
# (/questions/tagged/angularjs): angularjs
# (/questions/tagged/ionic-framework): ionic framework
# (/questions/tagged/angularfire): angularfire
# (/questions/tagged/account-kit): account kit
# (/questions/40867875/account-kit-with-ionic-v-1-3): asked
# (/users/6260343/thelastone): thelastone
# (/questions/40867874/how-can-i-obtain-a-domain-driven-design-architecture-using-spring-data-jpa): How can I obtain a DOMAIN DRIVEN DESIGN architecture using Spring Data JPA
# (/questions/tagged/java): java
# (/questions/tagged/spring): spring
# (/questions/tagged/spring-data): spring data
# (/questions/tagged/domain-driven-design): domain driven design
# (/questions/tagged/spring-data-jpa): spring data jpa
# (/questions/40867874/how-can-i-obtain-a-domain-driven-design-architecture-using-spring-data-jpa): asked
# (/users/1833945/andreanobili): AndreaNobili
# (/questions/40867873/how-to-prompt-byte-input-and-search-a-file-for-that-byte): How to prompt byte input and search a file for that byte
# (/questions/tagged/python-3.x): python 3 x
# (/questions/tagged/byte): byte
# (/questions/40867873/how-to-prompt-byte-input-and-search-a-file-for-that-byte): asked
# (/users/7223182/df86): df86
# (/questions/40867872/variable-holds-two-values): Variable holds two values
# (/questions/tagged/function): function
# (/questions/tagged/python-3.x): python 3 x
# (/questions/tagged/global-variables): global variables
# (/questions/40867872/variable-holds-two-values): asked
# (/users/6570334/unknownzdx): Unknownzdx
# (/questions/40867867/how-search-filter-in-pingfederate-pcv-works): How search filter in pingfederate PCV works
# (/questions/tagged/pingfederate): pingfederate
# (/questions/40867867/how-search-filter-in-pingfederate-pcv-works): asked
# (/users/7225822/newbie): Newbie
# (/questions/40867563/how-to-process-javascript-from-xmlhttprequest-donwnloaded-file): How to process javascript from XMLHttpRequest donwnloaded file
# (/questions/tagged/javascript): javascript
# (/questions/40867563/how-to-process-javascript-from-xmlhttprequest-donwnloaded-file): modified
# (/users/1687746/saurav-rastogi): Saurav Rastogi
# (/questions/40867866/unable-to-load-stylesheets): Unable to load stylesheets
# (/questions/tagged/css): css
# (/questions/tagged/wordpress): wordpress
# (/questions/40867866/unable-to-load-stylesheets): asked
# (/users/5484596/re-sole): RE SOLE
# (/questions/40867856/javascript-hide-autocomplete-div-onblur): Javascript hide autocomplete div onBlur
# (/questions/tagged/javascript): javascript
# (/questions/tagged/autocomplete): autocomplete
# (/questions/40867856/javascript-hide-autocomplete-div-onblur): asked
# (/users/7225747/dave): Dave
# (/questions/40867854/how-to-set-variable-in-high-chart-data-field): How to set variable in high chart data field
# (/questions/tagged/javascript): javascript
# (/questions/tagged/java): java
# (/questions/tagged/spring): spring
# (/questions/tagged/highcharts): highcharts
# (/questions/40867854/how-to-set-variable-in-high-chart-data-field): asked
# (/users/3942180/arpita): Arpita
# (/questions/40867138/binding-combobox-data-to-listview-data-in-wpf): Binding ComboBox data to ListView Data in wpf
# (/questions/tagged/c%23): c
# (/questions/tagged/wpf): wpf
# (/questions/tagged/wpf-controls): wpf controls
# (/questions/tagged/wpfdatagrid): wpfdatagrid
# (/questions/tagged/excel-addins): excel addins
# (/questions/40867138/binding-combobox-data-to-listview-data-in-wpf/?lastactivity): answered
# (/users/161885/muhammad-ummar): Muhammad Ummar
# (/questions/40861298/how-to-optimize-g1s-pause-time): How to Optimize G1 s Pause Time
# (/questions/tagged/java): java
# (/questions/tagged/garbage-collection): garbage collection
# (/questions/tagged/g1): g1
# (/questions/40861298/how-to-optimize-g1s-pause-time/?lastactivity): modified
# (/users/2555321/marcs): Marcs
# (/questions/32467212/google-maps-marker-label-with-multiple-characters): Google maps Marker Label with multiple characters
# (/questions/32467212/google-maps-marker-label-with-multiple-characters/?lastactivity): answered
# (/users/2046706/apostolis): Apostolis
# (/questions/40867052/how-to-get-same-properties-from-different-parent-modules-in-maven): How to get same properties from different parent modules in maven
# (/questions/tagged/java): java
# (/questions/tagged/maven): maven
# (/questions/40867052/how-to-get-same-properties-from-different-parent-modules-in-maven/?lastactivity): answered
# (/users/270371/davidxxx): davidxxx
# (/questions/40867834/where-to-find-my-ocp-apim-subscription-key-in-windows-azure): Where to find my Ocp Apim Subscription Key in Windows azure
# (/questions/tagged/api): api
# (/questions/40867834/where-to-find-my-ocp-apim-subscription-key-in-windows-azure): asked
# (/users/7022048/yj-yang): YJ Yang
# (/questions/40218828/testing-that-a-component-behaves-properly-when-the-service-it-calls-throws-an-ex): Testing that a component behaves properly when the service it calls throws an exception with Angular 2
# (/questions/tagged/unit-testing): unit testing
# (/questions/tagged/testing): testing
# (/questions/tagged/angular2): angular2
# (/questions/tagged/typescript): typescript
# (/questions/tagged/jasmine): jasmine
# (/questions/40218828/testing-that-a-component-behaves-properly-when-the-service-it-calls-throws-an-ex/?lastactivity): modified
# (/users/100822/sebastien): Sebastien
# (/questions/40865553/set-azurermvmaddomainextension-fails-to-add-vm-to-ad-domain): Set AzureRmVMADDomainExtension fails to add VM to AD Domain
# (/questions/tagged/json): json
# (/questions/40865553/set-azurermvmaddomainextension-fails-to-add-vm-to-ad-domain/?lastactivity): answered
# (/users/6498115/jenson-joseph): Jenson Joseph
# (/questions/40867231/strange-behavior-of-css-margins): Strange behavior of css margins
# (/questions/tagged/html): html
# (/questions/tagged/css): css
# (/questions/tagged/css3): css3
# (/questions/tagged/margin): margin
# (/questions/40867231/strange-behavior-of-css-margins/?lastactivity): answered
# (/users/7069532/ashish-m): Ashish M
# (/questions/40867804/how-can-i-get-the-url-of-a-thread-using-from-my-bot): How can I get the url of a thread using from my bot
# (/questions/tagged/facebook): facebook
# (/questions/tagged/facebook-messenger-bot): facebook messenger bot
# (/questions/40867804/how-can-i-get-the-url-of-a-thread-using-from-my-bot): asked
# (/users/2380470/alexis): Alexis
# (/questions/40867639/relation-between-entities-in-ddd): Relation between entities in DDD
# (/questions/tagged/php): php
# (/questions/tagged/domain-driven-design): domain driven design
# (/questions/40867639/relation-between-entities-in-ddd): modified
# (/users/65732/sepehr): sepehr
# (/questions/40867497/xpath-for-parent-element-with-certain-descendant-element-regardless-of-depth): XPath for parent element with certain descendant element regardless of depth
# (/questions/tagged/xml): xml
# (/questions/tagged/xpath): xpath
# (/questions/40867497/xpath-for-parent-element-with-certain-descendant-element-regardless-of-depth/?lastactivity): modified
# (/users/290085/kjhughes): kjhughes
# (/questions/40867792/zope-schema-list-save-list-of-lists): zope schema List Save List of lists
# (/questions/tagged/plone): plone
# (/questions/tagged/zope): zope
# (/questions/40867792/zope-schema-list-save-list-of-lists): asked
# (/users/966660/user966660): user966660
# (/questions/40867612/office-js-outlook-saving-a-unsaved-appointment-using-saveasync): Office js Outlook saving a unsaved appointment using saveAsync
# (/questions/tagged/outlook): outlook
# (/questions/tagged/ms-office): ms office
# (/questions/tagged/outlook-addin): outlook addin
# (/questions/tagged/office-js): office js
# (/questions/tagged/outlook-web-app): outlook web app
# (/questions/40867612/office-js-outlook-saving-a-unsaved-appointment-using-saveasync): modified
# (/users/4316374/alek-kowalczyk): alek kowalczyk
# (/questions/40867778/possible-to-get-the-message-body-with-lambda): Possible to get the message body with lambda
# (/questions/tagged/amazon-web-services): amazon web services
# (/questions/tagged/amazon-s3): amazon s3
# (/questions/tagged/aws-lambda): aws lambda
# (/questions/tagged/ses): ses
# (/questions/40867778/possible-to-get-the-message-body-with-lambda): asked
# (/users/1590345/maddo7): maddo7
# (/questions/40867772/rename-windows-cluster-registered-in-dns): rename windows cluster registered in DNS
# (/questions/tagged/dns): dns
# (/questions/tagged/cluster-computing): cluster computing
# (/questions/tagged/sybase): sybase
# (/questions/40867772/rename-windows-cluster-registered-in-dns): asked
# (/users/6011743/scass): scass
# (/questions/40867762/kentico-upload-attachment-permissions): Kentico upload attachment permissions
# (/questions/tagged/kentico): kentico
# (/questions/40867762/kentico-upload-attachment-permissions): asked
# (/users/935731/mark-handy): Mark Handy
# (/questions/40867749/varnish-wont-start-as-a-daemon): Varnish won t start as a daemon
# (/questions/tagged/ubuntu): ubuntu
# (/questions/tagged/varnish): varnish
# (/questions/40867749/varnish-wont-start-as-a-daemon): asked
# (/users/3170702/user3170702): user3170702
# (/questions/40867740/is-there-support-for-country-select-gem-in-rails-5): Is there support for country select gem in Rails 5
# (/questions/tagged/ruby-on-rails-5): ruby on rails 5
# (/questions/40867740/is-there-support-for-country-select-gem-in-rails-5): asked
# (/users/2112025/breen-ho): Breen ho
# (/questions/40867736/kryo-serialisation-in-chronicle-map-slow-byte-reading): Kryo serialisation in Chronicle Map slow byte reading
# (/questions/tagged/scala): scala
# (/questions/tagged/kryo): kryo
# (/questions/tagged/chronicle-map): chronicle map
# (/questions/40867736/kryo-serialisation-in-chronicle-map-slow-byte-reading): asked
# (/users/61876/anton): Anton
# (/questions/40861407/check-if-user-is-in-a-forest-using-location): Check if user is in a forest using location
# (/questions/40861407/check-if-user-is-in-a-forest-using-location/?lastactivity): answered
# (/users/916670/ynot): ynot
# (/questions/40867608/sroll-on-hover-and-text-leaping): Sroll on hover and text leaping
# (/questions/tagged/javascript): javascript
# (/questions/tagged/css): css
# (/questions/tagged/html5): html5
# (/questions/tagged/css3): css3
# (/questions/tagged/scrollbar): scrollbar
# (/questions/40867608/sroll-on-hover-and-text-leaping): modified
# (/users/4727602/whitcik): Whitcik
# (/questions/40867193/sql-rollup-with-alias): SQL Rollup with alias
# (/questions/tagged/sql): sql
# (/questions/tagged/postgresql): postgresql
# (/questions/40867193/sql-rollup-with-alias): modified
# (/users/6638204/user6638204): user6638204
# (/questions/40867662/android-launch-my-app-when-dialing-a-number): Android Launch my app when dialing a number
# (/questions/tagged/java): java
# (/questions/40867662/android-launch-my-app-when-dialing-a-number): modified
# (/users/6343685/ironman): Ironman
# (/questions/40867687/how-to-refresh-android-listview-after-syncadapter-completes-a-sync): How to refresh Android ListView after SyncAdapter completes a Sync
# (/questions/tagged/listview): listview
# (/questions/tagged/synchronization): synchronization
# (/questions/40867687/how-to-refresh-android-listview-after-syncadapter-completes-a-sync): asked
# (/users/1131949/captain-kenpachi): Captain Kenpachi
# (/questions/40867672/cup-parser-returns-syntax-error-for-a-valid-input): CUP parser returns syntax error for a valid input
# (/questions/tagged/java): java
# (/questions/tagged/parsing): parsing
# (/questions/tagged/compilation): compilation
# (/questions/tagged/jflex): jflex
# (/questions/tagged/cup): cup
# (/questions/40867672/cup-parser-returns-syntax-error-for-a-valid-input): asked
# (/users/7225757/plex): Plex
# (/questions/40865816/missing-gridlines-using-nvd3-ng2): Missing gridlines using nvd3 ng2
# (/questions/tagged/javascript): javascript
# (/questions/tagged/angular2): angular2
# (/questions/tagged/nvd3.js): nvd3 js
# (/questions/tagged/gridlines): gridlines
# (/questions/tagged/ng2-nvd3): ng2 nvd3
# (/questions/40865816/missing-gridlines-using-nvd3-ng2): modified
# (/users/7225361/ekuusi): ekuusi
# (/questions/40867490/magento2-argument-1-must-be-an-instance-of-magento-framework-app-helper-c): Magento2 Argument 1 must be an instance of Magento Framework App Helper Context
# (/questions/tagged/magento): magento
# (/questions/tagged/magento2): magento2
# (/questions/40867490/magento2-argument-1-must-be-an-instance-of-magento-framework-app-helper-c): asked
# (/users/7225265/paul-davies): Paul Davies
# (/questions/40866355/drawing-a-perpendicular-bisector-of-two-points-in-gnuplot): drawing a perpendicular bisector of two points in gnuplot
# (/questions/tagged/graph): graph
# (/questions/tagged/gnuplot): gnuplot
# (/questions/tagged/draw): draw
# (/questions/tagged/bisection): bisection
# (/questions/40866355/drawing-a-perpendicular-bisector-of-two-points-in-gnuplot): modified
# (/users/7064921/user7064921): user7064921
# (/questions/40867180/show-caption-on-chart-js): Show caption on chart js
# (/questions/tagged/chart.js): chart js
# (/questions/40867180/show-caption-on-chart-js): modified
# (/users/2311633/jonnus): Jonnus
# (/questions/40689454/final-adjustment-needed-for-collapsible-menu-jquery): Final adjustment needed for collapsible menu jquery
# (/questions/tagged/javascript): javascript
# (/questions/tagged/jquery): jquery
# (/questions/tagged/css): css
# (/questions/tagged/menu): menu
# (/questions/40689454/final-adjustment-needed-for-collapsible-menu-jquery/?lastactivity): answered
# (/users/1544886/k-scandrett): K Scandrett
# (/questions/40867256/webpack-exposing-global-variable-without-using-provideplugin-and-expose-loader): Webpack Exposing global variable without using ProvidePlugin and expose loader
# (/questions/tagged/javascript): javascript
# (/questions/tagged/webpack): webpack
# (/questions/40867256/webpack-exposing-global-variable-without-using-provideplugin-and-expose-loader): modified
# (/users/20788/mike-post): Mike Post
# (/questions/40867407/android-espresso-multidex-fail): Android Espresso multidex fail
# (/questions/tagged/android-espresso): android espresso
# (/questions/tagged/android-multidex): android multidex
# (/questions/40867407/android-espresso-multidex-fail): asked
# (/users/1571080/originx): originx
# (/questions/40867239/object-detection-algorithms-in-opencv): Object detection algorithms in opencv
# (/questions/tagged/image-processing): image processing
# (/questions/tagged/opencv3.0): opencv3 0
# (/questions/tagged/object-detection): object detection
# (/questions/40867239/object-detection-algorithms-in-opencv): modified
# (/users/4857206/george-katsikopoulos): George Katsikopoulos
# (/questions/40867192/auto-fill-jaxb-class-sample-request): Auto Fill JAXB Class Sample Request
# (/questions/tagged/java): java
# (/questions/tagged/web-services): web services
# (/questions/tagged/jaxb): jaxb
# (/questions/40867192/auto-fill-jaxb-class-sample-request): asked
# (/users/5655414/angryip): angryip
# (/questions/40866403/sqoop-1-99-3-export-into-mysql-returns-empty-tables): Sqoop 1 99 3 export into MySQL returns empty tables
# (/questions/tagged/mysql): mysql
# (/questions/tagged/datetime): datetime
# (/questions/tagged/export): export
# (/questions/tagged/hdfs): hdfs
# (/questions/tagged/sqoop): sqoop
# (/questions/40866403/sqoop-1-99-3-export-into-mysql-returns-empty-tables): modified
# (/users/7094932/lejla-d%c5%beanko): Lejla Danko
# (/questions/40866894/constraintlayout-margins-not-working): ConstraintLayout margins not working
# (/questions/tagged/android-xml): android xml
# (/questions/tagged/android-constraintlayout): android constraintlayout
# (/questions/tagged/constraint-layout): constraint layout
# (/questions/40866894/constraintlayout-margins-not-working): modified
# (/users/4512395/ognian-gloushkov): Ognian Gloushkov
# (/questions/40867156/android-background-service-for-location-is-not-working-in-other-phones): Android background service for location is not working in other phones
# (/questions/tagged/service): service
# (/questions/tagged/location): location
# (/questions/tagged/android-pendingintent): android pendingintent
# (/questions/tagged/android-gps): android gps
# (/questions/40867156/android-background-service-for-location-is-not-working-in-other-phones): asked
# (/users/7223593/sanjay-joshi): Sanjay Joshi
# (/questions/40867135/unsound-implicit-cast-warning-not-shown-for-generic-parameter): Unsound implicit cast warning not shown for generic parameter
# (/questions/tagged/static-analysis): static analysis
# (/questions/40867135/unsound-implicit-cast-warning-not-shown-for-generic-parameter): asked
# (/users/5521491/alexey-adamovskiy): Alexey Adamovskiy
# (/questions/40867016/scala-inline-unapply-extractor): Scala inline unapply extractor
# (/questions/tagged/scala): scala
# (/questions/tagged/inline): inline
# (/questions/tagged/extractor): extractor
# (/questions/40867016/scala-inline-unapply-extractor): asked
# (/users/1287856/mika%c3%abl-mayer): Mika l Mayer
# (/questions/40867007/php-handshake-fail-tls1-0): PHP handshake fail TLS1 0
# (/questions/tagged/php): php
# (/questions/tagged/ssl): ssl
# (/questions/tagged/openssl): openssl
# (/questions/40867007/php-handshake-fail-tls1-0): asked
# (/users/1903575/cronos): Cronos
# (/questions/40867004/selecting-all-rows-in-datagridview-and-export-it-to-crystalreport): Selecting All rows in datagridview and export it to crystalreport
# (/questions/tagged/vb.net): vb net
# (/questions/tagged/datagridview): datagridview
# (/questions/tagged/datarow): datarow
# (/questions/40867004/selecting-all-rows-in-datagridview-and-export-it-to-crystalreport): asked
# (/users/7225638/george-uy): George Uy
# (/questions/40866606/debugging-in-visual-studio-without-pdb-files-c-access-voilation): Debugging in Visual Studio without Pdb files C Access Voilation
# (/questions/tagged/c%2b%2b): c
# (/questions/tagged/opencv): opencv
# (/questions/tagged/exception-handling): exception handling
# (/questions/tagged/ffmpeg): ffmpeg
# (/questions/tagged/access-violation): access violation
# (/questions/40866606/debugging-in-visual-studio-without-pdb-files-c-access-voilation): modified
# (/users/4359558/prakash-m): Prakash M
# (/questions/40866787/making-servers-in-f): Making servers in F
# (/questions/tagged/.net):  net
# (/questions/tagged/f%23): f
# (/questions/tagged/microservices): microservices
# (/questions/40866787/making-servers-in-f): asked
# (/users/78640/giantsquid): GiantSquid
# (/questions/40866105/pouchdb-replication-throws-error-upon-replication): PouchDB Replication throws error upon replication
# (/questions/tagged/couchdb): couchdb
# (/questions/tagged/ubuntu-14.04): ubuntu 14 04
# (/questions/tagged/pouchdb): pouchdb
# (/questions/40866105/pouchdb-replication-throws-error-upon-replication): modified
# (/users/5730444/phonolog): Phonolog
# (/questions/40866244/objetctanimator-with-array-variable): ObjetctAnimator with array variable
# (/questions/tagged/animation): animation
# (/questions/tagged/objectanimator): objectanimator
# (/questions/40866244/objetctanimator-with-array-variable): modified
# (/users/1281081/asfk): AsfK
# (/questions/40865391/how-to-show-text-yes-no-inside-a-switch-in-react-native): How to show text YES NO inside a switch in react native
# (/questions/tagged/react-native): react native
# (/questions/40865391/how-to-show-text-yes-no-inside-a-switch-in-react-native): modified
# (/users/1090798/krish): Krish
# (/questions): complete list of questions
# (/tags): popular tags
# (/unanswered): unanswered questions
# (//stackexchange.com/questions?tab=hot):  Hot Network Questions
# (http://mathematica.stackexchange.com/questions/132323/how-to-effiectively-substitute-the-member-in-list-with-their-order):  How to effiectively substitute the member in list with their order
# (http://photo.stackexchange.com/questions/84861/why-is-this-child-portrait-not-compelling-what-went-wrong-and-what-could-have-b):  Why is this child portrait not compelling What went wrong and what could have been done better
# (http://worldbuilding.stackexchange.com/questions/62572/truth-stone-effects-on-the-justice-system-and-criminal-world):  Truth Stone Effects on the justice system and criminal world
# (http://academia.stackexchange.com/questions/80652/discussion-turned-into-argument-with-the-conference-keynote-speaker-feeling-bad):  Discussion turned into argument with the conference keynote speaker feeling bad
# (http://codegolf.stackexchange.com/questions/101469/grid-ascii-art-code-golf):  Grid ascii art code golf
# (http://worldbuilding.stackexchange.com/questions/62533/military-tank-drone-why-are-they-not-common-yet):  Military Tank drone why are they not common yet
# (http://tex.stackexchange.com/questions/341451/the-text-is-pushed-down-when-there-is-a-picture-in-the-other-column):  The text is pushed down when there is a picture in the other column
# (http://academia.stackexchange.com/questions/80643/unintentionally-disrespectful-in-the-statement-of-purpose-academic-essay):  Unintentionally disrespectful in the Statement of Purpose Academic essay
# (http://english.stackexchange.com/questions/360721/is-soul-to-soul-talk-a-common-expression-in-english):  Is soul to soul talk a common expression in English
# (http://physics.stackexchange.com/questions/294966/what-does-antimatter-look-like):  What does antimatter look like
# (http://puzzling.stackexchange.com/questions/46210/what-was-the-child-sent-to-buy):  What was the child sent to buy
# (http://stackoverflow.com/questions/40848551/how-does-adding-string-with-integer-work-in-javascript):  How does adding String with Integer work in JavaScript
# (http://mathoverflow.net/questions/255820/how-should-a-working-mathematician-think-about-sets-zfc-category-theory-ur):  How should a working mathematician think about sets ZFC category theory urelements
# (http://academia.stackexchange.com/questions/80561/how-to-professionally-handle-sexist-remarks-by-a-student):  How to professionally handle sexist remarks by a student
# (http://travel.stackexchange.com/questions/83389/how-are-different-meal-ratios-calculated-for-flights):  How are different meal ratios calculated for flights
# (http://sqa.stackexchange.com/questions/23932/do-we-use-need-test-cases-in-agile):  Do we use need test cases in Agile
# (http://scifi.stackexchange.com/questions/146136/why-no-medievalworld-or-romanworld):  Why no Medievalworld or Romanworld
# (http://mathematica.stackexchange.com/questions/132332/simple-rule-does-not-work):  Simple rule does not work
# (http://stackoverflow.com/questions/40861062/text-with-multiple-underlines):  Text with multiple underlines
# (http://mathoverflow.net/questions/255896/derivative-is-zero-on-a-dense-g-delta-set):  Derivative is Zero on a dense G delta set
# (http://codegolf.stackexchange.com/questions/101275/figure-and-ground):  Figure and Ground
# (http://superuser.com/questions/1150860/what-the-np-reading-means-for-a-dvi-computer-monitor):  What the NP reading means for a DVI computer monitor
# (http://scifi.stackexchange.com/questions/146011/why-does-prof-farnsworth-run-planet-express):  Why does Prof Farnsworth run Planet Express
# (http://puzzling.stackexchange.com/questions/46208/a-smart-girl):  A Smart Girl
# (#):  more hot questions
# (http://stackoverflow.com/company/about): about us
# (/tour): tour
# (/help): help
# (http://stackoverflow.blog?blb=1): blog
# (http://chat.stackoverflow.com): chat
# (http://data.stackexchange.com): data
# (http://stackexchange.com/legal): legal
# (http://stackexchange.com/legal/privacy-policy): privacy policy
# (http://stackoverflow.com/company/work-here): work here
# (http://stackexchange.com/mediakit): advertising info
# (None): mobile
# (/contact): contact us
# (http://meta.stackoverflow.com): feedback
# (//stackoverflow.com): Stack Overflow
# (//serverfault.com): Server Fault
# (//superuser.com): Super User
# (//webapps.stackexchange.com): Web Applications
# (//askubuntu.com): Ask Ubuntu
# (//webmasters.stackexchange.com): Webmasters
# (//gamedev.stackexchange.com): Game Development
# (//tex.stackexchange.com): TeX LaTeX
# (//softwareengineering.stackexchange.com): Software Engineering
# (//unix.stackexchange.com): Unix Linux
# (//apple.stackexchange.com): Ask Different Apple
# (//wordpress.stackexchange.com): WordPress Development
# (//gis.stackexchange.com): Geographic Information Systems
# (//electronics.stackexchange.com): Electrical Engineering
# (//android.stackexchange.com): Android Enthusiasts
# (//security.stackexchange.com): Information Security
# (//dba.stackexchange.com): Database Administrators
# (//drupal.stackexchange.com): Drupal Answers
# (//sharepoint.stackexchange.com): SharePoint
# (//ux.stackexchange.com): User Experience
# (//mathematica.stackexchange.com): Mathematica
# (//salesforce.stackexchange.com): Salesforce
# (//expressionengine.stackexchange.com): ExpressionEngine Answers
# (//crypto.stackexchange.com): Cryptography
# (//codereview.stackexchange.com): Code Review
# (//magento.stackexchange.com): Magento
# (//dsp.stackexchange.com): Signal Processing
# (//raspberrypi.stackexchange.com): Raspberry Pi
# (//codegolf.stackexchange.com): Programming Puzzles Code Golf
# (http://stackexchange.com/sites#technology):  more 7
# (//photo.stackexchange.com): Photography
# (//scifi.stackexchange.com): Science Fiction Fantasy
# (//graphicdesign.stackexchange.com): Graphic Design
# (//movies.stackexchange.com): Movies TV
# (//music.stackexchange.com): Music Practice Theory
# (//cooking.stackexchange.com): Seasoned Advice cooking
# (//diy.stackexchange.com): Home Improvement
# (//money.stackexchange.com): Personal Finance Money
# (//academia.stackexchange.com): Academia
# (http://stackexchange.com/sites#lifearts):  more 8
# (//english.stackexchange.com): English Language Usage
# (//skeptics.stackexchange.com): Skeptics
# (//judaism.stackexchange.com): Mi Yodeya Judaism
# (//travel.stackexchange.com): Travel
# (//christianity.stackexchange.com): Christianity
# (//ell.stackexchange.com): English Language Learners
# (//japanese.stackexchange.com): Japanese Language
# (//gaming.stackexchange.com): Arqade gaming
# (//bicycles.stackexchange.com): Bicycles
# (//rpg.stackexchange.com): Role playing Games
# (//anime.stackexchange.com): Anime Manga
# (//mechanics.stackexchange.com): Motor Vehicle Maintenance Repair
# (http://stackexchange.com/sites#culturerecreation):  more 17
# (//mathoverflow.net): MathOverflow
# (//math.stackexchange.com): Mathematics
# (//stats.stackexchange.com): Cross Validated stats
# (//cstheory.stackexchange.com): Theoretical Computer Science
# (//physics.stackexchange.com): Physics
# (//chemistry.stackexchange.com): Chemistry
# (//biology.stackexchange.com): Biology
# (//cs.stackexchange.com): Computer Science
# (//philosophy.stackexchange.com): Philosophy
# (http://stackexchange.com/sites#science):  more 3
# (//meta.stackexchange.com): Meta Stack Exchange
# (//stackapps.com): Stack Apps
# (//area51.stackexchange.com): Area 51
# (//talent.stackoverflow.com): Stack Overflow Talent
# (https://creativecommons.org/licenses/by-sa/3.0/): cc by sa 3 0
# (http://blog.stackoverflow.com/2009/06/attribution-required/): attribution required
# �
# �
# {'overflow': '\x01\xf1', 'stack': '\x00\xf1'}

# %%
import URLResolver.URLResolver as urlresolver
urlresolver.run()
# Out:
# url:  //stackoverflow.com
# url:  http://chat.stackoverflow.com
# Making docIndex: [1] http://chat.stackoverflow.com
# putting chat for docID 1 in forward index
# �r
# LEN HITS: 1
# url:  https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent&amp;utm_source=stackoverflow.com&amp;utm_medium=dev-story&amp;utm_campaign=signup-redirect
# Making docIndex: [2] https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent&amp;utm_source=stackoverflow.com&amp;utm_medium=dev-story&amp;utm_campaign=signup-redirect
# putting Sign up for docID 2 in forward index
# �r
# ��
# LEN HITS: 2
# url:  https://stackoverflow.com/users/login?ssrc=site_switcher&returnurl=http%3a%2f%2fstackoverflow.com%2f
# Making docIndex: [3] https://stackoverflow.com/users/login?ssrc=site_switcher&returnurl=http%3a%2f%2fstackoverflow.com%2f
# putting log in for docID 3 in forward index
# �r
# �r
# LEN HITS: 2
# url:  //stackexchange.com/sites
# url:  http://stackoverflow.blog
# Making docIndex: [4] http://stackoverflow.blog
# putting company blog for docID 4 in forward index
# �r
# �r
# LEN HITS: 2
# url:  https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent&utm_source=stackoverflow.com&utm_medium=dev-story&utm_campaign=signup-redirect
# Making docIndex: [5] https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent&utm_source=stackoverflow.com&utm_medium=dev-story&utm_campaign=signup-redirect
# putting sign up for docID 5 in forward index
# �r
# �r
# LEN HITS: 2
# url:  https://stackoverflow.com/users/login?ssrc=head&returnurl=http%3a%2f%2fstackoverflow.com%2f
# Making docIndex: [6] https://stackoverflow.com/users/login?ssrc=head&returnurl=http%3a%2f%2fstackoverflow.com%2f
# putting log in for docID 6 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/tour
# Making docIndex: [7] http://stackoverflow.com/tour
# putting tour for docID 7 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/
# putting  help  for docID 0 in forward index
# @�B�
# Ar
# LEN HITS: 2
# url:  http://stackoverflow.com/tour
# putting  Tour  for docID 7 in forward index
# ����
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/help
# Making docIndex: [8] http://stackoverflow.com/help
# putting  Help Center  for docID 8 in forward index
# P�S�
# Q�
# R�
# LEN HITS: 3
# url:  //meta.stackoverflow.com
# url:  http://stackoverflow.com/company/about
# Making docIndex: [9] http://stackoverflow.com/company/about
# putting  About Us  for docID 9 in forward index
# ����
# ��
# ��
# LEN HITS: 3
# url:  http://business.stackoverflow.com/?ref=topbar_help
# Making docIndex: [10] http://business.stackoverflow.com/?ref=topbar_help
# putting  Business  for docID 10 in forward index
# ���
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/
# putting  Stack Overflow  for docID 0 in forward index
# @�C�
# B�
# A�
# LEN HITS: 3
# url:  http://stackoverflow.com/questions
# Making docIndex: [11] http://stackoverflow.com/questions
# putting  Questions  for docID 11 in forward index
# 0�2�
# 1�
# LEN HITS: 2
# url:  http://stackoverflow.com/jobs?med=site-ui&ref=jobs-tab
# Making docIndex: [12] http://stackoverflow.com/jobs?med=site-ui&ref=jobs-tab
# putting  Jobs  for docID 12 in forward index
# p�r�
# q�
# LEN HITS: 2
# url:  http://stackoverflow.com/documentation
# Making docIndex: [13] http://stackoverflow.com/documentation
# putting  Documentation  for docID 13 in forward index
# ��
# �
# LEN HITS: 2
# url:  http://stackoverflow.com/tags
# Making docIndex: [14] http://stackoverflow.com/tags
# putting  Tags  for docID 14 in forward index
# ���
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/users
# Making docIndex: [15] http://stackoverflow.com/users
# putting  Users  for docID 15 in forward index
# ����
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/help/badges
# Making docIndex: [16] http://stackoverflow.com/help/badges
# putting  Badges  for docID 16 in forward index
# ��
# �
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/ask
# Making docIndex: [17] http://stackoverflow.com/questions/ask
# putting Ask Question for docID 17 in forward index
# ��
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/users/story/join
# Making docIndex: [18] http://stackoverflow.com/users/story/join
# putting Check out Developer Story  for docID 18 in forward index
# D�
# C�
# B�
# @�
# Ar
# LEN HITS: 5
# url:  http://stackoverflow.com/?tab=interesting
# Making docIndex: [19] http://stackoverflow.com/?tab=interesting
# putting  interesting for docID 19 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/?tab=hot
# Making docIndex: [20] http://stackoverflow.com/?tab=hot
# putting  hot for docID 20 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/?tab=week
# Making docIndex: [21] http://stackoverflow.com/?tab=week
# putting  week for docID 21 in forward index
# @�
# Ar
# LEN HITS: 2
# url:  http://stackoverflow.com/?tab=month
# Making docIndex: [22] http://stackoverflow.com/?tab=month
# putting  month for docID 22 in forward index
#  �
# !r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867963/how-to-print-sorted-data-on-json-load
# Making docIndex: [23] http://stackoverflow.com/questions/40867963/how-to-print-sorted-data-on-json-load
# putting How to print sorted data on json load  for docID 23 in forward index
# �r
# �r
# ��
# �r
# ��
# �r
# �r
# �r
# �r
# LEN HITS: 9
# url:  http://stackoverflow.com/questions/tagged/python
# Making docIndex: [24] http://stackoverflow.com/questions/tagged/python
# putting python for docID 24 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/json
# Making docIndex: [25] http://stackoverflow.com/questions/tagged/json
# putting json for docID 25 in forward index
# `r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/sorting
# Making docIndex: [26] http://stackoverflow.com/questions/tagged/sorting
# putting sorting for docID 26 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867963/how-to-print-sorted-data-on-json-load
# putting asked  for docID 23 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/7009113/tonemgub
# Making docIndex: [27] http://stackoverflow.com/users/7009113/tonemgub
# putting tonemgub for docID 27 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867959/how-to-install-a-program-from-github-only-using-terminal-linux
# Making docIndex: [28] http://stackoverflow.com/questions/40867959/how-to-install-a-program-from-github-only-using-terminal-linux
# putting How to install a program from github only using terminal linux  for docID 28 in forward index
# r
# �
# r
# r
# r
# 	r
# �
# r
# r
# r
#
# r
# r
# LEN HITS: 12
# url:  http://stackoverflow.com/questions/tagged/selenium
# Making docIndex: [29] http://stackoverflow.com/questions/tagged/selenium
# putting selenium for docID 29 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/firefox
# Making docIndex: [30] http://stackoverflow.com/questions/tagged/firefox
# putting firefox for docID 30 in forward index
# 0r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/geckodriver
# Making docIndex: [31] http://stackoverflow.com/questions/tagged/geckodriver
# putting geckodriver for docID 31 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867959/how-to-install-a-program-from-github-only-using-terminal-linux
# putting asked  for docID 28 in forward index
# �
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867956/readthedocs-is-there-a-way-to-autodoc-same-model-functions-separately-in-the-on
# Making docIndex: [32] http://stackoverflow.com/questions/40867956/readthedocs-is-there-a-way-to-autodoc-same-model-functions-separately-in-the-on
# putting Readthedocs Is there a way to autodoc same model functions separately in the one file  for docID 32 in forward index
# r
# �
# 	r
# �
# r
# �
# r
# r
# r
#
# r
# r
# r
# r
# r
# r
# r
# LEN HITS: 16
# url:  http://stackoverflow.com/questions/tagged/python
# putting python for docID 24 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/sphinx
# Making docIndex: [33] http://stackoverflow.com/questions/tagged/sphinx
# putting sphinx for docID 33 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/restructuredtext
# Making docIndex: [34] http://stackoverflow.com/questions/tagged/restructuredtext
# putting restructuredtext for docID 34 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/read-the-docs
# Making docIndex: [35] http://stackoverflow.com/questions/tagged/read-the-docs
# putting read the docs for docID 35 in forward index
# 0r
# 2r
# 1r
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/40867956/readthedocs-is-there-a-way-to-autodoc-same-model-functions-separately-in-the-on
# putting asked  for docID 32 in forward index
# �
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/2677101/joab-mendes
# Making docIndex: [36] http://stackoverflow.com/users/2677101/joab-mendes
# putting Joab Mendes for docID 36 in forward index
# p�
# q�
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867955/do-i-need-to-call-require-method-each-time-i-create-new-combobox
# Making docIndex: [37] http://stackoverflow.com/questions/40867955/do-i-need-to-call-require-method-each-time-i-create-new-combobox
# putting Do I need to call require method each time I create new combobox  for docID 37 in forward index
# �
# �
# �	�
# r
# r
# r
# r
# r
# r
# r
# r
#
# r
# r
# LEN HITS: 13
# url:  http://stackoverflow.com/questions/tagged/combobox
# Making docIndex: [38] http://stackoverflow.com/questions/tagged/combobox
# putting combobox for docID 38 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/dojo
# Making docIndex: [39] http://stackoverflow.com/questions/tagged/dojo
# putting dojo for docID 39 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867955/do-i-need-to-call-require-method-each-time-i-create-new-combobox
# putting asked  for docID 37 in forward index
# �
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/7119647/eniss
# Making docIndex: [40] http://stackoverflow.com/users/7119647/eniss
# putting Eniss for docID 40 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867954/prestashop-multistore-local-store-prices-are-overwritten-with-price-from-defau
# Making docIndex: [41] http://stackoverflow.com/questions/40867954/prestashop-multistore-local-store-prices-are-overwritten-with-price-from-defau
# putting Prestashop Multistore local store prices are overwritten with price from default shop for docID 41 in forward index
# ��
# �r
# �r
# �r
# �r
# �r
# �r
# ��
# �r
# �r
# �r
# �r
# LEN HITS: 12
# url:  http://stackoverflow.com/questions/tagged/prestashop
# Making docIndex: [42] http://stackoverflow.com/questions/tagged/prestashop
# putting prestashop for docID 42 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/prestashop-1.6
# Making docIndex: [43] http://stackoverflow.com/questions/tagged/prestashop-1.6
# putting prestashop 1 6 for docID 43 in forward index
# a�
# `r
# b�
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/tagged/multistore
# Making docIndex: [44] http://stackoverflow.com/questions/tagged/multistore
# putting multistore for docID 44 in forward index
# 0r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867954/prestashop-multistore-local-store-prices-are-overwritten-with-price-from-defau
# putting asked  for docID 41 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/3656266/larsd
# Making docIndex: [45] http://stackoverflow.com/users/3656266/larsd
# putting larsd for docID 45 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867951/custom-tableviewcell
# Making docIndex: [46] http://stackoverflow.com/questions/40867951/custom-tableviewcell
# putting Custom tableViewCell for docID 46 in forward index
# Q�
# P�
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/ios
# Making docIndex: [47] http://stackoverflow.com/questions/tagged/ios
# putting ios for docID 47 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/arrays
# Making docIndex: [48] http://stackoverflow.com/questions/tagged/arrays
# putting arrays for docID 48 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/uitableview
# Making docIndex: [49] http://stackoverflow.com/questions/tagged/uitableview
# putting uitableview for docID 49 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/swift3
# Making docIndex: [50] http://stackoverflow.com/questions/tagged/swift3
# putting swift3 for docID 50 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/cell
# Making docIndex: [51] http://stackoverflow.com/questions/tagged/cell
# putting cell for docID 51 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867951/custom-tableviewcell
# putting asked  for docID 46 in forward index
# Q�
# Pr
# LEN HITS: 2
# url:  http://stackoverflow.com/users/7135257/fatemeh
# Making docIndex: [52] http://stackoverflow.com/users/7135257/fatemeh
# putting fatemeh for docID 52 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40864945/rails-is-confusing-params-after-adding-locale-to-the-url
# Making docIndex: [53] http://stackoverflow.com/questions/40864945/rails-is-confusing-params-after-adding-locale-to-the-url
# putting Rails is confusing params after adding locale to the url for docID 53 in forward index
# er
# fr
# ar
# dr
# `�
# gr
# cr
# ir
# hr
# br
# LEN HITS: 10
# url:  http://stackoverflow.com/questions/tagged/ruby-on-rails-4
# Making docIndex: [54] http://stackoverflow.com/questions/tagged/ruby-on-rails-4
# putting ruby on rails 4 for docID 54 in forward index
# �r
# �r
# ��
# �r
# LEN HITS: 4
# url:  http://stackoverflow.com/questions/tagged/parameters
# Making docIndex: [55] http://stackoverflow.com/questions/tagged/parameters
# putting parameters for docID 55 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/routes
# Making docIndex: [56] http://stackoverflow.com/questions/tagged/routes
# putting routes for docID 56 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/internationalization
# Making docIndex: [57] http://stackoverflow.com/questions/tagged/internationalization
# putting internationalization for docID 57 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/locale
# Making docIndex: [58] http://stackoverflow.com/questions/tagged/locale
# putting locale for docID 58 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40864945/rails-is-confusing-params-after-adding-locale-to-the-url
# putting modified  for docID 53 in forward index
# a�
# `r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/3665315/syk
# Making docIndex: [59] http://stackoverflow.com/users/3665315/syk
# putting Syk for docID 59 in forward index
# �
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867947/unauthorized-response-from-rest-call-to-crm-using-adal-js
# Making docIndex: [60] http://stackoverflow.com/questions/40867947/unauthorized-response-from-rest-call-to-crm-using-adal-js
# putting Unauthorized response from Rest call to CRM using adal js for docID 60 in forward index
# �r
# ��
# ��
# �r
# �r
# �r
# �r
# �r
# �r
# ��
# LEN HITS: 10
# url:  http://stackoverflow.com/questions/tagged/javascript
# Making docIndex: [61] http://stackoverflow.com/questions/tagged/javascript
# putting javascript for docID 61 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/dynamics-crm
# Making docIndex: [62] http://stackoverflow.com/questions/tagged/dynamics-crm
# putting dynamics crm for docID 62 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/single-page-application
# Making docIndex: [63] http://stackoverflow.com/questions/tagged/single-page-application
# putting single page application for docID 63 in forward index
# br
# `r
# ar
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/tagged/adal
# Making docIndex: [64] http://stackoverflow.com/questions/tagged/adal
# putting adal for docID 64 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/adal.js
# Making docIndex: [65] http://stackoverflow.com/questions/tagged/adal.js
# putting adal js for docID 65 in forward index
# @r
# Ar
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867947/unauthorized-response-from-rest-call-to-crm-using-adal-js
# putting asked  for docID 60 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/7225815/dom
# Making docIndex: [66] http://stackoverflow.com/users/7225815/dom
# putting Dom for docID 66 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867946/how-to-find-mt2002-offending-dll
# Making docIndex: [67] http://stackoverflow.com/questions/40867946/how-to-find-mt2002-offending-dll
# putting How to find MT2002 Offending DLL  for docID 67 in forward index
# F�
# Ar
# D�
# Br
# @�
# E�
# C�
# LEN HITS: 7
# url:  http://stackoverflow.com/questions/tagged/c%23
# Making docIndex: [68] http://stackoverflow.com/questions/tagged/c%23
# putting c  for docID 68 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/xamarin
# Making docIndex: [69] http://stackoverflow.com/questions/tagged/xamarin
# putting xamarin for docID 69 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/xamarin.ios
# Making docIndex: [70] http://stackoverflow.com/questions/tagged/xamarin.ios
# putting xamarin ios for docID 70 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/vsts-build
# Making docIndex: [71] http://stackoverflow.com/questions/tagged/vsts-build
# putting vsts build for docID 71 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867946/how-to-find-mt2002-offending-dll
# putting asked  for docID 67 in forward index
# A�
# @r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/4539/noah
# Making docIndex: [72] http://stackoverflow.com/users/4539/noah
# putting Noah for docID 72 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867944/how-to-find-the-size-of-a-document-in-icloud-before-picking-it-and-downloading-t
# Making docIndex: [73] http://stackoverflow.com/questions/40867944/how-to-find-the-size-of-a-document-in-icloud-before-picking-it-and-downloading-t
# putting how to find the size of a document in iCloud before picking it and downloading to device using UIDocumentPickerViewController for docID 73 in forward index
# �r
# �r
# �r
# �r�r
# �r
# �r
# �r
# �r
# �r
# ��
# �r
# �r
# �r
# �r
# �r
# �r
# ��
# �r
# LEN HITS: 18
# url:  http://stackoverflow.com/questions/tagged/ios
# putting ios for docID 47 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/icloud
# Making docIndex: [74] http://stackoverflow.com/questions/tagged/icloud
# putting icloud for docID 74 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/uidocumentpickervc
# Making docIndex: [75] http://stackoverflow.com/questions/tagged/uidocumentpickervc
# putting uidocumentpickervc for docID 75 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867944/how-to-find-the-size-of-a-document-in-icloud-before-picking-it-and-downloading-t
# putting asked  for docID 73 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/499174/sujith1406
# Making docIndex: [76] http://stackoverflow.com/users/499174/sujith1406
# putting sujith1406 for docID 76 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867879/excel-len-search-and-find-double-space-bug
# Making docIndex: [77] http://stackoverflow.com/questions/40867879/excel-len-search-and-find-double-space-bug
# putting Excel LEN SEARCH and FIND Double Space Bug  for docID 77 in forward index
# �r
# ��
# ��
# ��
# ��
# ��
# ��
# ��
# ��
# LEN HITS: 9
# url:  http://stackoverflow.com/questions/tagged/excel
# Making docIndex: [78] http://stackoverflow.com/questions/tagged/excel
# putting excel for docID 78 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/excel-2010
# Making docIndex: [79] http://stackoverflow.com/questions/tagged/excel-2010
# putting excel 2010 for docID 79 in forward index
# �r
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867879/excel-len-search-and-find-double-space-bug
# putting modified  for docID 77 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/6613600/nullarbor
# Making docIndex: [80] http://stackoverflow.com/users/6613600/nullarbor
# putting Nullarbor for docID 80 in forward index
# p�
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867943/what-is-the-recommended-approach-to-have-less-contrived-code-in-the-function-of
# Making docIndex: [81] http://stackoverflow.com/questions/40867943/what-is-the-recommended-approach-to-have-less-contrived-code-in-the-function-of
# putting What is the recommended approach to have less contrived code in the function of my component that reacts on data changed from the store  for docID 81 in forward index
# ��
# �r
# �r
# �r
# �r
# �r
# ��
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r�r�r
# �r
# LEN HITS: 23
# url:  http://stackoverflow.com/questions/tagged/reactjs
# Making docIndex: [82] http://stackoverflow.com/questions/tagged/reactjs
# putting reactjs for docID 82 in forward index
#  r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/flux
# Making docIndex: [83] http://stackoverflow.com/questions/tagged/flux
# putting flux for docID 83 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/reactjs-flux
# Making docIndex: [84] http://stackoverflow.com/questions/tagged/reactjs-flux
# putting reactjs flux for docID 84 in forward index
# Qr
# Pr
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867943/what-is-the-recommended-approach-to-have-less-contrived-code-in-the-function-of
# putting asked  for docID 81 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/215553/ibiza
# Making docIndex: [85] http://stackoverflow.com/users/215553/ibiza
# putting ibiza for docID 85 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867942/unity-does-not-inject-dependency-after-configuring-oauth
# Making docIndex: [86] http://stackoverflow.com/questions/40867942/unity-does-not-inject-dependency-after-configuring-oauth
# putting Unity does not inject dependency after configuring OAuth  for docID 86 in forward index
# ��
# �r
# �r
# ��
# �r
# ��
# �r
# �r
# �r
# LEN HITS: 9
# url:  http://stackoverflow.com/questions/tagged/c%23
# putting c  for docID 68 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/oauth
# Making docIndex: [87] http://stackoverflow.com/questions/tagged/oauth
# putting oauth for docID 87 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/dependency-injection
# Making docIndex: [88] http://stackoverflow.com/questions/tagged/dependency-injection
# putting dependency injection for docID 88 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/asp.net-web-api2
# Making docIndex: [89] http://stackoverflow.com/questions/tagged/asp.net-web-api2
# putting asp net web api2 for docID 89 in forward index
# �r
# �r
# �r
# �r
# LEN HITS: 4
# url:  http://stackoverflow.com/questions/tagged/unity-container
# Making docIndex: [90] http://stackoverflow.com/questions/tagged/unity-container
# putting unity container for docID 90 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867942/unity-does-not-inject-dependency-after-configuring-oauth
# putting asked  for docID 86 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/1505521/user1505521
# Making docIndex: [91] http://stackoverflow.com/users/1505521/user1505521
# putting user1505521 for docID 91 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867941/devise-subdomains-from-www-appname-com-admin-login-to-admin-appname-com-login
# Making docIndex: [92] http://stackoverflow.com/questions/40867941/devise-subdomains-from-www-appname-com-admin-login-to-admin-appname-com-login
# putting Devise subdomains from www appname com admin login to admin appname com login for docID 92 in forward index
# Sr
# Rr
# Xr
# TrZr
# P�
# Qr
# VrYr
# Wr\r
# Ur[r
# LEN HITS: 9
# url:  http://stackoverflow.com/questions/tagged/ruby-on-rails
# Making docIndex: [93] http://stackoverflow.com/questions/tagged/ruby-on-rails
# putting ruby on rails for docID 93 in forward index
# �r
# �r
# �r
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/tagged/devise
# Making docIndex: [94] http://stackoverflow.com/questions/tagged/devise
# putting devise for docID 94 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/routes
# putting routes for docID 56 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867941/devise-subdomains-from-www-appname-com-admin-login-to-admin-appname-com-login
# putting asked  for docID 92 in forward index
# Q�
# Pr
# LEN HITS: 2
# url:  http://stackoverflow.com/users/1301037/user1301037
# Making docIndex: [95] http://stackoverflow.com/users/1301037/user1301037
# putting user1301037 for docID 95 in forward index
#  r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867723/swift-3-0-bool-to-int-issue
# Making docIndex: [96] http://stackoverflow.com/questions/40867723/swift-3-0-bool-to-int-issue
# putting Swift 3 0 Bool to Int issue for docID 96 in forward index
# �r
# ��
# �r
# ��
# ��
# ��
# ��
# LEN HITS: 7
# url:  http://stackoverflow.com/questions/tagged/ios
# putting ios for docID 47 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/swift
# Making docIndex: [97] http://stackoverflow.com/questions/tagged/swift
# putting swift for docID 97 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/swift3
# putting swift3 for docID 50 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867723/swift-3-0-bool-to-int-issue/?lastactivity
# Making docIndex: [98] http://stackoverflow.com/questions/40867723/swift-3-0-bool-to-int-issue/?lastactivity
# putting answered  for docID 98 in forward index
# �
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/3514372/artem-novichkov
# Making docIndex: [99] http://stackoverflow.com/users/3514372/artem-novichkov
# putting Artem Novichkov for docID 99 in forward index
# �
# �
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867937/regex-looping-through-a-foreach-to-find-a-certain-pattern
# Making docIndex: [100] http://stackoverflow.com/questions/40867937/regex-looping-through-a-foreach-to-find-a-certain-pattern
# putting Regex looping through a foreach to find a certain pattern for docID 100 in forward index
# ��
# �r�r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# LEN HITS: 9
# url:  http://stackoverflow.com/questions/tagged/c%23
# putting c  for docID 68 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/xml
# Making docIndex: [101] http://stackoverflow.com/questions/tagged/xml
# putting xml for docID 101 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867937/regex-looping-through-a-foreach-to-find-a-certain-pattern
# putting asked  for docID 100 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/5993382/craig-gallagher
# Making docIndex: [102] http://stackoverflow.com/users/5993382/craig-gallagher
# putting Craig Gallagher for docID 102 in forward index
# 0�
# 1�
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867934/split-delimited-string-and-store-values-in-json-object-using-dataweave
# Making docIndex: [103] http://stackoverflow.com/questions/40867934/split-delimited-string-and-store-values-in-json-object-using-dataweave
# putting Split delimited string and store values in JSON object using dataweave for docID 103 in forward index
# �r
# �r
# �r
# �r
# �r
# ��
# �r
# ��
# �r
# �r
# �r
# LEN HITS: 11
# url:  http://stackoverflow.com/questions/tagged/json
# putting json for docID 25 in forward index
# `r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/mule
# Making docIndex: [104] http://stackoverflow.com/questions/tagged/mule
# putting mule for docID 104 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/datamapper
# Making docIndex: [105] http://stackoverflow.com/questions/tagged/datamapper
# putting datamapper for docID 105 in forward index
# `r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/anypoint-studio
# Making docIndex: [106] http://stackoverflow.com/questions/tagged/anypoint-studio
# putting anypoint studio for docID 106 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/dataweave
# Making docIndex: [107] http://stackoverflow.com/questions/tagged/dataweave
# putting dataweave for docID 107 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867934/split-delimited-string-and-store-values-in-json-object-using-dataweave
# putting asked  for docID 103 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/3165854/user3165854
# Making docIndex: [108] http://stackoverflow.com/users/3165854/user3165854
# putting user3165854 for docID 108 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867862/mvc-display-text-after-post-and-keep-data-in-form
# Making docIndex: [109] http://stackoverflow.com/questions/40867862/mvc-display-text-after-post-and-keep-data-in-form
# putting mvc display text after post and keep data in form for docID 109 in forward index
# %r
# )r
# "r
# #r
# &r
#  r
# (r
# $r
# 'r
# !r
# LEN HITS: 10
# url:  http://stackoverflow.com/questions/tagged/asp.net-mvc
# Making docIndex: [110] http://stackoverflow.com/questions/tagged/asp.net-mvc
# putting asp net mvc for docID 110 in forward index
# 1r
# 0r
# 2r
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/tagged/asp.net-mvc-partialview
# Making docIndex: [111] http://stackoverflow.com/questions/tagged/asp.net-mvc-partialview
# putting asp net mvc partialview for docID 111 in forward index
# r
# r
# r
# r
# LEN HITS: 4
# url:  http://stackoverflow.com/questions/40867862/mvc-display-text-after-post-and-keep-data-in-form
# putting modified  for docID 109 in forward index
# !�
#  r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/4141606/antoinedelia
# Making docIndex: [112] http://stackoverflow.com/users/4141606/antoinedelia
# putting antoinedelia for docID 112 in forward index
# `r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/25300557/toast-notifications-in-asp-net-mvc-4
# Making docIndex: [113] http://stackoverflow.com/questions/25300557/toast-notifications-in-asp-net-mvc-4
# putting Toast notifications in ASP NET MVC 4 for docID 113 in forward index
# ��
# ��
# �r
# ��
# ��
# �r
# ��
# LEN HITS: 7
# url:  http://stackoverflow.com/questions/tagged/javascript
# putting javascript for docID 61 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/jquery
# Making docIndex: [114] http://stackoverflow.com/questions/tagged/jquery
# putting jquery for docID 114 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/asp.net-mvc-4
# Making docIndex: [115] http://stackoverflow.com/questions/tagged/asp.net-mvc-4
# putting asp net mvc 4 for docID 115 in forward index
# �r
# �r
# ��
# �r
# LEN HITS: 4
# url:  http://stackoverflow.com/questions/tagged/toastr
# Making docIndex: [116] http://stackoverflow.com/questions/tagged/toastr
# putting toastr for docID 116 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/25300557/toast-notifications-in-asp-net-mvc-4/?lastactivity
# Making docIndex: [117] http://stackoverflow.com/questions/25300557/toast-notifications-in-asp-net-mvc-4/?lastactivity
# putting answered  for docID 117 in forward index
# �
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/4219451/fatih-b%c3%9clb%c3%9cl
# Making docIndex: [118] http://stackoverflow.com/users/4219451/fatih-b%c3%9clb%c3%9cl
# putting Fatih B LB L for docID 118 in forward index
# 1�
# 2�
# 3�
# 0�
# LEN HITS: 4
# url:  http://stackoverflow.com/questions/40867928/how-to-set-oracle-apex-application-language-as-bi-publisher-report-language
# Making docIndex: [119] http://stackoverflow.com/questions/40867928/how-to-set-oracle-apex-application-language-as-bi-publisher-report-language
# putting How to set Oracle APEX application language as BI publisher report language for docID 119 in forward index
# �r
# �r
# �r
# �r
# �r�r
# �r
# ��
# ��
# ��
# �r
# ��
# LEN HITS: 11
# url:  http://stackoverflow.com/questions/tagged/oracle-apex
# Making docIndex: [120] http://stackoverflow.com/questions/tagged/oracle-apex
# putting oracle apex for docID 120 in forward index
# `r
# ar
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/oracle-bi
# Making docIndex: [121] http://stackoverflow.com/questions/tagged/oracle-bi
# putting oracle bi for docID 121 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867928/how-to-set-oracle-apex-application-language-as-bi-publisher-report-language
# putting asked  for docID 119 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/4091311/amol
# Making docIndex: [122] http://stackoverflow.com/users/4091311/amol
# putting Amol for docID 122 in forward index
# @�
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40864219/ssms-2008-sql-how-to-extract-specific-string-of-text
# Making docIndex: [123] http://stackoverflow.com/questions/40864219/ssms-2008-sql-how-to-extract-specific-string-of-text
# putting SSMS 2008 SQL how to extract specific string of text for docID 123 in forward index
# 'r
# $r
# (r
#  �
# &r
# #r
# )r
# "�
# !�
# %r
# LEN HITS: 10
# url:  http://stackoverflow.com/questions/tagged/sql
# Making docIndex: [124] http://stackoverflow.com/questions/tagged/sql
# putting sql for docID 124 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/ssms
# Making docIndex: [125] http://stackoverflow.com/questions/tagged/ssms
# putting ssms for docID 125 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40864219/ssms-2008-sql-how-to-extract-specific-string-of-text/?lastactivity
# Making docIndex: [126] http://stackoverflow.com/questions/40864219/ssms-2008-sql-how-to-extract-specific-string-of-text/?lastactivity
# putting modified  for docID 126 in forward index
# q�
# pr
# LEN HITS: 2
# url:  http://stackoverflow.com/users/5085719/rdkells
# Making docIndex: [127] http://stackoverflow.com/users/5085719/rdkells
# putting RDKells for docID 127 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40862955/having-dns-probe-finished-domainnx-regularly-on-a-domain
# Making docIndex: [128] http://stackoverflow.com/questions/40862955/having-dns-probe-finished-domainnx-regularly-on-a-domain
# putting Having dns probe finished domainnx regularly on a domain for docID 128 in forward index
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# ��
# LEN HITS: 9
# url:  http://stackoverflow.com/questions/tagged/heroku
# Making docIndex: [129] http://stackoverflow.com/questions/tagged/heroku
# putting heroku for docID 129 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/dns
# Making docIndex: [130] http://stackoverflow.com/questions/tagged/dns
# putting dns for docID 130 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/ovh
# Making docIndex: [131] http://stackoverflow.com/questions/tagged/ovh
# putting ovh for docID 131 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40862955/having-dns-probe-finished-domainnx-regularly-on-a-domain
# putting modified  for docID 128 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/1717031/mathrobin
# Making docIndex: [132] http://stackoverflow.com/users/1717031/mathrobin
# putting MathRobin for docID 132 in forward index
# P�
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/596481/simulate-javascript-key-events
# Making docIndex: [133] http://stackoverflow.com/questions/596481/simulate-javascript-key-events
# putting Simulate JavaScript Key Events for docID 133 in forward index
# Q�
# R�
# P�
# S�
# LEN HITS: 4
# url:  http://stackoverflow.com/questions/tagged/javascript
# putting javascript for docID 61 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/javascript-events
# Making docIndex: [134] http://stackoverflow.com/questions/tagged/javascript-events
# putting javascript events for docID 134 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/596481/simulate-javascript-key-events/?lastactivity
# Making docIndex: [135] http://stackoverflow.com/questions/596481/simulate-javascript-key-events/?lastactivity
# putting modified  for docID 135 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/6290027/monami
# Making docIndex: [136] http://stackoverflow.com/users/6290027/monami
# putting monami for docID 136 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867921/when-i-use-jekyll-template-if-page-title-category-first-get-fal
# Making docIndex: [137] http://stackoverflow.com/questions/40867921/when-i-use-jekyll-template-if-page-title-category-first-get-fal
# putting when i use jekyll template if page title category first get false for docID 137 in forward index
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# LEN HITS: 12
# url:  http://stackoverflow.com/questions/tagged/templates
# Making docIndex: [138] http://stackoverflow.com/questions/tagged/templates
# putting templates for docID 138 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/jekyll
# Making docIndex: [139] http://stackoverflow.com/questions/tagged/jekyll
# putting jekyll for docID 139 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/liquid
# Making docIndex: [140] http://stackoverflow.com/questions/tagged/liquid
# putting liquid for docID 140 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867921/when-i-use-jekyll-template-if-page-title-category-first-get-fal
# putting asked  for docID 137 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/4910220/silence
# Making docIndex: [141] http://stackoverflow.com/users/4910220/silence
# putting silence for docID 141 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867918/select-upload-history-from-oracle-table
# Making docIndex: [142] http://stackoverflow.com/questions/40867918/select-upload-history-from-oracle-table
# putting Select upload history from Oracle table for docID 142 in forward index
# Sr
# Qr
# T�
# Ur
# P�
# Rr
# LEN HITS: 6
# url:  http://stackoverflow.com/questions/tagged/oracle
# Making docIndex: [143] http://stackoverflow.com/questions/tagged/oracle
# putting oracle for docID 143 in forward index
#  r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/plsql
# Making docIndex: [144] http://stackoverflow.com/questions/tagged/plsql
# putting plsql for docID 144 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/dense-rank
# Making docIndex: [145] http://stackoverflow.com/questions/tagged/dense-rank
# putting dense rank for docID 145 in forward index
# Pr
# Qr
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/partition-by
# Making docIndex: [146] http://stackoverflow.com/questions/tagged/partition-by
# putting partition by for docID 146 in forward index
#  r
# !r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867918/select-upload-history-from-oracle-table
# putting asked  for docID 142 in forward index
# Q�
# Pr
# LEN HITS: 2
# url:  http://stackoverflow.com/users/549903/robin-clave
# Making docIndex: [147] http://stackoverflow.com/users/549903/robin-clave
# putting Robin clave for docID 147 in forward index
# �r
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867917/how-to-sign-old-ios-version
# Making docIndex: [148] http://stackoverflow.com/questions/40867917/how-to-sign-old-ios-version
# putting How to sign old iOS version for docID 148 in forward index
# r
# r
# �
# r
# �
# r
# LEN HITS: 6
# url:  http://stackoverflow.com/questions/tagged/ios
# putting ios for docID 47 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/iphone
# Making docIndex: [149] http://stackoverflow.com/questions/tagged/iphone
# putting iphone for docID 149 in forward index
#  r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/testing
# Making docIndex: [150] http://stackoverflow.com/questions/tagged/testing
# putting testing for docID 150 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/ios-ipsw-file
# Making docIndex: [151] http://stackoverflow.com/questions/tagged/ios-ipsw-file
# putting ios ipsw file for docID 151 in forward index
# �r
# �r
# �r
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/40867917/how-to-sign-old-ios-version
# putting asked  for docID 148 in forward index
# �
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/382788/mm24
# Making docIndex: [152] http://stackoverflow.com/users/382788/mm24
# putting mm24 for docID 152 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867783/how-to-set-a-different-image-for-each-pin-xamarin-ios
# Making docIndex: [153] http://stackoverflow.com/questions/40867783/how-to-set-a-different-image-for-each-pin-xamarin-ios
# putting How to set a different image for each pin Xamarin iOS for docID 153 in forward index
# 3r
# 9�
# 4r
# 2r
# 8r
# 6r
# 1r
# 5r
# :�
# 0�
# 7r
# LEN HITS: 11
# url:  http://stackoverflow.com/questions/tagged/ios
# putting ios for docID 47 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/xamarin
# putting xamarin for docID 69 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/xamarin.ios
# putting xamarin ios for docID 70 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867783/how-to-set-a-different-image-for-each-pin-xamarin-ios
# putting modified  for docID 153 in forward index
# 1�
# 0r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/6484526/don
# Making docIndex: [154] http://stackoverflow.com/users/6484526/don
# putting Don for docID 154 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867914/salesforce-report-exports-as-html-workaround
# Making docIndex: [155] http://stackoverflow.com/questions/40867914/salesforce-report-exports-as-html-workaround
# putting Salesforce report exports as html workaround for docID 155 in forward index
# rr
# p�
# ur
# sr
# tr
# qr
# LEN HITS: 6
# url:  http://stackoverflow.com/questions/tagged/salesforce
# Making docIndex: [156] http://stackoverflow.com/questions/tagged/salesforce
# putting salesforce for docID 156 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/html-xml-utils
# Making docIndex: [157] http://stackoverflow.com/questions/tagged/html-xml-utils
# putting html xml utils for docID 157 in forward index
# �r
# �r
# �r
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/40867914/salesforce-report-exports-as-html-workaround
# putting asked  for docID 155 in forward index
# q�
# pr
# LEN HITS: 2
# url:  http://stackoverflow.com/users/7178871/adam-mcdermott
# Making docIndex: [158] http://stackoverflow.com/users/7178871/adam-mcdermott
# putting Adam McDermott for docID 158 in forward index
# 1�
# 0�
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867645/undefined-reference-to-symbol-sem-closeglibc-2-2-5
# Making docIndex: [159] http://stackoverflow.com/questions/40867645/undefined-reference-to-symbol-sem-closeglibc-2-2-5
# putting undefined reference to symbol sem close GLIBC 2 2 5  for docID 159 in forward index
# ��
# �r
# �r
# �r
# �r
# ���
# ��
# �r
# �r
# ��
# LEN HITS: 10
# url:  http://stackoverflow.com/questions/tagged/c%2b%2b
# Making docIndex: [160] http://stackoverflow.com/questions/tagged/c%2b%2b
# putting c  for docID 160 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/linux
# Making docIndex: [161] http://stackoverflow.com/questions/tagged/linux
# putting linux for docID 161 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/cmake
# Making docIndex: [162] http://stackoverflow.com/questions/tagged/cmake
# putting cmake for docID 162 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/activemq
# Making docIndex: [163] http://stackoverflow.com/questions/tagged/activemq
# putting activemq for docID 163 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/activemq-cpp
# Making docIndex: [164] http://stackoverflow.com/questions/tagged/activemq-cpp
# putting activemq cpp for docID 164 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867645/undefined-reference-to-symbol-sem-closeglibc-2-2-5/?lastactivity
# Making docIndex: [165] http://stackoverflow.com/questions/40867645/undefined-reference-to-symbol-sem-closeglibc-2-2-5/?lastactivity
# putting answered  for docID 165 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/6533075/sch%c3%bctze
# Making docIndex: [166] http://stackoverflow.com/users/6533075/sch%c3%bctze
# putting Sch tze for docID 166 in forward index
# r
# �
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/37471440/js-surroundcontents-only-retains-highlight-on-text-about-20-of-the-highlight
# Making docIndex: [167] http://stackoverflow.com/questions/37471440/js-surroundcontents-only-retains-highlight-on-text-about-20-of-the-highlight
# putting JS surroundContents only retains highlight on text about 20 of the highlight attempts for docID 167 in forward index
# �r
# �r
# ��
# ��
# �r
# �r
# �r
# ��
# �r
# �r
# �r�r
# �r
# LEN HITS: 12
# url:  http://stackoverflow.com/questions/tagged/javascript
# putting javascript for docID 61 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/highlighting
# Making docIndex: [168] http://stackoverflow.com/questions/tagged/highlighting
# putting highlighting for docID 168 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/37471440/js-surroundcontents-only-retains-highlight-on-text-about-20-of-the-highlight/?lastactivity
# Making docIndex: [169] http://stackoverflow.com/questions/37471440/js-surroundcontents-only-retains-highlight-on-text-about-20-of-the-highlight/?lastactivity
# putting answered  for docID 169 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/1544886/k-scandrett
# Making docIndex: [170] http://stackoverflow.com/users/1544886/k-scandrett
# putting K Scandrett for docID 170 in forward index
# p�
# q�
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867515/excel-connect-to-mssql-returns-login-failed-for-user
# Making docIndex: [171] http://stackoverflow.com/questions/40867515/excel-connect-to-mssql-returns-login-failed-for-user
# putting Excel connect to MSSQL returns Login failed for user for docID 171 in forward index
# �r
# �r
# ��
# �r
# �r
# �r
# ��
# ��
# �r
# LEN HITS: 9
# url:  http://stackoverflow.com/questions/tagged/sql-server
# Making docIndex: [172] http://stackoverflow.com/questions/tagged/sql-server
# putting sql server for docID 172 in forward index
# Qr
# Pr
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/excel
# putting excel for docID 78 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/connection
# Making docIndex: [173] http://stackoverflow.com/questions/tagged/connection
# putting connection for docID 173 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867515/excel-connect-to-mssql-returns-login-failed-for-user
# putting modified  for docID 171 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/121260/eric-darchis
# Making docIndex: [174] http://stackoverflow.com/users/121260/eric-darchis
# putting Eric Darchis for docID 174 in forward index
# ��
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867902/including-geofire-calls-in-a-firebase-transaction
# Making docIndex: [175] http://stackoverflow.com/questions/40867902/including-geofire-calls-in-a-firebase-transaction
# putting Including GeoFire calls in a Firebase transaction for docID 175 in forward index
# $r
# &r
# "r
# !�
# %�
#  �
# #r
# LEN HITS: 7
# url:  http://stackoverflow.com/questions/tagged/firebase-database
# Making docIndex: [176] http://stackoverflow.com/questions/tagged/firebase-database
# putting firebase database for docID 176 in forward index
# 0r
# 1r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/geofire
# Making docIndex: [177] http://stackoverflow.com/questions/tagged/geofire
# putting geofire for docID 177 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867902/including-geofire-calls-in-a-firebase-transaction
# putting asked  for docID 175 in forward index
# !�
#  r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/682778/crocodile
# Making docIndex: [178] http://stackoverflow.com/users/682778/crocodile
# putting Crocodile for docID 178 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867900/perl-extract-substring-to-a-character-with-count-zero-or-more
# Making docIndex: [179] http://stackoverflow.com/questions/40867900/perl-extract-substring-to-a-character-with-count-zero-or-more
# ...
# putting modified  for docID 436 in forward index
# �
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/5730444/phonolog
# Making docIndex: [440] http://stackoverflow.com/users/5730444/phonolog
# putting Phonolog for docID 440 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40866244/objetctanimator-with-array-variable
# Making docIndex: [441] http://stackoverflow.com/questions/40866244/objetctanimator-with-array-variable
# putting ObjetctAnimator with array variable for docID 441 in forward index
# r
# r
# r
# �
# LEN HITS: 4
# url:  http://stackoverflow.com/questions/tagged/animation
# Making docIndex: [442] http://stackoverflow.com/questions/tagged/animation
# putting animation for docID 442 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/objectanimator
# Making docIndex: [443] http://stackoverflow.com/questions/tagged/objectanimator
# putting objectanimator for docID 443 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40866244/objetctanimator-with-array-variable
# putting modified  for docID 441 in forward index
# �
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/1281081/asfk
# Making docIndex: [444] http://stackoverflow.com/users/1281081/asfk
# putting AsfK for docID 444 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40865391/how-to-show-text-yes-no-inside-a-switch-in-react-native
# Making docIndex: [445] http://stackoverflow.com/questions/40865391/how-to-show-text-yes-no-inside-a-switch-in-react-native
# putting How to show text YES NO inside a switch in react native for docID 445 in forward index
# wr
# qr
# rr
# sr
# vr
# u�
# zr
# p�
# xr
# yr
# t�
# {r
# LEN HITS: 12
# url:  http://stackoverflow.com/questions/tagged/react-native
# Making docIndex: [446] http://stackoverflow.com/questions/tagged/react-native
# putting react native for docID 446 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40865391/how-to-show-text-yes-no-inside-a-switch-in-react-native
# putting modified  for docID 445 in forward index
# q�
# pr
# LEN HITS: 2
# url:  http://stackoverflow.com/users/1090798/krish
# Making docIndex: [447] http://stackoverflow.com/users/1090798/krish
# putting Krish for docID 447 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions
# putting complete list of questions for docID 11 in forward index
# 2r
# 1r
# 0r
# 3r
# LEN HITS: 4
# url:  http://stackoverflow.com/tags
# putting popular tags for docID 14 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/unanswered
# Making docIndex: [448] http://stackoverflow.com/unanswered
# putting unanswered questions for docID 448 in forward index
# �r
# �r
# LEN HITS: 2
# url:  //stackexchange.com/questions?tab=hot
# url:  http://mathematica.stackexchange.com/questions/132323/how-to-effiectively-substitute-the-member-in-list-with-their-order
# Making docIndex: [449] http://mathematica.stackexchange.com/questions/132323/how-to-effiectively-substitute-the-member-in-list-with-their-order
# putting  How to effiectively substitute the member in list with their order  for docID 449 in forward index
# ����
# �r
# �r
# �r
# �r
# ��
# �r
# �r
# �r
# �r
# �r
# �r
# LEN HITS: 12
# url:  http://photo.stackexchange.com/questions/84861/why-is-this-child-portrait-not-compelling-what-went-wrong-and-what-could-have-b
# Making docIndex: [450] http://photo.stackexchange.com/questions/84861/why-is-this-child-portrait-not-compelling-what-went-wrong-and-what-could-have-b
# putting  Why is this child portrait not compelling What went wrong and what could have been done better  for docID 450 in forward index
# ����
# �r
# ���r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# ��
# LEN HITS: 17
# url:  http://worldbuilding.stackexchange.com/questions/62572/truth-stone-effects-on-the-justice-system-and-criminal-world
# Making docIndex: [451] http://worldbuilding.stackexchange.com/questions/62572/truth-stone-effects-on-the-justice-system-and-criminal-world
# putting  Truth Stone Effects on the justice system and criminal world  for docID 451 in forward index
# ���
# �r
# ��
# �r
# �r
# �r
# ��
# ��
# �r
# �r
# �r
# LEN HITS: 11
# url:  http://academia.stackexchange.com/questions/80652/discussion-turned-into-argument-with-the-conference-keynote-speaker-feeling-bad
# Making docIndex: [452] http://academia.stackexchange.com/questions/80652/discussion-turned-into-argument-with-the-conference-keynote-speaker-feeling-bad
# putting  Discussion turned into argument with the conference keynote speaker feeling bad  for docID 452 in forward index
# ����
# �r
# �r
# ��
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# LEN HITS: 12
# url:  http://codegolf.stackexchange.com/questions/101469/grid-ascii-art-code-golf
# Making docIndex: [453] http://codegolf.stackexchange.com/questions/101469/grid-ascii-art-code-golf
# putting  Grid ascii art code golf  for docID 453 in forward index
#  �&�
# $r
# #r
# !�
# %r
# "r
# LEN HITS: 6
# url:  http://worldbuilding.stackexchange.com/questions/62533/military-tank-drone-why-are-they-not-common-yet
# Making docIndex: [454] http://worldbuilding.stackexchange.com/questions/62533/military-tank-drone-why-are-they-not-common-yet
# putting  Military Tank drone why are they not common yet  for docID 454 in forward index
# ���
# ��
# �r
# �r
# �r
# �r
# �r
# ��
# �r
# �r
# LEN HITS: 10
# url:  http://tex.stackexchange.com/questions/341451/the-text-is-pushed-down-when-there-is-a-picture-in-the-other-column
# Making docIndex: [455] http://tex.stackexchange.com/questions/341451/the-text-is-pushed-down-when-there-is-a-picture-in-the-other-column
# putting  The text is pushed down when there is a picture in the other column  for docID 455 in forward index
# ���
# �r
# �r
# �r
# �r
# �r�r
# �r
# �r
# �r
# �r
# �r
# �r
# ��r
# LEN HITS: 13
# url:  http://academia.stackexchange.com/questions/80643/unintentionally-disrespectful-in-the-statement-of-purpose-academic-essay
# Making docIndex: [456] http://academia.stackexchange.com/questions/80643/unintentionally-disrespectful-in-the-statement-of-purpose-academic-essay
# putting  Unintentionally disrespectful in the Statement of Purpose Academic essay  for docID 456 in forward index
# P�Z�
# Yr
# Rr
# Vr
# X�
# W�
# U�
# Sr
# Tr
# Q�
# LEN HITS: 10
# url:  http://english.stackexchange.com/questions/360721/is-soul-to-soul-talk-a-common-expression-in-english
# Making docIndex: [457] http://english.stackexchange.com/questions/360721/is-soul-to-soul-talk-a-common-expression-in-english
# putting  Is soul to soul talk a common expression in English  for docID 457 in forward index
# 0�;�
# 6r
# 1�
# :�
# 2r4r
# 3r
# 7r
# 9r
# 8r
# 5r
# LEN HITS: 10
# url:  http://physics.stackexchange.com/questions/294966/what-does-antimatter-look-like
# Making docIndex: [458] http://physics.stackexchange.com/questions/294966/what-does-antimatter-look-like
# putting  What does antimatter look like  for docID 458 in forward index
# ����
# ��
# �r
# �r
# �r
# �r
# LEN HITS: 6
# url:  http://puzzling.stackexchange.com/questions/46210/what-was-the-child-sent-to-buy
# Making docIndex: [459] http://puzzling.stackexchange.com/questions/46210/what-was-the-child-sent-to-buy
# putting  What was the child sent to buy  for docID 459 in forward index
# ���
# ��
# �r
# �r
# �r
# �r
# �r
# �r
# LEN HITS: 8
# url:  http://stackoverflow.com/questions/40848551/how-does-adding-string-with-integer-work-in-javascript
# Making docIndex: [460] http://stackoverflow.com/questions/40848551/how-does-adding-string-with-integer-work-in-javascript
# putting  How does adding String with Integer work in JavaScript  for docID 460 in forward index
# P�Z�
# Sr
# Y�
# T�
# Wr
# Q�
# Rr
# Xr
# V�
# Ur
# LEN HITS: 10
# url:  http://mathoverflow.net/questions/255820/how-should-a-working-mathematician-think-about-sets-zfc-category-theory-ur
# Making docIndex: [461] http://mathoverflow.net/questions/255820/how-should-a-working-mathematician-think-about-sets-zfc-category-theory-ur
# putting  How should a working mathematician think about sets ZFC category theory urelements  for docID 461 in forward index
# ����
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# ��
# �r
# ��
# �r
# �r
# LEN HITS: 13
# url:  http://academia.stackexchange.com/questions/80561/how-to-professionally-handle-sexist-remarks-by-a-student
# Making docIndex: [462] http://academia.stackexchange.com/questions/80561/how-to-professionally-handle-sexist-remarks-by-a-student
# putting  How to professionally handle sexist remarks by a student  for docID 462 in forward index
# ��
# r
# r
# r
# r
# �
# r
# r
# r
# r
# LEN HITS: 10
# url:  http://travel.stackexchange.com/questions/83389/how-are-different-meal-ratios-calculated-for-flights
# Making docIndex: [463] http://travel.stackexchange.com/questions/83389/how-are-different-meal-ratios-calculated-for-flights
# putting  How are different meal ratios calculated for flights  for docID 463 in forward index
# ���
# �r
# �r
# �r
# ��
# �r
# �r
# �r
# �r
# LEN HITS: 9
# url:  http://sqa.stackexchange.com/questions/23932/do-we-use-need-test-cases-in-agile
# Making docIndex: [464] http://sqa.stackexchange.com/questions/23932/do-we-use-need-test-cases-in-agile
# putting  Do we use need test cases in Agile  for docID 464 in forward index
# P�Y�
# Q�
# Rr
# X�
# Sr
# Tr
# Wr
# Ur
# Vr
# LEN HITS: 9
# url:  http://scifi.stackexchange.com/questions/146136/why-no-medievalworld-or-romanworld
# Making docIndex: [465] http://scifi.stackexchange.com/questions/146136/why-no-medievalworld-or-romanworld
# putting  Why no Medievalworld or Romanworld  for docID 465 in forward index
# ����
# �r
# ��
# ��
# ��
# �r
# LEN HITS: 6
# url:  http://mathematica.stackexchange.com/questions/132332/simple-rule-does-not-work
# Making docIndex: [466] http://mathematica.stackexchange.com/questions/132332/simple-rule-does-not-work
# putting  Simple rule does not work  for docID 466 in forward index
# 0�6�
# 1�
# 5r
# 2r
# 3r
# 4r
# LEN HITS: 6
# url:  http://stackoverflow.com/questions/40861062/text-with-multiple-underlines
# Making docIndex: [467] http://stackoverflow.com/questions/40861062/text-with-multiple-underlines
# putting  Text with multiple underlines  for docID 467 in forward index
# 0�5�
# 1�
# 2r
# 4r
# 3r
# LEN HITS: 5
# url:  http://mathoverflow.net/questions/255896/derivative-is-zero-on-a-dense-g-delta-set
# Making docIndex: [468] http://mathoverflow.net/questions/255896/derivative-is-zero-on-a-dense-g-delta-set
# putting  Derivative is Zero on a dense G delta set  for docID 468 in forward index
# p�z�
# ur
# yr
# vr
# w�
# tr
# rr
# s�
# xr
# q�
# LEN HITS: 10
# url:  http://codegolf.stackexchange.com/questions/101275/figure-and-ground
# Making docIndex: [469] http://codegolf.stackexchange.com/questions/101275/figure-and-ground
# putting  Figure and Ground  for docID 469 in forward index
# ���
# �r
# ��
# ��
# LEN HITS: 4
# url:  http://superuser.com/questions/1150860/what-the-np-reading-means-for-a-dvi-computer-monitor
# Making docIndex: [470] http://superuser.com/questions/1150860/what-the-np-reading-means-for-a-dvi-computer-monitor
# putting  What the NP reading means for a DVI computer monitor  for docID 470 in forward index
# 0�;�
# 7r
# 1�
# 8�
# :r
# 6r
# 5r
# 9r
# 3�
# 2r
# 4r
# LEN HITS: 11
# url:  http://scifi.stackexchange.com/questions/146011/why-does-prof-farnsworth-run-planet-express
# Making docIndex: [471] http://scifi.stackexchange.com/questions/146011/why-does-prof-farnsworth-run-planet-express
# putting  Why does Prof Farnsworth run Planet Express  for docID 471 in forward index
# ��
# r
# �
# �
# r
# �
# �
# �
# LEN HITS: 8
# url:  http://puzzling.stackexchange.com/questions/46208/a-smart-girl
# Making docIndex: [472] http://puzzling.stackexchange.com/questions/46208/a-smart-girl
# putting  A Smart Girl  for docID 472 in forward index
# ���
# ��
# ��
# ��
# LEN HITS: 4
# url:  http://stackoverflow.com/
# putting  more hot questions  for docID 0 in forward index
# @�D�
# Br
# Cr
# Ar
# LEN HITS: 4
# url:  http://stackoverflow.com/company/about
# putting about us for docID 9 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/tour
# putting tour for docID 7 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/help
# putting help for docID 8 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.blog?blb=1
# Making docIndex: [473] http://stackoverflow.blog?blb=1
# putting blog for docID 473 in forward index
# �r
# LEN HITS: 1
# url:  http://chat.stackoverflow.com
# putting chat for docID 1 in forward index
# �r
# LEN HITS: 1
# url:  http://data.stackexchange.com
# Making docIndex: [474] http://data.stackexchange.com
# putting data for docID 474 in forward index
# �r
# LEN HITS: 1
# url:  http://stackexchange.com/legal
# Making docIndex: [475] http://stackexchange.com/legal
# putting legal for docID 475 in forward index
# �r
# LEN HITS: 1
# url:  http://stackexchange.com/legal/privacy-policy
# Making docIndex: [476] http://stackexchange.com/legal/privacy-policy
# putting privacy policy for docID 476 in forward index
# r
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/company/work-here
# Making docIndex: [477] http://stackoverflow.com/company/work-here
# putting work here for docID 477 in forward index
# pr
# qr
# LEN HITS: 2
# url:  http://stackexchange.com/mediakit
# Making docIndex: [478] http://stackexchange.com/mediakit
# putting advertising info for docID 478 in forward index
# ar
# `r
# LEN HITS: 2
# url:  http://stackoverflow.com/contact
# Making docIndex: [479] http://stackoverflow.com/contact
# putting contact us for docID 479 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://meta.stackoverflow.com
# Making docIndex: [480] http://meta.stackoverflow.com
# putting feedback for docID 480 in forward index
# 0r
# LEN HITS: 1
# url:  //stackoverflow.com
# url:  //serverfault.com
# url:  //superuser.com
# url:  //webapps.stackexchange.com
# url:  //askubuntu.com
# url:  //webmasters.stackexchange.com
# url:  //gamedev.stackexchange.com
# url:  //tex.stackexchange.com
# url:  //softwareengineering.stackexchange.com
# url:  //unix.stackexchange.com
# url:  //apple.stackexchange.com
# url:  //wordpress.stackexchange.com
# url:  //gis.stackexchange.com
# url:  //electronics.stackexchange.com
# url:  //android.stackexchange.com
# url:  //security.stackexchange.com
# url:  //dba.stackexchange.com
# url:  //drupal.stackexchange.com
# url:  //sharepoint.stackexchange.com
# url:  //ux.stackexchange.com
# url:  //mathematica.stackexchange.com
# url:  //salesforce.stackexchange.com
# url:  //expressionengine.stackexchange.com
# url:  //crypto.stackexchange.com
# url:  //codereview.stackexchange.com
# url:  //magento.stackexchange.com
# url:  //dsp.stackexchange.com
# url:  //raspberrypi.stackexchange.com
# url:  //codegolf.stackexchange.com
# url:  http://stackexchange.com/sites
# Making docIndex: [481] http://stackexchange.com/sites
# putting  more 7  for docID 481 in forward index
#  �#�
# "�
# !r
# LEN HITS: 3
# url:  //photo.stackexchange.com
# url:  //scifi.stackexchange.com
# url:  //graphicdesign.stackexchange.com
# url:  //movies.stackexchange.com
# url:  //music.stackexchange.com
# url:  //cooking.stackexchange.com
# url:  //diy.stackexchange.com
# url:  //money.stackexchange.com
# url:  //academia.stackexchange.com
# url:  http://stackexchange.com/sites
# putting  more 8  for docID 481 in forward index
#  �#�
# "�
# !r
# LEN HITS: 3
# url:  //english.stackexchange.com
# url:  //skeptics.stackexchange.com
# url:  //judaism.stackexchange.com
# url:  //travel.stackexchange.com
# url:  //christianity.stackexchange.com
# url:  //ell.stackexchange.com
# url:  //japanese.stackexchange.com
# url:  //gaming.stackexchange.com
# url:  //bicycles.stackexchange.com
# url:  //rpg.stackexchange.com
# url:  //anime.stackexchange.com
# url:  //mechanics.stackexchange.com
# url:  http://stackexchange.com/sites
# putting  more 17  for docID 481 in forward index
#  �#�
# "�
# !r
# LEN HITS: 3
# url:  //mathoverflow.net
# url:  //math.stackexchange.com
# url:  //stats.stackexchange.com
# url:  //cstheory.stackexchange.com
# url:  //physics.stackexchange.com
# url:  //chemistry.stackexchange.com
# url:  //biology.stackexchange.com
# url:  //cs.stackexchange.com
# url:  //philosophy.stackexchange.com
# url:  http://stackexchange.com/sites
# putting  more 3  for docID 481 in forward index
#  �#�
# "�
# !r
# LEN HITS: 3
# url:  //meta.stackexchange.com
# url:  //stackapps.com
# url:  //area51.stackexchange.com
# url:  //talent.stackoverflow.com
# url:  https://creativecommons.org/licenses/by-sa/3.0/
# Making docIndex: [482] https://creativecommons.org/licenses/by-sa/3.0/
# putting cc by sa 3 0 for docID 482 in forward index
# �r
# ��
# �r
# �r
# ��
# LEN HITS: 5
# url:  http://blog.stackoverflow.com/2009/06/attribution-required/
# Making docIndex: [483] http://blog.stackoverflow.com/2009/06/attribution-required/
# putting attribution required for docID 483 in forward index
# 1r
# 0r
# LEN HITS: 2

# %%
i = 0
docI = docIndex.getDocIndex(i)
while docI is not None:
    print docIndex.getUrlFromList(docI[3], docI[4])
    i += 1
    docI = docIndex.getDocIndex(i)
# Out:
# http://stackoverflow.com/
# http://chat.stackoverflow.com
# https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent&amp;utm_source=stackoverflow.com&amp;utm_medium=dev-story&amp;utm_campaign=signup-redirect
# https://stackoverflow.com/users/login?ssrc=site_switcher&returnurl=http%3a%2f%2fstackoverflow.com%2f
# http://stackoverflow.blog
# https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent&utm_source=stackoverflow.com&utm_medium=dev-story&utm_campaign=signup-redirect
# https://stackoverflow.com/users/login?ssrc=head&returnurl=http%3a%2f%2fstackoverflow.com%2f
# http://stackoverflow.com/tour
# http://stackoverflow.com/help
# http://stackoverflow.com/company/about
# http://business.stackoverflow.com/?ref=topbar_help
# http://stackoverflow.com/questions
# http://stackoverflow.com/jobs?med=site-ui&ref=jobs-tab
# http://stackoverflow.com/documentation
# http://stackoverflow.com/tags
# http://stackoverflow.com/users
# http://stackoverflow.com/help/badges
# http://stackoverflow.com/questions/ask
# http://stackoverflow.com/users/story/join
# http://stackoverflow.com/?tab=interesting
# http://stackoverflow.com/?tab=hot
# http://stackoverflow.com/?tab=week
# http://stackoverflow.com/?tab=month
# http://stackoverflow.com/questions/40867963/how-to-print-sorted-data-on-json-load
# http://stackoverflow.com/questions/tagged/python
# http://stackoverflow.com/questions/tagged/json
# http://stackoverflow.com/questions/tagged/sorting
# http://stackoverflow.com/users/7009113/tonemgub
# http://stackoverflow.com/questions/40867959/how-to-install-a-program-from-github-only-using-terminal-linux
# http://stackoverflow.com/questions/tagged/selenium
# http://stackoverflow.com/questions/tagged/firefox
# http://stackoverflow.com/questions/tagged/geckodriver
# http://stackoverflow.com/questions/40867956/readthedocs-is-there-a-way-to-autodoc-same-model-functions-separately-in-the-on
# http://stackoverflow.com/questions/tagged/sphinx
# http://stackoverflow.com/questions/tagged/restructuredtext
# http://stackoverflow.com/questions/tagged/read-the-docs
# http://stackoverflow.com/users/2677101/joab-mendes
# http://stackoverflow.com/questions/40867955/do-i-need-to-call-require-method-each-time-i-create-new-combobox
# http://stackoverflow.com/questions/tagged/combobox
# http://stackoverflow.com/questions/tagged/dojo
# http://stackoverflow.com/users/7119647/eniss
# http://stackoverflow.com/questions/40867954/prestashop-multistore-local-store-prices-are-overwritten-with-price-from-defau
# http://stackoverflow.com/questions/tagged/prestashop
# http://stackoverflow.com/questions/tagged/prestashop-1.6
# http://stackoverflow.com/questions/tagged/multistore
# http://stackoverflow.com/users/3656266/larsd
# http://stackoverflow.com/questions/40867951/custom-tableviewcell
# http://stackoverflow.com/questions/tagged/ios
# http://stackoverflow.com/questions/tagged/arrays
# http://stackoverflow.com/questions/tagged/uitableview
# http://stackoverflow.com/questions/tagged/swift3
# http://stackoverflow.com/questions/tagged/cell
# http://stackoverflow.com/users/7135257/fatemeh
# http://stackoverflow.com/questions/40864945/rails-is-confusing-params-after-adding-locale-to-the-url
# http://stackoverflow.com/questions/tagged/ruby-on-rails-4
# http://stackoverflow.com/questions/tagged/parameters
# http://stackoverflow.com/questions/tagged/routes
# http://stackoverflow.com/questions/tagged/internationalization
# http://stackoverflow.com/questions/tagged/locale
# http://stackoverflow.com/users/3665315/syk
# http://stackoverflow.com/questions/40867947/unauthorized-response-from-rest-call-to-crm-using-adal-js
# http://stackoverflow.com/questions/tagged/javascript
# http://stackoverflow.com/questions/tagged/dynamics-crm
# http://stackoverflow.com/questions/tagged/single-page-application
# http://stackoverflow.com/questions/tagged/adal
# http://stackoverflow.com/questions/tagged/adal.js
# http://stackoverflow.com/users/7225815/dom
# http://stackoverflow.com/questions/40867946/how-to-find-mt2002-offending-dll
# http://stackoverflow.com/questions/tagged/c%23
# http://stackoverflow.com/questions/tagged/xamarin
# http://stackoverflow.com/questions/tagged/xamarin.ios
# http://stackoverflow.com/questions/tagged/vsts-build
# http://stackoverflow.com/users/4539/noah
# http://stackoverflow.com/questions/40867944/how-to-find-the-size-of-a-document-in-icloud-before-picking-it-and-downloading-t
# http://stackoverflow.com/questions/tagged/icloud
# http://stackoverflow.com/questions/tagged/uidocumentpickervc
# http://stackoverflow.com/users/499174/sujith1406
# http://stackoverflow.com/questions/40867879/excel-len-search-and-find-double-space-bug
# http://stackoverflow.com/questions/tagged/excel
# http://stackoverflow.com/questions/tagged/excel-2010
# http://stackoverflow.com/users/6613600/nullarbor
# http://stackoverflow.com/questions/40867943/what-is-the-recommended-approach-to-have-less-contrived-code-in-the-function-of
# http://stackoverflow.com/questions/tagged/reactjs
# http://stackoverflow.com/questions/tagged/flux
# http://stackoverflow.com/questions/tagged/reactjs-flux
# http://stackoverflow.com/users/215553/ibiza
# http://stackoverflow.com/questions/40867942/unity-does-not-inject-dependency-after-configuring-oauth
# http://stackoverflow.com/questions/tagged/oauth
# http://stackoverflow.com/questions/tagged/dependency-injection
# http://stackoverflow.com/questions/tagged/asp.net-web-api2
# http://stackoverflow.com/questions/tagged/unity-container
# http://stackoverflow.com/users/1505521/user1505521
# http://stackoverflow.com/questions/40867941/devise-subdomains-from-www-appname-com-admin-login-to-admin-appname-com-login
# http://stackoverflow.com/questions/tagged/ruby-on-rails
# http://stackoverflow.com/questions/tagged/devise
# http://stackoverflow.com/users/1301037/user1301037
# http://stackoverflow.com/questions/40867723/swift-3-0-bool-to-int-issue
# http://stackoverflow.com/questions/tagged/swift
# http://stackoverflow.com/questions/40867723/swift-3-0-bool-to-int-issue/?lastactivity
# http://stackoverflow.com/users/3514372/artem-novichkov
# http://stackoverflow.com/questions/40867937/regex-looping-through-a-foreach-to-find-a-certain-pattern
# http://stackoverflow.com/questions/tagged/xml
# http://stackoverflow.com/users/5993382/craig-gallagher
# http://stackoverflow.com/questions/40867934/split-delimited-string-and-store-values-in-json-object-using-dataweave
# http://stackoverflow.com/questions/tagged/mule
# http://stackoverflow.com/questions/tagged/datamapper
# http://stackoverflow.com/questions/tagged/anypoint-studio
# http://stackoverflow.com/questions/tagged/dataweave
# http://stackoverflow.com/users/3165854/user3165854
# http://stackoverflow.com/questions/40867862/mvc-display-text-after-post-and-keep-data-in-form
# http://stackoverflow.com/questions/tagged/asp.net-mvc
# http://stackoverflow.com/questions/tagged/asp.net-mvc-partialview
# http://stackoverflow.com/users/4141606/antoinedelia
# http://stackoverflow.com/questions/25300557/toast-notifications-in-asp-net-mvc-4
# http://stackoverflow.com/questions/tagged/jquery
# http://stackoverflow.com/questions/tagged/asp.net-mvc-4
# http://stackoverflow.com/questions/tagged/toastr
# http://stackoverflow.com/questions/25300557/toast-notifications-in-asp-net-mvc-4/?lastactivity
# http://stackoverflow.com/users/4219451/fatih-b%c3%9clb%c3%9cl
# http://stackoverflow.com/questions/40867928/how-to-set-oracle-apex-application-language-as-bi-publisher-report-language
# http://stackoverflow.com/questions/tagged/oracle-apex
# http://stackoverflow.com/questions/tagged/oracle-bi
# http://stackoverflow.com/users/4091311/amol
# http://stackoverflow.com/questions/40864219/ssms-2008-sql-how-to-extract-specific-string-of-text
# http://stackoverflow.com/questions/tagged/sql
# http://stackoverflow.com/questions/tagged/ssms
# http://stackoverflow.com/questions/40864219/ssms-2008-sql-how-to-extract-specific-string-of-text/?lastactivity
# http://stackoverflow.com/users/5085719/rdkells
# http://stackoverflow.com/questions/40862955/having-dns-probe-finished-domainnx-regularly-on-a-domain
# http://stackoverflow.com/questions/tagged/heroku
# http://stackoverflow.com/questions/tagged/dns
# http://stackoverflow.com/questions/tagged/ovh
# http://stackoverflow.com/users/1717031/mathrobin
# http://stackoverflow.com/questions/596481/simulate-javascript-key-events
# http://stackoverflow.com/questions/tagged/javascript-events
# http://stackoverflow.com/questions/596481/simulate-javascript-key-events/?lastactivity
# http://stackoverflow.com/users/6290027/monami
# http://stackoverflow.com/questions/40867921/when-i-use-jekyll-template-if-page-title-category-first-get-fal
# http://stackoverflow.com/questions/tagged/templates
# http://stackoverflow.com/questions/tagged/jekyll
# http://stackoverflow.com/questions/tagged/liquid
# http://stackoverflow.com/users/4910220/silence
# http://stackoverflow.com/questions/40867918/select-upload-history-from-oracle-table
# http://stackoverflow.com/questions/tagged/oracle
# http://stackoverflow.com/questions/tagged/plsql
# http://stackoverflow.com/questions/tagged/dense-rank
# http://stackoverflow.com/questions/tagged/partition-by
# http://stackoverflow.com/users/549903/robin-clave
# http://stackoverflow.com/questions/40867917/how-to-sign-old-ios-version
# http://stackoverflow.com/questions/tagged/iphone
# http://stackoverflow.com/questions/tagged/testing
# http://stackoverflow.com/questions/tagged/ios-ipsw-file
# http://stackoverflow.com/users/382788/mm24
# http://stackoverflow.com/questions/40867783/how-to-set-a-different-image-for-each-pin-xamarin-ios
# http://stackoverflow.com/users/6484526/don
# http://stackoverflow.com/questions/40867914/salesforce-report-exports-as-html-workaround
# http://stackoverflow.com/questions/tagged/salesforce
# http://stackoverflow.com/questions/tagged/html-xml-utils
# http://stackoverflow.com/users/7178871/adam-mcdermott
# http://stackoverflow.com/questions/40867645/undefined-reference-to-symbol-sem-closeglibc-2-2-5
# http://stackoverflow.com/questions/tagged/c%2b%2b
# http://stackoverflow.com/questions/tagged/linux
# http://stackoverflow.com/questions/tagged/cmake
# http://stackoverflow.com/questions/tagged/activemq
# http://stackoverflow.com/questions/tagged/activemq-cpp
# http://stackoverflow.com/questions/40867645/undefined-reference-to-symbol-sem-closeglibc-2-2-5/?lastactivity
# http://stackoverflow.com/users/6533075/sch%c3%bctze
# http://stackoverflow.com/questions/37471440/js-surroundcontents-only-retains-highlight-on-text-about-20-of-the-highlight
# http://stackoverflow.com/questions/tagged/highlighting
# http://stackoverflow.com/questions/37471440/js-surroundcontents-only-retains-highlight-on-text-about-20-of-the-highlight/?lastactivity
# http://stackoverflow.com/users/1544886/k-scandrett
# http://stackoverflow.com/questions/40867515/excel-connect-to-mssql-returns-login-failed-for-user
# http://stackoverflow.com/questions/tagged/sql-server
# http://stackoverflow.com/questions/tagged/connection
# http://stackoverflow.com/users/121260/eric-darchis
# http://stackoverflow.com/questions/40867902/including-geofire-calls-in-a-firebase-transaction
# http://stackoverflow.com/questions/tagged/firebase-database
# http://stackoverflow.com/questions/tagged/geofire
# http://stackoverflow.com/users/682778/crocodile
# http://stackoverflow.com/questions/40867900/perl-extract-substring-to-a-character-with-count-zero-or-more
# http://stackoverflow.com/questions/tagged/regex
# http://stackoverflow.com/questions/tagged/string
# http://stackoverflow.com/questions/tagged/perl
# http://stackoverflow.com/users/278910/ontherocks
# http://stackoverflow.com/questions/40867897/how-do-i-ask-for-the-input-of-a-variable-when-needed-instead-of-typing-input-b
# http://stackoverflow.com/questions/tagged/python-3.x
# http://stackoverflow.com/users/7164679/dave-matthew
# http://stackoverflow.com/questions/40867894/using-javascript-to-loop-through-nodes-of-an-xml-feed
# http://stackoverflow.com/questions/tagged/xml-parsing
# http://stackoverflow.com/users/1555453/tim-cadieux
# http://stackoverflow.com/questions/40867893/creating-a-custom-video-similar-to-facebook-birthday-videos-programmatically
# http://stackoverflow.com/questions/tagged/java
# http://stackoverflow.com/questions/tagged/video
# http://stackoverflow.com/questions/tagged/webpage
# http://stackoverflow.com/users/5621098/robin-abishek
# http://stackoverflow.com/questions/40867892/different-menu-level-with-same-viewcontroller
# http://stackoverflow.com/users/6267839/chris
# http://stackoverflow.com/questions/40867889/sapui5-multiple-vizframes-in-view
# http://stackoverflow.com/questions/tagged/sapui5
# http://stackoverflow.com/questions/tagged/openui5
# http://stackoverflow.com/users/1191056/alexander-fuchs
# http://stackoverflow.com/questions/40867885/jsonschema2pojo-make-private-classes-from-definitions
# http://stackoverflow.com/questions/tagged/jsonschema
# http://stackoverflow.com/questions/tagged/jsonschema2pojo
# http://stackoverflow.com/users/3392595/forepick
# http://stackoverflow.com/questions/40865592/lapply-function-in-r
# http://stackoverflow.com/questions/tagged/r
# http://stackoverflow.com/questions/tagged/for-loop
# http://stackoverflow.com/questions/tagged/lapply
# http://stackoverflow.com/users/6019081/neha-sharma
# http://stackoverflow.com/questions/40867878/loading-routers-paths-from-external-files
# http://stackoverflow.com/questions/tagged/angular2
# http://stackoverflow.com/questions/tagged/angular2-routing
# http://stackoverflow.com/users/2203299/tom
# http://stackoverflow.com/questions/40867875/account-kit-with-ionic-v-1-3
# http://stackoverflow.com/questions/tagged/angularjs
# http://stackoverflow.com/questions/tagged/ionic-framework
# http://stackoverflow.com/questions/tagged/angularfire
# http://stackoverflow.com/questions/tagged/account-kit
# http://stackoverflow.com/users/6260343/thelastone
# http://stackoverflow.com/questions/40867874/how-can-i-obtain-a-domain-driven-design-architecture-using-spring-data-jpa
# http://stackoverflow.com/questions/tagged/spring
# http://stackoverflow.com/questions/tagged/spring-data
# http://stackoverflow.com/questions/tagged/domain-driven-design
# http://stackoverflow.com/questions/tagged/spring-data-jpa
# http://stackoverflow.com/users/1833945/andreanobili
# http://stackoverflow.com/questions/40867873/how-to-prompt-byte-input-and-search-a-file-for-that-byte
# http://stackoverflow.com/questions/tagged/byte
# http://stackoverflow.com/users/7223182/df86
# http://stackoverflow.com/questions/40867872/variable-holds-two-values
# http://stackoverflow.com/questions/tagged/function
# http://stackoverflow.com/questions/tagged/global-variables
# http://stackoverflow.com/users/6570334/unknownzdx
# http://stackoverflow.com/questions/40867867/how-search-filter-in-pingfederate-pcv-works
# http://stackoverflow.com/questions/tagged/pingfederate
# http://stackoverflow.com/users/7225822/newbie
# http://stackoverflow.com/questions/40867563/how-to-process-javascript-from-xmlhttprequest-donwnloaded-file
# http://stackoverflow.com/users/1687746/saurav-rastogi
# http://stackoverflow.com/questions/40867866/unable-to-load-stylesheets
# http://stackoverflow.com/questions/tagged/css
# http://stackoverflow.com/questions/tagged/wordpress
# http://stackoverflow.com/users/5484596/re-sole
# http://stackoverflow.com/questions/40867856/javascript-hide-autocomplete-div-onblur
# http://stackoverflow.com/questions/tagged/autocomplete
# http://stackoverflow.com/users/7225747/dave
# http://stackoverflow.com/questions/40867854/how-to-set-variable-in-high-chart-data-field
# http://stackoverflow.com/questions/tagged/highcharts
# http://stackoverflow.com/users/3942180/arpita
# http://stackoverflow.com/questions/40867138/binding-combobox-data-to-listview-data-in-wpf
# http://stackoverflow.com/questions/tagged/wpf
# http://stackoverflow.com/questions/tagged/wpf-controls
# http://stackoverflow.com/questions/tagged/wpfdatagrid
# http://stackoverflow.com/questions/tagged/excel-addins
# http://stackoverflow.com/questions/40867138/binding-combobox-data-to-listview-data-in-wpf/?lastactivity
# http://stackoverflow.com/users/161885/muhammad-ummar
# http://stackoverflow.com/questions/40861298/how-to-optimize-g1s-pause-time
# http://stackoverflow.com/questions/tagged/garbage-collection
# http://stackoverflow.com/questions/tagged/g1
# http://stackoverflow.com/questions/40861298/how-to-optimize-g1s-pause-time/?lastactivity
# http://stackoverflow.com/users/2555321/marcs
# http://stackoverflow.com/questions/32467212/google-maps-marker-label-with-multiple-characters
# http://stackoverflow.com/questions/32467212/google-maps-marker-label-with-multiple-characters/?lastactivity
# http://stackoverflow.com/users/2046706/apostolis
# http://stackoverflow.com/questions/40867052/how-to-get-same-properties-from-different-parent-modules-in-maven
# http://stackoverflow.com/questions/tagged/maven
# http://stackoverflow.com/questions/40867052/how-to-get-same-properties-from-different-parent-modules-in-maven/?lastactivity
# http://stackoverflow.com/users/270371/davidxxx
# http://stackoverflow.com/questions/40867834/where-to-find-my-ocp-apim-subscription-key-in-windows-azure
# http://stackoverflow.com/questions/tagged/api
# http://stackoverflow.com/users/7022048/yj-yang
# http://stackoverflow.com/questions/40218828/testing-that-a-component-behaves-properly-when-the-service-it-calls-throws-an-ex
# http://stackoverflow.com/questions/tagged/unit-testing
# http://stackoverflow.com/questions/tagged/typescript
# http://stackoverflow.com/questions/tagged/jasmine
# http://stackoverflow.com/questions/40218828/testing-that-a-component-behaves-properly-when-the-service-it-calls-throws-an-ex/?lastactivity
# http://stackoverflow.com/users/100822/sebastien
# http://stackoverflow.com/questions/40865553/set-azurermvmaddomainextension-fails-to-add-vm-to-ad-domain
# http://stackoverflow.com/questions/40865553/set-azurermvmaddomainextension-fails-to-add-vm-to-ad-domain/?lastactivity
# http://stackoverflow.com/users/6498115/jenson-joseph
# http://stackoverflow.com/questions/40867231/strange-behavior-of-css-margins
# http://stackoverflow.com/questions/tagged/html
# http://stackoverflow.com/questions/tagged/css3
# http://stackoverflow.com/questions/tagged/margin
# http://stackoverflow.com/questions/40867231/strange-behavior-of-css-margins/?lastactivity
# http://stackoverflow.com/users/7069532/ashish-m
# http://stackoverflow.com/questions/40867804/how-can-i-get-the-url-of-a-thread-using-from-my-bot
# http://stackoverflow.com/questions/tagged/facebook
# http://stackoverflow.com/questions/tagged/facebook-messenger-bot
# http://stackoverflow.com/users/2380470/alexis
# http://stackoverflow.com/questions/40867639/relation-between-entities-in-ddd
# http://stackoverflow.com/questions/tagged/php
# http://stackoverflow.com/users/65732/sepehr
# http://stackoverflow.com/questions/40867497/xpath-for-parent-element-with-certain-descendant-element-regardless-of-depth
# http://stackoverflow.com/questions/tagged/xpath
# http://stackoverflow.com/questions/40867497/xpath-for-parent-element-with-certain-descendant-element-regardless-of-depth/?lastactivity
# http://stackoverflow.com/users/290085/kjhughes
# http://stackoverflow.com/questions/40867792/zope-schema-list-save-list-of-lists
# http://stackoverflow.com/questions/tagged/plone
# http://stackoverflow.com/questions/tagged/zope
# http://stackoverflow.com/users/966660/user966660
# http://stackoverflow.com/questions/40867612/office-js-outlook-saving-a-unsaved-appointment-using-saveasync
# http://stackoverflow.com/questions/tagged/outlook
# http://stackoverflow.com/questions/tagged/ms-office
# http://stackoverflow.com/questions/tagged/outlook-addin
# http://stackoverflow.com/questions/tagged/office-js
# http://stackoverflow.com/questions/tagged/outlook-web-app
# http://stackoverflow.com/users/4316374/alek-kowalczyk
# http://stackoverflow.com/questions/40867778/possible-to-get-the-message-body-with-lambda
# http://stackoverflow.com/questions/tagged/amazon-web-services
# http://stackoverflow.com/questions/tagged/amazon-s3
# http://stackoverflow.com/questions/tagged/aws-lambda
# http://stackoverflow.com/questions/tagged/ses
# http://stackoverflow.com/users/1590345/maddo7
# http://stackoverflow.com/questions/40867772/rename-windows-cluster-registered-in-dns
# http://stackoverflow.com/questions/tagged/cluster-computing
# http://stackoverflow.com/questions/tagged/sybase
# http://stackoverflow.com/users/6011743/scass
# http://stackoverflow.com/questions/40867762/kentico-upload-attachment-permissions
# http://stackoverflow.com/questions/tagged/kentico
# http://stackoverflow.com/users/935731/mark-handy
# http://stackoverflow.com/questions/40867749/varnish-wont-start-as-a-daemon
# http://stackoverflow.com/questions/tagged/ubuntu
# http://stackoverflow.com/questions/tagged/varnish
# http://stackoverflow.com/users/3170702/user3170702
# http://stackoverflow.com/questions/40867740/is-there-support-for-country-select-gem-in-rails-5
# http://stackoverflow.com/questions/tagged/ruby-on-rails-5
# http://stackoverflow.com/users/2112025/breen-ho
# http://stackoverflow.com/questions/40867736/kryo-serialisation-in-chronicle-map-slow-byte-reading
# http://stackoverflow.com/questions/tagged/scala
# http://stackoverflow.com/questions/tagged/kryo
# http://stackoverflow.com/questions/tagged/chronicle-map
# http://stackoverflow.com/users/61876/anton
# http://stackoverflow.com/questions/40861407/check-if-user-is-in-a-forest-using-location
# http://stackoverflow.com/questions/40861407/check-if-user-is-in-a-forest-using-location/?lastactivity
# http://stackoverflow.com/users/916670/ynot
# http://stackoverflow.com/questions/40867608/sroll-on-hover-and-text-leaping
# http://stackoverflow.com/questions/tagged/html5
# http://stackoverflow.com/questions/tagged/scrollbar
# http://stackoverflow.com/users/4727602/whitcik
# http://stackoverflow.com/questions/40867193/sql-rollup-with-alias
# http://stackoverflow.com/questions/tagged/postgresql
# http://stackoverflow.com/users/6638204/user6638204
# http://stackoverflow.com/questions/40867662/android-launch-my-app-when-dialing-a-number
# http://stackoverflow.com/users/6343685/ironman
# http://stackoverflow.com/questions/40867687/how-to-refresh-android-listview-after-syncadapter-completes-a-sync
# http://stackoverflow.com/questions/tagged/listview
# http://stackoverflow.com/questions/tagged/synchronization
# http://stackoverflow.com/users/1131949/captain-kenpachi
# http://stackoverflow.com/questions/40867672/cup-parser-returns-syntax-error-for-a-valid-input
# http://stackoverflow.com/questions/tagged/parsing
# http://stackoverflow.com/questions/tagged/compilation
# http://stackoverflow.com/questions/tagged/jflex
# http://stackoverflow.com/questions/tagged/cup
# http://stackoverflow.com/users/7225757/plex
# http://stackoverflow.com/questions/40865816/missing-gridlines-using-nvd3-ng2
# http://stackoverflow.com/questions/tagged/nvd3.js
# http://stackoverflow.com/questions/tagged/gridlines
# http://stackoverflow.com/questions/tagged/ng2-nvd3
# http://stackoverflow.com/users/7225361/ekuusi
# http://stackoverflow.com/questions/40867490/magento2-argument-1-must-be-an-instance-of-magento-framework-app-helper-c
# http://stackoverflow.com/questions/tagged/magento
# http://stackoverflow.com/questions/tagged/magento2
# http://stackoverflow.com/users/7225265/paul-davies
# http://stackoverflow.com/questions/40866355/drawing-a-perpendicular-bisector-of-two-points-in-gnuplot
# http://stackoverflow.com/questions/tagged/graph
# http://stackoverflow.com/questions/tagged/gnuplot
# http://stackoverflow.com/questions/tagged/draw
# http://stackoverflow.com/questions/tagged/bisection
# http://stackoverflow.com/users/7064921/user7064921
# http://stackoverflow.com/questions/40867180/show-caption-on-chart-js
# http://stackoverflow.com/questions/tagged/chart.js
# http://stackoverflow.com/users/2311633/jonnus
# http://stackoverflow.com/questions/40689454/final-adjustment-needed-for-collapsible-menu-jquery
# http://stackoverflow.com/questions/tagged/menu
# http://stackoverflow.com/questions/40689454/final-adjustment-needed-for-collapsible-menu-jquery/?lastactivity
# http://stackoverflow.com/questions/40867256/webpack-exposing-global-variable-without-using-provideplugin-and-expose-loader
# http://stackoverflow.com/questions/tagged/webpack
# http://stackoverflow.com/users/20788/mike-post
# http://stackoverflow.com/questions/40867407/android-espresso-multidex-fail
# http://stackoverflow.com/questions/tagged/android-espresso
# http://stackoverflow.com/questions/tagged/android-multidex
# http://stackoverflow.com/users/1571080/originx
# http://stackoverflow.com/questions/40867239/object-detection-algorithms-in-opencv
# http://stackoverflow.com/questions/tagged/image-processing
# http://stackoverflow.com/questions/tagged/opencv3.0
# http://stackoverflow.com/questions/tagged/object-detection
# http://stackoverflow.com/users/4857206/george-katsikopoulos
# http://stackoverflow.com/questions/40867192/auto-fill-jaxb-class-sample-request
# http://stackoverflow.com/questions/tagged/web-services
# http://stackoverflow.com/questions/tagged/jaxb
# http://stackoverflow.com/users/5655414/angryip
# http://stackoverflow.com/questions/40866403/sqoop-1-99-3-export-into-mysql-returns-empty-tables
# http://stackoverflow.com/questions/tagged/mysql
# http://stackoverflow.com/questions/tagged/datetime
# http://stackoverflow.com/questions/tagged/export
# http://stackoverflow.com/questions/tagged/hdfs
# http://stackoverflow.com/questions/tagged/sqoop
# http://stackoverflow.com/users/7094932/lejla-d%c5%beanko
# http://stackoverflow.com/questions/40866894/constraintlayout-margins-not-working
# http://stackoverflow.com/questions/tagged/android-xml
# http://stackoverflow.com/questions/tagged/android-constraintlayout
# http://stackoverflow.com/questions/tagged/constraint-layout
# http://stackoverflow.com/users/4512395/ognian-gloushkov
# http://stackoverflow.com/questions/40867156/android-background-service-for-location-is-not-working-in-other-phones
# http://stackoverflow.com/questions/tagged/service
# http://stackoverflow.com/questions/tagged/location
# http://stackoverflow.com/questions/tagged/android-pendingintent
# http://stackoverflow.com/questions/tagged/android-gps
# http://stackoverflow.com/users/7223593/sanjay-joshi
# http://stackoverflow.com/questions/40867135/unsound-implicit-cast-warning-not-shown-for-generic-parameter
# http://stackoverflow.com/questions/tagged/static-analysis
# http://stackoverflow.com/users/5521491/alexey-adamovskiy
# http://stackoverflow.com/questions/40867016/scala-inline-unapply-extractor
# http://stackoverflow.com/questions/tagged/inline
# http://stackoverflow.com/questions/tagged/extractor
# http://stackoverflow.com/users/1287856/mika%c3%abl-mayer
# http://stackoverflow.com/questions/40867007/php-handshake-fail-tls1-0
# http://stackoverflow.com/questions/tagged/ssl
# http://stackoverflow.com/questions/tagged/openssl
# http://stackoverflow.com/users/1903575/cronos
# http://stackoverflow.com/questions/40867004/selecting-all-rows-in-datagridview-and-export-it-to-crystalreport
# http://stackoverflow.com/questions/tagged/vb.net
# http://stackoverflow.com/questions/tagged/datagridview
# http://stackoverflow.com/questions/tagged/datarow
# http://stackoverflow.com/users/7225638/george-uy
# http://stackoverflow.com/questions/40866606/debugging-in-visual-studio-without-pdb-files-c-access-voilation
# http://stackoverflow.com/questions/tagged/opencv
# http://stackoverflow.com/questions/tagged/exception-handling
# http://stackoverflow.com/questions/tagged/ffmpeg
# http://stackoverflow.com/questions/tagged/access-violation
# http://stackoverflow.com/users/4359558/prakash-m
# http://stackoverflow.com/questions/40866787/making-servers-in-f
# http://stackoverflow.com/questions/tagged/.net
# http://stackoverflow.com/questions/tagged/f%23
# http://stackoverflow.com/questions/tagged/microservices
# http://stackoverflow.com/users/78640/giantsquid
# http://stackoverflow.com/questions/40866105/pouchdb-replication-throws-error-upon-replication
# http://stackoverflow.com/questions/tagged/couchdb
# http://stackoverflow.com/questions/tagged/ubuntu-14.04
# http://stackoverflow.com/questions/tagged/pouchdb
# http://stackoverflow.com/users/5730444/phonolog
# http://stackoverflow.com/questions/40866244/objetctanimator-with-array-variable
# http://stackoverflow.com/questions/tagged/animation
# http://stackoverflow.com/questions/tagged/objectanimator
# http://stackoverflow.com/users/1281081/asfk
# http://stackoverflow.com/questions/40865391/how-to-show-text-yes-no-inside-a-switch-in-react-native
# http://stackoverflow.com/questions/tagged/react-native
# http://stackoverflow.com/users/1090798/krish
# http://stackoverflow.com/unanswered
# http://mathematica.stackexchange.com/questions/132323/how-to-effiectively-substitute-the-member-in-list-with-their-order
# http://photo.stackexchange.com/questions/84861/why-is-this-child-portrait-not-compelling-what-went-wrong-and-what-could-have-b
# http://worldbuilding.stackexchange.com/questions/62572/truth-stone-effects-on-the-justice-system-and-criminal-world
# http://academia.stackexchange.com/questions/80652/discussion-turned-into-argument-with-the-conference-keynote-speaker-feeling-bad
# http://codegolf.stackexchange.com/questions/101469/grid-ascii-art-code-golf
# http://worldbuilding.stackexchange.com/questions/62533/military-tank-drone-why-are-they-not-common-yet
# http://tex.stackexchange.com/questions/341451/the-text-is-pushed-down-when-there-is-a-picture-in-the-other-column
# http://academia.stackexchange.com/questions/80643/unintentionally-disrespectful-in-the-statement-of-purpose-academic-essay
# http://english.stackexchange.com/questions/360721/is-soul-to-soul-talk-a-common-expression-in-english
# http://physics.stackexchange.com/questions/294966/what-does-antimatter-look-like
# http://puzzling.stackexchange.com/questions/46210/what-was-the-child-sent-to-buy
# http://stackoverflow.com/questions/40848551/how-does-adding-string-with-integer-work-in-javascript
# http://mathoverflow.net/questions/255820/how-should-a-working-mathematician-think-about-sets-zfc-category-theory-ur
# http://academia.stackexchange.com/questions/80561/how-to-professionally-handle-sexist-remarks-by-a-student
# http://travel.stackexchange.com/questions/83389/how-are-different-meal-ratios-calculated-for-flights
# http://sqa.stackexchange.com/questions/23932/do-we-use-need-test-cases-in-agile
# http://scifi.stackexchange.com/questions/146136/why-no-medievalworld-or-romanworld
# http://mathematica.stackexchange.com/questions/132332/simple-rule-does-not-work
# http://stackoverflow.com/questions/40861062/text-with-multiple-underlines
# http://mathoverflow.net/questions/255896/derivative-is-zero-on-a-dense-g-delta-set
# http://codegolf.stackexchange.com/questions/101275/figure-and-ground
# http://superuser.com/questions/1150860/what-the-np-reading-means-for-a-dvi-computer-monitor
# http://scifi.stackexchange.com/questions/146011/why-does-prof-farnsworth-run-planet-express
# http://puzzling.stackexchange.com/questions/46208/a-smart-girl
# http://stackoverflow.blog?blb=1
# http://data.stackexchange.com
# http://stackexchange.com/legal
# http://stackexchange.com/legal/privacy-policy
# http://stackoverflow.com/company/work-here
# http://stackexchange.com/mediakit
# http://stackoverflow.com/contact
# http://meta.stackoverflow.com
# http://stackexchange.com/sites
# https://creativecommons.org/licenses/by-sa/3.0/
# http://blog.stackoverflow.com/2009/06/attribution-required/

# %%
def is_valid_wordID(wordIDBytes):
    for i in wordIDBytes:
        if i != 0:
            return True
    return False

def forward_index_review():
    with open('barrels/forward_index.bin', 'r+b') as fp:
        fp.seek(0, 2)
        size = fp.tell()
        fp.seek(0, 0)
        while(fp.tell() < size):
            docID = struct.unpack("I", fp.read(4))[0]
            print "DOC ID: ", docID
            while is_valid_wordID(struct.unpack("BBB", fp.read(3))):
                fp.seek(-3, 1)
                hit_data = struct.unpack("I", fp.read(4))[0]
                num_hits = hit_data & 0xFF
                wordID = hit_data >> 8 & 0xFFFFFF
                print "WordID: ", wordID
                print "num_hits: ", num_hits
                print ""
                fp.seek(num_hits*2, 1)
            print "======================="

forward_index_review()
# Out:
# DOC ID:  0
# WordID:  1
# num_hits:  1
#
# WordID:  2
# num_hits:  1
#
# =======================
# DOC ID:  1
# WordID:  3
# num_hits:  1
#
# =======================
# DOC ID:  2
# WordID:  4
# num_hits:  1
#
# WordID:  5
# num_hits:  1
#
# =======================
# DOC ID:  3
# WordID:  6
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# =======================
# DOC ID:  4
# WordID:  8
# num_hits:  1
#
# WordID:  9
# num_hits:  1
#
# =======================
# DOC ID:  5
# WordID:  4
# num_hits:  1
#
# WordID:  5
# num_hits:  1
#
# =======================
# DOC ID:  6
# WordID:  6
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# =======================
# DOC ID:  7
# WordID:  10
# num_hits:  1
#
# =======================
# DOC ID:  0
# WordID:  0
# num_hits:  2
#
# WordID:  11
# num_hits:  1
#
# =======================
# DOC ID:  7
# WordID:  0
# num_hits:  2
#
# WordID:  10
# num_hits:  1
#
# =======================
# DOC ID:  8
# WordID:  0
# num_hits:  2
#
# WordID:  11
# num_hits:  1
#
# WordID:  12
# num_hits:  1
#
# =======================
# DOC ID:  9
# WordID:  0
# num_hits:  2
#
# WordID:  13
# num_hits:  1
#
# WordID:  14
# num_hits:  1
#
# =======================
# DOC ID:  10
# WordID:  0
# num_hits:  2
#
# WordID:  15
# num_hits:  1
#
# =======================
# DOC ID:  0
# WordID:  0
# num_hits:  2
#
# WordID:  1
# num_hits:  1
#
# WordID:  2
# num_hits:  1
#
# =======================
# DOC ID:  11
# WordID:  0
# num_hits:  2
#
# WordID:  16
# num_hits:  1
#
# =======================
# DOC ID:  12
# WordID:  0
# num_hits:  2
#
# WordID:  17
# num_hits:  1
#
# =======================
# DOC ID:  13
# WordID:  0
# num_hits:  2
#
# WordID:  18
# num_hits:  1
#
# =======================
# DOC ID:  14
# WordID:  0
# num_hits:  2
#
# WordID:  19
# num_hits:  1
#
# =======================
# DOC ID:  15
# WordID:  0
# num_hits:  2
#
# WordID:  20
# num_hits:  1
#
# =======================
# DOC ID:  16
# WordID:  0
# num_hits:  2
#
# WordID:  21
# num_hits:  1
#
# =======================
# DOC ID:  17
# WordID:  22
# num_hits:  1
#
# WordID:  23
# num_hits:  1
#
# =======================
# DOC ID:  18
# WordID:  0
# num_hits:  1
#
# WordID:  24
# num_hits:  1
#
# WordID:  25
# num_hits:  1
#
# WordID:  26
# num_hits:  1
#
# WordID:  27
# num_hits:  1
#
# =======================
# DOC ID:  19
# WordID:  0
# num_hits:  1
#
# WordID:  28
# num_hits:  1
#
# =======================
# DOC ID:  20
# WordID:  0
# num_hits:  1
#
# WordID:  29
# num_hits:  1
#
# =======================
# DOC ID:  21
# WordID:  0
# num_hits:  1
#
# WordID:  30
# num_hits:  1
#
# =======================
# DOC ID:  22
# WordID:  0
# num_hits:  1
#
# WordID:  31
# num_hits:  1
#
# =======================
# DOC ID:  23
# WordID:  32
# num_hits:  1
#
# WordID:  33
# num_hits:  1
#
# WordID:  0
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  36
# num_hits:  1
#
# WordID:  37
# num_hits:  1
#
# WordID:  38
# num_hits:  1
#
# WordID:  39
# num_hits:  1
#
# =======================
# DOC ID:  24
# WordID:  40
# num_hits:  1
#
# =======================
# DOC ID:  25
# WordID:  36
# num_hits:  1
#
# =======================
# DOC ID:  26
# WordID:  41
# num_hits:  1
#
# =======================
# DOC ID:  23
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  27
# WordID:  43
# num_hits:  1
#
# =======================
# DOC ID:  28
# WordID:  44
# num_hits:  1
#
# WordID:  0
# num_hits:  1
#
# WordID:  45
# num_hits:  1
#
# WordID:  46
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  47
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  48
# num_hits:  1
#
# WordID:  49
# num_hits:  1
#
# WordID:  50
# num_hits:  1
#
# WordID:  51
# num_hits:  1
#
# WordID:  52
# num_hits:  1
#
# =======================
# DOC ID:  29
# WordID:  53
# num_hits:  1
#
# =======================
# DOC ID:  30
# WordID:  54
# num_hits:  1
#
# =======================
# DOC ID:  31
# WordID:  55
# num_hits:  1
#
# =======================
# DOC ID:  28
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  32
# WordID:  44
# num_hits:  1
#
# WordID:  0
# num_hits:  1
#
# WordID:  56
# num_hits:  1
#
# WordID:  57
# num_hits:  1
#
# WordID:  58
# num_hits:  1
#
# WordID:  59
# num_hits:  1
#
# WordID:  60
# num_hits:  1
#
# WordID:  61
# num_hits:  1
#
# WordID:  62
# num_hits:  1
#
# WordID:  63
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  64
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  65
# num_hits:  1
#
# WordID:  66
# num_hits:  1
#
# WordID:  67
# num_hits:  1
#
# =======================
# DOC ID:  24
# WordID:  40
# num_hits:  1
#
# =======================
# DOC ID:  33
# WordID:  68
# num_hits:  1
#
# =======================
# DOC ID:  34
# WordID:  69
# num_hits:  1
#
# =======================
# DOC ID:  35
# WordID:  70
# num_hits:  1
#
# WordID:  71
# num_hits:  1
#
# WordID:  67
# num_hits:  1
#
# =======================
# DOC ID:  32
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  36
# WordID:  72
# num_hits:  1
#
# WordID:  73
# num_hits:  1
#
# =======================
# DOC ID:  37
# WordID:  0
# num_hits:  1
#
# WordID:  74
# num_hits:  1
#
# WordID:  75
# num_hits:  2
#
# WordID:  76
# num_hits:  1
#
# WordID:  77
# num_hits:  1
#
# WordID:  78
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  79
# num_hits:  1
#
# WordID:  80
# num_hits:  1
#
# WordID:  81
# num_hits:  1
#
# WordID:  82
# num_hits:  1
#
# WordID:  83
# num_hits:  1
#
# WordID:  84
# num_hits:  1
#
# =======================
# DOC ID:  38
# WordID:  76
# num_hits:  1
#
# =======================
# DOC ID:  39
# WordID:  85
# num_hits:  1
#
# =======================
# DOC ID:  37
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  40
# WordID:  86
# num_hits:  1
#
# =======================
# DOC ID:  41
# WordID:  87
# num_hits:  1
#
# WordID:  88
# num_hits:  1
#
# WordID:  46
# num_hits:  1
#
# WordID:  89
# num_hits:  1
#
# WordID:  90
# num_hits:  1
#
# WordID:  91
# num_hits:  1
#
# WordID:  92
# num_hits:  1
#
# WordID:  93
# num_hits:  1
#
# WordID:  94
# num_hits:  1
#
# WordID:  95
# num_hits:  1
#
# WordID:  96
# num_hits:  1
#
# WordID:  97
# num_hits:  1
#
# =======================
# DOC ID:  42
# WordID:  93
# num_hits:  1
#
# =======================
# DOC ID:  43
# WordID:  98
# num_hits:  1
#
# WordID:  93
# num_hits:  1
#
# WordID:  99
# num_hits:  1
#
# =======================
# DOC ID:  44
# WordID:  87
# num_hits:  1
#
# =======================
# DOC ID:  41
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  45
# WordID:  100
# num_hits:  1
#
# =======================
# DOC ID:  46
# WordID:  101
# num_hits:  1
#
# WordID:  102
# num_hits:  1
#
# =======================
# DOC ID:  47
# WordID:  103
# num_hits:  1
#
# =======================
# DOC ID:  48
# WordID:  104
# num_hits:  1
#
# =======================
# DOC ID:  49
# WordID:  105
# num_hits:  1
#
# =======================
# DOC ID:  50
# WordID:  106
# num_hits:  1
#
# =======================
# DOC ID:  51
# WordID:  107
# num_hits:  1
#
# =======================
# DOC ID:  46
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  52
# WordID:  108
# num_hits:  1
#
# =======================
# DOC ID:  53
# WordID:  109
# num_hits:  1
#
# WordID:  110
# num_hits:  1
#
# WordID:  59
# num_hits:  1
#
# WordID:  111
# num_hits:  1
#
# WordID:  112
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  113
# num_hits:  1
#
# WordID:  114
# num_hits:  1
#
# WordID:  67
# num_hits:  1
#
# WordID:  115
# num_hits:  1
#
# =======================
# DOC ID:  54
# WordID:  33
# num_hits:  1
#
# WordID:  116
# num_hits:  1
#
# WordID:  117
# num_hits:  1
#
# WordID:  112
# num_hits:  1
#
# =======================
# DOC ID:  55
# WordID:  118
# num_hits:  1
#
# =======================
# DOC ID:  56
# WordID:  119
# num_hits:  1
#
# =======================
# DOC ID:  57
# WordID:  120
# num_hits:  1
#
# =======================
# DOC ID:  58
# WordID:  110
# num_hits:  1
#
# =======================
# DOC ID:  53
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  59
# WordID:  122
# num_hits:  1
#
# =======================
# DOC ID:  60
# WordID:  46
# num_hits:  1
#
# WordID:  123
# num_hits:  1
#
# WordID:  124
# num_hits:  1
#
# WordID:  125
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  79
# num_hits:  1
#
# WordID:  126
# num_hits:  1
#
# WordID:  52
# num_hits:  1
#
# WordID:  127
# num_hits:  1
#
# WordID:  128
# num_hits:  1
#
# =======================
# DOC ID:  61
# WordID:  129
# num_hits:  1
#
# =======================
# DOC ID:  62
# WordID:  130
# num_hits:  1
#
# WordID:  128
# num_hits:  1
#
# =======================
# DOC ID:  63
# WordID:  131
# num_hits:  1
#
# WordID:  132
# num_hits:  1
#
# WordID:  133
# num_hits:  1
#
# =======================
# DOC ID:  64
# WordID:  126
# num_hits:  1
#
# =======================
# DOC ID:  65
# WordID:  126
# num_hits:  1
#
# WordID:  125
# num_hits:  1
#
# =======================
# DOC ID:  60
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  66
# WordID:  134
# num_hits:  1
#
# =======================
# DOC ID:  67
# WordID:  0
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  135
# num_hits:  1
#
# WordID:  136
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  137
# num_hits:  1
#
# WordID:  138
# num_hits:  1
#
# =======================
# DOC ID:  68
# WordID:  0
# num_hits:  1
#
# WordID:  139
# num_hits:  1
#
# =======================
# DOC ID:  69
# WordID:  140
# num_hits:  1
#
# =======================
# DOC ID:  70
# WordID:  140
# num_hits:  1
#
# WordID:  103
# num_hits:  1
#
# =======================
# DOC ID:  71
# WordID:  141
# num_hits:  1
#
# WordID:  142
# num_hits:  1
#
# =======================
# DOC ID:  67
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  72
# WordID:  143
# num_hits:  1
#
# =======================
# DOC ID:  73
# WordID:  44
# num_hits:  1
#
# WordID:  144
# num_hits:  1
#
# WordID:  145
# num_hits:  1
#
# WordID:  34
# num_hits:  2
#
# WordID:  146
# num_hits:  1
#
# WordID:  147
# num_hits:  1
#
# WordID:  148
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  149
# num_hits:  1
#
# WordID:  150
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  151
# num_hits:  1
#
# WordID:  52
# num_hits:  1
#
# WordID:  67
# num_hits:  1
#
# WordID:  152
# num_hits:  1
#
# WordID:  136
# num_hits:  1
#
# WordID:  153
# num_hits:  1
#
# WordID:  154
# num_hits:  1
#
# =======================
# DOC ID:  47
# WordID:  103
# num_hits:  1
#
# =======================
# DOC ID:  74
# WordID:  150
# num_hits:  1
#
# =======================
# DOC ID:  75
# WordID:  155
# num_hits:  1
#
# =======================
# DOC ID:  73
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  76
# WordID:  156
# num_hits:  1
#
# =======================
# DOC ID:  77
# WordID:  144
# num_hits:  1
#
# WordID:  0
# num_hits:  1
#
# WordID:  157
# num_hits:  1
#
# WordID:  158
# num_hits:  1
#
# WordID:  159
# num_hits:  1
#
# WordID:  160
# num_hits:  1
#
# WordID:  161
# num_hits:  1
#
# WordID:  162
# num_hits:  1
#
# WordID:  136
# num_hits:  1
#
# =======================
# DOC ID:  78
# WordID:  160
# num_hits:  1
#
# =======================
# DOC ID:  79
# WordID:  160
# num_hits:  1
#
# WordID:  163
# num_hits:  1
#
# =======================
# DOC ID:  77
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  80
# WordID:  164
# num_hits:  1
#
# =======================
# DOC ID:  81
# WordID:  0
# num_hits:  1
#
# WordID:  165
# num_hits:  1
#
# WordID:  166
# num_hits:  1
#
# WordID:  59
# num_hits:  1
#
# WordID:  167
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  168
# num_hits:  1
#
# WordID:  46
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  169
# num_hits:  1
#
# WordID:  170
# num_hits:  1
#
# WordID:  97
# num_hits:  1
#
# WordID:  171
# num_hits:  1
#
# WordID:  172
# num_hits:  1
#
# WordID:  173
# num_hits:  1
#
# WordID:  174
# num_hits:  1
#
# WordID:  33
# num_hits:  1
#
# WordID:  39
# num_hits:  1
#
# WordID:  175
# num_hits:  1
#
# WordID:  146
# num_hits:  1
#
# WordID:  176
# num_hits:  1
#
# WordID:  67
# num_hits:  3
#
# WordID:  177
# num_hits:  1
#
# =======================
# DOC ID:  82
# WordID:  178
# num_hits:  1
#
# =======================
# DOC ID:  83
# WordID:  179
# num_hits:  1
#
# =======================
# DOC ID:  84
# WordID:  179
# num_hits:  1
#
# WordID:  178
# num_hits:  1
#
# =======================
# DOC ID:  81
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  85
# WordID:  180
# num_hits:  1
#
# =======================
# DOC ID:  86
# WordID:  0
# num_hits:  1
#
# WordID:  181
# num_hits:  1
#
# WordID:  111
# num_hits:  1
#
# WordID:  182
# num_hits:  1
#
# WordID:  183
# num_hits:  1
#
# WordID:  184
# num_hits:  1
#
# WordID:  185
# num_hits:  1
#
# WordID:  186
# num_hits:  1
#
# WordID:  187
# num_hits:  1
#
# =======================
# DOC ID:  68
# WordID:  0
# num_hits:  1
#
# WordID:  139
# num_hits:  1
#
# =======================
# DOC ID:  87
# WordID:  182
# num_hits:  1
#
# =======================
# DOC ID:  88
# WordID:  183
# num_hits:  1
#
# WordID:  188
# num_hits:  1
#
# =======================
# DOC ID:  89
# WordID:  189
# num_hits:  1
#
# WordID:  190
# num_hits:  1
#
# WordID:  191
# num_hits:  1
#
# WordID:  192
# num_hits:  1
#
# =======================
# DOC ID:  90
# WordID:  184
# num_hits:  1
#
# WordID:  193
# num_hits:  1
#
# =======================
# DOC ID:  86
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  91
# WordID:  194
# num_hits:  1
#
# =======================
# DOC ID:  92
# WordID:  195
# num_hits:  1
#
# WordID:  46
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  196
# num_hits:  2
#
# WordID:  197
# num_hits:  1
#
# WordID:  198
# num_hits:  1
#
# WordID:  199
# num_hits:  2
#
# WordID:  200
# num_hits:  2
#
# WordID:  201
# num_hits:  2
#
# =======================
# DOC ID:  93
# WordID:  33
# num_hits:  1
#
# WordID:  116
# num_hits:  1
#
# WordID:  112
# num_hits:  1
#
# =======================
# DOC ID:  94
# WordID:  197
# num_hits:  1
#
# =======================
# DOC ID:  56
# WordID:  119
# num_hits:  1
#
# =======================
# DOC ID:  92
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  95
# WordID:  202
# num_hits:  1
#
# =======================
# DOC ID:  96
# WordID:  34
# num_hits:  1
#
# WordID:  203
# num_hits:  1
#
# WordID:  204
# num_hits:  1
#
# WordID:  205
# num_hits:  1
#
# WordID:  206
# num_hits:  1
#
# WordID:  207
# num_hits:  1
#
# WordID:  208
# num_hits:  1
#
# =======================
# DOC ID:  47
# WordID:  103
# num_hits:  1
#
# =======================
# DOC ID:  97
# WordID:  208
# num_hits:  1
#
# =======================
# DOC ID:  50
# WordID:  106
# num_hits:  1
#
# =======================
# DOC ID:  98
# WordID:  0
# num_hits:  1
#
# WordID:  209
# num_hits:  1
#
# =======================
# DOC ID:  99
# WordID:  210
# num_hits:  1
#
# WordID:  211
# num_hits:  1
#
# =======================
# DOC ID:  100
# WordID:  212
# num_hits:  1
#
# WordID:  44
# num_hits:  2
#
# WordID:  34
# num_hits:  1
#
# WordID:  213
# num_hits:  1
#
# WordID:  214
# num_hits:  1
#
# WordID:  215
# num_hits:  1
#
# WordID:  216
# num_hits:  1
#
# WordID:  217
# num_hits:  1
#
# WordID:  136
# num_hits:  1
#
# =======================
# DOC ID:  68
# WordID:  0
# num_hits:  1
#
# WordID:  139
# num_hits:  1
#
# =======================
# DOC ID:  101
# WordID:  218
# num_hits:  1
#
# =======================
# DOC ID:  100
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  102
# WordID:  219
# num_hits:  1
#
# WordID:  220
# num_hits:  1
#
# =======================
# DOC ID:  103
# WordID:  144
# num_hits:  1
#
# WordID:  221
# num_hits:  1
#
# WordID:  222
# num_hits:  1
#
# WordID:  223
# num_hits:  1
#
# WordID:  224
# num_hits:  1
#
# WordID:  36
# num_hits:  1
#
# WordID:  225
# num_hits:  1
#
# WordID:  226
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  52
# num_hits:  1
#
# WordID:  97
# num_hits:  1
#
# =======================
# DOC ID:  25
# WordID:  36
# num_hits:  1
#
# =======================
# DOC ID:  104
# WordID:  227
# num_hits:  1
#
# =======================
# DOC ID:  105
# WordID:  228
# num_hits:  1
#
# =======================
# DOC ID:  106
# WordID:  229
# num_hits:  1
#
# WordID:  230
# num_hits:  1
#
# =======================
# DOC ID:  107
# WordID:  221
# num_hits:  1
#
# =======================
# DOC ID:  103
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  108
# WordID:  231
# num_hits:  1
#
# =======================
# DOC ID:  109
# WordID:  144
# num_hits:  1
#
# WordID:  232
# num_hits:  1
#
# WordID:  233
# num_hits:  1
#
# WordID:  111
# num_hits:  1
#
# WordID:  234
# num_hits:  1
#
# WordID:  235
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  236
# num_hits:  1
#
# WordID:  39
# num_hits:  1
#
# WordID:  237
# num_hits:  1
#
# =======================
# DOC ID:  110
# WordID:  190
# num_hits:  1
#
# WordID:  191
# num_hits:  1
#
# WordID:  235
# num_hits:  1
#
# =======================
# DOC ID:  111
# WordID:  190
# num_hits:  1
#
# WordID:  191
# num_hits:  1
#
# WordID:  238
# num_hits:  1
#
# WordID:  235
# num_hits:  1
#
# =======================
# DOC ID:  109
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  112
# WordID:  239
# num_hits:  1
#
# =======================
# DOC ID:  113
# WordID:  240
# num_hits:  1
#
# WordID:  191
# num_hits:  1
#
# WordID:  241
# num_hits:  1
#
# WordID:  235
# num_hits:  1
#
# WordID:  117
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  190
# num_hits:  1
#
# =======================
# DOC ID:  61
# WordID:  129
# num_hits:  1
#
# =======================
# DOC ID:  114
# WordID:  242
# num_hits:  1
#
# =======================
# DOC ID:  115
# WordID:  190
# num_hits:  1
#
# WordID:  191
# num_hits:  1
#
# WordID:  117
# num_hits:  1
#
# WordID:  235
# num_hits:  1
#
# =======================
# DOC ID:  116
# WordID:  243
# num_hits:  1
#
# =======================
# DOC ID:  117
# WordID:  0
# num_hits:  1
#
# WordID:  209
# num_hits:  1
#
# =======================
# DOC ID:  118
# WordID:  244
# num_hits:  1
#
# WordID:  245
# num_hits:  1
#
# WordID:  246
# num_hits:  1
#
# WordID:  247
# num_hits:  1
#
# =======================
# DOC ID:  119
# WordID:  248
# num_hits:  1
#
# WordID:  249
# num_hits:  1
#
# WordID:  250
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  251
# num_hits:  2
#
# WordID:  131
# num_hits:  1
#
# WordID:  252
# num_hits:  1
#
# WordID:  253
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  254
# num_hits:  1
#
# WordID:  255
# num_hits:  1
#
# =======================
# DOC ID:  120
# WordID:  255
# num_hits:  1
#
# WordID:  252
# num_hits:  1
#
# =======================
# DOC ID:  121
# WordID:  255
# num_hits:  1
#
# WordID:  253
# num_hits:  1
#
# =======================
# DOC ID:  119
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  122
# WordID:  256
# num_hits:  1
#
# =======================
# DOC ID:  123
# WordID:  223
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  146
# num_hits:  1
#
# WordID:  257
# num_hits:  1
#
# WordID:  258
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  233
# num_hits:  1
#
# WordID:  259
# num_hits:  1
#
# WordID:  260
# num_hits:  1
#
# WordID:  261
# num_hits:  1
#
# =======================
# DOC ID:  124
# WordID:  259
# num_hits:  1
#
# =======================
# DOC ID:  125
# WordID:  257
# num_hits:  1
#
# =======================
# DOC ID:  126
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  127
# WordID:  262
# num_hits:  1
#
# =======================
# DOC ID:  128
# WordID:  263
# num_hits:  1
#
# WordID:  33
# num_hits:  1
#
# WordID:  264
# num_hits:  1
#
# WordID:  265
# num_hits:  1
#
# WordID:  266
# num_hits:  1
#
# WordID:  267
# num_hits:  1
#
# WordID:  44
# num_hits:  1
#
# WordID:  268
# num_hits:  1
#
# WordID:  269
# num_hits:  1
#
# =======================
# DOC ID:  129
# WordID:  270
# num_hits:  1
#
# =======================
# DOC ID:  130
# WordID:  265
# num_hits:  1
#
# =======================
# DOC ID:  131
# WordID:  271
# num_hits:  1
#
# =======================
# DOC ID:  128
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  132
# WordID:  272
# num_hits:  1
#
# =======================
# DOC ID:  133
# WordID:  129
# num_hits:  1
#
# WordID:  273
# num_hits:  1
#
# WordID:  274
# num_hits:  1
#
# WordID:  275
# num_hits:  1
#
# =======================
# DOC ID:  61
# WordID:  129
# num_hits:  1
#
# =======================
# DOC ID:  134
# WordID:  129
# num_hits:  1
#
# WordID:  275
# num_hits:  1
#
# =======================
# DOC ID:  135
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  136
# WordID:  276
# num_hits:  1
#
# =======================
# DOC ID:  137
# WordID:  277
# num_hits:  1
#
# WordID:  278
# num_hits:  1
#
# WordID:  279
# num_hits:  1
#
# WordID:  280
# num_hits:  1
#
# WordID:  75
# num_hits:  1
#
# WordID:  281
# num_hits:  1
#
# WordID:  282
# num_hits:  1
#
# WordID:  283
# num_hits:  1
#
# WordID:  284
# num_hits:  1
#
# WordID:  285
# num_hits:  1
#
# WordID:  133
# num_hits:  1
#
# WordID:  286
# num_hits:  1
#
# =======================
# DOC ID:  138
# WordID:  287
# num_hits:  1
#
# =======================
# DOC ID:  139
# WordID:  283
# num_hits:  1
#
# =======================
# DOC ID:  140
# WordID:  288
# num_hits:  1
#
# =======================
# DOC ID:  137
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  141
# WordID:  289
# num_hits:  1
#
# =======================
# DOC ID:  142
# WordID:  46
# num_hits:  1
#
# WordID:  290
# num_hits:  1
#
# WordID:  255
# num_hits:  1
#
# WordID:  291
# num_hits:  1
#
# WordID:  292
# num_hits:  1
#
# WordID:  293
# num_hits:  1
#
# =======================
# DOC ID:  143
# WordID:  255
# num_hits:  1
#
# =======================
# DOC ID:  144
# WordID:  294
# num_hits:  1
#
# =======================
# DOC ID:  145
# WordID:  295
# num_hits:  1
#
# WordID:  296
# num_hits:  1
#
# =======================
# DOC ID:  146
# WordID:  297
# num_hits:  1
#
# WordID:  298
# num_hits:  1
#
# =======================
# DOC ID:  142
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  147
# WordID:  299
# num_hits:  1
#
# WordID:  300
# num_hits:  1
#
# =======================
# DOC ID:  148
# WordID:  301
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  103
# num_hits:  1
#
# WordID:  5
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  302
# num_hits:  1
#
# =======================
# DOC ID:  47
# WordID:  103
# num_hits:  1
#
# =======================
# DOC ID:  149
# WordID:  303
# num_hits:  1
#
# =======================
# DOC ID:  150
# WordID:  304
# num_hits:  1
#
# =======================
# DOC ID:  151
# WordID:  103
# num_hits:  1
#
# WordID:  305
# num_hits:  1
#
# WordID:  65
# num_hits:  1
#
# =======================
# DOC ID:  148
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  152
# WordID:  306
# num_hits:  1
#
# =======================
# DOC ID:  153
# WordID:  44
# num_hits:  1
#
# WordID:  140
# num_hits:  1
#
# WordID:  307
# num_hits:  1
#
# WordID:  250
# num_hits:  1
#
# WordID:  308
# num_hits:  1
#
# WordID:  309
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  310
# num_hits:  1
#
# WordID:  103
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  80
# num_hits:  1
#
# =======================
# DOC ID:  47
# WordID:  103
# num_hits:  1
#
# =======================
# DOC ID:  69
# WordID:  140
# num_hits:  1
#
# =======================
# DOC ID:  70
# WordID:  140
# num_hits:  1
#
# WordID:  103
# num_hits:  1
#
# =======================
# DOC ID:  153
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  154
# WordID:  311
# num_hits:  1
#
# =======================
# DOC ID:  155
# WordID:  312
# num_hits:  1
#
# WordID:  313
# num_hits:  1
#
# WordID:  314
# num_hits:  1
#
# WordID:  254
# num_hits:  1
#
# WordID:  315
# num_hits:  1
#
# WordID:  248
# num_hits:  1
#
# =======================
# DOC ID:  156
# WordID:  313
# num_hits:  1
#
# =======================
# DOC ID:  157
# WordID:  218
# num_hits:  1
#
# WordID:  316
# num_hits:  1
#
# WordID:  315
# num_hits:  1
#
# =======================
# DOC ID:  155
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  158
# WordID:  317
# num_hits:  1
#
# WordID:  318
# num_hits:  1
#
# =======================
# DOC ID:  159
# WordID:  0
# num_hits:  1
#
# WordID:  319
# num_hits:  1
#
# WordID:  320
# num_hits:  1
#
# WordID:  321
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  322
# num_hits:  2
#
# WordID:  323
# num_hits:  1
#
# WordID:  324
# num_hits:  1
#
# WordID:  325
# num_hits:  1
#
# WordID:  326
# num_hits:  1
#
# =======================
# DOC ID:  160
# WordID:  0
# num_hits:  1
#
# WordID:  139
# num_hits:  1
#
# =======================
# DOC ID:  161
# WordID:  51
# num_hits:  1
#
# =======================
# DOC ID:  162
# WordID:  327
# num_hits:  1
#
# =======================
# DOC ID:  163
# WordID:  328
# num_hits:  1
#
# =======================
# DOC ID:  164
# WordID:  329
# num_hits:  1
#
# WordID:  328
# num_hits:  1
#
# =======================
# DOC ID:  165
# WordID:  0
# num_hits:  1
#
# WordID:  209
# num_hits:  1
#
# =======================
# DOC ID:  166
# WordID:  330
# num_hits:  1
#
# WordID:  331
# num_hits:  1
#
# =======================
# DOC ID:  167
# WordID:  33
# num_hits:  1
#
# WordID:  13
# num_hits:  1
#
# WordID:  332
# num_hits:  1
#
# WordID:  333
# num_hits:  1
#
# WordID:  334
# num_hits:  1
#
# WordID:  146
# num_hits:  1
#
# WordID:  335
# num_hits:  1
#
# WordID:  125
# num_hits:  1
#
# WordID:  48
# num_hits:  1
#
# WordID:  233
# num_hits:  1
#
# WordID:  336
# num_hits:  2
#
# WordID:  67
# num_hits:  1
#
# =======================
# DOC ID:  61
# WordID:  129
# num_hits:  1
#
# =======================
# DOC ID:  168
# WordID:  337
# num_hits:  1
#
# =======================
# DOC ID:  169
# WordID:  0
# num_hits:  1
#
# WordID:  209
# num_hits:  1
#
# =======================
# DOC ID:  170
# WordID:  338
# num_hits:  1
#
# WordID:  339
# num_hits:  1
#
# =======================
# DOC ID:  171
# WordID:  309
# num_hits:  1
#
# WordID:  340
# num_hits:  1
#
# WordID:  160
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  341
# num_hits:  1
#
# WordID:  342
# num_hits:  1
#
# WordID:  200
# num_hits:  1
#
# WordID:  343
# num_hits:  1
#
# WordID:  344
# num_hits:  1
#
# =======================
# DOC ID:  172
# WordID:  345
# num_hits:  1
#
# WordID:  259
# num_hits:  1
#
# =======================
# DOC ID:  78
# WordID:  160
# num_hits:  1
#
# =======================
# DOC ID:  173
# WordID:  346
# num_hits:  1
#
# =======================
# DOC ID:  171
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  174
# WordID:  347
# num_hits:  1
#
# WordID:  348
# num_hits:  1
#
# =======================
# DOC ID:  175
# WordID:  44
# num_hits:  1
#
# WordID:  349
# num_hits:  1
#
# WordID:  350
# num_hits:  1
#
# WordID:  351
# num_hits:  1
#
# WordID:  352
# num_hits:  1
#
# WordID:  353
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# =======================
# DOC ID:  176
# WordID:  352
# num_hits:  1
#
# WordID:  354
# num_hits:  1
#
# =======================
# DOC ID:  177
# WordID:  351
# num_hits:  1
#
# =======================
# DOC ID:  175
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  178
# WordID:  355
# num_hits:  1
#
# =======================
# DOC ID:  179
# WordID:  44
# num_hits:  1
#
# WordID:  356
# num_hits:  1
#
# WordID:  91
# num_hits:  1
#
# WordID:  357
# num_hits:  1
#
# WordID:  358
# num_hits:  1
#
# WordID:  359
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  360
# num_hits:  1
#
# WordID:  261
# num_hits:  1
#
# WordID:  361
# num_hits:  1
#
# WordID:  362
# num_hits:  1
#
# =======================
# DOC ID:  180
# WordID:  212
# num_hits:  1
#
# =======================
# DOC ID:  181
# WordID:  223
# num_hits:  1
#
# =======================
# DOC ID:  182
# WordID:  358
# num_hits:  1
#
# =======================
# DOC ID:  179
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  183
# WordID:  363
# num_hits:  1
#
# =======================
# DOC ID:  184
# WordID:  44
# num_hits:  1
#
# WordID:  74
# num_hits:  1
#
# WordID:  364
# num_hits:  1
#
# WordID:  309
# num_hits:  1
#
# WordID:  365
# num_hits:  1
#
# WordID:  75
# num_hits:  1
#
# WordID:  146
# num_hits:  2
#
# WordID:  366
# num_hits:  1
#
# WordID:  282
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  367
# num_hits:  1
#
# WordID:  368
# num_hits:  1
#
# WordID:  22
# num_hits:  1
#
# WordID:  369
# num_hits:  2
#
# WordID:  67
# num_hits:  1
#
# WordID:  0
# num_hits:  1
#
# WordID:  370
# num_hits:  1
#
# WordID:  151
# num_hits:  1
#
# =======================
# DOC ID:  185
# WordID:  40
# num_hits:  1
#
# WordID:  371
# num_hits:  1
#
# WordID:  206
# num_hits:  1
#
# =======================
# DOC ID:  184
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  186
# WordID:  372
# num_hits:  1
#
# WordID:  373
# num_hits:  1
#
# =======================
# DOC ID:  187
# WordID:  218
# num_hits:  1
#
# WordID:  374
# num_hits:  1
#
# WordID:  146
# num_hits:  1
#
# WordID:  129
# num_hits:  1
#
# WordID:  375
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  215
# num_hits:  1
#
# WordID:  52
# num_hits:  1
#
# WordID:  376
# num_hits:  1
#
# WordID:  377
# num_hits:  1
#
# =======================
# DOC ID:  61
# WordID:  129
# num_hits:  1
#
# =======================
# DOC ID:  101
# WordID:  218
# num_hits:  1
#
# =======================
# DOC ID:  188
# WordID:  218
# num_hits:  1
#
# WordID:  378
# num_hits:  1
#
# =======================
# DOC ID:  187
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  189
# WordID:  379
# num_hits:  1
#
# WordID:  380
# num_hits:  1
#
# =======================
# DOC ID:  190
# WordID:  44
# num_hits:  1
#
# WordID:  381
# num_hits:  1
#
# WordID:  382
# num_hits:  1
#
# WordID:  383
# num_hits:  1
#
# WordID:  102
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  384
# num_hits:  1
#
# WordID:  385
# num_hits:  1
#
# WordID:  386
# num_hits:  1
#
# WordID:  387
# num_hits:  1
#
# =======================
# DOC ID:  61
# WordID:  129
# num_hits:  1
#
# =======================
# DOC ID:  191
# WordID:  388
# num_hits:  1
#
# =======================
# DOC ID:  192
# WordID:  385
# num_hits:  1
#
# =======================
# DOC ID:  193
# WordID:  389
# num_hits:  1
#
# =======================
# DOC ID:  190
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  194
# WordID:  390
# num_hits:  1
#
# WordID:  300
# num_hits:  1
#
# =======================
# DOC ID:  195
# WordID:  307
# num_hits:  1
#
# WordID:  391
# num_hits:  1
#
# WordID:  392
# num_hits:  1
#
# WordID:  61
# num_hits:  1
#
# WordID:  393
# num_hits:  1
#
# WordID:  91
# num_hits:  1
#
# =======================
# DOC ID:  47
# WordID:  103
# num_hits:  1
#
# =======================
# DOC ID:  97
# WordID:  208
# num_hits:  1
#
# =======================
# DOC ID:  195
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  196
# WordID:  394
# num_hits:  1
#
# =======================
# DOC ID:  197
# WordID:  395
# num_hits:  1
#
# WordID:  396
# num_hits:  1
#
# WordID:  397
# num_hits:  1
#
# WordID:  398
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# =======================
# DOC ID:  61
# WordID:  129
# num_hits:  1
#
# =======================
# DOC ID:  198
# WordID:  396
# num_hits:  1
#
# =======================
# DOC ID:  199
# WordID:  399
# num_hits:  1
#
# =======================
# DOC ID:  197
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  200
# WordID:  400
# num_hits:  1
#
# WordID:  401
# num_hits:  1
#
# =======================
# DOC ID:  201
# WordID:  46
# num_hits:  1
#
# WordID:  402
# num_hits:  1
#
# WordID:  403
# num_hits:  1
#
# WordID:  404
# num_hits:  1
#
# WordID:  405
# num_hits:  1
#
# WordID:  406
# num_hits:  1
#
# =======================
# DOC ID:  191
# WordID:  388
# num_hits:  1
#
# =======================
# DOC ID:  202
# WordID:  407
# num_hits:  1
#
# =======================
# DOC ID:  203
# WordID:  402
# num_hits:  1
#
# =======================
# DOC ID:  201
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  204
# WordID:  408
# num_hits:  1
#
# =======================
# DOC ID:  205
# WordID:  171
# num_hits:  1
#
# WordID:  409
# num_hits:  1
#
# WordID:  410
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# =======================
# DOC ID:  206
# WordID:  409
# num_hits:  1
#
# =======================
# DOC ID:  207
# WordID:  377
# num_hits:  1
#
# WordID:  309
# num_hits:  1
#
# =======================
# DOC ID:  208
# WordID:  410
# num_hits:  1
#
# =======================
# DOC ID:  205
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  209
# WordID:  411
# num_hits:  1
#
# WordID:  412
# num_hits:  1
#
# =======================
# DOC ID:  210
# WordID:  413
# num_hits:  1
#
# WordID:  414
# num_hits:  1
#
# WordID:  415
# num_hits:  1
#
# WordID:  46
# num_hits:  1
#
# WordID:  416
# num_hits:  1
#
# WordID:  417
# num_hits:  1
#
# WordID:  418
# num_hits:  1
#
# =======================
# DOC ID:  211
# WordID:  419
# num_hits:  1
#
# =======================
# DOC ID:  212
# WordID:  419
# num_hits:  1
#
# WordID:  420
# num_hits:  1
#
# =======================
# DOC ID:  210
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  213
# WordID:  421
# num_hits:  1
#
# =======================
# DOC ID:  214
# WordID:  422
# num_hits:  1
#
# WordID:  423
# num_hits:  1
#
# WordID:  98
# num_hits:  1
#
# WordID:  206
# num_hits:  1
#
# WordID:  424
# num_hits:  1
#
# WordID:  425
# num_hits:  1
#
# WordID:  91
# num_hits:  1
#
# =======================
# DOC ID:  215
# WordID:  426
# num_hits:  1
#
# =======================
# DOC ID:  216
# WordID:  427
# num_hits:  1
#
# WordID:  425
# num_hits:  1
#
# =======================
# DOC ID:  217
# WordID:  428
# num_hits:  1
#
# =======================
# DOC ID:  218
# WordID:  422
# num_hits:  1
#
# WordID:  423
# num_hits:  1
#
# =======================
# DOC ID:  214
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  219
# WordID:  429
# num_hits:  1
#
# =======================
# DOC ID:  220
# WordID:  44
# num_hits:  1
#
# WordID:  0
# num_hits:  1
#
# WordID:  264
# num_hits:  1
#
# WordID:  75
# num_hits:  1
#
# WordID:  430
# num_hits:  1
#
# WordID:  431
# num_hits:  1
#
# WordID:  432
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  433
# num_hits:  1
#
# WordID:  434
# num_hits:  1
#
# WordID:  435
# num_hits:  1
#
# WordID:  52
# num_hits:  1
#
# WordID:  39
# num_hits:  1
#
# WordID:  436
# num_hits:  1
#
# =======================
# DOC ID:  191
# WordID:  388
# num_hits:  1
#
# =======================
# DOC ID:  221
# WordID:  430
# num_hits:  1
#
# =======================
# DOC ID:  222
# WordID:  430
# num_hits:  1
#
# WordID:  39
# num_hits:  1
#
# =======================
# DOC ID:  223
# WordID:  432
# num_hits:  1
#
# WordID:  264
# num_hits:  1
#
# WordID:  433
# num_hits:  1
#
# =======================
# DOC ID:  224
# WordID:  435
# num_hits:  1
#
# WordID:  430
# num_hits:  1
#
# WordID:  39
# num_hits:  1
#
# =======================
# DOC ID:  220
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  225
# WordID:  437
# num_hits:  1
#
# =======================
# DOC ID:  226
# WordID:  144
# num_hits:  1
#
# WordID:  44
# num_hits:  1
#
# WordID:  157
# num_hits:  1
#
# WordID:  438
# num_hits:  1
#
# WordID:  309
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  172
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  65
# num_hits:  1
#
# WordID:  369
# num_hits:  1
#
# WordID:  439
# num_hits:  2
#
# WordID:  0
# num_hits:  1
#
# =======================
# DOC ID:  185
# WordID:  40
# num_hits:  1
#
# WordID:  371
# num_hits:  1
#
# WordID:  206
# num_hits:  1
#
# =======================
# DOC ID:  227
# WordID:  439
# num_hits:  1
#
# =======================
# DOC ID:  226
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  228
# WordID:  440
# num_hits:  1
#
# =======================
# DOC ID:  229
# WordID:  367
# num_hits:  1
#
# WordID:  0
# num_hits:  1
#
# WordID:  441
# num_hits:  1
#
# WordID:  225
# num_hits:  1
#
# WordID:  442
# num_hits:  1
#
# =======================
# DOC ID:  230
# WordID:  171
# num_hits:  1
#
# =======================
# DOC ID:  185
# WordID:  40
# num_hits:  1
#
# WordID:  371
# num_hits:  1
#
# WordID:  206
# num_hits:  1
#
# =======================
# DOC ID:  231
# WordID:  443
# num_hits:  1
#
# WordID:  444
# num_hits:  1
#
# =======================
# DOC ID:  229
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  232
# WordID:  445
# num_hits:  1
#
# =======================
# DOC ID:  233
# WordID:  157
# num_hits:  1
#
# WordID:  446
# num_hits:  1
#
# WordID:  447
# num_hits:  1
#
# WordID:  448
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  449
# num_hits:  1
#
# =======================
# DOC ID:  234
# WordID:  446
# num_hits:  1
#
# =======================
# DOC ID:  233
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  235
# WordID:  450
# num_hits:  1
#
# =======================
# DOC ID:  236
# WordID:  0
# num_hits:  1
#
# WordID:  46
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  451
# num_hits:  1
#
# WordID:  129
# num_hits:  1
#
# WordID:  452
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  65
# num_hits:  1
#
# WordID:  453
# num_hits:  1
#
# =======================
# DOC ID:  61
# WordID:  129
# num_hits:  1
#
# =======================
# DOC ID:  236
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  237
# WordID:  454
# num_hits:  1
#
# WordID:  455
# num_hits:  1
#
# =======================
# DOC ID:  238
# WordID:  32
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  456
# num_hits:  1
#
# WordID:  457
# num_hits:  1
#
# =======================
# DOC ID:  239
# WordID:  458
# num_hits:  1
#
# =======================
# DOC ID:  240
# WordID:  459
# num_hits:  1
#
# =======================
# DOC ID:  238
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  241
# WordID:  460
# num_hits:  1
#
# WordID:  461
# num_hits:  1
#
# =======================
# DOC ID:  242
# WordID:  462
# num_hits:  1
#
# WordID:  463
# num_hits:  1
#
# WordID:  129
# num_hits:  1
#
# WordID:  464
# num_hits:  1
#
# WordID:  465
# num_hits:  1
#
# =======================
# DOC ID:  61
# WordID:  129
# num_hits:  1
#
# =======================
# DOC ID:  243
# WordID:  462
# num_hits:  1
#
# =======================
# DOC ID:  242
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  244
# WordID:  373
# num_hits:  1
#
# =======================
# DOC ID:  245
# WordID:  466
# num_hits:  1
#
# WordID:  250
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  467
# num_hits:  1
#
# WordID:  468
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  367
# num_hits:  1
#
# WordID:  39
# num_hits:  1
#
# =======================
# DOC ID:  61
# WordID:  129
# num_hits:  1
#
# =======================
# DOC ID:  191
# WordID:  388
# num_hits:  1
#
# =======================
# DOC ID:  221
# WordID:  430
# num_hits:  1
#
# =======================
# DOC ID:  246
# WordID:  469
# num_hits:  1
#
# =======================
# DOC ID:  245
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  247
# WordID:  470
# num_hits:  1
#
# =======================
# DOC ID:  248
# WordID:  76
# num_hits:  1
#
# WordID:  471
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  472
# num_hits:  1
#
# WordID:  473
# num_hits:  1
#
# WordID:  39
# num_hits:  2
#
# =======================
# DOC ID:  68
# WordID:  0
# num_hits:  1
#
# WordID:  139
# num_hits:  1
#
# =======================
# DOC ID:  249
# WordID:  472
# num_hits:  1
#
# =======================
# DOC ID:  250
# WordID:  472
# num_hits:  1
#
# WordID:  474
# num_hits:  1
#
# =======================
# DOC ID:  251
# WordID:  475
# num_hits:  1
#
# =======================
# DOC ID:  252
# WordID:  160
# num_hits:  1
#
# WordID:  476
# num_hits:  1
#
# =======================
# DOC ID:  253
# WordID:  0
# num_hits:  1
#
# WordID:  209
# num_hits:  1
#
# =======================
# DOC ID:  254
# WordID:  477
# num_hits:  1
#
# WordID:  478
# num_hits:  1
#
# =======================
# DOC ID:  255
# WordID:  479
# num_hits:  1
#
# WordID:  480
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  416
# num_hits:  1
#
# WordID:  78
# num_hits:  1
#
# WordID:  481
# num_hits:  1
#
# =======================
# DOC ID:  191
# WordID:  388
# num_hits:  1
#
# =======================
# DOC ID:  256
# WordID:  482
# num_hits:  1
#
# WordID:  483
# num_hits:  1
#
# =======================
# DOC ID:  257
# WordID:  480
# num_hits:  1
#
# =======================
# DOC ID:  258
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  259
# WordID:  484
# num_hits:  1
#
# =======================
# DOC ID:  260
# WordID:  485
# num_hits:  1
#
# WordID:  398
# num_hits:  1
#
# WordID:  486
# num_hits:  1
#
# WordID:  487
# num_hits:  1
#
# WordID:  488
# num_hits:  1
#
# WordID:  489
# num_hits:  1
#
# WordID:  91
# num_hits:  1
#
# =======================
# DOC ID:  261
# WordID:  0
# num_hits:  1
#
# WordID:  209
# num_hits:  1
#
# =======================
# DOC ID:  262
# WordID:  490
# num_hits:  1
#
# =======================
# DOC ID:  263
# WordID:  0
# num_hits:  1
#
# WordID:  307
# num_hits:  1
#
# WordID:  46
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  491
# num_hits:  1
#
# WordID:  281
# num_hits:  1
#
# WordID:  492
# num_hits:  1
#
# WordID:  61
# num_hits:  1
#
# WordID:  493
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  494
# num_hits:  1
#
# =======================
# DOC ID:  191
# WordID:  388
# num_hits:  1
#
# =======================
# DOC ID:  264
# WordID:  493
# num_hits:  1
#
# =======================
# DOC ID:  265
# WordID:  0
# num_hits:  1
#
# WordID:  209
# num_hits:  1
#
# =======================
# DOC ID:  266
# WordID:  495
# num_hits:  1
#
# =======================
# DOC ID:  267
# WordID:  496
# num_hits:  1
#
# WordID:  177
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  273
# num_hits:  1
#
# WordID:  497
# num_hits:  1
#
# WordID:  498
# num_hits:  1
#
# WordID:  499
# num_hits:  1
#
# WordID:  500
# num_hits:  1
#
# WordID:  136
# num_hits:  1
#
# WordID:  501
# num_hits:  1
#
# =======================
# DOC ID:  268
# WordID:  502
# num_hits:  1
#
# =======================
# DOC ID:  267
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  269
# WordID:  503
# num_hits:  1
#
# WordID:  504
# num_hits:  1
#
# =======================
# DOC ID:  270
# WordID:  44
# num_hits:  1
#
# WordID:  505
# num_hits:  1
#
# WordID:  304
# num_hits:  1
#
# WordID:  506
# num_hits:  1
#
# WordID:  350
# num_hits:  1
#
# WordID:  507
# num_hits:  1
#
# WordID:  172
# num_hits:  1
#
# WordID:  282
# num_hits:  1
#
# WordID:  508
# num_hits:  1
#
# WordID:  174
# num_hits:  1
#
# WordID:  148
# num_hits:  1
#
# WordID:  375
# num_hits:  1
#
# WordID:  509
# num_hits:  1
#
# WordID:  322
# num_hits:  1
#
# WordID:  67
# num_hits:  1
#
# WordID:  91
# num_hits:  1
#
# WordID:  510
# num_hits:  1
#
# =======================
# DOC ID:  271
# WordID:  304
# num_hits:  1
#
# WordID:  511
# num_hits:  1
#
# =======================
# DOC ID:  150
# WordID:  304
# num_hits:  1
#
# =======================
# DOC ID:  211
# WordID:  419
# num_hits:  1
#
# =======================
# DOC ID:  272
# WordID:  512
# num_hits:  1
#
# =======================
# DOC ID:  273
# WordID:  513
# num_hits:  1
#
# =======================
# DOC ID:  274
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  275
# WordID:  514
# num_hits:  1
#
# =======================
# DOC ID:  276
# WordID:  515
# num_hits:  1
#
# WordID:  250
# num_hits:  1
#
# WordID:  516
# num_hits:  1
#
# WordID:  517
# num_hits:  1
#
# WordID:  518
# num_hits:  1
#
# WordID:  34
# num_hits:  2
#
# WordID:  519
# num_hits:  1
#
# WordID:  264
# num_hits:  1
#
# =======================
# DOC ID:  25
# WordID:  36
# num_hits:  1
#
# =======================
# DOC ID:  277
# WordID:  0
# num_hits:  1
#
# WordID:  209
# num_hits:  1
#
# =======================
# DOC ID:  278
# WordID:  520
# num_hits:  1
#
# WordID:  521
# num_hits:  1
#
# =======================
# DOC ID:  279
# WordID:  146
# num_hits:  1
#
# WordID:  522
# num_hits:  1
#
# WordID:  523
# num_hits:  1
#
# WordID:  458
# num_hits:  1
#
# WordID:  524
# num_hits:  1
#
# =======================
# DOC ID:  280
# WordID:  315
# num_hits:  1
#
# =======================
# DOC ID:  239
# WordID:  458
# num_hits:  1
#
# =======================
# DOC ID:  281
# WordID:  525
# num_hits:  1
#
# =======================
# DOC ID:  282
# WordID:  526
# num_hits:  1
#
# =======================
# DOC ID:  283
# WordID:  0
# num_hits:  1
#
# WordID:  209
# num_hits:  1
#
# =======================
# DOC ID:  284
# WordID:  527
# num_hits:  1
#
# WordID:  528
# num_hits:  1
#
# =======================
# DOC ID:  285
# WordID:  44
# num_hits:  1
#
# WordID:  46
# num_hits:  1
#
# WordID:  529
# num_hits:  1
#
# WordID:  281
# num_hits:  1
#
# WordID:  75
# num_hits:  1
#
# WordID:  146
# num_hits:  1
#
# WordID:  530
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  114
# num_hits:  1
#
# WordID:  52
# num_hits:  1
#
# WordID:  67
# num_hits:  1
#
# WordID:  177
# num_hits:  1
#
# WordID:  434
# num_hits:  1
#
# =======================
# DOC ID:  286
# WordID:  386
# num_hits:  1
#
# =======================
# DOC ID:  287
# WordID:  531
# num_hits:  1
#
# WordID:  386
# num_hits:  1
#
# WordID:  530
# num_hits:  1
#
# =======================
# DOC ID:  285
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  288
# WordID:  532
# num_hits:  1
#
# =======================
# DOC ID:  289
# WordID:  533
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  534
# num_hits:  1
#
# WordID:  535
# num_hits:  1
#
# WordID:  536
# num_hits:  1
#
# =======================
# DOC ID:  290
# WordID:  537
# num_hits:  1
#
# =======================
# DOC ID:  223
# WordID:  432
# num_hits:  1
#
# WordID:  264
# num_hits:  1
#
# WordID:  433
# num_hits:  1
#
# =======================
# DOC ID:  289
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  291
# WordID:  538
# num_hits:  1
#
# =======================
# DOC ID:  292
# WordID:  539
# num_hits:  1
#
# WordID:  540
# num_hits:  1
#
# WordID:  309
# num_hits:  1
#
# WordID:  491
# num_hits:  1
#
# WordID:  213
# num_hits:  1
#
# WordID:  541
# num_hits:  2
#
# WordID:  542
# num_hits:  1
#
# WordID:  146
# num_hits:  1
#
# WordID:  91
# num_hits:  1
#
# WordID:  543
# num_hits:  1
#
# =======================
# DOC ID:  101
# WordID:  218
# num_hits:  1
#
# =======================
# DOC ID:  293
# WordID:  539
# num_hits:  1
#
# =======================
# DOC ID:  294
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  295
# WordID:  544
# num_hits:  1
#
# =======================
# DOC ID:  296
# WordID:  146
# num_hits:  1
#
# WordID:  545
# num_hits:  2
#
# WordID:  546
# num_hits:  1
#
# WordID:  547
# num_hits:  1
#
# WordID:  548
# num_hits:  1
#
# WordID:  549
# num_hits:  1
#
# =======================
# DOC ID:  297
# WordID:  550
# num_hits:  1
#
# =======================
# DOC ID:  298
# WordID:  547
# num_hits:  1
#
# =======================
# DOC ID:  296
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  299
# WordID:  551
# num_hits:  1
#
# =======================
# DOC ID:  300
# WordID:  44
# num_hits:  1
#
# WordID:  552
# num_hits:  1
#
# WordID:  553
# num_hits:  1
#
# WordID:  554
# num_hits:  1
#
# WordID:  555
# num_hits:  1
#
# WordID:  125
# num_hits:  1
#
# WordID:  556
# num_hits:  1
#
# WordID:  52
# num_hits:  1
#
# WordID:  557
# num_hits:  1
#
# =======================
# DOC ID:  301
# WordID:  552
# num_hits:  1
#
# =======================
# DOC ID:  302
# WordID:  554
# num_hits:  1
#
# WordID:  558
# num_hits:  1
#
# =======================
# DOC ID:  303
# WordID:  552
# num_hits:  1
#
# WordID:  559
# num_hits:  1
#
# =======================
# DOC ID:  304
# WordID:  554
# num_hits:  1
#
# WordID:  125
# num_hits:  1
#
# =======================
# DOC ID:  305
# WordID:  189
# num_hits:  1
#
# WordID:  552
# num_hits:  1
#
# WordID:  560
# num_hits:  1
#
# =======================
# DOC ID:  300
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  306
# WordID:  561
# num_hits:  1
#
# WordID:  562
# num_hits:  1
#
# =======================
# DOC ID:  307
# WordID:  563
# num_hits:  1
#
# WordID:  0
# num_hits:  1
#
# WordID:  281
# num_hits:  1
#
# WordID:  564
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  67
# num_hits:  1
#
# WordID:  91
# num_hits:  1
#
# WordID:  565
# num_hits:  1
#
# WordID:  566
# num_hits:  1
#
# =======================
# DOC ID:  308
# WordID:  567
# num_hits:  1
#
# WordID:  189
# num_hits:  1
#
# WordID:  568
# num_hits:  1
#
# =======================
# DOC ID:  309
# WordID:  569
# num_hits:  1
#
# WordID:  568
# num_hits:  1
#
# =======================
# DOC ID:  310
# WordID:  570
# num_hits:  1
#
# WordID:  566
# num_hits:  1
#
# =======================
# DOC ID:  311
# WordID:  571
# num_hits:  1
#
# =======================
# DOC ID:  307
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  312
# WordID:  572
# num_hits:  1
#
# =======================
# DOC ID:  313
# WordID:  573
# num_hits:  1
#
# WordID:  496
# num_hits:  1
#
# WordID:  574
# num_hits:  1
#
# WordID:  575
# num_hits:  1
#
# WordID:  265
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# =======================
# DOC ID:  130
# WordID:  265
# num_hits:  1
#
# =======================
# DOC ID:  314
# WordID:  575
# num_hits:  1
#
# WordID:  576
# num_hits:  1
#
# =======================
# DOC ID:  315
# WordID:  577
# num_hits:  1
#
# =======================
# DOC ID:  313
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  316
# WordID:  578
# num_hits:  1
#
# =======================
# DOC ID:  317
# WordID:  579
# num_hits:  1
#
# WordID:  580
# num_hits:  1
#
# WordID:  290
# num_hits:  1
#
# WordID:  581
# num_hits:  1
#
# =======================
# DOC ID:  318
# WordID:  579
# num_hits:  1
#
# =======================
# DOC ID:  317
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  319
# WordID:  582
# num_hits:  1
#
# WordID:  583
# num_hits:  1
#
# =======================
# DOC ID:  320
# WordID:  44
# num_hits:  1
#
# WordID:  584
# num_hits:  1
#
# WordID:  585
# num_hits:  1
#
# WordID:  586
# num_hits:  1
#
# WordID:  254
# num_hits:  1
#
# WordID:  587
# num_hits:  1
#
# WordID:  588
# num_hits:  1
#
# =======================
# DOC ID:  321
# WordID:  589
# num_hits:  1
#
# =======================
# DOC ID:  322
# WordID:  584
# num_hits:  1
#
# =======================
# DOC ID:  320
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  323
# WordID:  590
# num_hits:  1
#
# =======================
# DOC ID:  324
# WordID:  0
# num_hits:  1
#
# WordID:  309
# num_hits:  1
#
# WordID:  591
# num_hits:  1
#
# WordID:  59
# num_hits:  1
#
# WordID:  60
# num_hits:  1
#
# WordID:  112
# num_hits:  1
#
# WordID:  323
# num_hits:  1
#
# WordID:  592
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  593
# num_hits:  1
#
# WordID:  292
# num_hits:  1
#
# =======================
# DOC ID:  325
# WordID:  33
# num_hits:  1
#
# WordID:  323
# num_hits:  1
#
# WordID:  116
# num_hits:  1
#
# WordID:  112
# num_hits:  1
#
# =======================
# DOC ID:  324
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  326
# WordID:  594
# num_hits:  1
#
# WordID:  595
# num_hits:  1
#
# =======================
# DOC ID:  327
# WordID:  596
# num_hits:  1
#
# WordID:  597
# num_hits:  1
#
# WordID:  598
# num_hits:  1
#
# WordID:  599
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  439
# num_hits:  1
#
# WordID:  600
# num_hits:  1
#
# WordID:  601
# num_hits:  1
#
# =======================
# DOC ID:  328
# WordID:  602
# num_hits:  1
#
# =======================
# DOC ID:  329
# WordID:  599
# num_hits:  1
#
# =======================
# DOC ID:  330
# WordID:  596
# num_hits:  1
#
# WordID:  598
# num_hits:  1
#
# =======================
# DOC ID:  327
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  331
# WordID:  603
# num_hits:  1
#
# =======================
# DOC ID:  332
# WordID:  44
# num_hits:  1
#
# WordID:  604
# num_hits:  1
#
# WordID:  59
# num_hits:  1
#
# WordID:  605
# num_hits:  1
#
# WordID:  344
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  52
# num_hits:  1
#
# WordID:  26
# num_hits:  1
#
# WordID:  286
# num_hits:  1
#
# =======================
# DOC ID:  333
# WordID:  0
# num_hits:  1
#
# WordID:  209
# num_hits:  1
#
# ...
#
# =======================
# DOC ID:  394
# WordID:  696
# num_hits:  1
#
# =======================
# DOC ID:  395
# WordID:  700
# num_hits:  1
#
# =======================
# DOC ID:  396
# WordID:  695
# num_hits:  1
#
# =======================
# DOC ID:  391
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  397
# WordID:  701
# num_hits:  1
#
# WordID:  702
# num_hits:  1
#
# =======================
# DOC ID:  398
# WordID:  187
# num_hits:  1
#
# WordID:  522
# num_hits:  1
#
# WordID:  703
# num_hits:  1
#
# WordID:  704
# num_hits:  1
#
# =======================
# DOC ID:  399
# WordID:  218
# num_hits:  1
#
# WordID:  619
# num_hits:  1
#
# =======================
# DOC ID:  400
# WordID:  619
# num_hits:  1
#
# WordID:  704
# num_hits:  1
#
# =======================
# DOC ID:  401
# WordID:  705
# num_hits:  1
#
# WordID:  706
# num_hits:  1
#
# =======================
# DOC ID:  398
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  402
# WordID:  707
# num_hits:  1
#
# WordID:  708
# num_hits:  1
#
# =======================
# DOC ID:  403
# WordID:  703
# num_hits:  1
#
# WordID:  309
# num_hits:  1
#
# WordID:  507
# num_hits:  1
#
# WordID:  709
# num_hits:  1
#
# WordID:  59
# num_hits:  1
#
# WordID:  710
# num_hits:  1
#
# WordID:  605
# num_hits:  1
#
# WordID:  711
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  187
# num_hits:  1
#
# WordID:  619
# num_hits:  1
#
# =======================
# DOC ID:  404
# WordID:  507
# num_hits:  1
#
# =======================
# DOC ID:  405
# WordID:  605
# num_hits:  1
#
# =======================
# DOC ID:  406
# WordID:  619
# num_hits:  1
#
# WordID:  712
# num_hits:  1
#
# =======================
# DOC ID:  407
# WordID:  619
# num_hits:  1
#
# WordID:  713
# num_hits:  1
#
# =======================
# DOC ID:  403
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  408
# WordID:  714
# num_hits:  1
#
# WordID:  715
# num_hits:  1
#
# =======================
# DOC ID:  409
# WordID:  716
# num_hits:  1
#
# WordID:  309
# num_hits:  1
#
# WordID:  717
# num_hits:  1
#
# WordID:  718
# num_hits:  1
#
# WordID:  719
# num_hits:  1
#
# WordID:  720
# num_hits:  1
#
# WordID:  187
# num_hits:  1
#
# WordID:  721
# num_hits:  1
#
# WordID:  722
# num_hits:  1
#
# =======================
# DOC ID:  410
# WordID:  723
# num_hits:  1
#
# WordID:  724
# num_hits:  1
#
# =======================
# DOC ID:  409
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  411
# WordID:  725
# num_hits:  1
#
# WordID:  726
# num_hits:  1
#
# =======================
# DOC ID:  412
# WordID:  727
# num_hits:  1
#
# WordID:  728
# num_hits:  1
#
# WordID:  729
# num_hits:  1
#
# WordID:  602
# num_hits:  1
#
# =======================
# DOC ID:  328
# WordID:  602
# num_hits:  1
#
# =======================
# DOC ID:  413
# WordID:  728
# num_hits:  1
#
# =======================
# DOC ID:  414
# WordID:  729
# num_hits:  1
#
# =======================
# DOC ID:  412
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  415
# WordID:  730
# num_hits:  1
#
# WordID:  246
# num_hits:  1
#
# WordID:  731
# num_hits:  1
#
# =======================
# DOC ID:  416
# WordID:  674
# num_hits:  1
#
# WordID:  205
# num_hits:  1
#
# WordID:  732
# num_hits:  1
#
# WordID:  537
# num_hits:  1
#
# WordID:  733
# num_hits:  1
#
# =======================
# DOC ID:  290
# WordID:  537
# num_hits:  1
#
# =======================
# DOC ID:  417
# WordID:  734
# num_hits:  1
#
# =======================
# DOC ID:  418
# WordID:  735
# num_hits:  1
#
# =======================
# DOC ID:  416
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  419
# WordID:  736
# num_hits:  1
#
# =======================
# DOC ID:  420
# WordID:  144
# num_hits:  1
#
# WordID:  737
# num_hits:  1
#
# WordID:  738
# num_hits:  1
#
# WordID:  739
# num_hits:  1
#
# WordID:  740
# num_hits:  1
#
# WordID:  148
# num_hits:  1
#
# WordID:  741
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  696
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# =======================
# DOC ID:  421
# WordID:  742
# num_hits:  1
#
# WordID:  190
# num_hits:  1
#
# =======================
# DOC ID:  422
# WordID:  741
# num_hits:  1
#
# =======================
# DOC ID:  423
# WordID:  743
# num_hits:  1
#
# =======================
# DOC ID:  420
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  424
# WordID:  744
# num_hits:  1
#
# WordID:  683
# num_hits:  1
#
# =======================
# DOC ID:  425
# WordID:  413
# num_hits:  1
#
# WordID:  745
# num_hits:  1
#
# WordID:  139
# num_hits:  1
#
# WordID:  0
# num_hits:  1
#
# WordID:  746
# num_hits:  1
#
# WordID:  747
# num_hits:  1
#
# WordID:  748
# num_hits:  1
#
# WordID:  671
# num_hits:  1
#
# WordID:  229
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  749
# num_hits:  1
#
# =======================
# DOC ID:  160
# WordID:  0
# num_hits:  1
#
# WordID:  139
# num_hits:  1
#
# =======================
# DOC ID:  426
# WordID:  679
# num_hits:  1
#
# =======================
# DOC ID:  427
# WordID:  505
# num_hits:  1
#
# WordID:  750
# num_hits:  1
#
# =======================
# DOC ID:  428
# WordID:  751
# num_hits:  1
#
# =======================
# DOC ID:  429
# WordID:  747
# num_hits:  1
#
# WordID:  752
# num_hits:  1
#
# =======================
# DOC ID:  425
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  430
# WordID:  753
# num_hits:  1
#
# WordID:  527
# num_hits:  1
#
# =======================
# DOC ID:  431
# WordID:  0
# num_hits:  1
#
# WordID:  754
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  755
# num_hits:  1
#
# WordID:  756
# num_hits:  1
#
# =======================
# DOC ID:  432
# WordID:  0
# num_hits:  1
#
# WordID:  190
# num_hits:  1
#
# =======================
# DOC ID:  433
# WordID:  0
# num_hits:  1
#
# WordID:  755
# num_hits:  1
#
# =======================
# DOC ID:  434
# WordID:  757
# num_hits:  1
#
# =======================
# DOC ID:  431
# WordID:  0
# num_hits:  1
#
# WordID:  42
# num_hits:  1
#
# =======================
# DOC ID:  435
# WordID:  758
# num_hits:  1
#
# =======================
# DOC ID:  436
# WordID:  759
# num_hits:  1
#
# WordID:  760
# num_hits:  2
#
# WordID:  761
# num_hits:  1
#
# WordID:  510
# num_hits:  1
#
# WordID:  633
# num_hits:  1
#
# =======================
# DOC ID:  437
# WordID:  762
# num_hits:  1
#
# =======================
# DOC ID:  438
# WordID:  763
# num_hits:  1
#
# WordID:  764
# num_hits:  1
#
# WordID:  589
# num_hits:  1
#
# =======================
# DOC ID:  439
# WordID:  759
# num_hits:  1
#
# =======================
# DOC ID:  436
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  440
# WordID:  765
# num_hits:  1
#
# =======================
# DOC ID:  441
# WordID:  367
# num_hits:  1
#
# WordID:  766
# num_hits:  1
#
# WordID:  91
# num_hits:  1
#
# WordID:  767
# num_hits:  1
#
# =======================
# DOC ID:  442
# WordID:  768
# num_hits:  1
#
# =======================
# DOC ID:  443
# WordID:  769
# num_hits:  1
#
# =======================
# DOC ID:  441
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  444
# WordID:  770
# num_hits:  1
#
# =======================
# DOC ID:  445
# WordID:  44
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  662
# num_hits:  1
#
# WordID:  233
# num_hits:  1
#
# WordID:  771
# num_hits:  1
#
# WordID:  772
# num_hits:  1
#
# WordID:  773
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  774
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  775
# num_hits:  1
#
# WordID:  776
# num_hits:  1
#
# =======================
# DOC ID:  446
# WordID:  773
# num_hits:  1
#
# WordID:  776
# num_hits:  1
#
# =======================
# DOC ID:  445
# WordID:  0
# num_hits:  1
#
# WordID:  121
# num_hits:  1
#
# =======================
# DOC ID:  447
# WordID:  777
# num_hits:  1
#
# =======================
# DOC ID:  11
# WordID:  146
# num_hits:  1
#
# WordID:  545
# num_hits:  1
#
# WordID:  778
# num_hits:  1
#
# WordID:  16
# num_hits:  1
#
# =======================
# DOC ID:  14
# WordID:  779
# num_hits:  1
#
# WordID:  19
# num_hits:  1
#
# =======================
# DOC ID:  448
# WordID:  16
# num_hits:  1
#
# WordID:  780
# num_hits:  1
#
# =======================
# DOC ID:  449
# WordID:  0
# num_hits:  2
#
# WordID:  34
# num_hits:  1
#
# WordID:  545
# num_hits:  1
#
# WordID:  781
# num_hits:  1
#
# WordID:  782
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  783
# num_hits:  1
#
# WordID:  67
# num_hits:  1
#
# WordID:  91
# num_hits:  1
#
# WordID:  784
# num_hits:  1
#
# WordID:  785
# num_hits:  1
#
# =======================
# DOC ID:  450
# WordID:  0
# num_hits:  2
#
# WordID:  144
# num_hits:  1
#
# WordID:  168
# num_hits:  2
#
# WordID:  786
# num_hits:  1
#
# WordID:  787
# num_hits:  1
#
# WordID:  788
# num_hits:  1
#
# WordID:  59
# num_hits:  1
#
# WordID:  789
# num_hits:  1
#
# WordID:  790
# num_hits:  1
#
# WordID:  791
# num_hits:  1
#
# WordID:  792
# num_hits:  1
#
# WordID:  167
# num_hits:  1
#
# WordID:  793
# num_hits:  1
#
# WordID:  187
# num_hits:  1
#
# WordID:  794
# num_hits:  1
#
# WordID:  795
# num_hits:  1
#
# WordID:  796
# num_hits:  1
#
# =======================
# DOC ID:  451
# WordID:  0
# num_hits:  2
#
# WordID:  33
# num_hits:  1
#
# WordID:  797
# num_hits:  1
#
# WordID:  144
# num_hits:  1
#
# WordID:  798
# num_hits:  1
#
# WordID:  799
# num_hits:  1
#
# WordID:  800
# num_hits:  1
#
# WordID:  801
# num_hits:  1
#
# WordID:  802
# num_hits:  1
#
# WordID:  67
# num_hits:  1
#
# WordID:  803
# num_hits:  1
#
# =======================
# DOC ID:  452
# WordID:  0
# num_hits:  2
#
# WordID:  804
# num_hits:  1
#
# WordID:  805
# num_hits:  1
#
# WordID:  806
# num_hits:  1
#
# WordID:  807
# num_hits:  1
#
# WordID:  645
# num_hits:  1
#
# WordID:  808
# num_hits:  1
#
# WordID:  809
# num_hits:  1
#
# WordID:  67
# num_hits:  1
#
# WordID:  810
# num_hits:  1
#
# WordID:  91
# num_hits:  1
#
# WordID:  694
# num_hits:  1
#
# =======================
# DOC ID:  453
# WordID:  0
# num_hits:  2
#
# WordID:  165
# num_hits:  1
#
# WordID:  811
# num_hits:  1
#
# WordID:  812
# num_hits:  1
#
# WordID:  813
# num_hits:  1
#
# WordID:  814
# num_hits:  1
#
# =======================
# DOC ID:  454
# WordID:  0
# num_hits:  2
#
# WordID:  815
# num_hits:  1
#
# WordID:  816
# num_hits:  1
#
# WordID:  817
# num_hits:  1
#
# WordID:  94
# num_hits:  1
#
# WordID:  818
# num_hits:  1
#
# WordID:  187
# num_hits:  1
#
# WordID:  819
# num_hits:  1
#
# WordID:  796
# num_hits:  1
#
# WordID:  820
# num_hits:  1
#
# =======================
# DOC ID:  455
# WordID:  0
# num_hits:  2
#
# WordID:  44
# num_hits:  1
#
# WordID:  821
# num_hits:  1
#
# WordID:  822
# num_hits:  1
#
# WordID:  233
# num_hits:  1
#
# WordID:  59
# num_hits:  2
#
# WordID:  60
# num_hits:  1
#
# WordID:  282
# num_hits:  1
#
# WordID:  823
# num_hits:  1
#
# WordID:  824
# num_hits:  1
#
# WordID:  710
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  67
# num_hits:  2
#
# =======================
# DOC ID:  456
# WordID:  0
# num_hits:  2
#
# WordID:  825
# num_hits:  1
#
# WordID:  826
# num_hits:  1
#
# WordID:  146
# num_hits:  1
#
# WordID:  827
# num_hits:  1
#
# WordID:  828
# num_hits:  1
#
# WordID:  829
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  67
# num_hits:  1
#
# WordID:  830
# num_hits:  1
#
# =======================
# DOC ID:  457
# WordID:  0
# num_hits:  2
#
# WordID:  44
# num_hits:  1
#
# WordID:  59
# num_hits:  1
#
# WordID:  831
# num_hits:  1
#
# WordID:  832
# num_hits:  2
#
# WordID:  34
# num_hits:  1
#
# WordID:  820
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  833
# num_hits:  1
#
# WordID:  834
# num_hits:  1
#
# =======================
# DOC ID:  458
# WordID:  0
# num_hits:  2
#
# WordID:  168
# num_hits:  1
#
# WordID:  835
# num_hits:  1
#
# WordID:  836
# num_hits:  1
#
# WordID:  185
# num_hits:  1
#
# WordID:  837
# num_hits:  1
#
# =======================
# DOC ID:  459
# WordID:  0
# num_hits:  2
#
# WordID:  168
# num_hits:  1
#
# WordID:  838
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  793
# num_hits:  1
#
# WordID:  67
# num_hits:  1
#
# WordID:  839
# num_hits:  1
#
# WordID:  840
# num_hits:  1
#
# =======================
# DOC ID:  460
# WordID:  0
# num_hits:  2
#
# WordID:  109
# num_hits:  1
#
# WordID:  129
# num_hits:  1
#
# WordID:  223
# num_hits:  1
#
# WordID:  841
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  185
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  842
# num_hits:  1
#
# WordID:  91
# num_hits:  1
#
# =======================
# DOC ID:  461
# WordID:  0
# num_hits:  2
#
# WordID:  44
# num_hits:  1
#
# WordID:  13
# num_hits:  1
#
# WordID:  843
# num_hits:  1
#
# WordID:  703
# num_hits:  1
#
# WordID:  844
# num_hits:  1
#
# WordID:  845
# num_hits:  1
#
# WordID:  846
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  847
# num_hits:  1
#
# WordID:  848
# num_hits:  1
#
# WordID:  277
# num_hits:  1
#
# WordID:  849
# num_hits:  1
#
# =======================
# DOC ID:  462
# WordID:  0
# num_hits:  2
#
# WordID:  44
# num_hits:  1
#
# WordID:  850
# num_hits:  1
#
# WordID:  34
# num_hits:  1
#
# WordID:  851
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  852
# num_hits:  1
#
# WordID:  853
# num_hits:  1
#
# WordID:  854
# num_hits:  1
#
# WordID:  298
# num_hits:  1
#
# =======================
# DOC ID:  463
# WordID:  0
# num_hits:  2
#
# WordID:  307
# num_hits:  1
#
# WordID:  309
# num_hits:  1
#
# WordID:  855
# num_hits:  1
#
# WordID:  35
# num_hits:  1
#
# WordID:  856
# num_hits:  1
#
# WordID:  94
# num_hits:  1
#
# WordID:  857
# num_hits:  1
#
# WordID:  858
# num_hits:  1
#
# =======================
# DOC ID:  464
# WordID:  0
# num_hits:  2
#
# WordID:  74
# num_hits:  1
#
# WordID:  859
# num_hits:  1
#
# WordID:  860
# num_hits:  1
#
# WordID:  278
# num_hits:  1
#
# WordID:  81
# num_hits:  1
#
# WordID:  7
# num_hits:  1
#
# WordID:  861
# num_hits:  1
#
# WordID:  862
# num_hits:  1
#
# =======================
# DOC ID:  465
# WordID:  0
# num_hits:  2
#
# WordID:  772
# num_hits:  1
#
# WordID:  863
# num_hits:  1
#
# WordID:  796
# num_hits:  1
#
# WordID:  864
# num_hits:  1
#
# WordID:  361
# num_hits:  1
#
# =======================
# DOC ID:  466
# WordID:  0
# num_hits:  2
#
# WordID:  865
# num_hits:  1
#
# WordID:  841
# num_hits:  1
#
# WordID:  866
# num_hits:  1
#
# WordID:  185
# num_hits:  1
#
# WordID:  187
# num_hits:  1
#
# =======================
# DOC ID:  467
# WordID:  0
# num_hits:  2
#
# WordID:  233
# num_hits:  1
#
# WordID:  91
# num_hits:  1
#
# WordID:  867
# num_hits:  1
#
# WordID:  398
# num_hits:  1
#
# =======================
# DOC ID:  468
# WordID:  0
# num_hits:  2
#
# WordID:  44
# num_hits:  1
#
# WordID:  250
# num_hits:  1
#
# WordID:  295
# num_hits:  1
#
# WordID:  868
# num_hits:  1
#
# WordID:  33
# num_hits:  1
#
# WordID:  59
# num_hits:  1
#
# WordID:  360
# num_hits:  1
#
# WordID:  869
# num_hits:  1
#
# WordID:  870
# num_hits:  1
#
# =======================
# DOC ID:  469
# WordID:  0
# num_hits:  2
#
# WordID:  144
# num_hits:  1
#
# WordID:  871
# num_hits:  1
#
# WordID:  872
# num_hits:  1
#
# =======================
# DOC ID:  470
# WordID:  0
# num_hits:  2
#
# WordID:  44
# num_hits:  1
#
# WordID:  168
# num_hits:  1
#
# WordID:  873
# num_hits:  1
#
# WordID:  874
# num_hits:  1
#
# WordID:  309
# num_hits:  1
#
# WordID:  875
# num_hits:  1
#
# WordID:  876
# num_hits:  1
#
# WordID:  877
# num_hits:  1
#
# WordID:  67
# num_hits:  1
#
# WordID:  600
# num_hits:  1
#
# =======================
# DOC ID:  471
# WordID:  0
# num_hits:  2
#
# WordID:  878
# num_hits:  1
#
# WordID:  879
# num_hits:  1
#
# WordID:  880
# num_hits:  1
#
# WordID:  185
# num_hits:  1
#
# WordID:  881
# num_hits:  1
#
# WordID:  882
# num_hits:  1
#
# WordID:  796
# num_hits:  1
#
# =======================
# DOC ID:  472
# WordID:  0
# num_hits:  2
#
# WordID:  44
# num_hits:  1
#
# WordID:  883
# num_hits:  1
#
# WordID:  884
# num_hits:  1
#
# =======================
# DOC ID:  0
# WordID:  0
# num_hits:  2
#
# WordID:  29
# num_hits:  1
#
# WordID:  16
# num_hits:  1
#
# WordID:  362
# num_hits:  1
#
# =======================
# DOC ID:  9
# WordID:  13
# num_hits:  1
#
# WordID:  14
# num_hits:  1
#
# =======================
# DOC ID:  7
# WordID:  10
# num_hits:  1
#
# =======================
# DOC ID:  8
# WordID:  11
# num_hits:  1
#
# =======================
# DOC ID:  473
# WordID:  8
# num_hits:  1
#
# =======================
# DOC ID:  1
# WordID:  3
# num_hits:  1
#
# =======================
# DOC ID:  474
# WordID:  39
# num_hits:  1
#
# =======================
# DOC ID:  475
# WordID:  885
# num_hits:  1
#
# =======================
# DOC ID:  476
# WordID:  886
# num_hits:  1
#
# WordID:  887
# num_hits:  1
#
# =======================
# DOC ID:  477
# WordID:  841
# num_hits:  1
#
# WordID:  888
# num_hits:  1
#
# =======================
# DOC ID:  478
# WordID:  889
# num_hits:  1
#
# WordID:  890
# num_hits:  1
#
# =======================
# DOC ID:  479
# WordID:  891
# num_hits:  1
#
# WordID:  14
# num_hits:  1
#
# =======================
# DOC ID:  480
# WordID:  892
# num_hits:  1
#
# =======================
# DOC ID:  481
# WordID:  0
# num_hits:  2
#
# WordID:  893
# num_hits:  1
#
# WordID:  362
# num_hits:  1
#
# =======================
# DOC ID:  481
# WordID:  0
# num_hits:  2
#
# WordID:  894
# num_hits:  1
#
# WordID:  362
# num_hits:  1
#
# =======================
# DOC ID:  481
# WordID:  0
# num_hits:  2
#
# WordID:  895
# num_hits:  1
#
# WordID:  362
# num_hits:  1
#
# =======================
# DOC ID:  481
# WordID:  0
# num_hits:  2
#
# WordID:  206
# num_hits:  1
#
# WordID:  362
# num_hits:  1
#
# =======================
# DOC ID:  482
# WordID:  896
# num_hits:  1
#
# WordID:  205
# num_hits:  1
#
# WordID:  897
# num_hits:  1
#
# WordID:  298
# num_hits:  1
#
# WordID:  206
# num_hits:  1
#
# =======================
# DOC ID:  483
# WordID:  898
# num_hits:  1
#
# WordID:  899
# num_hits:  1
#
# =======================

# %%
import barrels.Sorter as sorter
import lexicon.Lexicon as lexicon

sorter.sort()
# Out:
# Doc ID [0] Num Hits[2]
# Doc ID [7] Num Hits[2]
# Doc ID [8] Num Hits[2]
# Doc ID [9] Num Hits[2]
# Doc ID [10] Num Hits[2]
# Doc ID [0] Num Hits[2]
# Doc ID [11] Num Hits[2]
# Doc ID [12] Num Hits[2]
# Doc ID [13] Num Hits[2]
# Doc ID [14] Num Hits[2]
# Doc ID [15] Num Hits[2]
# Doc ID [16] Num Hits[2]
# Doc ID [18] Num Hits[1]
# Doc ID [19] Num Hits[1]
# Doc ID [20] Num Hits[1]
# Doc ID [21] Num Hits[1]
# Doc ID [22] Num Hits[1]
# Doc ID [23] Num Hits[1]
# Doc ID [23] Num Hits[1]
# Doc ID [28] Num Hits[1]
# Doc ID [28] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [37] Num Hits[1]
# Doc ID [37] Num Hits[1]
# Doc ID [41] Num Hits[1]
# Doc ID [46] Num Hits[1]
# Doc ID [53] Num Hits[1]
# Doc ID [60] Num Hits[1]
# Doc ID [67] Num Hits[1]
# Doc ID [68] Num Hits[1]
# Doc ID [67] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [77] Num Hits[1]
# Doc ID [77] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [86] Num Hits[1]
# Doc ID [68] Num Hits[1]
# Doc ID [86] Num Hits[1]
# Doc ID [92] Num Hits[1]
# Doc ID [98] Num Hits[1]
# Doc ID [68] Num Hits[1]
# Doc ID [100] Num Hits[1]
# Doc ID [103] Num Hits[1]
# Doc ID [109] Num Hits[1]
# Doc ID [117] Num Hits[1]
# Doc ID [119] Num Hits[1]
# Doc ID [126] Num Hits[1]
# Doc ID [128] Num Hits[1]
# Doc ID [135] Num Hits[1]
# Doc ID [137] Num Hits[1]
# Doc ID [142] Num Hits[1]
# Doc ID [148] Num Hits[1]
# Doc ID [153] Num Hits[1]
# Doc ID [155] Num Hits[1]
# Doc ID [159] Num Hits[1]
# Doc ID [160] Num Hits[1]
# Doc ID [165] Num Hits[1]
# Doc ID [169] Num Hits[1]
# Doc ID [171] Num Hits[1]
# Doc ID [175] Num Hits[1]
# Doc ID [179] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [187] Num Hits[1]
# Doc ID [190] Num Hits[1]
# Doc ID [195] Num Hits[1]
# Doc ID [197] Num Hits[1]
# Doc ID [201] Num Hits[1]
# Doc ID [205] Num Hits[1]
# Doc ID [210] Num Hits[1]
# Doc ID [214] Num Hits[1]
# Doc ID [220] Num Hits[1]
# Doc ID [220] Num Hits[1]
# Doc ID [226] Num Hits[1]
# Doc ID [226] Num Hits[1]
# Doc ID [229] Num Hits[1]
# Doc ID [229] Num Hits[1]
# Doc ID [233] Num Hits[1]
# Doc ID [236] Num Hits[1]
# Doc ID [236] Num Hits[1]
# Doc ID [238] Num Hits[1]
# Doc ID [242] Num Hits[1]
# Doc ID [245] Num Hits[1]
# Doc ID [68] Num Hits[1]
# Doc ID [253] Num Hits[1]
# Doc ID [258] Num Hits[1]
# Doc ID [261] Num Hits[1]
# Doc ID [263] Num Hits[1]
# Doc ID [265] Num Hits[1]
# Doc ID [267] Num Hits[1]
# Doc ID [274] Num Hits[1]
# Doc ID [277] Num Hits[1]
# Doc ID [283] Num Hits[1]
# Doc ID [285] Num Hits[1]
# Doc ID [289] Num Hits[1]
# Doc ID [294] Num Hits[1]
# Doc ID [296] Num Hits[1]
# Doc ID [300] Num Hits[1]
# Doc ID [307] Num Hits[1]
# Doc ID [307] Num Hits[1]
# Doc ID [313] Num Hits[1]
# Doc ID [317] Num Hits[1]
# Doc ID [320] Num Hits[1]
# Doc ID [324] Num Hits[1]
# Doc ID [324] Num Hits[1]
# Doc ID [327] Num Hits[1]
# Doc ID [333] Num Hits[1]
# Doc ID [335] Num Hits[1]
# Doc ID [339] Num Hits[1]
# Doc ID [342] Num Hits[1]
# Doc ID [344] Num Hits[1]
# Doc ID [348] Num Hits[1]
# Doc ID [354] Num Hits[1]
# Doc ID [359] Num Hits[1]
# Doc ID [363] Num Hits[1]
# Doc ID [369] Num Hits[1]
# Doc ID [372] Num Hits[1]
# Doc ID [374] Num Hits[1]
# Doc ID [375] Num Hits[1]
# Doc ID [378] Num Hits[1]
# Doc ID [382] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [398] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [412] Num Hits[1]
# Doc ID [416] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [160] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [431] Num Hits[1]
# Doc ID [432] Num Hits[1]
# Doc ID [433] Num Hits[1]
# Doc ID [431] Num Hits[1]
# Doc ID [436] Num Hits[1]
# Doc ID [441] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [449] Num Hits[2]
# Doc ID [450] Num Hits[2]
# Doc ID [451] Num Hits[2]
# Doc ID [452] Num Hits[2]
# Doc ID [453] Num Hits[2]
# Doc ID [454] Num Hits[2]
# Doc ID [455] Num Hits[2]
# Doc ID [456] Num Hits[2]
# Doc ID [457] Num Hits[2]
# Doc ID [458] Num Hits[2]
# Doc ID [459] Num Hits[2]
# Doc ID [460] Num Hits[2]
# Doc ID [461] Num Hits[2]
# Doc ID [462] Num Hits[2]
# Doc ID [463] Num Hits[2]
# Doc ID [464] Num Hits[2]
# Doc ID [465] Num Hits[2]
# Doc ID [466] Num Hits[2]
# Doc ID [467] Num Hits[2]
# Doc ID [468] Num Hits[2]
# Doc ID [469] Num Hits[2]
# Doc ID [470] Num Hits[2]
# Doc ID [471] Num Hits[2]
# Doc ID [472] Num Hits[2]
# Doc ID [0] Num Hits[2]
# Doc ID [481] Num Hits[2]
# Doc ID [481] Num Hits[2]
# Doc ID [481] Num Hits[2]
# Doc ID [481] Num Hits[2]
# Doc ID [0] Num Hits[1]
# Doc ID [0] Num Hits[1]
# Doc ID [0] Num Hits[1]
# Doc ID [0] Num Hits[1]
# Doc ID [1] Num Hits[1]
# Doc ID [1] Num Hits[1]
# Doc ID [2] Num Hits[1]
# Doc ID [5] Num Hits[1]
# Doc ID [2] Num Hits[1]
# Doc ID [5] Num Hits[1]
# Doc ID [148] Num Hits[1]
# Doc ID [3] Num Hits[1]
# Doc ID [6] Num Hits[1]
# Doc ID [3] Num Hits[1]
# Doc ID [6] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [103] Num Hits[1]
# Doc ID [109] Num Hits[1]
# Doc ID [113] Num Hits[1]
# Doc ID [175] Num Hits[1]
# Doc ID [197] Num Hits[1]
# Doc ID [205] Num Hits[1]
# Doc ID [233] Num Hits[1]
# Doc ID [245] Num Hits[1]
# Doc ID [248] Num Hits[1]
# Doc ID [263] Num Hits[1]
# Doc ID [267] Num Hits[1]
# Doc ID [289] Num Hits[1]
# Doc ID [313] Num Hits[1]
# Doc ID [324] Num Hits[1]
# Doc ID [327] Num Hits[1]
# Doc ID [332] Num Hits[1]
# Doc ID [363] Num Hits[1]
# Doc ID [382] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [431] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [457] Num Hits[1]
# Doc ID [460] Num Hits[1]
# Doc ID [464] Num Hits[1]
# Doc ID [4] Num Hits[1]
# Doc ID [473] Num Hits[1]
# Doc ID [4] Num Hits[1]
# Doc ID [7] Num Hits[1]
# Doc ID [7] Num Hits[1]
# Doc ID [7] Num Hits[1]
# Doc ID [0] Num Hits[1]
# Doc ID [8] Num Hits[1]
# Doc ID [8] Num Hits[1]
# Doc ID [8] Num Hits[1]
# Doc ID [9] Num Hits[1]
# Doc ID [167] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [9] Num Hits[1]
# Doc ID [9] Num Hits[1]
# Doc ID [9] Num Hits[1]
# Doc ID [479] Num Hits[1]
# Doc ID [10] Num Hits[1]
# Doc ID [11] Num Hits[1]
# Doc ID [11] Num Hits[1]
# Doc ID [448] Num Hits[1]
# Doc ID [0] Num Hits[1]
# Doc ID [12] Num Hits[1]
# Doc ID [13] Num Hits[1]
# Doc ID [14] Num Hits[1]
# Doc ID [14] Num Hits[1]
# Doc ID [15] Num Hits[1]
# Doc ID [16] Num Hits[1]
# Doc ID [17] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [17] Num Hits[1]
# Doc ID [18] Num Hits[1]
# Doc ID [18] Num Hits[1]
# Doc ID [18] Num Hits[1]
# Doc ID [332] Num Hits[1]
# Doc ID [18] Num Hits[1]
# Doc ID [19] Num Hits[1]
# Doc ID [20] Num Hits[1]
# Doc ID [0] Num Hits[1]
# Doc ID [21] Num Hits[1]
# Doc ID [22] Num Hits[1]
# Doc ID [23] Num Hits[1]
# Doc ID [238] Num Hits[1]
# Doc ID [23] Num Hits[1]
# Doc ID [54] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [93] Num Hits[1]
# Doc ID [128] Num Hits[1]
# Doc ID [167] Num Hits[1]
# Doc ID [325] Num Hits[1]
# Doc ID [335] Num Hits[1]
# Doc ID [369] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [468] Num Hits[1]
# Doc ID [23] Num Hits[1]
# Doc ID [28] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [37] Num Hits[1]
# Doc ID [53] Num Hits[1]
# Doc ID [60] Num Hits[1]
# Doc ID [67] Num Hits[1]
# Doc ID [73] Num Hits[2]
# Doc ID [81] Num Hits[1]
# Doc ID [92] Num Hits[1]
# Doc ID [96] Num Hits[1]
# Doc ID [100] Num Hits[1]
# Doc ID [119] Num Hits[1]
# Doc ID [123] Num Hits[1]
# Doc ID [148] Num Hits[1]
# Doc ID [153] Num Hits[1]
# Doc ID [159] Num Hits[1]
# Doc ID [171] Num Hits[1]
# Doc ID [179] Num Hits[1]
# Doc ID [187] Num Hits[1]
# Doc ID [190] Num Hits[1]
# Doc ID [226] Num Hits[1]
# Doc ID [236] Num Hits[1]
# Doc ID [238] Num Hits[1]
# Doc ID [245] Num Hits[1]
# Doc ID [248] Num Hits[1]
# Doc ID [255] Num Hits[1]
# Doc ID [263] Num Hits[1]
# Doc ID [267] Num Hits[1]
# Doc ID [276] Num Hits[2]
# Doc ID [307] Num Hits[1]
# Doc ID [344] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [457] Num Hits[1]
# Doc ID [459] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [23] Num Hits[1]
# Doc ID [28] Num Hits[1]
# Doc ID [67] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [119] Num Hits[1]
# Doc ID [123] Num Hits[1]
# Doc ID [148] Num Hits[1]
# Doc ID [153] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [220] Num Hits[1]
# Doc ID [226] Num Hits[1]
# Doc ID [233] Num Hits[1]
# Doc ID [236] Num Hits[1]
# Doc ID [245] Num Hits[1]
# Doc ID [255] Num Hits[1]
# Doc ID [263] Num Hits[1]
# Doc ID [285] Num Hits[1]
# Doc ID [344] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [460] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [463] Num Hits[1]
# Doc ID [23] Num Hits[1]
# Doc ID [25] Num Hits[1]
# Doc ID [103] Num Hits[1]
# Doc ID [25] Num Hits[1]
# Doc ID [25] Num Hits[1]
# Doc ID [23] Num Hits[1]
# Doc ID [23] Num Hits[1]
# Doc ID [23] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [109] Num Hits[1]
# Doc ID [220] Num Hits[1]
# Doc ID [222] Num Hits[1]
# Doc ID [224] Num Hits[1]
# Doc ID [245] Num Hits[1]
# Doc ID [248] Num Hits[2]
# Doc ID [474] Num Hits[1]
# Doc ID [24] Num Hits[1]
# Doc ID [24] Num Hits[1]
# Doc ID [185] Num Hits[1]
# Doc ID [185] Num Hits[1]
# Doc ID [185] Num Hits[1]
# Doc ID [26] Num Hits[1]
# Doc ID [23] Num Hits[1]
# Doc ID [28] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [37] Num Hits[1]
# Doc ID [41] Num Hits[1]
# Doc ID [46] Num Hits[1]
# Doc ID [60] Num Hits[1]
# Doc ID [67] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [86] Num Hits[1]
# Doc ID [92] Num Hits[1]
# Doc ID [100] Num Hits[1]
# Doc ID [103] Num Hits[1]
# Doc ID [119] Num Hits[1]
# Doc ID [137] Num Hits[1]
# Doc ID [142] Num Hits[1]
# Doc ID [148] Num Hits[1]
# Doc ID [155] Num Hits[1]
# Doc ID [175] Num Hits[1]
# Doc ID [179] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [187] Num Hits[1]
# Doc ID [190] Num Hits[1]
# Doc ID [195] Num Hits[1]
# Doc ID [197] Num Hits[1]
# Doc ID [201] Num Hits[1]
# Doc ID [210] Num Hits[1]
# Doc ID [214] Num Hits[1]
# Doc ID [220] Num Hits[1]
# Doc ID [226] Num Hits[1]
# Doc ID [229] Num Hits[1]
# Doc ID [233] Num Hits[1]
# Doc ID [238] Num Hits[1]
# Doc ID [242] Num Hits[1]
# Doc ID [245] Num Hits[1]
# Doc ID [267] Num Hits[1]
# Doc ID [285] Num Hits[1]
# Doc ID [296] Num Hits[1]
# Doc ID [307] Num Hits[1]
# Doc ID [313] Num Hits[1]
# Doc ID [317] Num Hits[1]
# Doc ID [320] Num Hits[1]
# Doc ID [324] Num Hits[1]
# Doc ID [327] Num Hits[1]
# Doc ID [344] Num Hits[1]
# Doc ID [348] Num Hits[1]
# Doc ID [359] Num Hits[1]
# Doc ID [378] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [412] Num Hits[1]
# Doc ID [416] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [431] Num Hits[1]
# Doc ID [27] Num Hits[1]
# Doc ID [28] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [100] Num Hits[2]
# Doc ID [128] Num Hits[1]
# Doc ID [153] Num Hits[1]
# Doc ID [175] Num Hits[1]
# Doc ID [179] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [190] Num Hits[1]
# Doc ID [220] Num Hits[1]
# Doc ID [226] Num Hits[1]
# Doc ID [270] Num Hits[1]
# Doc ID [285] Num Hits[1]
# Doc ID [300] Num Hits[1]
# Doc ID [320] Num Hits[1]
# Doc ID [332] Num Hits[1]
# Doc ID [342] Num Hits[1]
# Doc ID [344] Num Hits[1]
# Doc ID [348] Num Hits[1]
# Doc ID [363] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [457] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [468] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [472] Num Hits[1]
# Doc ID [28] Num Hits[1]
# Doc ID [28] Num Hits[1]
# Doc ID [41] Num Hits[1]
# Doc ID [60] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [92] Num Hits[1]
# Doc ID [142] Num Hits[1]
# Doc ID [201] Num Hits[1]
# Doc ID [210] Num Hits[1]
# Doc ID [236] Num Hits[1]
# Doc ID [263] Num Hits[1]
# Doc ID [285] Num Hits[1]
# Doc ID [28] Num Hits[1]
# Doc ID [28] Num Hits[1]
# Doc ID [167] Num Hits[1]
# Doc ID [28] Num Hits[1]
# Doc ID [28] Num Hits[1]
# Doc ID [28] Num Hits[1]
# Doc ID [161] Num Hits[1]
# Doc ID [28] Num Hits[1]
# Doc ID [60] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [103] Num Hits[1]
# Doc ID [187] Num Hits[1]
# Doc ID [220] Num Hits[1]
# Doc ID [285] Num Hits[1]
# Doc ID [300] Num Hits[1]
# Doc ID [332] Num Hits[1]
# Doc ID [354] Num Hits[1]
# Doc ID [375] Num Hits[1]
# Doc ID [29] Num Hits[1]
# Doc ID [30] Num Hits[1]
# Doc ID [31] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [53] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [324] Num Hits[1]
# Doc ID [332] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [455] Num Hits[2]
# Doc ID [457] Num Hits[1]
# Doc ID [468] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [324] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [195] Num Hits[1]
# Doc ID [263] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [151] Num Hits[1]
# Doc ID [226] Num Hits[1]
# Doc ID [236] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [32] Num Hits[1]
# Doc ID [35] Num Hits[1]
# Doc ID [53] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [81] Num Hits[3]
# Doc ID [167] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [270] Num Hits[1]
# Doc ID [285] Num Hits[1]
# Doc ID [307] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [455] Num Hits[2]
# Doc ID [456] Num Hits[1]
# Doc ID [459] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [33] Num Hits[1]
# Doc ID [34] Num Hits[1]
# Doc ID [35] Num Hits[1]
# Doc ID [35] Num Hits[1]
# Doc ID [36] Num Hits[1]
# Doc ID [36] Num Hits[1]
# Doc ID [37] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [464] Num Hits[1]
# Doc ID [37] Num Hits[2]
# Doc ID [137] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [220] Num Hits[1]
# Doc ID [285] Num Hits[1]
# Doc ID [37] Num Hits[1]
# Doc ID [38] Num Hits[1]
# Doc ID [248] Num Hits[1]
# Doc ID [37] Num Hits[1]
# Doc ID [37] Num Hits[1]
# Doc ID [255] Num Hits[1]
# Doc ID [37] Num Hits[1]
# Doc ID [60] Num Hits[1]
# Doc ID [37] Num Hits[1]
# Doc ID [153] Num Hits[1]
# Doc ID [37] Num Hits[1]
# Doc ID [464] Num Hits[1]
# Doc ID [37] Num Hits[1]
# Doc ID [37] Num Hits[1]
# Doc ID [37] Num Hits[1]
# Doc ID [39] Num Hits[1]
# Doc ID [40] Num Hits[1]
# Doc ID [41] Num Hits[1]
# Doc ID [44] Num Hits[1]
# Doc ID [41] Num Hits[1]
# Doc ID [41] Num Hits[1]
# Doc ID [41] Num Hits[1]
# Doc ID [41] Num Hits[1]
# Doc ID [179] Num Hits[1]
# Doc ID [195] Num Hits[1]
# Doc ID [214] Num Hits[1]
# Doc ID [260] Num Hits[1]
# Doc ID [270] Num Hits[1]
# Doc ID [292] Num Hits[1]
# Doc ID [307] Num Hits[1]
# Doc ID [339] Num Hits[1]
# Doc ID [441] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [460] Num Hits[1]
# Doc ID [467] Num Hits[1]
# Doc ID [41] Num Hits[1]
# Doc ID [41] Num Hits[1]
# Doc ID [42] Num Hits[1]
# Doc ID [43] Num Hits[1]
# Doc ID [41] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [463] Num Hits[1]
# Doc ID [41] Num Hits[1]
# Doc ID [41] Num Hits[1]
# Doc ID [41] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [103] Num Hits[1]
# Doc ID [43] Num Hits[1]
# Doc ID [214] Num Hits[1]
# Doc ID [359] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [43] Num Hits[1]
# Doc ID [45] Num Hits[1]
# Doc ID [46] Num Hits[1]
# Doc ID [46] Num Hits[1]
# Doc ID [190] Num Hits[1]
# Doc ID [47] Num Hits[1]
# Doc ID [70] Num Hits[1]
# Doc ID [47] Num Hits[1]
# Doc ID [47] Num Hits[1]
# Doc ID [148] Num Hits[1]
# Doc ID [47] Num Hits[1]
# Doc ID [151] Num Hits[1]
# Doc ID [153] Num Hits[1]
# Doc ID [47] Num Hits[1]
# Doc ID [70] Num Hits[1]
# Doc ID [47] Num Hits[1]
# Doc ID [48] Num Hits[1]
# Doc ID [49] Num Hits[1]
# Doc ID [50] Num Hits[1]
# Doc ID [50] Num Hits[1]
# Doc ID [51] Num Hits[1]
# Doc ID [52] Num Hits[1]
# Doc ID [53] Num Hits[1]
# Doc ID [460] Num Hits[1]
# Doc ID [53] Num Hits[1]
# Doc ID [58] Num Hits[1]
# Doc ID [53] Num Hits[1]
# Doc ID [86] Num Hits[1]
# Doc ID [109] Num Hits[1]
# Doc ID [344] Num Hits[1]
# Doc ID [53] Num Hits[1]
# Doc ID [54] Num Hits[1]
# Doc ID [93] Num Hits[1]
# Doc ID [324] Num Hits[1]
# Doc ID [325] Num Hits[1]
# Doc ID [53] Num Hits[1]
# Doc ID [53] Num Hits[1]
# Doc ID [285] Num Hits[1]
# Doc ID [53] Num Hits[1]
# Doc ID [54] Num Hits[1]
# Doc ID [93] Num Hits[1]
# Doc ID [325] Num Hits[1]
# Doc ID [54] Num Hits[1]
# Doc ID [113] Num Hits[1]
# Doc ID [115] Num Hits[1]
# Doc ID [55] Num Hits[1]
# Doc ID [56] Num Hits[1]
# Doc ID [56] Num Hits[1]
# Doc ID [57] Num Hits[1]
# Doc ID [53] Num Hits[1]
# Doc ID [77] Num Hits[1]
# Doc ID [109] Num Hits[1]
# Doc ID [126] Num Hits[1]
# Doc ID [128] Num Hits[1]
# Doc ID [135] Num Hits[1]
# Doc ID [153] Num Hits[1]
# Doc ID [171] Num Hits[1]
# Doc ID [205] Num Hits[1]
# Doc ID [236] Num Hits[1]
# Doc ID [258] Num Hits[1]
# Doc ID [274] Num Hits[1]
# Doc ID [289] Num Hits[1]
# Doc ID [294] Num Hits[1]
# Doc ID [300] Num Hits[1]
# Doc ID [335] Num Hits[1]
# Doc ID [339] Num Hits[1]
# Doc ID [342] Num Hits[1]
# Doc ID [354] Num Hits[1]
# Doc ID [363] Num Hits[1]
# Doc ID [369] Num Hits[1]
# Doc ID [375] Num Hits[1]
# Doc ID [382] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [398] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [436] Num Hits[1]
# Doc ID [441] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [59] Num Hits[1]
# Doc ID [60] Num Hits[1]
# Doc ID [60] Num Hits[1]
# Doc ID [60] Num Hits[1]
# Doc ID [65] Num Hits[1]
# Doc ID [167] Num Hits[1]
# Doc ID [300] Num Hits[1]
# Doc ID [304] Num Hits[1]
# Doc ID [355] Num Hits[1]
# Doc ID [369] Num Hits[1]
# Doc ID [370] Num Hits[1]
# Doc ID [60] Num Hits[1]
# Doc ID [64] Num Hits[1]
# Doc ID [65] Num Hits[1]
# Doc ID [60] Num Hits[1]
# Doc ID [60] Num Hits[1]
# Doc ID [62] Num Hits[1]
# Doc ID [61] Num Hits[1]
# Doc ID [61] Num Hits[1]
# Doc ID [133] Num Hits[1]
# Doc ID [61] Num Hits[1]
# Doc ID [134] Num Hits[1]
# Doc ID [61] Num Hits[1]
# Doc ID [187] Num Hits[1]
# Doc ID [61] Num Hits[1]
# Doc ID [61] Num Hits[1]
# Doc ID [61] Num Hits[1]
# Doc ID [236] Num Hits[1]
# Doc ID [61] Num Hits[1]
# Doc ID [242] Num Hits[1]
# Doc ID [61] Num Hits[1]
# Doc ID [61] Num Hits[1]
# Doc ID [61] Num Hits[1]
# Doc ID [61] Num Hits[1]
# Doc ID [61] Num Hits[1]
# Doc ID [61] Num Hits[1]
# Doc ID [460] Num Hits[1]
# Doc ID [62] Num Hits[1]
# Doc ID [63] Num Hits[1]
# Doc ID [119] Num Hits[1]
# Doc ID [63] Num Hits[1]
# Doc ID [63] Num Hits[1]
# Doc ID [137] Num Hits[1]
# Doc ID [66] Num Hits[1]
# Doc ID [67] Num Hits[1]
# Doc ID [67] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [77] Num Hits[1]
# Doc ID [100] Num Hits[1]
# Doc ID [267] Num Hits[1]
# Doc ID [67] Num Hits[1]
# Doc ID [67] Num Hits[1]
# Doc ID [68] Num Hits[1]
# Doc ID [68] Num Hits[1]
# Doc ID [68] Num Hits[1]
# Doc ID [160] Num Hits[1]
# Doc ID [68] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [160] Num Hits[1]
# Doc ID [69] Num Hits[1]
# Doc ID [70] Num Hits[1]
# Doc ID [153] Num Hits[1]
# Doc ID [69] Num Hits[1]
# Doc ID [70] Num Hits[1]
# Doc ID [71] Num Hits[1]
# Doc ID [71] Num Hits[1]
# Doc ID [72] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [77] Num Hits[1]
# Doc ID [103] Num Hits[1]
# Doc ID [109] Num Hits[1]
# Doc ID [226] Num Hits[1]
# Doc ID [335] Num Hits[1]
# Doc ID [375] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [469] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [123] Num Hits[1]
# Doc ID [167] Num Hits[1]
# Doc ID [184] Num Hits[2]
# Doc ID [187] Num Hits[1]
# Doc ID [279] Num Hits[1]
# Doc ID [285] Num Hits[1]
# Doc ID [292] Num Hits[1]
# Doc ID [296] Num Hits[1]
# Doc ID [359] Num Hits[1]
# Doc ID [363] Num Hits[1]
# Doc ID [11] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [270] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [74] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [73] Num Hits[1]
# Doc ID [75] Num Hits[1]
# Doc ID [76] Num Hits[1]
# Doc ID [77] Num Hits[1]
# Doc ID [226] Num Hits[1]
# Doc ID [233] Num Hits[1]
# Doc ID [77] Num Hits[1]
# Doc ID [77] Num Hits[1]
# Doc ID [77] Num Hits[1]
# Doc ID [78] Num Hits[1]
# Doc ID [79] Num Hits[1]
# Doc ID [171] Num Hits[1]
# Doc ID [78] Num Hits[1]
# Doc ID [252] Num Hits[1]
# Doc ID [77] Num Hits[1]
# Doc ID [77] Num Hits[1]
# Doc ID [79] Num Hits[1]
# Doc ID [80] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [453] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [450] Num Hits[2]
# Doc ID [458] Num Hits[1]
# Doc ID [459] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [205] Num Hits[1]
# Doc ID [230] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [226] Num Hits[1]
# Doc ID [270] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [270] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [81] Num Hits[1]
# Doc ID [267] Num Hits[1]
# Doc ID [285] Num Hits[1]
# Doc ID [342] Num Hits[1]
# Doc ID [82] Num Hits[1]
# Doc ID [84] Num Hits[1]
# Doc ID [83] Num Hits[1]
# Doc ID [84] Num Hits[1]
# Doc ID [85] Num Hits[1]
# Doc ID [86] Num Hits[1]
# Doc ID [86] Num Hits[1]
# Doc ID [87] Num Hits[1]
# Doc ID [86] Num Hits[1]
# Doc ID [88] Num Hits[1]
# Doc ID [86] Num Hits[1]
# Doc ID [90] Num Hits[1]
# Doc ID [86] Num Hits[1]
# Doc ID [458] Num Hits[1]
# Doc ID [460] Num Hits[1]
# Doc ID [466] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [86] Num Hits[1]
# Doc ID [86] Num Hits[1]
# Doc ID [398] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [466] Num Hits[1]
# Doc ID [88] Num Hits[1]
# Doc ID [89] Num Hits[1]
# Doc ID [305] Num Hits[1]
# Doc ID [308] Num Hits[1]
# Doc ID [388] Num Hits[1]
# Doc ID [89] Num Hits[1]
# Doc ID [110] Num Hits[1]
# Doc ID [111] Num Hits[1]
# Doc ID [113] Num Hits[1]
# Doc ID [115] Num Hits[1]
# Doc ID [421] Num Hits[1]
# Doc ID [432] Num Hits[1]
# Doc ID [89] Num Hits[1]
# Doc ID [110] Num Hits[1]
# Doc ID [111] Num Hits[1]
# Doc ID [113] Num Hits[1]
# Doc ID [115] Num Hits[1]
# Doc ID [89] Num Hits[1]
# Doc ID [90] Num Hits[1]
# Doc ID [91] Num Hits[1]
# Doc ID [92] Num Hits[1]
# Doc ID [92] Num Hits[2]
# Doc ID [92] Num Hits[1]
# Doc ID [94] Num Hits[1]
# Doc ID [92] Num Hits[1]
# Doc ID [92] Num Hits[2]
# Doc ID [92] Num Hits[2]
# Doc ID [171] Num Hits[1]
# Doc ID [92] Num Hits[2]
# Doc ID [95] Num Hits[1]
# Doc ID [96] Num Hits[1]
# Doc ID [96] Num Hits[1]
# Doc ID [96] Num Hits[1]
# Doc ID [384] Num Hits[1]
# Doc ID [416] Num Hits[1]
# Doc ID [482] Num Hits[1]
# Doc ID [96] Num Hits[1]
# Doc ID [185] Num Hits[1]
# Doc ID [214] Num Hits[1]
# Doc ID [185] Num Hits[1]
# Doc ID [185] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [481] Num Hits[1]
# Doc ID [482] Num Hits[1]
# Doc ID [96] Num Hits[1]
# Doc ID [96] Num Hits[1]
# Doc ID [97] Num Hits[1]
# Doc ID [97] Num Hits[1]
# Doc ID [98] Num Hits[1]
# Doc ID [117] Num Hits[1]
# Doc ID [165] Num Hits[1]
# Doc ID [169] Num Hits[1]
# Doc ID [253] Num Hits[1]
# Doc ID [261] Num Hits[1]
# Doc ID [265] Num Hits[1]
# Doc ID [277] Num Hits[1]
# Doc ID [283] Num Hits[1]
# Doc ID [333] Num Hits[1]
# Doc ID [374] Num Hits[1]
# Doc ID [99] Num Hits[1]
# Doc ID [99] Num Hits[1]
# Doc ID [100] Num Hits[1]
# Doc ID [180] Num Hits[1]
# Doc ID [100] Num Hits[1]
# Doc ID [292] Num Hits[1]
# Doc ID [100] Num Hits[1]
# Doc ID [100] Num Hits[1]
# Doc ID [187] Num Hits[1]
# Doc ID [100] Num Hits[1]
# Doc ID [100] Num Hits[1]
# Doc ID [101] Num Hits[1]
# Doc ID [157] Num Hits[1]
# Doc ID [187] Num Hits[1]
# Doc ID [101] Num Hits[1]
# Doc ID [188] Num Hits[1]
# Doc ID [101] Num Hits[1]
# Doc ID [399] Num Hits[1]
# Doc ID [102] Num Hits[1]
# Doc ID [102] Num Hits[1]
# Doc ID [103] Num Hits[1]
# Doc ID [107] Num Hits[1]
# Doc ID [103] Num Hits[1]
# Doc ID [103] Num Hits[1]
# Doc ID [123] Num Hits[1]
# Doc ID [181] Num Hits[1]
# Doc ID [460] Num Hits[1]
# Doc ID [103] Num Hits[1]
# Doc ID [382] Num Hits[1]
# Doc ID [385] Num Hits[1]
# Doc ID [103] Num Hits[1]
# Doc ID [229] Num Hits[1]
# Doc ID [103] Num Hits[1]
# Doc ID [104] Num Hits[1]
# Doc ID [105] Num Hits[1]
# Doc ID [106] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [106] Num Hits[1]
# Doc ID [108] Num Hits[1]
# Doc ID [109] Num Hits[1]
# Doc ID [109] Num Hits[1]
# Doc ID [123] Num Hits[1]
# Doc ID [167] Num Hits[1]
# Doc ID [335] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [467] Num Hits[1]
# Doc ID [109] Num Hits[1]
# Doc ID [109] Num Hits[1]
# Doc ID [110] Num Hits[1]
# Doc ID [111] Num Hits[1]
# Doc ID [113] Num Hits[1]
# Doc ID [115] Num Hits[1]
# Doc ID [109] Num Hits[1]
# Doc ID [377] Num Hits[1]
# Doc ID [109] Num Hits[1]
# Doc ID [111] Num Hits[1]
# Doc ID [112] Num Hits[1]
# Doc ID [113] Num Hits[1]
# Doc ID [113] Num Hits[1]
# Doc ID [114] Num Hits[1]
# Doc ID [372] Num Hits[1]
# Doc ID [114] Num Hits[1]
# Doc ID [116] Num Hits[1]
# Doc ID [118] Num Hits[1]
# Doc ID [118] Num Hits[1]
# Doc ID [118] Num Hits[1]
# Doc ID [415] Num Hits[1]
# Doc ID [118] Num Hits[1]
# Doc ID [119] Num Hits[1]
# Doc ID [155] Num Hits[1]
# Doc ID [119] Num Hits[1]
# Doc ID [119] Num Hits[1]
# Doc ID [153] Num Hits[1]
# Doc ID [245] Num Hits[1]
# Doc ID [276] Num Hits[1]
# Doc ID [468] Num Hits[1]
# Doc ID [119] Num Hits[2]
# Doc ID [119] Num Hits[1]
# Doc ID [120] Num Hits[1]
# Doc ID [119] Num Hits[1]
# Doc ID [121] Num Hits[1]
# Doc ID [119] Num Hits[1]
# Doc ID [155] Num Hits[1]
# Doc ID [320] Num Hits[1]
# Doc ID [119] Num Hits[1]
# Doc ID [120] Num Hits[1]
# Doc ID [121] Num Hits[1]
# Doc ID [142] Num Hits[1]
# Doc ID [143] Num Hits[1]
# Doc ID [122] Num Hits[1]
# Doc ID [123] Num Hits[1]
# Doc ID [125] Num Hits[1]
# Doc ID [123] Num Hits[1]
# Doc ID [123] Num Hits[1]
# Doc ID [124] Num Hits[1]
# Doc ID [172] Num Hits[1]
# Doc ID [339] Num Hits[1]
# Doc ID [124] Num Hits[1]
# Doc ID [123] Num Hits[1]
# Doc ID [123] Num Hits[1]
# Doc ID [179] Num Hits[1]
# Doc ID [127] Num Hits[1]
# Doc ID [128] Num Hits[1]
# Doc ID [128] Num Hits[1]
# Doc ID [220] Num Hits[1]
# Doc ID [223] Num Hits[1]
# Doc ID [276] Num Hits[1]
# Doc ID [223] Num Hits[1]
# Doc ID [128] Num Hits[1]
# Doc ID [130] Num Hits[1]
# Doc ID [313] Num Hits[1]
# Doc ID [130] Num Hits[1]
# Doc ID [128] Num Hits[1]
# Doc ID [128] Num Hits[1]
# Doc ID [128] Num Hits[1]
# Doc ID [128] Num Hits[1]
# Doc ID [129] Num Hits[1]
# Doc ID [131] Num Hits[1]
# Doc ID [132] Num Hits[1]
# Doc ID [133] Num Hits[1]
# Doc ID [267] Num Hits[1]
# Doc ID [133] Num Hits[1]
# Doc ID [133] Num Hits[1]
# Doc ID [134] Num Hits[1]
# Doc ID [136] Num Hits[1]
# Doc ID [137] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [137] Num Hits[1]
# Doc ID [464] Num Hits[1]
# Doc ID [137] Num Hits[1]
# Doc ID [137] Num Hits[1]
# Doc ID [137] Num Hits[1]
# Doc ID [263] Num Hits[1]
# Doc ID [285] Num Hits[1]
# Doc ID [307] Num Hits[1]
# Doc ID [137] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [270] Num Hits[1]
# Doc ID [342] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [137] Num Hits[1]
# Doc ID [139] Num Hits[1]
# Doc ID [137] Num Hits[1]
# Doc ID [137] Num Hits[1]
# Doc ID [137] Num Hits[1]
# Doc ID [332] Num Hits[1]
# Doc ID [138] Num Hits[1]
# Doc ID [140] Num Hits[1]
# Doc ID [141] Num Hits[1]
# Doc ID [142] Num Hits[1]
# Doc ID [317] Num Hits[1]
# Doc ID [142] Num Hits[1]
# Doc ID [142] Num Hits[1]
# Doc ID [324] Num Hits[1]
# Doc ID [142] Num Hits[1]
# Doc ID [144] Num Hits[1]
# Doc ID [145] Num Hits[1]
# Doc ID [468] Num Hits[1]
# Doc ID [145] Num Hits[1]
# Doc ID [146] Num Hits[1]
# Doc ID [146] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [482] Num Hits[1]
# Doc ID [147] Num Hits[1]
# Doc ID [147] Num Hits[1]
# Doc ID [194] Num Hits[1]
# Doc ID [148] Num Hits[1]
# Doc ID [148] Num Hits[1]
# Doc ID [149] Num Hits[1]
# Doc ID [150] Num Hits[1]
# Doc ID [270] Num Hits[1]
# Doc ID [271] Num Hits[1]
# Doc ID [150] Num Hits[1]
# Doc ID [151] Num Hits[1]
# Doc ID [152] Num Hits[1]
# Doc ID [153] Num Hits[1]
# Doc ID [195] Num Hits[1]
# Doc ID [263] Num Hits[1]
# Doc ID [463] Num Hits[1]
# Doc ID [153] Num Hits[1]
# Doc ID [153] Num Hits[1]
# Doc ID [171] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [207] Num Hits[1]
# Doc ID [226] Num Hits[1]
# Doc ID [292] Num Hits[1]
# Doc ID [324] Num Hits[1]
# Doc ID [348] Num Hits[1]
# Doc ID [372] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [463] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [153] Num Hits[1]
# Doc ID [383] Num Hits[1]
# Doc ID [154] Num Hits[1]
# Doc ID [155] Num Hits[1]
# Doc ID [155] Num Hits[1]
# Doc ID [156] Num Hits[1]
# Doc ID [155] Num Hits[1]
# Doc ID [155] Num Hits[1]
# Doc ID [157] Num Hits[1]
# Doc ID [280] Num Hits[1]
# Doc ID [157] Num Hits[1]
# Doc ID [158] Num Hits[1]
# Doc ID [158] Num Hits[1]
# Doc ID [159] Num Hits[1]
# Doc ID [159] Num Hits[1]
# Doc ID [159] Num Hits[1]
# Doc ID [159] Num Hits[2]
# Doc ID [270] Num Hits[1]
# Doc ID [159] Num Hits[1]
# Doc ID [324] Num Hits[1]
# Doc ID [325] Num Hits[1]
# Doc ID [159] Num Hits[1]
# Doc ID [159] Num Hits[1]
# Doc ID [159] Num Hits[1]
# Doc ID [162] Num Hits[1]
# Doc ID [163] Num Hits[1]
# Doc ID [164] Num Hits[1]
# Doc ID [164] Num Hits[1]
# Doc ID [166] Num Hits[1]
# Doc ID [166] Num Hits[1]
# Doc ID [167] Num Hits[1]
# Doc ID [167] Num Hits[1]
# Doc ID [167] Num Hits[1]
# Doc ID [167] Num Hits[1]
# Doc ID [167] Num Hits[2]
# Doc ID [168] Num Hits[1]
# Doc ID [170] Num Hits[1]
# Doc ID [170] Num Hits[1]
# Doc ID [170] Num Hits[1]
# Doc ID [170] Num Hits[1]
# Doc ID [171] Num Hits[1]
# Doc ID [171] Num Hits[1]
# Doc ID [348] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [171] Num Hits[1]
# Doc ID [171] Num Hits[1]
# Doc ID [171] Num Hits[1]
# Doc ID [332] Num Hits[1]
# Doc ID [172] Num Hits[1]
# Doc ID [173] Num Hits[1]
# Doc ID [174] Num Hits[1]
# Doc ID [174] Num Hits[1]
# Doc ID [175] Num Hits[1]
# Doc ID [175] Num Hits[1]
# Doc ID [270] Num Hits[1]
# Doc ID [175] Num Hits[1]
# Doc ID [177] Num Hits[1]
# Doc ID [175] Num Hits[1]
# Doc ID [176] Num Hits[1]
# Doc ID [175] Num Hits[1]
# Doc ID [176] Num Hits[1]
# Doc ID [178] Num Hits[1]
# Doc ID [179] Num Hits[1]
# Doc ID [179] Num Hits[1]
# Doc ID [179] Num Hits[1]
# Doc ID [182] Num Hits[1]
# Doc ID [179] Num Hits[1]
# Doc ID [179] Num Hits[1]
# Doc ID [468] Num Hits[1]
# Doc ID [179] Num Hits[1]
# Doc ID [465] Num Hits[1]
# Doc ID [179] Num Hits[1]
# Doc ID [0] Num Hits[1]
# Doc ID [481] Num Hits[1]
# Doc ID [481] Num Hits[1]
# Doc ID [481] Num Hits[1]
# Doc ID [481] Num Hits[1]
# Doc ID [183] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [372] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [229] Num Hits[1]
# Doc ID [245] Num Hits[1]
# Doc ID [375] Num Hits[1]
# Doc ID [441] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [184] Num Hits[2]
# Doc ID [226] Num Hits[1]
# Doc ID [348] Num Hits[1]
# Doc ID [184] Num Hits[1]
# Doc ID [185] Num Hits[1]
# Doc ID [185] Num Hits[1]
# Doc ID [185] Num Hits[1]
# Doc ID [186] Num Hits[1]
# Doc ID [186] Num Hits[1]
# Doc ID [244] Num Hits[1]
# Doc ID [187] Num Hits[1]
# Doc ID [187] Num Hits[1]
# Doc ID [270] Num Hits[1]
# Doc ID [359] Num Hits[1]
# Doc ID [187] Num Hits[1]
# Doc ID [187] Num Hits[1]
# Doc ID [207] Num Hits[1]
# Doc ID [188] Num Hits[1]
# Doc ID [349] Num Hits[1]
# Doc ID [189] Num Hits[1]
# Doc ID [189] Num Hits[1]
# Doc ID [190] Num Hits[1]
# Doc ID [190] Num Hits[1]
# Doc ID [190] Num Hits[1]
# Doc ID [190] Num Hits[1]
# Doc ID [190] Num Hits[1]
# Doc ID [192] Num Hits[1]
# Doc ID [190] Num Hits[1]
# Doc ID [286] Num Hits[1]
# Doc ID [287] Num Hits[1]
# Doc ID [190] Num Hits[1]
# Doc ID [191] Num Hits[1]
# Doc ID [191] Num Hits[1]
# Doc ID [191] Num Hits[1]
# Doc ID [191] Num Hits[1]
# Doc ID [191] Num Hits[1]
# Doc ID [191] Num Hits[1]
# Doc ID [191] Num Hits[1]
# Doc ID [191] Num Hits[1]
# Doc ID [191] Num Hits[1]
# Doc ID [193] Num Hits[1]
# Doc ID [194] Num Hits[1]
# Doc ID [195] Num Hits[1]
# Doc ID [195] Num Hits[1]
# Doc ID [372] Num Hits[1]
# Doc ID [373] Num Hits[1]
# Doc ID [195] Num Hits[1]
# Doc ID [196] Num Hits[1]
# Doc ID [197] Num Hits[1]
# Doc ID [197] Num Hits[1]
# Doc ID [198] Num Hits[1]
# Doc ID [197] Num Hits[1]
# Doc ID [197] Num Hits[1]
# Doc ID [260] Num Hits[1]
# Doc ID [467] Num Hits[1]
# Doc ID [199] Num Hits[1]
# Doc ID [200] Num Hits[1]
# Doc ID [200] Num Hits[1]
# Doc ID [201] Num Hits[1]
# Doc ID [203] Num Hits[1]
# Doc ID [201] Num Hits[1]
# Doc ID [201] Num Hits[1]
# Doc ID [201] Num Hits[1]
# Doc ID [201] Num Hits[1]
# Doc ID [202] Num Hits[1]
# Doc ID [204] Num Hits[1]
# Doc ID [205] Num Hits[1]
# Doc ID [206] Num Hits[1]
# Doc ID [205] Num Hits[1]
# Doc ID [208] Num Hits[1]
# Doc ID [209] Num Hits[1]
# Doc ID [209] Num Hits[1]
# Doc ID [210] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [210] Num Hits[1]
# Doc ID [210] Num Hits[1]
# Doc ID [210] Num Hits[1]
# Doc ID [255] Num Hits[1]
# Doc ID [210] Num Hits[1]
# Doc ID [210] Num Hits[1]
# Doc ID [211] Num Hits[1]
# Doc ID [212] Num Hits[1]
# Doc ID [211] Num Hits[1]
# Doc ID [211] Num Hits[1]
# Doc ID [212] Num Hits[1]
# Doc ID [213] Num Hits[1]
# Doc ID [214] Num Hits[1]
# Doc ID [218] Num Hits[1]
# Doc ID [214] Num Hits[1]
# Doc ID [218] Num Hits[1]
# Doc ID [214] Num Hits[1]
# Doc ID [214] Num Hits[1]
# Doc ID [216] Num Hits[1]
# Doc ID [215] Num Hits[1]
# Doc ID [216] Num Hits[1]
# Doc ID [359] Num Hits[1]
# Doc ID [217] Num Hits[1]
# Doc ID [219] Num Hits[1]
# Doc ID [220] Num Hits[1]
# Doc ID [221] Num Hits[1]
# Doc ID [222] Num Hits[1]
# Doc ID [224] Num Hits[1]
# Doc ID [221] Num Hits[1]
# Doc ID [220] Num Hits[1]
# Doc ID [220] Num Hits[1]
# Doc ID [223] Num Hits[1]
# Doc ID [223] Num Hits[1]
# Doc ID [220] Num Hits[1]
# Doc ID [223] Num Hits[1]
# Doc ID [223] Num Hits[1]
# Doc ID [220] Num Hits[1]
# Doc ID [285] Num Hits[1]
# Doc ID [220] Num Hits[1]
# Doc ID [224] Num Hits[1]
# Doc ID [220] Num Hits[1]
# Doc ID [225] Num Hits[1]
# Doc ID [226] Num Hits[1]
# Doc ID [226] Num Hits[2]
# Doc ID [227] Num Hits[1]
# Doc ID [327] Num Hits[1]
# Doc ID [228] Num Hits[1]
# Doc ID [229] Num Hits[1]
# Doc ID [229] Num Hits[1]
# Doc ID [363] Num Hits[1]
# Doc ID [231] Num Hits[1]
# Doc ID [231] Num Hits[1]
# Doc ID [375] Num Hits[1]
# Doc ID [232] Num Hits[1]
# Doc ID [233] Num Hits[1]
# Doc ID [234] Num Hits[1]
# Doc ID [233] Num Hits[1]
# Doc ID [233] Num Hits[1]
# Doc ID [233] Num Hits[1]
# Doc ID [235] Num Hits[1]
# Doc ID [236] Num Hits[1]
# Doc ID [236] Num Hits[1]
# Doc ID [236] Num Hits[1]
# Doc ID [237] Num Hits[1]
# Doc ID [237] Num Hits[1]
# Doc ID [238] Num Hits[1]
# Doc ID [238] Num Hits[1]
# Doc ID [239] Num Hits[1]
# Doc ID [279] Num Hits[1]
# Doc ID [239] Num Hits[1]
# Doc ID [239] Num Hits[1]
# Doc ID [239] Num Hits[1]
# Doc ID [240] Num Hits[1]
# Doc ID [241] Num Hits[1]
# Doc ID [241] Num Hits[1]
# Doc ID [242] Num Hits[1]
# Doc ID [243] Num Hits[1]
# Doc ID [242] Num Hits[1]
# Doc ID [242] Num Hits[1]
# Doc ID [242] Num Hits[1]
# Doc ID [245] Num Hits[1]
# Doc ID [245] Num Hits[1]
# Doc ID [369] Num Hits[1]
# Doc ID [370] Num Hits[1]
# Doc ID [245] Num Hits[1]
# Doc ID [246] Num Hits[1]
# Doc ID [247] Num Hits[1]
# Doc ID [248] Num Hits[1]
# Doc ID [248] Num Hits[1]
# Doc ID [249] Num Hits[1]
# Doc ID [250] Num Hits[1]
# Doc ID [248] Num Hits[1]
# Doc ID [344] Num Hits[1]
# Doc ID [345] Num Hits[1]
# Doc ID [250] Num Hits[1]
# Doc ID [251] Num Hits[1]
# Doc ID [252] Num Hits[1]
# Doc ID [254] Num Hits[1]
# Doc ID [254] Num Hits[1]
# Doc ID [255] Num Hits[1]
# Doc ID [255] Num Hits[1]
# Doc ID [257] Num Hits[1]
# Doc ID [255] Num Hits[1]
# Doc ID [256] Num Hits[1]
# Doc ID [256] Num Hits[1]
# Doc ID [259] Num Hits[1]
# Doc ID [260] Num Hits[1]
# Doc ID [260] Num Hits[1]
# Doc ID [260] Num Hits[1]
# Doc ID [260] Num Hits[1]
# Doc ID [260] Num Hits[1]
# Doc ID [262] Num Hits[1]
# Doc ID [263] Num Hits[1]
# Doc ID [292] Num Hits[1]
# Doc ID [263] Num Hits[1]
# Doc ID [263] Num Hits[1]
# Doc ID [264] Num Hits[1]
# Doc ID [263] Num Hits[1]
# Doc ID [266] Num Hits[1]
# Doc ID [267] Num Hits[1]
# Doc ID [313] Num Hits[1]
# Doc ID [267] Num Hits[1]
# Doc ID [267] Num Hits[1]
# Doc ID [267] Num Hits[1]
# Doc ID [267] Num Hits[1]
# Doc ID [267] Num Hits[1]
# Doc ID [268] Num Hits[1]
# Doc ID [269] Num Hits[1]
# Doc ID [269] Num Hits[1]
# Doc ID [270] Num Hits[1]
# Doc ID [427] Num Hits[1]
# Doc ID [270] Num Hits[1]
# Doc ID [270] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [404] Num Hits[1]
# Doc ID [270] Num Hits[1]
# Doc ID [270] Num Hits[1]
# Doc ID [270] Num Hits[1]
# Doc ID [436] Num Hits[1]
# Doc ID [271] Num Hits[1]
# Doc ID [272] Num Hits[1]
# Doc ID [273] Num Hits[1]
# Doc ID [275] Num Hits[1]
# Doc ID [276] Num Hits[1]
# Doc ID [276] Num Hits[1]
# Doc ID [276] Num Hits[1]
# Doc ID [276] Num Hits[1]
# Doc ID [276] Num Hits[1]
# Doc ID [278] Num Hits[1]
# Doc ID [278] Num Hits[1]
# Doc ID [279] Num Hits[1]
# Doc ID [398] Num Hits[1]
# Doc ID [279] Num Hits[1]
# Doc ID [279] Num Hits[1]
# Doc ID [281] Num Hits[1]
# Doc ID [281] Num Hits[1]
# Doc ID [282] Num Hits[1]
# Doc ID [284] Num Hits[1]
# Doc ID [430] Num Hits[1]
# Doc ID [284] Num Hits[1]
# Doc ID [285] Num Hits[1]
# Doc ID [285] Num Hits[1]
# Doc ID [287] Num Hits[1]
# Doc ID [287] Num Hits[1]
# Doc ID [288] Num Hits[1]
# Doc ID [289] Num Hits[1]
# Doc ID [289] Num Hits[1]
# Doc ID [289] Num Hits[1]
# Doc ID [289] Num Hits[1]
# Doc ID [290] Num Hits[1]
# Doc ID [416] Num Hits[1]
# Doc ID [290] Num Hits[1]
# Doc ID [291] Num Hits[1]
# Doc ID [292] Num Hits[1]
# Doc ID [293] Num Hits[1]
# Doc ID [292] Num Hits[1]
# Doc ID [292] Num Hits[2]
# Doc ID [292] Num Hits[1]
# Doc ID [292] Num Hits[1]
# Doc ID [295] Num Hits[1]
# Doc ID [296] Num Hits[2]
# Doc ID [11] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [296] Num Hits[1]
# Doc ID [296] Num Hits[1]
# Doc ID [298] Num Hits[1]
# Doc ID [296] Num Hits[1]
# Doc ID [296] Num Hits[1]
# Doc ID [297] Num Hits[1]
# Doc ID [299] Num Hits[1]
# Doc ID [300] Num Hits[1]
# Doc ID [301] Num Hits[1]
# Doc ID [303] Num Hits[1]
# Doc ID [305] Num Hits[1]
# Doc ID [300] Num Hits[1]
# Doc ID [300] Num Hits[1]
# Doc ID [302] Num Hits[1]
# Doc ID [304] Num Hits[1]
# Doc ID [300] Num Hits[1]
# Doc ID [300] Num Hits[1]
# Doc ID [300] Num Hits[1]
# Doc ID [302] Num Hits[1]
# Doc ID [303] Num Hits[1]
# Doc ID [305] Num Hits[1]
# Doc ID [342] Num Hits[1]
# Doc ID [359] Num Hits[1]
# Doc ID [306] Num Hits[1]
# Doc ID [306] Num Hits[1]
# Doc ID [307] Num Hits[1]
# Doc ID [307] Num Hits[1]
# Doc ID [307] Num Hits[1]
# Doc ID [307] Num Hits[1]
# Doc ID [310] Num Hits[1]
# Doc ID [308] Num Hits[1]
# Doc ID [388] Num Hits[1]
# Doc ID [308] Num Hits[1]
# Doc ID [309] Num Hits[1]
# Doc ID [309] Num Hits[1]
# Doc ID [310] Num Hits[1]
# Doc ID [311] Num Hits[1]
# Doc ID [312] Num Hits[1]
# Doc ID [313] Num Hits[1]
# Doc ID [313] Num Hits[1]
# Doc ID [313] Num Hits[1]
# Doc ID [314] Num Hits[1]
# Doc ID [314] Num Hits[1]
# Doc ID [315] Num Hits[1]
# Doc ID [316] Num Hits[1]
# Doc ID [317] Num Hits[1]
# Doc ID [318] Num Hits[1]
# Doc ID [317] Num Hits[1]
# Doc ID [317] Num Hits[1]
# Doc ID [319] Num Hits[1]
# Doc ID [319] Num Hits[1]
# Doc ID [320] Num Hits[1]
# Doc ID [322] Num Hits[1]
# Doc ID [320] Num Hits[1]
# Doc ID [320] Num Hits[1]
# Doc ID [320] Num Hits[1]
# Doc ID [320] Num Hits[1]
# Doc ID [321] Num Hits[1]
# Doc ID [438] Num Hits[1]
# Doc ID [323] Num Hits[1]
# Doc ID [324] Num Hits[1]
# Doc ID [324] Num Hits[1]
# Doc ID [324] Num Hits[1]
# Doc ID [326] Num Hits[1]
# Doc ID [326] Num Hits[1]
# Doc ID [327] Num Hits[1]
# Doc ID [330] Num Hits[1]
# Doc ID [327] Num Hits[1]
# Doc ID [327] Num Hits[1]
# Doc ID [330] Num Hits[1]
# Doc ID [327] Num Hits[1]
# Doc ID [329] Num Hits[1]
# Doc ID [327] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [327] Num Hits[1]
# Doc ID [328] Num Hits[1]
# Doc ID [412] Num Hits[1]
# Doc ID [328] Num Hits[1]
# Doc ID [331] Num Hits[1]
# Doc ID [332] Num Hits[1]
# Doc ID [332] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [405] Num Hits[1]
# Doc ID [334] Num Hits[1]
# Doc ID [335] Num Hits[1]
# Doc ID [335] Num Hits[1]
# Doc ID [335] Num Hits[1]
# Doc ID [336] Num Hits[1]
# Doc ID [337] Num Hits[1]
# Doc ID [338] Num Hits[1]
# Doc ID [339] Num Hits[1]
# Doc ID [339] Num Hits[1]
# Doc ID [340] Num Hits[1]
# Doc ID [341] Num Hits[1]
# Doc ID [342] Num Hits[1]
# Doc ID [342] Num Hits[1]
# Doc ID [342] Num Hits[1]
# Doc ID [344] Num Hits[1]
# Doc ID [378] Num Hits[1]
# Doc ID [379] Num Hits[1]
# Doc ID [380] Num Hits[1]
# Doc ID [399] Num Hits[1]
# Doc ID [400] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [406] Num Hits[1]
# Doc ID [407] Num Hits[1]
# Doc ID [342] Num Hits[1]
# Doc ID [343] Num Hits[1]
# Doc ID [344] Num Hits[1]
# Doc ID [344] Num Hits[1]
# Doc ID [344] Num Hits[1]
# Doc ID [344] Num Hits[1]
# Doc ID [346] Num Hits[1]
# Doc ID [347] Num Hits[1]
# Doc ID [347] Num Hits[1]
# Doc ID [348] Num Hits[1]
# Doc ID [352] Num Hits[1]
# Doc ID [348] Num Hits[1]
# Doc ID [348] Num Hits[1]
# Doc ID [348] Num Hits[1]
# Doc ID [348] Num Hits[1]
# Doc ID [436] Num Hits[1]
# Doc ID [350] Num Hits[1]
# Doc ID [351] Num Hits[1]
# Doc ID [353] Num Hits[1]
# Doc ID [354] Num Hits[1]
# Doc ID [356] Num Hits[1]
# Doc ID [354] Num Hits[1]
# Doc ID [355] Num Hits[1]
# Doc ID [357] Num Hits[1]
# Doc ID [354] Num Hits[1]
# Doc ID [357] Num Hits[1]
# Doc ID [354] Num Hits[1]
# Doc ID [358] Num Hits[1]
# Doc ID [359] Num Hits[1]
# Doc ID [359] Num Hits[1]
# Doc ID [361] Num Hits[1]
# Doc ID [359] Num Hits[1]
# Doc ID [359] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [359] Num Hits[1]
# Doc ID [359] Num Hits[1]
# Doc ID [360] Num Hits[1]
# Doc ID [359] Num Hits[1]
# Doc ID [359] Num Hits[1]
# Doc ID [362] Num Hits[1]
# Doc ID [362] Num Hits[1]
# Doc ID [363] Num Hits[1]
# Doc ID [365] Num Hits[1]
# Doc ID [363] Num Hits[1]
# Doc ID [363] Num Hits[1]
# Doc ID [363] Num Hits[1]
# Doc ID [363] Num Hits[1]
# Doc ID [364] Num Hits[1]
# Doc ID [366] Num Hits[1]
# Doc ID [367] Num Hits[1]
# Doc ID [368] Num Hits[1]
# Doc ID [369] Num Hits[1]
# Doc ID [369] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [371] Num Hits[1]
# Doc ID [372] Num Hits[1]
# Doc ID [372] Num Hits[1]
# Doc ID [372] Num Hits[1]
# Doc ID [375] Num Hits[1]
# Doc ID [375] Num Hits[1]
# Doc ID [375] Num Hits[1]
# Doc ID [375] Num Hits[1]
# Doc ID [376] Num Hits[1]
# Doc ID [375] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [375] Num Hits[1]
# Doc ID [377] Num Hits[1]
# Doc ID [378] Num Hits[1]
# Doc ID [416] Num Hits[1]
# Doc ID [378] Num Hits[1]
# Doc ID [379] Num Hits[1]
# Doc ID [378] Num Hits[1]
# Doc ID [380] Num Hits[1]
# Doc ID [381] Num Hits[1]
# Doc ID [382] Num Hits[1]
# Doc ID [385] Num Hits[1]
# Doc ID [382] Num Hits[1]
# Doc ID [426] Num Hits[1]
# Doc ID [382] Num Hits[1]
# Doc ID [383] Num Hits[1]
# Doc ID [384] Num Hits[1]
# Doc ID [386] Num Hits[1]
# Doc ID [424] Num Hits[1]
# Doc ID [386] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [389] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [390] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [396] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [394] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [392] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [393] Num Hits[1]
# Doc ID [395] Num Hits[1]
# Doc ID [397] Num Hits[1]
# Doc ID [397] Num Hits[1]
# Doc ID [398] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [398] Num Hits[1]
# Doc ID [400] Num Hits[1]
# Doc ID [401] Num Hits[1]
# Doc ID [401] Num Hits[1]
# Doc ID [402] Num Hits[1]
# Doc ID [402] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [406] Num Hits[1]
# Doc ID [407] Num Hits[1]
# Doc ID [408] Num Hits[1]
# Doc ID [408] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [410] Num Hits[1]
# Doc ID [410] Num Hits[1]
# Doc ID [411] Num Hits[1]
# Doc ID [411] Num Hits[1]
# Doc ID [412] Num Hits[1]
# Doc ID [412] Num Hits[1]
# Doc ID [413] Num Hits[1]
# Doc ID [412] Num Hits[1]
# Doc ID [414] Num Hits[1]
# Doc ID [415] Num Hits[1]
# Doc ID [415] Num Hits[1]
# Doc ID [416] Num Hits[1]
# Doc ID [416] Num Hits[1]
# Doc ID [417] Num Hits[1]
# Doc ID [418] Num Hits[1]
# Doc ID [419] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [422] Num Hits[1]
# Doc ID [421] Num Hits[1]
# Doc ID [423] Num Hits[1]
# Doc ID [424] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [429] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [427] Num Hits[1]
# Doc ID [428] Num Hits[1]
# Doc ID [429] Num Hits[1]
# Doc ID [430] Num Hits[1]
# Doc ID [431] Num Hits[1]
# Doc ID [431] Num Hits[1]
# Doc ID [433] Num Hits[1]
# Doc ID [431] Num Hits[1]
# Doc ID [434] Num Hits[1]
# Doc ID [435] Num Hits[1]
# Doc ID [436] Num Hits[1]
# Doc ID [439] Num Hits[1]
# Doc ID [436] Num Hits[2]
# Doc ID [436] Num Hits[1]
# Doc ID [437] Num Hits[1]
# Doc ID [438] Num Hits[1]
# Doc ID [438] Num Hits[1]
# Doc ID [440] Num Hits[1]
# Doc ID [441] Num Hits[1]
# Doc ID [441] Num Hits[1]
# Doc ID [442] Num Hits[1]
# Doc ID [443] Num Hits[1]
# Doc ID [444] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [465] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [446] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [446] Num Hits[1]
# Doc ID [447] Num Hits[1]
# Doc ID [11] Num Hits[1]
# Doc ID [14] Num Hits[1]
# Doc ID [448] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [459] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [465] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [453] Num Hits[1]
# Doc ID [453] Num Hits[1]
# Doc ID [453] Num Hits[1]
# Doc ID [453] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [457] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [457] Num Hits[1]
# Doc ID [457] Num Hits[2]
# Doc ID [457] Num Hits[1]
# Doc ID [457] Num Hits[1]
# Doc ID [458] Num Hits[1]
# Doc ID [458] Num Hits[1]
# Doc ID [458] Num Hits[1]
# Doc ID [459] Num Hits[1]
# Doc ID [459] Num Hits[1]
# Doc ID [459] Num Hits[1]
# Doc ID [460] Num Hits[1]
# Doc ID [466] Num Hits[1]
# Doc ID [477] Num Hits[1]
# Doc ID [460] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [463] Num Hits[1]
# Doc ID [463] Num Hits[1]
# Doc ID [463] Num Hits[1]
# Doc ID [463] Num Hits[1]
# Doc ID [464] Num Hits[1]
# Doc ID [464] Num Hits[1]
# Doc ID [464] Num Hits[1]
# Doc ID [464] Num Hits[1]
# Doc ID [465] Num Hits[1]
# Doc ID [465] Num Hits[1]
# Doc ID [466] Num Hits[1]
# Doc ID [466] Num Hits[1]
# Doc ID [467] Num Hits[1]
# Doc ID [468] Num Hits[1]
# Doc ID [468] Num Hits[1]
# Doc ID [468] Num Hits[1]
# Doc ID [469] Num Hits[1]
# Doc ID [469] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [472] Num Hits[1]
# Doc ID [472] Num Hits[1]
# Doc ID [475] Num Hits[1]
# Doc ID [476] Num Hits[1]
# Doc ID [476] Num Hits[1]
# Doc ID [477] Num Hits[1]
# Doc ID [478] Num Hits[1]
# Doc ID [478] Num Hits[1]
# Doc ID [479] Num Hits[1]
# Doc ID [480] Num Hits[1]
# Doc ID [481] Num Hits[1]
# Doc ID [481] Num Hits[1]
# Doc ID [481] Num Hits[1]
# Doc ID [482] Num Hits[1]
# Doc ID [482] Num Hits[1]
# Doc ID [483] Num Hits[1]
# Doc ID [483] Num Hits[1]

# %%
def reverse_index_review():
    with open('barrels/reverse_index.bin', 'r+b') as fp:
        fp.seek(0, 0)
        for i in xrange(0, 30):
            hits_data = struct.unpack("I", fp.read(4))[0]
            print "\t",bin(hits_data)
            nhits = hits_data & 0b11111
            hits_data -= nhits
            hits_data = hits_data >> 5
            docID = hits_data
            print "NUM HITS: %d" %nhits
            print "DOC ID: %d" %docID
            fp.seek(nhits*2, 1)

reverse_index_review()
# Out:
# 	0b10
# NUM HITS: 2
# DOC ID: 0
# 	0b11100010
# NUM HITS: 2
# DOC ID: 7
# 	0b100000010
# NUM HITS: 2
# DOC ID: 8
# 	0b100100010
# NUM HITS: 2
# DOC ID: 9
# 	0b101000010
# NUM HITS: 2
# DOC ID: 10
# 	0b10
# NUM HITS: 2
# DOC ID: 0
# 	0b101100010
# NUM HITS: 2
# DOC ID: 11
# 	0b110000010
# NUM HITS: 2
# DOC ID: 12
# 	0b110100010
# NUM HITS: 2
# DOC ID: 13
# 	0b111000010
# NUM HITS: 2
# DOC ID: 14
# 	0b111100010
# NUM HITS: 2
# DOC ID: 15
# 	0b1000000010
# NUM HITS: 2
# DOC ID: 16
# 	0b1001000001
# NUM HITS: 1
# DOC ID: 18
# 	0b1001100001
# NUM HITS: 1
# DOC ID: 19
# 	0b1010000001
# NUM HITS: 1
# DOC ID: 20
# 	0b1010100001
# NUM HITS: 1
# DOC ID: 21
# 	0b1011000001
# NUM HITS: 1
# DOC ID: 22
# 	0b1011100001
# NUM HITS: 1
# DOC ID: 23
# 	0b1011100001
# NUM HITS: 1
# DOC ID: 23
# 	0b1110000001
# NUM HITS: 1
# DOC ID: 28
# 	0b1110000001
# NUM HITS: 1
# DOC ID: 28
# 	0b10000000001
# NUM HITS: 1
# DOC ID: 32
# 	0b10000000001
# NUM HITS: 1
# DOC ID: 32
# 	0b10010100001
# NUM HITS: 1
# DOC ID: 37
# 	0b10010100001
# NUM HITS: 1
# DOC ID: 37
# 	0b10100100001
# NUM HITS: 1
# DOC ID: 41
# 	0b10111000001
# NUM HITS: 1
# DOC ID: 46
# 	0b11010100001
# NUM HITS: 1
# DOC ID: 53
# 	0b11110000001
# NUM HITS: 1
# DOC ID: 60
# 	0b100001100001
# NUM HITS: 1
# DOC ID: 67

# %%
import searcher.Searcher as searcher

searcher.search('news')
# Out:
# WordID is none... Word not found....

# %%
crawler.run(1)
parser.run(1)
urlresolver.run()
sorter.sort()
# Out:
# (http://stackoverflow.com/users/login?returnurl=http%3a%2f%2fchat.stackoverflow.com%2f): log in
# (/users): users 146
# (/rooms): rooms 63
# (/faq): faq
# (?tab=all&sort=active): all
# (?tab=all&sort=created): created
# (?tab=all&sort=people): people
# (?tab=all&sort=event): event
# (?tab=all&sort=active): active
# (/rooms/6/python): Python
# (/users/1527217/khajvah): khajvah
# (/transcript/6): 1151k
# (/rooms/info/6/python): info
# (/rooms/75819/gmts): GMTs
# (/users/4564247/pierre-lafortune): Pierre Lafortune
# (/transcript/75819): 113k
# (/rooms/info/75819/gmts): info
# (/rooms/41570/so-close-vote-reviewers): SO Close Vote Reviewers
# (/users/4805174/kayess): kayess
# (/rooms/info/41570/so-close-vote-reviewers?tab=schedule):  in 6h Clear the CVQ
# (/transcript/41570): 602k
# (/rooms/info/41570/so-close-vote-reviewers): info
# (/rooms/11/php): PHP
# (/users/727208/teresko): tereko
# (/transcript/11): 2565k
# (/rooms/info/11/php): info
# (/rooms/26424/iosandroidchaosoverflow):  iOS Android ChaosOverFlow
# (/users/757214/wez): Wez
# (/transcript/26424): 1038k
# (/rooms/info/26424/iosandroidchaosoverflow): info
# (/rooms/126814/nato-headquarters): NATO Headquarters
# (/users/6817005/natobot): NATOBot
# (/transcript/126814): 43 3k
# (/rooms/info/126814/nato-headquarters): info
# (/rooms/139/javanot-android): Java NOT ANDROID
# (/users/4581014/hans1984): Hans1984
# (/transcript/139): 490k
# (/rooms/info/139/javanot-android): info
# (/rooms/10/loungec): Lounge C
# (/users/5280922/thephd): ThePhD
# (/transcript/10): 4787k
# (/rooms/info/10/loungec): info
# (/rooms/29074/html-css-webdesign): HTML CSS WebDesign
# (/users/2065702/zach-saucier): Zach Saucier
# (/transcript/29074): 781k
# (/rooms/info/29074/html-css-webdesign): info
# (/rooms/18165/wpf): WPF
# (/users/656243/lynn-crumbling): Lynn Crumbling
# (/rooms/info/18165/wpf?tab=schedule):  in 322d Happy Birthday WPF
# (/transcript/18165): 380k
# (/rooms/info/18165/wpf): info
# (/rooms/7/c): C
# (/users/1307748/scheien): scheien
# (/transcript/7): 1973k
# (/rooms/info/7/c): info
# (/rooms/116940/c-questions-and-answers): C Questions and Answers
# (/users/4636773/max-payne): Max Payne
# (/transcript/116940): 13 6k
# (/rooms/info/116940/c-questions-and-answers): info
# (/rooms/111347/sobotics): SOBotics
# (/users/6294609/queen): Queen
# (/transcript/111347): 148k
# (/rooms/info/111347/sobotics): info
# (/rooms/19132/java-and-android-era): Java and Android era
# (/users/4581014/hans1984): Hans1984
# (/transcript/19132): 601k
# (/rooms/info/19132/java-and-android-era): info
# (/rooms/81492/tamil-android-ios-developers-and-web-dev): Tamil Android IOS Developers And We
# (/users/5105555/kishore-kumar): Kishore Kumar
# (/transcript/81492): 30 3k
# (/rooms/info/81492/tamil-android-ios-developers-and-web-dev): info
# (/rooms/15/android): Android
# (/users/4763177/cpteric): CptEric
# (/transcript/15): 1303k
# (/rooms/info/15/android): info
# (/rooms/17/javascript): JavaScript
# (/users/2615209/ben-fortune): Ben Fortune
# (/transcript/17): 3703k
# (/rooms/info/17/javascript): info
# (/rooms/25312/r-public): R Public
# (/users/6817005/natobot): NATOBot
# (/transcript/25312): 33 9k
# (/rooms/info/25312/r-public): info
# (/rooms/90230/socvr-request-graveyard): SOCVR Request Graveyard
# (/users/4342498/nathanoliver): NathanOliver
# (/transcript/90230): 39 7k
# (/rooms/info/90230/socvr-request-graveyard): info
# (/rooms/69317/css-svg-shapes-and-designs): CSS SVG Shapes and Designs
# (/users/3373905/leo-the-lion): Leo the lion
# (/transcript/69317): 84 1k
# (/rooms/info/69317/css-svg-shapes-and-designs): info
# (?tab=all&sort=active&nohide=true): show frozen rooms
# (/faq): faq
# (http://stackexchange.com/legal): legal
# (http://stackexchange.com/legal/privacy-policy): privacy policy
# (#): mobile
# q
# q
# q
# q
# q
# url:  //stackoverflow.com
# url:  http://chat.stackoverflow.com
# putting chat for docID 1 in forward index
# �r
# LEN HITS: 1
# url:  https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent&amp;utm_source=stackoverflow.com&amp;utm_medium=dev-story&amp;utm_campaign=signup-redirect
# putting Sign up for docID 2 in forward index
# �r
# ��
# LEN HITS: 2
# url:  https://stackoverflow.com/users/login?ssrc=site_switcher&returnurl=http%3a%2f%2fstackoverflow.com%2f
# putting log in for docID 3 in forward index
# �r
# �r
# LEN HITS: 2
# url:  //stackexchange.com/sites
# url:  http://stackoverflow.blog
# putting company blog for docID 4 in forward index
# �r
# �r
# LEN HITS: 2
# url:  https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent&utm_source=stackoverflow.com&utm_medium=dev-story&utm_campaign=signup-redirect
# putting sign up for docID 5 in forward index
# �r
# �r
# LEN HITS: 2
# url:  https://stackoverflow.com/users/login?ssrc=head&returnurl=http%3a%2f%2fstackoverflow.com%2f
# putting log in for docID 6 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/tour
# putting tour for docID 7 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/
# putting  help  for docID 0 in forward index
# @�B�
# Ar
# LEN HITS: 2
# url:  http://stackoverflow.com/tour
# putting  Tour  for docID 7 in forward index
# ����
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/help
# putting  Help Center  for docID 8 in forward index
# P�S�
# Q�
# R�
# LEN HITS: 3
# url:  //meta.stackoverflow.com
# url:  http://stackoverflow.com/company/about
# putting  About Us  for docID 9 in forward index
# ����
# ��
# ��
# LEN HITS: 3
# url:  http://business.stackoverflow.com/?ref=topbar_help
# putting  Business  for docID 10 in forward index
# ���
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/
# putting  Stack Overflow  for docID 0 in forward index
# @�C�
# B�
# A�
# LEN HITS: 3
# url:  http://stackoverflow.com/questions
# putting  Questions  for docID 11 in forward index
# 0�2�
# 1�
# LEN HITS: 2
# url:  http://stackoverflow.com/jobs?med=site-ui&ref=jobs-tab
# putting  Jobs  for docID 12 in forward index
# p�r�
# q�
# LEN HITS: 2
# url:  http://stackoverflow.com/documentation
# putting  Documentation  for docID 13 in forward index
# ��
# �
# LEN HITS: 2
# url:  http://stackoverflow.com/tags
# putting  Tags  for docID 14 in forward index
# ���
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/users
# putting  Users  for docID 15 in forward index
# ����
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/help/badges
# putting  Badges  for docID 16 in forward index
# ��
# �
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/ask
# putting Ask Question for docID 17 in forward index
# ��
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/users/story/join
# putting Check out Developer Story  for docID 18 in forward index
# D�
# C�
# B�
# @�
# Ar
# LEN HITS: 5
# url:  http://stackoverflow.com/?tab=interesting
# putting  interesting for docID 19 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/?tab=hot
# putting  hot for docID 20 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/?tab=week
# putting  week for docID 21 in forward index
# @�
# Ar
# LEN HITS: 2
# url:  http://stackoverflow.com/?tab=month
# putting  month for docID 22 in forward index
#  �
# !r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867963/how-to-print-sorted-data-on-json-load
# putting How to print sorted data on json load  for docID 23 in forward index
# �r
# �r
# ��
# �r
# ��
# �r
# �r
# �r
# �r
# LEN HITS: 9
# url:  http://stackoverflow.com/questions/tagged/python
# putting python for docID 24 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/json
# putting json for docID 25 in forward index
# `r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/sorting
# putting sorting for docID 26 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867963/how-to-print-sorted-data-on-json-load
# putting asked  for docID 23 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/7009113/tonemgub
# putting tonemgub for docID 27 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867959/how-to-install-a-program-from-github-only-using-terminal-linux
# putting How to install a program from github only using terminal linux  for docID 28 in forward index
# r
# �
# r
# r
# r
# 	r
# �
# r
# r
# r
#
# r
# r
# LEN HITS: 12
# url:  http://stackoverflow.com/questions/tagged/selenium
# putting selenium for docID 29 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/firefox
# putting firefox for docID 30 in forward index
# 0r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/geckodriver
# putting geckodriver for docID 31 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867959/how-to-install-a-program-from-github-only-using-terminal-linux
# putting asked  for docID 28 in forward index
# �
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867956/readthedocs-is-there-a-way-to-autodoc-same-model-functions-separately-in-the-on
# putting Readthedocs Is there a way to autodoc same model functions separately in the one file  for docID 32 in forward index
# r
# �
# 	r
# �
# r
# �
# r
# r
# r
#
# r
# r
# r
# r
# r
# r
# r
# LEN HITS: 16
# url:  http://stackoverflow.com/questions/tagged/python
# putting python for docID 24 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/sphinx
# putting sphinx for docID 33 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/restructuredtext
# putting restructuredtext for docID 34 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/read-the-docs
# putting read the docs for docID 35 in forward index
# 0r
# 2r
# 1r
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/40867956/readthedocs-is-there-a-way-to-autodoc-same-model-functions-separately-in-the-on
# putting asked  for docID 32 in forward index
# �
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/2677101/joab-mendes
# putting Joab Mendes for docID 36 in forward index
# p�
# q�
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867955/do-i-need-to-call-require-method-each-time-i-create-new-combobox
# putting Do I need to call require method each time I create new combobox  for docID 37 in forward index
# �
# �
# �	�
# r
# r
# r
# r
# r
# r
# r
# r
#
# r
# r
# LEN HITS: 13
# url:  http://stackoverflow.com/questions/tagged/combobox
# putting combobox for docID 38 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/dojo
# putting dojo for docID 39 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867955/do-i-need-to-call-require-method-each-time-i-create-new-combobox
# putting asked  for docID 37 in forward index
# �
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/7119647/eniss
# putting Eniss for docID 40 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867954/prestashop-multistore-local-store-prices-are-overwritten-with-price-from-defau
# putting Prestashop Multistore local store prices are overwritten with price from default shop for docID 41 in forward index
# ��
# �r
# �r
# �r
# �r
# �r
# �r
# ��
# �r
# �r
# �r
# �r
# LEN HITS: 12
# url:  http://stackoverflow.com/questions/tagged/prestashop
# putting prestashop for docID 42 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/prestashop-1.6
# putting prestashop 1 6 for docID 43 in forward index
# a�
# `r
# b�
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/tagged/multistore
# putting multistore for docID 44 in forward index
# 0r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867954/prestashop-multistore-local-store-prices-are-overwritten-with-price-from-defau
# putting asked  for docID 41 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/3656266/larsd
# putting larsd for docID 45 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867951/custom-tableviewcell
# putting Custom tableViewCell for docID 46 in forward index
# Q�
# P�
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/ios
# putting ios for docID 47 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/arrays
# putting arrays for docID 48 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/uitableview
# putting uitableview for docID 49 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/swift3
# putting swift3 for docID 50 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/cell
# putting cell for docID 51 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867951/custom-tableviewcell
# putting asked  for docID 46 in forward index
# Q�
# Pr
# LEN HITS: 2
# url:  http://stackoverflow.com/users/7135257/fatemeh
# putting fatemeh for docID 52 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40864945/rails-is-confusing-params-after-adding-locale-to-the-url
# putting Rails is confusing params after adding locale to the url for docID 53 in forward index
# er
# fr
# ar
# dr
# `�
# gr
# cr
# ir
# hr
# br
# LEN HITS: 10
# url:  http://stackoverflow.com/questions/tagged/ruby-on-rails-4
# putting ruby on rails 4 for docID 54 in forward index
# �r
# �r
# ��
# �r
# LEN HITS: 4
# url:  http://stackoverflow.com/questions/tagged/parameters
# putting parameters for docID 55 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/routes
# putting routes for docID 56 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/internationalization
# putting internationalization for docID 57 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/locale
# putting locale for docID 58 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40864945/rails-is-confusing-params-after-adding-locale-to-the-url
# putting modified  for docID 53 in forward index
# a�
# `r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/3665315/syk
# putting Syk for docID 59 in forward index
# �
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867947/unauthorized-response-from-rest-call-to-crm-using-adal-js
# putting Unauthorized response from Rest call to CRM using adal js for docID 60 in forward index
# �r
# ��
# ��
# �r
# �r
# �r
# �r
# �r
# �r
# ��
# LEN HITS: 10
# url:  http://stackoverflow.com/questions/tagged/javascript
# putting javascript for docID 61 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/dynamics-crm
# putting dynamics crm for docID 62 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/single-page-application
# putting single page application for docID 63 in forward index
# br
# `r
# ar
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/tagged/adal
# putting adal for docID 64 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/adal.js
# putting adal js for docID 65 in forward index
# @r
# Ar
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867947/unauthorized-response-from-rest-call-to-crm-using-adal-js
# putting asked  for docID 60 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/7225815/dom
# putting Dom for docID 66 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867946/how-to-find-mt2002-offending-dll
# putting How to find MT2002 Offending DLL  for docID 67 in forward index
# F�
# Ar
# D�
# Br
# @�
# E�
# C�
# LEN HITS: 7
# url:  http://stackoverflow.com/questions/tagged/c%23
# putting c  for docID 68 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/xamarin
# putting xamarin for docID 69 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/xamarin.ios
# putting xamarin ios for docID 70 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/vsts-build
# putting vsts build for docID 71 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867946/how-to-find-mt2002-offending-dll
# putting asked  for docID 67 in forward index
# A�
# @r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/4539/noah
# putting Noah for docID 72 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867944/how-to-find-the-size-of-a-document-in-icloud-before-picking-it-and-downloading-t
# putting how to find the size of a document in iCloud before picking it and downloading to device using UIDocumentPickerViewController for docID 73 in forward index
# �r
# �r
# �r
# �r�r
# �r
# �r
# �r
# �r
# �r
# ��
# �r
# �r
# �r
# �r
# �r
# �r
# ��
# �r
# LEN HITS: 18
# url:  http://stackoverflow.com/questions/tagged/ios
# putting ios for docID 47 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/icloud
# putting icloud for docID 74 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/uidocumentpickervc
# putting uidocumentpickervc for docID 75 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867944/how-to-find-the-size-of-a-document-in-icloud-before-picking-it-and-downloading-t
# putting asked  for docID 73 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/499174/sujith1406
# putting sujith1406 for docID 76 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867879/excel-len-search-and-find-double-space-bug
# putting Excel LEN SEARCH and FIND Double Space Bug  for docID 77 in forward index
# �r
# ��
# ��
# ��
# ��
# ��
# ��
# ��
# ��
# LEN HITS: 9
# url:  http://stackoverflow.com/questions/tagged/excel
# putting excel for docID 78 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/excel-2010
# putting excel 2010 for docID 79 in forward index
# �r
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867879/excel-len-search-and-find-double-space-bug
# putting modified  for docID 77 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/6613600/nullarbor
# putting Nullarbor for docID 80 in forward index
# p�
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867943/what-is-the-recommended-approach-to-have-less-contrived-code-in-the-function-of
# putting What is the recommended approach to have less contrived code in the function of my component that reacts on data changed from the store  for docID 81 in forward index
# ��
# �r
# �r
# �r
# �r
# �r
# ��
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r�r�r
# �r
# LEN HITS: 23
# url:  http://stackoverflow.com/questions/tagged/reactjs
# putting reactjs for docID 82 in forward index
#  r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/flux
# putting flux for docID 83 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/reactjs-flux
# putting reactjs flux for docID 84 in forward index
# Qr
# Pr
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867943/what-is-the-recommended-approach-to-have-less-contrived-code-in-the-function-of
# putting asked  for docID 81 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/215553/ibiza
# putting ibiza for docID 85 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867942/unity-does-not-inject-dependency-after-configuring-oauth
# putting Unity does not inject dependency after configuring OAuth  for docID 86 in forward index
# ��
# �r
# �r
# ��
# �r
# ��
# �r
# �r
# �r
# LEN HITS: 9
# url:  http://stackoverflow.com/questions/tagged/c%23
# putting c  for docID 68 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/oauth
# putting oauth for docID 87 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/dependency-injection
# putting dependency injection for docID 88 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/asp.net-web-api2
# putting asp net web api2 for docID 89 in forward index
# �r
# �r
# �r
# �r
# LEN HITS: 4
# url:  http://stackoverflow.com/questions/tagged/unity-container
# putting unity container for docID 90 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867942/unity-does-not-inject-dependency-after-configuring-oauth
# putting asked  for docID 86 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/1505521/user1505521
# putting user1505521 for docID 91 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867941/devise-subdomains-from-www-appname-com-admin-login-to-admin-appname-com-login
# putting Devise subdomains from www appname com admin login to admin appname com login for docID 92 in forward index
# Sr
# Rr
# Xr
# TrZr
# P�
# Qr
# VrYr
# Wr\r
# Ur[r
# LEN HITS: 9
# url:  http://stackoverflow.com/questions/tagged/ruby-on-rails
# putting ruby on rails for docID 93 in forward index
# �r
# �r
# �r
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/tagged/devise
# putting devise for docID 94 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/routes
# putting routes for docID 56 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867941/devise-subdomains-from-www-appname-com-admin-login-to-admin-appname-com-login
# putting asked  for docID 92 in forward index
# Q�
# Pr
# LEN HITS: 2
# url:  http://stackoverflow.com/users/1301037/user1301037
# putting user1301037 for docID 95 in forward index
#  r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867723/swift-3-0-bool-to-int-issue
# putting Swift 3 0 Bool to Int issue for docID 96 in forward index
# �r
# ��
# �r
# ��
# ��
# ��
# ��
# LEN HITS: 7
# url:  http://stackoverflow.com/questions/tagged/ios
# putting ios for docID 47 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/swift
# putting swift for docID 97 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/swift3
# putting swift3 for docID 50 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867723/swift-3-0-bool-to-int-issue/?lastactivity
# putting answered  for docID 98 in forward index
# �
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/3514372/artem-novichkov
# putting Artem Novichkov for docID 99 in forward index
# �
# �
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867937/regex-looping-through-a-foreach-to-find-a-certain-pattern
# putting Regex looping through a foreach to find a certain pattern for docID 100 in forward index
# ��
# �r�r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# LEN HITS: 9
# url:  http://stackoverflow.com/questions/tagged/c%23
# putting c  for docID 68 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/xml
# putting xml for docID 101 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867937/regex-looping-through-a-foreach-to-find-a-certain-pattern
# putting asked  for docID 100 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/5993382/craig-gallagher
# putting Craig Gallagher for docID 102 in forward index
# 0�
# 1�
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867934/split-delimited-string-and-store-values-in-json-object-using-dataweave
# putting Split delimited string and store values in JSON object using dataweave for docID 103 in forward index
# �r
# �r
# �r
# �r
# �r
# ��
# �r
# ��
# �r
# �r
# �r
# LEN HITS: 11
# url:  http://stackoverflow.com/questions/tagged/json
# putting json for docID 25 in forward index
# `r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/mule
# putting mule for docID 104 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/datamapper
# putting datamapper for docID 105 in forward index
# `r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/anypoint-studio
# putting anypoint studio for docID 106 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/dataweave
# putting dataweave for docID 107 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867934/split-delimited-string-and-store-values-in-json-object-using-dataweave
# putting asked  for docID 103 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/3165854/user3165854
# putting user3165854 for docID 108 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867862/mvc-display-text-after-post-and-keep-data-in-form
# putting mvc display text after post and keep data in form for docID 109 in forward index
# %r
# )r
# "r
# #r
# &r
#  r
# (r
# $r
# 'r
# !r
# LEN HITS: 10
# url:  http://stackoverflow.com/questions/tagged/asp.net-mvc
# putting asp net mvc for docID 110 in forward index
# 1r
# 0r
# 2r
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/tagged/asp.net-mvc-partialview
# putting asp net mvc partialview for docID 111 in forward index
# r
# r
# r
# r
# LEN HITS: 4
# url:  http://stackoverflow.com/questions/40867862/mvc-display-text-after-post-and-keep-data-in-form
# putting modified  for docID 109 in forward index
# !�
#  r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/4141606/antoinedelia
# putting antoinedelia for docID 112 in forward index
# `r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/25300557/toast-notifications-in-asp-net-mvc-4
# putting Toast notifications in ASP NET MVC 4 for docID 113 in forward index
# ��
# ��
# �r
# ��
# ��
# �r
# ��
# LEN HITS: 7
# url:  http://stackoverflow.com/questions/tagged/javascript
# putting javascript for docID 61 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/jquery
# putting jquery for docID 114 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/asp.net-mvc-4
# putting asp net mvc 4 for docID 115 in forward index
# �r
# �r
# ��
# �r
# LEN HITS: 4
# url:  http://stackoverflow.com/questions/tagged/toastr
# putting toastr for docID 116 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/25300557/toast-notifications-in-asp-net-mvc-4/?lastactivity
# putting answered  for docID 117 in forward index
# �
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/4219451/fatih-b%c3%9clb%c3%9cl
# putting Fatih B LB L for docID 118 in forward index
# 1�
# 2�
# 3�
# 0�
# LEN HITS: 4
# url:  http://stackoverflow.com/questions/40867928/how-to-set-oracle-apex-application-language-as-bi-publisher-report-language
# putting How to set Oracle APEX application language as BI publisher report language for docID 119 in forward index
# �r
# �r
# �r
# �r
# �r�r
# �r
# ��
# ��
# ��
# �r
# ��
# LEN HITS: 11
# url:  http://stackoverflow.com/questions/tagged/oracle-apex
# putting oracle apex for docID 120 in forward index
# `r
# ar
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/oracle-bi
# putting oracle bi for docID 121 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867928/how-to-set-oracle-apex-application-language-as-bi-publisher-report-language
# putting asked  for docID 119 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/4091311/amol
# putting Amol for docID 122 in forward index
# @�
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40864219/ssms-2008-sql-how-to-extract-specific-string-of-text
# putting SSMS 2008 SQL how to extract specific string of text for docID 123 in forward index
# 'r
# $r
# (r
#  �
# &r
# #r
# )r
# "�
# !�
# %r
# LEN HITS: 10
# url:  http://stackoverflow.com/questions/tagged/sql
# putting sql for docID 124 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/ssms
# putting ssms for docID 125 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40864219/ssms-2008-sql-how-to-extract-specific-string-of-text/?lastactivity
# putting modified  for docID 126 in forward index
# q�
# pr
# LEN HITS: 2
# url:  http://stackoverflow.com/users/5085719/rdkells
# putting RDKells for docID 127 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40862955/having-dns-probe-finished-domainnx-regularly-on-a-domain
# putting Having dns probe finished domainnx regularly on a domain for docID 128 in forward index
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# ��
# LEN HITS: 9
# url:  http://stackoverflow.com/questions/tagged/heroku
# putting heroku for docID 129 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/dns
# putting dns for docID 130 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/ovh
# putting ovh for docID 131 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40862955/having-dns-probe-finished-domainnx-regularly-on-a-domain
# putting modified  for docID 128 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/1717031/mathrobin
# putting MathRobin for docID 132 in forward index
# P�
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/596481/simulate-javascript-key-events
# putting Simulate JavaScript Key Events for docID 133 in forward index
# Q�
# R�
# P�
# S�
# LEN HITS: 4
# url:  http://stackoverflow.com/questions/tagged/javascript
# putting javascript for docID 61 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/javascript-events
# putting javascript events for docID 134 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/596481/simulate-javascript-key-events/?lastactivity
# putting modified  for docID 135 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/6290027/monami
# putting monami for docID 136 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867921/when-i-use-jekyll-template-if-page-title-category-first-get-fal
# putting when i use jekyll template if page title category first get false for docID 137 in forward index
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# LEN HITS: 12
# url:  http://stackoverflow.com/questions/tagged/templates
# putting templates for docID 138 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/jekyll
# putting jekyll for docID 139 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/liquid
# putting liquid for docID 140 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867921/when-i-use-jekyll-template-if-page-title-category-first-get-fal
# putting asked  for docID 137 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/4910220/silence
# putting silence for docID 141 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867918/select-upload-history-from-oracle-table
# putting Select upload history from Oracle table for docID 142 in forward index
# Sr
# Qr
# T�
# Ur
# P�
# Rr
# LEN HITS: 6
# url:  http://stackoverflow.com/questions/tagged/oracle
# putting oracle for docID 143 in forward index
#  r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/plsql
# putting plsql for docID 144 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/dense-rank
# putting dense rank for docID 145 in forward index
# Pr
# Qr
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/partition-by
# putting partition by for docID 146 in forward index
#  r
# !r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867918/select-upload-history-from-oracle-table
# putting asked  for docID 142 in forward index
# Q�
# Pr
# LEN HITS: 2
# url:  http://stackoverflow.com/users/549903/robin-clave
# putting Robin clave for docID 147 in forward index
# �r
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867917/how-to-sign-old-ios-version
# putting How to sign old iOS version for docID 148 in forward index
# r
# r
# �
# r
# �
# r
# LEN HITS: 6
# url:  http://stackoverflow.com/questions/tagged/ios
# putting ios for docID 47 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/iphone
# putting iphone for docID 149 in forward index
#  r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/testing
# putting testing for docID 150 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/ios-ipsw-file
# putting ios ipsw file for docID 151 in forward index
# �r
# �r
# �r
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/40867917/how-to-sign-old-ios-version
# putting asked  for docID 148 in forward index
# �
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/382788/mm24
# putting mm24 for docID 152 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867783/how-to-set-a-different-image-for-each-pin-xamarin-ios
# putting How to set a different image for each pin Xamarin iOS for docID 153 in forward index
# 3r
# 9�
# 4r
# 2r
# 8r
# 6r
# 1r
# 5r
# :�
# 0�
# 7r
# LEN HITS: 11
# url:  http://stackoverflow.com/questions/tagged/ios
# putting ios for docID 47 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/xamarin
# putting xamarin for docID 69 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/xamarin.ios
# putting xamarin ios for docID 70 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867783/how-to-set-a-different-image-for-each-pin-xamarin-ios
# putting modified  for docID 153 in forward index
# 1�
# 0r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/6484526/don
# putting Don for docID 154 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867914/salesforce-report-exports-as-html-workaround
# putting Salesforce report exports as html workaround for docID 155 in forward index
# rr
# p�
# ur
# sr
# tr
# qr
# LEN HITS: 6
# url:  http://stackoverflow.com/questions/tagged/salesforce
# putting salesforce for docID 156 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/html-xml-utils
# putting html xml utils for docID 157 in forward index
# �r
# �r
# �r
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/40867914/salesforce-report-exports-as-html-workaround
# putting asked  for docID 155 in forward index
# q�
# pr
# LEN HITS: 2
# url:  http://stackoverflow.com/users/7178871/adam-mcdermott
# putting Adam McDermott for docID 158 in forward index
# 1�
# 0�
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867645/undefined-reference-to-symbol-sem-closeglibc-2-2-5
# putting undefined reference to symbol sem close GLIBC 2 2 5  for docID 159 in forward index
# ��
# �r
# �r
# �r
# �r
# ���
# ��
# �r
# �r
# ��
# LEN HITS: 10
# url:  http://stackoverflow.com/questions/tagged/c%2b%2b
# putting c  for docID 160 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/linux
# putting linux for docID 161 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/cmake
# putting cmake for docID 162 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/activemq
# putting activemq for docID 163 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/activemq-cpp
# putting activemq cpp for docID 164 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867645/undefined-reference-to-symbol-sem-closeglibc-2-2-5/?lastactivity
# putting answered  for docID 165 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/6533075/sch%c3%bctze
# putting Sch tze for docID 166 in forward index
# r
# �
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/37471440/js-surroundcontents-only-retains-highlight-on-text-about-20-of-the-highlight
# putting JS surroundContents only retains highlight on text about 20 of the highlight attempts for docID 167 in forward index
# �r
# �r
# ��
# ��
# �r
# �r
# �r
# ��
# �r
# �r
# �r�r
# �r
# LEN HITS: 12
# url:  http://stackoverflow.com/questions/tagged/javascript
# putting javascript for docID 61 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/highlighting
# putting highlighting for docID 168 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/37471440/js-surroundcontents-only-retains-highlight-on-text-about-20-of-the-highlight/?lastactivity
# putting answered  for docID 169 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/1544886/k-scandrett
# putting K Scandrett for docID 170 in forward index
# p�
# q�
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867515/excel-connect-to-mssql-returns-login-failed-for-user
# putting Excel connect to MSSQL returns Login failed for user for docID 171 in forward index
# �r
# �r
# ��
# �r
# �r
# �r
# ��
# ��
# �r
# LEN HITS: 9
# url:  http://stackoverflow.com/questions/tagged/sql-server
# putting sql server for docID 172 in forward index
# Qr
# Pr
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/excel
# putting excel for docID 78 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/connection
# putting connection for docID 173 in forward index
# Pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867515/excel-connect-to-mssql-returns-login-failed-for-user
# putting modified  for docID 171 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/121260/eric-darchis
# putting Eric Darchis for docID 174 in forward index
# ��
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867902/including-geofire-calls-in-a-firebase-transaction
# putting Including GeoFire calls in a Firebase transaction for docID 175 in forward index
# $r
# &r
# "r
# !�
# %�
#  �
# #r
# LEN HITS: 7
# url:  http://stackoverflow.com/questions/tagged/firebase-database
# putting firebase database for docID 176 in forward index
# 0r
# 1r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/geofire
# putting geofire for docID 177 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867902/including-geofire-calls-in-a-firebase-transaction
# putting asked  for docID 175 in forward index
# !�
#  r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/682778/crocodile
# putting Crocodile for docID 178 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867900/perl-extract-substring-to-a-character-with-count-zero-or-more
# putting perl extract substring to a character with count zero or more for docID 179 in forward index
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# LEN HITS: 11
# url:  http://stackoverflow.com/questions/tagged/regex
# putting regex for docID 180 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/string
# putting string for docID 181 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/perl
# putting perl for docID 182 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867900/perl-extract-substring-to-a-character-with-count-zero-or-more
# putting asked  for docID 179 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/278910/ontherocks
# putting ontherocks for docID 183 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867897/how-do-i-ask-for-the-input-of-a-variable-when-needed-instead-of-typing-input-b
# putting How do I ask for the input of a variable when needed instead of typing input before every line  for docID 184 in forward index
# �r
# �r
# �r
# �r
# �r
# ��
# �r�r
# �r
# �r
# ��
# �r
# �r
# �r
# �r�r
# �r
# ��
# �r
# �r
# LEN HITS: 18
# url:  http://stackoverflow.com/questions/tagged/python-3.x
# putting python 3 x for docID 185 in forward index
# `r
# br
# a�
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/40867897/how-do-i-ask-for-the-input-of-a-variable-when-needed-instead-of-typing-input-b
# putting asked  for docID 184 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/7164679/dave-matthew
# putting Dave Matthew for docID 186 in forward index
# ��
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867894/using-javascript-to-loop-through-nodes-of-an-xml-feed
# putting Using javascript to loop through Nodes of an XML Feed for docID 187 in forward index
# ��
# ��
# �r
# �r
# �r
# �r
# �r
# ��
# ��
# �r
# LEN HITS: 10
# url:  http://stackoverflow.com/questions/tagged/javascript
# putting javascript for docID 61 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/xml
# putting xml for docID 101 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/xml-parsing
# putting xml parsing for docID 188 in forward index
# r
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867894/using-javascript-to-loop-through-nodes-of-an-xml-feed
# putting asked  for docID 187 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/1555453/tim-cadieux
# putting Tim Cadieux for docID 189 in forward index
# ��
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867893/creating-a-custom-video-similar-to-facebook-birthday-videos-programmatically
# putting Creating a custom video similar to Facebook birthday videos programmatically for docID 190 in forward index
# qr
# p�
# xr
# yr
# rr
# ur
# wr
# sr
# v�
# tr
# LEN HITS: 10
# url:  http://stackoverflow.com/questions/tagged/javascript
# putting javascript for docID 61 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/java
# putting java for docID 191 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/video
# putting video for docID 192 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/webpage
# putting webpage for docID 193 in forward index
# `r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867893/creating-a-custom-video-similar-to-facebook-birthday-videos-programmatically
# putting asked  for docID 190 in forward index
# q�
# pr
# LEN HITS: 2
# url:  http://stackoverflow.com/users/5621098/robin-abishek
# putting robin abishek for docID 194 in forward index
# Qr
# Pr
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867892/different-menu-level-with-same-viewcontroller
# putting different menu level with same viewcontroller for docID 195 in forward index
# �r
# �r
# �r
# �r
# �r
# �r
# LEN HITS: 6
# url:  http://stackoverflow.com/questions/tagged/ios
# putting ios for docID 47 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/swift
# putting swift for docID 97 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867892/different-menu-level-with-same-viewcontroller
# putting asked  for docID 195 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/6267839/chris
# putting Chris for docID 196 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867889/sapui5-multiple-vizframes-in-view
# putting SAPUI5 multiple VizFrames in View for docID 197 in forward index
# ��
# ��
# ��
# �r
# �r
# LEN HITS: 5
# url:  http://stackoverflow.com/questions/tagged/javascript
# putting javascript for docID 61 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/sapui5
# putting sapui5 for docID 198 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/openui5
# putting openui5 for docID 199 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867889/sapui5-multiple-vizframes-in-view
# putting asked  for docID 197 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/1191056/alexander-fuchs
# putting Alexander Fuchs for docID 200 in forward index
# A�
# @�
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867885/jsonschema2pojo-make-private-classes-from-definitions
# putting jsonschema2pojo make private classes from definitions for docID 201 in forward index
# �r
# �r
# �r
# �r
# �r
# �r
# LEN HITS: 6
# url:  http://stackoverflow.com/questions/tagged/java
# putting java for docID 191 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/jsonschema
# putting jsonschema for docID 202 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/jsonschema2pojo
# putting jsonschema2pojo for docID 203 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867885/jsonschema2pojo-make-private-classes-from-definitions
# putting asked  for docID 201 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/3392595/forepick
# putting Forepick for docID 204 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40865592/lapply-function-in-r
# putting lapply function in R for docID 205 in forward index
# qr
# s�
# pr
# rr
# LEN HITS: 4
# url:  http://stackoverflow.com/questions/tagged/r
# putting r for docID 206 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/for-loop
# putting for loop for docID 207 in forward index
# r
# r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/lapply
# putting lapply for docID 208 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40865592/lapply-function-in-r
# putting modified  for docID 205 in forward index
# q�
# pr
# LEN HITS: 2
# url:  http://stackoverflow.com/users/6019081/neha-sharma
# putting Neha Sharma for docID 209 in forward index
# ��
# ��
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867878/loading-routers-paths-from-external-files
# putting Loading router s paths from external files for docID 210 in forward index
# �r
# �r
# ��
# �r
# �r
# �r
# �r
# LEN HITS: 7
# url:  http://stackoverflow.com/questions/tagged/angular2
# putting angular2 for docID 211 in forward index
# pr
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/angular2-routing
# putting angular2 routing for docID 212 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867878/loading-routers-paths-from-external-files
# putting asked  for docID 210 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/2203299/tom
# putting Tom for docID 213 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867875/account-kit-with-ionic-v-1-3
# putting Account kit with ionic v 1 3 for docID 214 in forward index
# ��
# �r
# ��
# ��
# �r
# �r
# �r
# LEN HITS: 7
# url:  http://stackoverflow.com/questions/tagged/angularjs
# putting angularjs for docID 215 in forward index
#  r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/ionic-framework
# putting ionic framework for docID 216 in forward index
# 1r
# 0r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/angularfire
# putting angularfire for docID 217 in forward index
# r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/account-kit
# putting account kit for docID 218 in forward index
# �r
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867875/account-kit-with-ionic-v-1-3
# putting asked  for docID 214 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/6260343/thelastone
# putting thelastone for docID 219 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867874/how-can-i-obtain-a-domain-driven-design-architecture-using-spring-data-jpa
# putting How can I obtain a DOMAIN DRIVEN DESIGN architecture using Spring Data JPA  for docID 220 in forward index
# �r
# ��
# ��
# ��
# ��
# �r
# ��
# ��
# ��
# �r
# ��
# �r
# ��
# �r
# LEN HITS: 14
# url:  http://stackoverflow.com/questions/tagged/java
# putting java for docID 191 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/spring
# putting spring for docID 221 in forward index
# @r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/spring-data
# putting spring data for docID 222 in forward index
# Pr
# Qr
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/tagged/domain-driven-design
# putting domain driven design for docID 223 in forward index
# r
# r
# r
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/tagged/spring-data-jpa
# putting spring data jpa for docID 224 in forward index
# Br
# @r
# Ar
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/40867874/how-can-i-obtain-a-domain-driven-design-architecture-using-spring-data-jpa
# putting asked  for docID 220 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/1833945/andreanobili
# putting AndreaNobili for docID 225 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867873/how-to-prompt-byte-input-and-search-a-file-for-that-byte
# putting How to prompt byte input and search a file for that byte  for docID 226 in forward index
# �r
# �r
# �r
# �r
# �r
# �r
# �r
# ��
# �r
# �r
# �r�r
# ��
# LEN HITS: 12
# url:  http://stackoverflow.com/questions/tagged/python-3.x
# putting python 3 x for docID 185 in forward index
# `r
# br
# a�
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/tagged/byte
# putting byte for docID 227 in forward index
#  r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867873/how-to-prompt-byte-input-and-search-a-file-for-that-byte
# putting asked  for docID 226 in forward index
# ��
# �r
# LEN HITS: 2
# url:  http://stackoverflow.com/users/7223182/df86
# putting df86 for docID 228 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867872/variable-holds-two-values
# putting Variable holds two values  for docID 229 in forward index
# P�
# T�
# Qr
# Sr
# Rr
# LEN HITS: 5
# url:  http://stackoverflow.com/questions/tagged/function
# putting function for docID 230 in forward index
# �r
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/tagged/python-3.x
# putting python 3 x for docID 185 in forward index
# `r
# br
# a�
# LEN HITS: 3
# url:  http://stackoverflow.com/questions/tagged/global-variables
# putting global variables for docID 231 in forward index
# !r
#  r
# LEN HITS: 2
# url:  http://stackoverflow.com/questions/40867872/variable-holds-two-values
# putting asked  for docID 229 in forward index
# Q�
# Pr
# LEN HITS: 2
# url:  http://stackoverflow.com/users/6570334/unknownzdx
# putting Unknownzdx for docID 232 in forward index
# ��
# LEN HITS: 1
# url:  http://stackoverflow.com/questions/40867867/how-search-filter-in-pingfederate-pcv-works
# putting How search filter in pingfederate PCV works for docID 233 in forward index
# r
# r
# �
# r
# �
# r
# r
# LEN HITS: 7
# url:  http://stackoverflow.com/questions/tagged/pingfederate
# ...
# Doc ID [425] Num Hits[1]
# Doc ID [375] Num Hits[1]
# Doc ID [375] Num Hits[1]
# Doc ID [377] Num Hits[1]
# Doc ID [377] Num Hits[1]
# Doc ID [378] Num Hits[1]
# Doc ID [416] Num Hits[1]
# Doc ID [378] Num Hits[1]
# Doc ID [416] Num Hits[1]
# Doc ID [378] Num Hits[1]
# Doc ID [379] Num Hits[1]
# Doc ID [378] Num Hits[1]
# Doc ID [379] Num Hits[1]
# Doc ID [378] Num Hits[1]
# Doc ID [380] Num Hits[1]
# Doc ID [378] Num Hits[1]
# Doc ID [380] Num Hits[1]
# Doc ID [381] Num Hits[1]
# Doc ID [381] Num Hits[1]
# Doc ID [382] Num Hits[1]
# Doc ID [385] Num Hits[1]
# Doc ID [382] Num Hits[1]
# Doc ID [385] Num Hits[1]
# Doc ID [382] Num Hits[1]
# Doc ID [426] Num Hits[1]
# Doc ID [382] Num Hits[1]
# Doc ID [426] Num Hits[1]
# Doc ID [382] Num Hits[1]
# Doc ID [382] Num Hits[1]
# Doc ID [383] Num Hits[1]
# Doc ID [383] Num Hits[1]
# Doc ID [384] Num Hits[1]
# Doc ID [384] Num Hits[1]
# Doc ID [386] Num Hits[1]
# Doc ID [424] Num Hits[1]
# Doc ID [386] Num Hits[1]
# Doc ID [424] Num Hits[1]
# Doc ID [386] Num Hits[1]
# Doc ID [386] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [564] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [389] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [389] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [387] Num Hits[1]
# Doc ID [390] Num Hits[1]
# Doc ID [390] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [396] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [396] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [394] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [394] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [392] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [392] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [391] Num Hits[1]
# Doc ID [393] Num Hits[1]
# Doc ID [393] Num Hits[1]
# Doc ID [395] Num Hits[1]
# Doc ID [395] Num Hits[1]
# Doc ID [397] Num Hits[1]
# Doc ID [397] Num Hits[1]
# Doc ID [397] Num Hits[1]
# Doc ID [397] Num Hits[1]
# Doc ID [398] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [398] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [398] Num Hits[1]
# Doc ID [400] Num Hits[1]
# Doc ID [398] Num Hits[1]
# Doc ID [400] Num Hits[1]
# Doc ID [401] Num Hits[1]
# Doc ID [401] Num Hits[1]
# Doc ID [401] Num Hits[1]
# Doc ID [401] Num Hits[1]
# Doc ID [402] Num Hits[1]
# Doc ID [402] Num Hits[1]
# Doc ID [402] Num Hits[1]
# Doc ID [402] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [403] Num Hits[1]
# Doc ID [406] Num Hits[1]
# Doc ID [406] Num Hits[1]
# Doc ID [407] Num Hits[1]
# Doc ID [407] Num Hits[1]
# Doc ID [408] Num Hits[1]
# Doc ID [408] Num Hits[1]
# Doc ID [408] Num Hits[1]
# Doc ID [408] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [409] Num Hits[1]
# Doc ID [410] Num Hits[1]
# Doc ID [410] Num Hits[1]
# Doc ID [410] Num Hits[1]
# Doc ID [410] Num Hits[1]
# Doc ID [411] Num Hits[1]
# Doc ID [411] Num Hits[1]
# Doc ID [411] Num Hits[1]
# Doc ID [411] Num Hits[1]
# Doc ID [412] Num Hits[1]
# Doc ID [412] Num Hits[1]
# Doc ID [412] Num Hits[1]
# Doc ID [413] Num Hits[1]
# Doc ID [412] Num Hits[1]
# Doc ID [413] Num Hits[1]
# Doc ID [412] Num Hits[1]
# Doc ID [414] Num Hits[1]
# Doc ID [412] Num Hits[1]
# Doc ID [414] Num Hits[1]
# Doc ID [415] Num Hits[1]
# Doc ID [415] Num Hits[1]
# Doc ID [415] Num Hits[1]
# Doc ID [415] Num Hits[1]
# Doc ID [416] Num Hits[1]
# Doc ID [416] Num Hits[1]
# Doc ID [416] Num Hits[1]
# Doc ID [416] Num Hits[1]
# Doc ID [417] Num Hits[1]
# Doc ID [417] Num Hits[1]
# Doc ID [418] Num Hits[1]
# Doc ID [418] Num Hits[1]
# Doc ID [419] Num Hits[1]
# Doc ID [419] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [1] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [488] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [422] Num Hits[1]
# Doc ID [420] Num Hits[1]
# Doc ID [422] Num Hits[1]
# Doc ID [421] Num Hits[1]
# Doc ID [421] Num Hits[1]
# Doc ID [423] Num Hits[1]
# Doc ID [423] Num Hits[1]
# Doc ID [424] Num Hits[1]
# Doc ID [424] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [429] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [429] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [425] Num Hits[1]
# Doc ID [427] Num Hits[1]
# Doc ID [427] Num Hits[1]
# Doc ID [428] Num Hits[1]
# Doc ID [428] Num Hits[1]
# Doc ID [429] Num Hits[1]
# Doc ID [429] Num Hits[1]
# Doc ID [430] Num Hits[1]
# Doc ID [430] Num Hits[1]
# Doc ID [431] Num Hits[1]
# Doc ID [431] Num Hits[1]
# Doc ID [431] Num Hits[1]
# Doc ID [433] Num Hits[1]
# Doc ID [431] Num Hits[1]
# Doc ID [433] Num Hits[1]
# Doc ID [431] Num Hits[1]
# Doc ID [431] Num Hits[1]
# Doc ID [434] Num Hits[1]
# Doc ID [434] Num Hits[1]
# Doc ID [435] Num Hits[1]
# Doc ID [435] Num Hits[1]
# Doc ID [436] Num Hits[1]
# Doc ID [439] Num Hits[1]
# Doc ID [436] Num Hits[1]
# Doc ID [439] Num Hits[1]
# Doc ID [436] Num Hits[2]
# Doc ID [436] Num Hits[2]
# Doc ID [436] Num Hits[1]
# Doc ID [436] Num Hits[1]
# Doc ID [437] Num Hits[1]
# Doc ID [437] Num Hits[1]
# Doc ID [438] Num Hits[1]
# Doc ID [438] Num Hits[1]
# Doc ID [438] Num Hits[1]
# Doc ID [438] Num Hits[1]
# Doc ID [440] Num Hits[1]
# Doc ID [440] Num Hits[1]
# Doc ID [441] Num Hits[1]
# Doc ID [441] Num Hits[1]
# Doc ID [441] Num Hits[1]
# Doc ID [441] Num Hits[1]
# Doc ID [442] Num Hits[1]
# Doc ID [442] Num Hits[1]
# Doc ID [443] Num Hits[1]
# Doc ID [443] Num Hits[1]
# Doc ID [444] Num Hits[1]
# Doc ID [444] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [465] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [465] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [446] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [446] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [446] Num Hits[1]
# Doc ID [445] Num Hits[1]
# Doc ID [446] Num Hits[1]
# Doc ID [447] Num Hits[1]
# Doc ID [447] Num Hits[1]
# Doc ID [11] Num Hits[1]
# Doc ID [11] Num Hits[1]
# Doc ID [14] Num Hits[1]
# Doc ID [14] Num Hits[1]
# Doc ID [448] Num Hits[1]
# Doc ID [448] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [449] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [459] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [459] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [465] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [450] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [465] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [451] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [452] Num Hits[1]
# Doc ID [453] Num Hits[1]
# Doc ID [453] Num Hits[1]
# Doc ID [453] Num Hits[1]
# Doc ID [453] Num Hits[1]
# Doc ID [453] Num Hits[1]
# Doc ID [453] Num Hits[1]
# Doc ID [453] Num Hits[1]
# Doc ID [453] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [457] Num Hits[1]
# Doc ID [454] Num Hits[1]
# Doc ID [457] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [455] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [456] Num Hits[1]
# Doc ID [457] Num Hits[1]
# Doc ID [457] Num Hits[1]
# Doc ID [457] Num Hits[2]
# Doc ID [457] Num Hits[2]
# Doc ID [457] Num Hits[1]
# Doc ID [457] Num Hits[1]
# Doc ID [457] Num Hits[1]
# Doc ID [457] Num Hits[1]
# Doc ID [458] Num Hits[1]
# Doc ID [458] Num Hits[1]
# Doc ID [458] Num Hits[1]
# Doc ID [458] Num Hits[1]
# Doc ID [458] Num Hits[1]
# Doc ID [458] Num Hits[1]
# Doc ID [459] Num Hits[1]
# Doc ID [459] Num Hits[1]
# Doc ID [459] Num Hits[1]
# Doc ID [459] Num Hits[1]
# Doc ID [459] Num Hits[1]
# Doc ID [459] Num Hits[1]
# Doc ID [460] Num Hits[1]
# Doc ID [466] Num Hits[1]
# Doc ID [477] Num Hits[1]
# Doc ID [460] Num Hits[1]
# Doc ID [466] Num Hits[1]
# Doc ID [477] Num Hits[1]
# Doc ID [460] Num Hits[1]
# Doc ID [460] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [461] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [462] Num Hits[1]
# Doc ID [463] Num Hits[1]
# Doc ID [463] Num Hits[1]
# Doc ID [463] Num Hits[1]
# Doc ID [463] Num Hits[1]
# Doc ID [463] Num Hits[1]
# Doc ID [463] Num Hits[1]
# Doc ID [463] Num Hits[1]
# Doc ID [463] Num Hits[1]
# Doc ID [464] Num Hits[1]
# Doc ID [464] Num Hits[1]
# Doc ID [549] Num Hits[1]
# Doc ID [464] Num Hits[1]
# Doc ID [464] Num Hits[1]
# Doc ID [464] Num Hits[1]
# Doc ID [464] Num Hits[1]
# Doc ID [464] Num Hits[1]
# Doc ID [464] Num Hits[1]
# Doc ID [465] Num Hits[1]
# Doc ID [465] Num Hits[1]
# Doc ID [465] Num Hits[1]
# Doc ID [465] Num Hits[1]
# Doc ID [466] Num Hits[1]
# Doc ID [466] Num Hits[1]
# Doc ID [466] Num Hits[1]
# Doc ID [466] Num Hits[1]
# Doc ID [467] Num Hits[1]
# Doc ID [467] Num Hits[1]
# Doc ID [468] Num Hits[1]
# Doc ID [468] Num Hits[1]
# Doc ID [468] Num Hits[1]
# Doc ID [468] Num Hits[1]
# Doc ID [468] Num Hits[1]
# Doc ID [468] Num Hits[1]
# Doc ID [469] Num Hits[1]
# Doc ID [469] Num Hits[1]
# Doc ID [469] Num Hits[1]
# Doc ID [469] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [470] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [471] Num Hits[1]
# Doc ID [472] Num Hits[1]
# Doc ID [472] Num Hits[1]
# Doc ID [472] Num Hits[1]
# Doc ID [472] Num Hits[1]
# Doc ID [475] Num Hits[1]
# Doc ID [475] Num Hits[1]
# Doc ID [475] Num Hits[1]
# Doc ID [476] Num Hits[1]
# Doc ID [476] Num Hits[1]
# Doc ID [476] Num Hits[1]
# Doc ID [476] Num Hits[1]
# Doc ID [476] Num Hits[1]
# Doc ID [476] Num Hits[1]
# Doc ID [477] Num Hits[1]
# Doc ID [477] Num Hits[1]
# Doc ID [478] Num Hits[1]
# Doc ID [478] Num Hits[1]
# Doc ID [495] Num Hits[1]
# Doc ID [499] Num Hits[1]
# Doc ID [504] Num Hits[1]
# Doc ID [508] Num Hits[1]
# Doc ID [512] Num Hits[1]
# Doc ID [516] Num Hits[1]
# Doc ID [520] Num Hits[1]
# Doc ID [524] Num Hits[1]
# Doc ID [528] Num Hits[1]
# Doc ID [533] Num Hits[1]
# Doc ID [537] Num Hits[1]
# Doc ID [541] Num Hits[1]
# Doc ID [545] Num Hits[1]
# Doc ID [548] Num Hits[1]
# Doc ID [552] Num Hits[1]
# Doc ID [556] Num Hits[1]
# Doc ID [560] Num Hits[1]
# Doc ID [563] Num Hits[1]
# Doc ID [567] Num Hits[1]
# Doc ID [571] Num Hits[1]
# Doc ID [478] Num Hits[1]
# Doc ID [478] Num Hits[1]
# Doc ID [479] Num Hits[1]
# Doc ID [479] Num Hits[1]
# Doc ID [480] Num Hits[1]
# Doc ID [480] Num Hits[1]
# Doc ID [481] Num Hits[1]
# Doc ID [481] Num Hits[1]
# Doc ID [481] Num Hits[1]
# Doc ID [481] Num Hits[1]
# Doc ID [481] Num Hits[1]
# Doc ID [481] Num Hits[1]
# Doc ID [482] Num Hits[1]
# Doc ID [482] Num Hits[1]
# Doc ID [482] Num Hits[1]
# Doc ID [482] Num Hits[1]
# Doc ID [483] Num Hits[1]
# Doc ID [483] Num Hits[1]
# Doc ID [483] Num Hits[1]
# Doc ID [483] Num Hits[1]
# Doc ID [1] Num Hits[1]
# Doc ID [486] Num Hits[1]
# Doc ID [572] Num Hits[1]
# Doc ID [1] Num Hits[1]
# Doc ID [485] Num Hits[1]
# Doc ID [486] Num Hits[1]
# Doc ID [487] Num Hits[1]
# Doc ID [487] Num Hits[1]
# Doc ID [489] Num Hits[1]
# Doc ID [490] Num Hits[1]
# Doc ID [491] Num Hits[1]
# Doc ID [488] Num Hits[1]
# Doc ID [493] Num Hits[1]
# Doc ID [494] Num Hits[1]
# Doc ID [496] Num Hits[1]
# Doc ID [497] Num Hits[1]
# Doc ID [497] Num Hits[1]
# Doc ID [498] Num Hits[1]
# Doc ID [500] Num Hits[1]
# Doc ID [500] Num Hits[1]
# Doc ID [500] Num Hits[1]
# Doc ID [501] Num Hits[1]
# Doc ID [502] Num Hits[1]
# Doc ID [502] Num Hits[1]
# Doc ID [502] Num Hits[1]
# Doc ID [503] Num Hits[1]
# Doc ID [506] Num Hits[1]
# Doc ID [507] Num Hits[1]
# Doc ID [509] Num Hits[1]
# Doc ID [510] Num Hits[1]
# Doc ID [511] Num Hits[1]
# Doc ID [513] Num Hits[1]
# Doc ID [513] Num Hits[1]
# Doc ID [514] Num Hits[1]
# Doc ID [514] Num Hits[1]
# Doc ID [515] Num Hits[1]
# Doc ID [551] Num Hits[1]
# Doc ID [515] Num Hits[1]
# Doc ID [518] Num Hits[1]
# Doc ID [518] Num Hits[1]
# Doc ID [519] Num Hits[1]
# Doc ID [521] Num Hits[1]
# Doc ID [522] Num Hits[1]
# Doc ID [523] Num Hits[1]
# Doc ID [525] Num Hits[1]
# Doc ID [526] Num Hits[1]
# Doc ID [526] Num Hits[1]
# Doc ID [527] Num Hits[1]
# Doc ID [530] Num Hits[1]
# Doc ID [530] Num Hits[1]
# Doc ID [531] Num Hits[1]
# Doc ID [531] Num Hits[1]
# Doc ID [532] Num Hits[1]
# Doc ID [535] Num Hits[1]
# Doc ID [536] Num Hits[1]
# Doc ID [538] Num Hits[1]
# Doc ID [539] Num Hits[1]
# Doc ID [539] Num Hits[1]
# Doc ID [540] Num Hits[1]
# Doc ID [540] Num Hits[1]
# Doc ID [542] Num Hits[1]
# Doc ID [543] Num Hits[1]
# Doc ID [544] Num Hits[1]
# Doc ID [546] Num Hits[1]
# Doc ID [547] Num Hits[1]
# Doc ID [549] Num Hits[1]
# Doc ID [549] Num Hits[1]
# Doc ID [550] Num Hits[1]
# Doc ID [550] Num Hits[1]
# Doc ID [551] Num Hits[1]
# Doc ID [554] Num Hits[1]
# Doc ID [555] Num Hits[1]
# Doc ID [558] Num Hits[1]
# Doc ID [558] Num Hits[1]
# Doc ID [559] Num Hits[1]
# Doc ID [561] Num Hits[1]
# Doc ID [562] Num Hits[1]
# Doc ID [562] Num Hits[1]
# Doc ID [564] Num Hits[1]
# Doc ID [564] Num Hits[1]
# Doc ID [565] Num Hits[1]
# Doc ID [566] Num Hits[1]
# Doc ID [566] Num Hits[1]
# Doc ID [568] Num Hits[1]
# Doc ID [568] Num Hits[1]
# Doc ID [568] Num Hits[1]
# Doc ID [569] Num Hits[1]
# Doc ID [569] Num Hits[1]
# Doc ID [570] Num Hits[1]
# Doc ID [570] Num Hits[1]
# Doc ID [572] Num Hits[1]
# Doc ID [1] Num Hits[1]

# %%
searcher.search('news')
# Out:
# WordID is none... Word not found....

# %%
import urlserver.URLServer as urlserver

#Now i am parsing all documents in the docIndex
def iterate():
    docID_list = urlserver.make_list()
    for i in docID_list:
        print(i)
        crawler.run(i)
        parser.run(i)
    urlresolver.run()
    sorter.sort()
    
iterate()
# Out:
# 2
# (//stackoverflow.com): current community
# (http://chat.stackoverflow.com): chat
# (https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent&amp;utm_source=stackoverflow.com&amp;utm_medium=dev-story&amp;utm_campaign=signup-redirect): Sign up
# (https://stackoverflow.com/users/login?ssrc=site_switcher): log in
# (//stackexchange.com/sites): more stack exchange communities
# (http://stackoverflow.blog): company blog
# (https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent&utm_source=stackoverflow.com&utm_medium=dev-story&utm_campaign=signup-redirect): sign up
# (https://stackoverflow.com/users/login?ssrc=head): log in
# (/tour): tour
# (#):  help
# (/tour):  Tour
# (/help):  Help Center
# (//meta.stackoverflow.com):  Meta
# (http://stackoverflow.com/company/about):  About Us
# (http://business.stackoverflow.com/?ref=topbar_help):  Business
# (/):  Stack Overflow
# (/questions):  Questions
# (/jobs?med=site-ui&ref=jobs-tab):  Jobs
# (/documentation):  Documentation
# (/tags):  Tags
# (/users):  Users
# (/help/badges):  Badges
# (/questions/ask): Ask Question
# (/users/login?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent): Log in
# (/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent): Sign up
# (None): more sign up options
# (http://openid.net/what/): more about OpenId
# (http://openid.net/get/): how to get an OpenID enabled account
# (http://stackexchange.com/legal/privacy-policy): privacy policy
# (http://stackexchange.com/legal/terms-of-service): terms of service
# (/users/login?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent): Log in
# (https://careers.stackoverflow.com/employer/login): Sign up on Talent
# (http://stackoverflow.com/company/about): about us
# (/tour): tour
# (/help): help
# (http://stackoverflow.blog?blb=1): blog
# (http://chat.stackoverflow.com): chat
# (http://data.stackexchange.com): data
# (http://stackexchange.com/legal): legal
# (http://stackexchange.com/legal/privacy-policy): privacy policy
# (http://stackoverflow.com/company/work-here): work here
# (http://stackexchange.com/mediakit): advertising info
# (None): mobile
# (/contact): contact us
# (http://meta.stackoverflow.com): feedback
# (//stackoverflow.com): Stack Overflow
# (//serverfault.com): Server Fault
# (//superuser.com): Super User
# (//webapps.stackexchange.com): Web Applications
# (//askubuntu.com): Ask Ubuntu
# (//webmasters.stackexchange.com): Webmasters
# (//gamedev.stackexchange.com): Game Development
# (//tex.stackexchange.com): TeX LaTeX
# (//softwareengineering.stackexchange.com): Software Engineering
# (//unix.stackexchange.com): Unix Linux
# (//apple.stackexchange.com): Ask Different Apple
# (//wordpress.stackexchange.com): WordPress Development
# (//gis.stackexchange.com): Geographic Information Systems
# (//electronics.stackexchange.com): Electrical Engineering
# (//android.stackexchange.com): Android Enthusiasts
# (//security.stackexchange.com): Information Security
# (//dba.stackexchange.com): Database Administrators
# (//drupal.stackexchange.com): Drupal Answers
# (//sharepoint.stackexchange.com): SharePoint
# (//ux.stackexchange.com): User Experience
# (//mathematica.stackexchange.com): Mathematica
# (//salesforce.stackexchange.com): Salesforce
# (//expressionengine.stackexchange.com): ExpressionEngine Answers
# (//crypto.stackexchange.com): Cryptography
# (//codereview.stackexchange.com): Code Review
# (//magento.stackexchange.com): Magento
# (//dsp.stackexchange.com): Signal Processing
# (//raspberrypi.stackexchange.com): Raspberry Pi
# (//codegolf.stackexchange.com): Programming Puzzles Code Golf
# (http://stackexchange.com/sites#technology):  more 7
# (//photo.stackexchange.com): Photography
# (//scifi.stackexchange.com): Science Fiction Fantasy
# (//graphicdesign.stackexchange.com): Graphic Design
# (//movies.stackexchange.com): Movies TV
# (//music.stackexchange.com): Music Practice Theory
# (//cooking.stackexchange.com): Seasoned Advice cooking
# (//diy.stackexchange.com): Home Improvement
# (//money.stackexchange.com): Personal Finance Money
# (//academia.stackexchange.com): Academia
# (http://stackexchange.com/sites#lifearts):  more 8
# (//english.stackexchange.com): English Language Usage
# (//skeptics.stackexchange.com): Skeptics
# (//judaism.stackexchange.com): Mi Yodeya Judaism
# (//travel.stackexchange.com): Travel
# (//christianity.stackexchange.com): Christianity
# (//ell.stackexchange.com): English Language Learners
# (//japanese.stackexchange.com): Japanese Language
# (//gaming.stackexchange.com): Arqade gaming
# (//bicycles.stackexchange.com): Bicycles
# (//rpg.stackexchange.com): Role playing Games
# (//anime.stackexchange.com): Anime Manga
# (//mechanics.stackexchange.com): Motor Vehicle Maintenance Repair
# (http://stackexchange.com/sites#culturerecreation):  more 17
# (//mathoverflow.net): MathOverflow
# (//math.stackexchange.com): Mathematics
# (//stats.stackexchange.com): Cross Validated stats
# (//cstheory.stackexchange.com): Theoretical Computer Science
# (//physics.stackexchange.com): Physics
# (//chemistry.stackexchange.com): Chemistry
# (//biology.stackexchange.com): Biology
# (//cs.stackexchange.com): Computer Science
# (//philosophy.stackexchange.com): Philosophy
# (http://stackexchange.com/sites#science):  more 3
# (//meta.stackexchange.com): Meta Stack Exchange
# (//stackapps.com): Stack Apps
# (//area51.stackexchange.com): Area 51
# (//talent.stackoverflow.com): Stack Overflow Talent
# (https://creativecommons.org/licenses/by-sa/3.0/): cc by sa 3 0
# (http://blog.stackoverflow.com/2009/06/attribution-required/): attribution required
# �
# �
# �
# �
# 3
# (//stackoverflow.com): current community
# (http://chat.stackoverflow.com): chat
# (https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent&amp;utm_source=stackoverflow.com&amp;utm_medium=dev-story&amp;utm_campaign=signup-redirect): Sign up
# (https://stackoverflow.com/users/login?ssrc=site_switcher): log in
# (//stackexchange.com/sites): more stack exchange communities
# (http://stackoverflow.blog): company blog
# (https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent&utm_source=stackoverflow.com&utm_medium=dev-story&utm_campaign=signup-redirect): sign up
# (https://stackoverflow.com/users/login?ssrc=head): log in
# (/tour): tour
# (#):  help
# (/tour):  Tour
# (/help):  Help Center
# (//meta.stackoverflow.com):  Meta
# (http://stackoverflow.com/company/about):  About Us
# (http://business.stackoverflow.com/?ref=topbar_help):  Business
# (/):  Stack Overflow
# (/questions):  Questions
# (/jobs?med=site-ui&ref=jobs-tab):  Jobs
# (/documentation):  Documentation
# (/tags):  Tags
# (/users):  Users
# (/help/badges):  Badges
# (/questions/ask): Ask Question
# (/users/login?ssrc=site_switcher&returnurl=http%3a%2f%2fstackoverflow.com%2f): Log in
# (/users/signup?ssrc=site_switcher&returnurl=http%3a%2f%2fstackoverflow.com%2f): Sign up
# (//stackexchange.com/sites): communities
# (/users/account-recovery): forgot
# (None): more login options
# (http://openid.net/what/): more about OpenId
# (http://openid.net/get/): how to get an OpenID enabled account
# (/users/signup?ssrc=site_switcher&returnurl=http%3a%2f%2fstackoverflow.com%2f): Sign up
# (https://careers.stackoverflow.com/employer/login): Log in on Talent
# (http://stackoverflow.com/company/about): about us
# (/tour): tour
# (/help): help
# (http://stackoverflow.blog?blb=1): blog
# (http://chat.stackoverflow.com): chat
# (http://data.stackexchange.com): data
# (http://stackexchange.com/legal): legal
# (http://stackexchange.com/legal/privacy-policy): privacy policy
# (http://stackoverflow.com/company/work-here): work here
# (http://stackexchange.com/mediakit): advertising info
# (None): mobile
# (/contact): contact us
# (http://meta.stackoverflow.com): feedback
# (//stackoverflow.com): Stack Overflow
# (//serverfault.com): Server Fault
# (//superuser.com): Super User
# (//webapps.stackexchange.com): Web Applications
# (//askubuntu.com): Ask Ubuntu
# (//webmasters.stackexchange.com): Webmasters
# (//gamedev.stackexchange.com): Game Development
# (//tex.stackexchange.com): TeX LaTeX
# (//softwareengineering.stackexchange.com): Software Engineering
# (//unix.stackexchange.com): Unix Linux
# (//apple.stackexchange.com): Ask Different Apple
# (//wordpress.stackexchange.com): WordPress Development
# (//gis.stackexchange.com): Geographic Information Systems
# (//electronics.stackexchange.com): Electrical Engineering
# (//android.stackexchange.com): Android Enthusiasts
# (//security.stackexchange.com): Information Security
# (//dba.stackexchange.com): Database Administrators
# (//drupal.stackexchange.com): Drupal Answers
# (//sharepoint.stackexchange.com): SharePoint
# (//ux.stackexchange.com): User Experience
# (//mathematica.stackexchange.com): Mathematica
# (//salesforce.stackexchange.com): Salesforce
# (//expressionengine.stackexchange.com): ExpressionEngine Answers
# (//crypto.stackexchange.com): Cryptography
# (//codereview.stackexchange.com): Code Review
# (//magento.stackexchange.com): Magento
# (//dsp.stackexchange.com): Signal Processing
# (//raspberrypi.stackexchange.com): Raspberry Pi
# (//codegolf.stackexchange.com): Programming Puzzles Code Golf
# (http://stackexchange.com/sites#technology):  more 7
# (//photo.stackexchange.com): Photography
# (//scifi.stackexchange.com): Science Fiction Fantasy
# (//graphicdesign.stackexchange.com): Graphic Design
# (//movies.stackexchange.com): Movies TV
# (//music.stackexchange.com): Music Practice Theory
# (//cooking.stackexchange.com): Seasoned Advice cooking
# (//diy.stackexchange.com): Home Improvement
# (//money.stackexchange.com): Personal Finance Money
# (//academia.stackexchange.com): Academia
# (http://stackexchange.com/sites#lifearts):  more 8
# (//english.stackexchange.com): English Language Usage
# (//skeptics.stackexchange.com): Skeptics
# (//judaism.stackexchange.com): Mi Yodeya Judaism
# (//travel.stackexchange.com): Travel
# (//christianity.stackexchange.com): Christianity
# (//ell.stackexchange.com): English Language Learners
# (//japanese.stackexchange.com): Japanese Language
# (//gaming.stackexchange.com): Arqade gaming
# (//bicycles.stackexchange.com): Bicycles
# (//rpg.stackexchange.com): Role playing Games
# (//anime.stackexchange.com): Anime Manga
# (//mechanics.stackexchange.com): Motor Vehicle Maintenance Repair
# (http://stackexchange.com/sites#culturerecreation):  more 17
# (//mathoverflow.net): MathOverflow
# (//math.stackexchange.com): Mathematics
# (//stats.stackexchange.com): Cross Validated stats
# (//cstheory.stackexchange.com): Theoretical Computer Science
# (//physics.stackexchange.com): Physics
# (//chemistry.stackexchange.com): Chemistry
# (//biology.stackexchange.com): Biology
# (//cs.stackexchange.com): Computer Science
# (//philosophy.stackexchange.com): Philosophy
# (http://stackexchange.com/sites#science):  more 3
# (//meta.stackexchange.com): Meta Stack Exchange
# (//stackapps.com): Stack Apps
# (//area51.stackexchange.com): Area 51
# (//talent.stackoverflow.com): Stack Overflow Talent
# (https://creativecommons.org/licenses/by-sa/3.0/): cc by sa 3 0
# (http://blog.stackoverflow.com/2009/06/attribution-required/): attribution required
# �
# �
# �
# �
# 4
# (https://stackoverflow.com/company/about): About Us
# (https://stackoverflow.com/company/work-here): Work Here
# (http://meta.stackoverflow.com/): Any feedback
# (https://stackexchange.com/about/contact): Contact Us
# (https://stackexchange.com/legal/privacy-policy): Privacy Policy
# (https://stackexchange.com/legal): Legal
# (https://www.facebook.com/officialstackoverflow/): Facebook
# (https://twitter.com/stackoverflow): Twitter
# (https://www.linkedin.com/company/stack-overflow): LinkedIn
# �
#
# q
# q
# q
# q
# q
# q
# �
# 	q
# q
# �
# ��
# 5
# (//stackoverflow.com): current community
# (http://chat.stackoverflow.com): chat
# (https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent&amp;utm_source=stackoverflow.com&amp;utm_medium=dev-story&amp;utm_campaign=signup-redirect): Sign up
# (https://stackoverflow.com/users/login?ssrc=site_switcher): log in
# (//stackexchange.com/sites): more stack exchange communities
# (http://stackoverflow.blog): company blog
# (https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent&utm_source=stackoverflow.com&utm_medium=dev-story&utm_campaign=signup-redirect): sign up
# (https://stackoverflow.com/users/login?ssrc=head): log in
# (/tour): tour
# (#):  help
# (/tour):  Tour
# (/help):  Help Center
# (//meta.stackoverflow.com):  Meta
# (http://stackoverflow.com/company/about):  About Us
# (http://business.stackoverflow.com/?ref=topbar_help):  Business
# (/):  Stack Overflow
# (/questions):  Questions
# (/jobs?med=site-ui&ref=jobs-tab):  Jobs
# (/documentation):  Documentation
# (/tags):  Tags
# (/users):  Users
# (/help/badges):  Badges
# (/questions/ask): Ask Question
# (/users/login?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent): Log in
# (/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent): Sign up
# (None): more sign up options
# (http://openid.net/what/): more about OpenId
# (http://openid.net/get/): how to get an OpenID enabled account
# (http://stackexchange.com/legal/privacy-policy): privacy policy
# (http://stackexchange.com/legal/terms-of-service): terms of service
# (/users/login?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent): Log in
# (https://careers.stackoverflow.com/employer/login): Sign up on Talent
# (http://stackoverflow.com/company/about): about us
# (/tour): tour
# (/help): help
# (http://stackoverflow.blog?blb=1): blog
# (http://chat.stackoverflow.com): chat
# (http://data.stackexchange.com): data
# (http://stackexchange.com/legal): legal
# (http://stackexchange.com/legal/privacy-policy): privacy policy
# (http://stackoverflow.com/company/work-here): work here
# (http://stackexchange.com/mediakit): advertising info
# (None): mobile
# (/contact): contact us
# (http://meta.stackoverflow.com): feedback
# (//stackoverflow.com): Stack Overflow
# (//serverfault.com): Server Fault
# (//superuser.com): Super User
# (//webapps.stackexchange.com): Web Applications
# (//askubuntu.com): Ask Ubuntu
# (//webmasters.stackexchange.com): Webmasters
# (//gamedev.stackexchange.com): Game Development
# (//tex.stackexchange.com): TeX LaTeX
# (//softwareengineering.stackexchange.com): Software Engineering
# (//unix.stackexchange.com): Unix Linux
# (//apple.stackexchange.com): Ask Different Apple
# (//wordpress.stackexchange.com): WordPress Development
# (//gis.stackexchange.com): Geographic Information Systems
# (//electronics.stackexchange.com): Electrical Engineering
# (//android.stackexchange.com): Android Enthusiasts
# (//security.stackexchange.com): Information Security
# (//dba.stackexchange.com): Database Administrators
# (//drupal.stackexchange.com): Drupal Answers
# (//sharepoint.stackexchange.com): SharePoint
# (//ux.stackexchange.com): User Experience
# (//mathematica.stackexchange.com): Mathematica
# (//salesforce.stackexchange.com): Salesforce
# (//expressionengine.stackexchange.com): ExpressionEngine Answers
# (//crypto.stackexchange.com): Cryptography
# (//codereview.stackexchange.com): Code Review
# (//magento.stackexchange.com): Magento
# (//dsp.stackexchange.com): Signal Processing
# (//raspberrypi.stackexchange.com): Raspberry Pi
# (//codegolf.stackexchange.com): Programming Puzzles Code Golf
# (http://stackexchange.com/sites#technology):  more 7
# (//photo.stackexchange.com): Photography
# (//scifi.stackexchange.com): Science Fiction Fantasy
# (//graphicdesign.stackexchange.com): Graphic Design
# (//movies.stackexchange.com): Movies TV
# (//music.stackexchange.com): Music Practice Theory
# (//cooking.stackexchange.com): Seasoned Advice cooking
# (//diy.stackexchange.com): Home Improvement
# (//money.stackexchange.com): Personal Finance Money
# (//academia.stackexchange.com): Academia
# (http://stackexchange.com/sites#lifearts):  more 8
# (//english.stackexchange.com): English Language Usage
# (//skeptics.stackexchange.com): Skeptics
# (//judaism.stackexchange.com): Mi Yodeya Judaism
# (//travel.stackexchange.com): Travel
# (//christianity.stackexchange.com): Christianity
# (//ell.stackexchange.com): English Language Learners
# (//japanese.stackexchange.com): Japanese Language
# (//gaming.stackexchange.com): Arqade gaming
# (//bicycles.stackexchange.com): Bicycles
# (//rpg.stackexchange.com): Role playing Games
# (//anime.stackexchange.com): Anime Manga
# (//mechanics.stackexchange.com): Motor Vehicle Maintenance Repair
# (http://stackexchange.com/sites#culturerecreation):  more 17
# (//mathoverflow.net): MathOverflow
# (//math.stackexchange.com): Mathematics
# (//stats.stackexchange.com): Cross Validated stats
# (//cstheory.stackexchange.com): Theoretical Computer Science
# (//physics.stackexchange.com): Physics
# (//chemistry.stackexchange.com): Chemistry
# (//biology.stackexchange.com): Biology
# (//cs.stackexchange.com): Computer Science
# (//philosophy.stackexchange.com): Philosophy
# (http://stackexchange.com/sites#science):  more 3
# (//meta.stackexchange.com): Meta Stack Exchange
# (//stackapps.com): Stack Apps
# (//area51.stackexchange.com): Area 51
# (//talent.stackoverflow.com): Stack Overflow Talent
# (https://creativecommons.org/licenses/by-sa/3.0/): cc by sa 3 0
# (http://blog.stackoverflow.com/2009/06/attribution-required/): attribution required
# �
# �
# �
# �
# 6
# (//stackoverflow.com): current community
# (http://chat.stackoverflow.com): chat
# (https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent&amp;utm_source=stackoverflow.com&amp;utm_medium=dev-story&amp;utm_campaign=signup-redirect): Sign up
# (https://stackoverflow.com/users/login?ssrc=site_switcher): log in
# (//stackexchange.com/sites): more stack exchange communities
# (http://stackoverflow.blog): company blog
# (https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent&utm_source=stackoverflow.com&utm_medium=dev-story&utm_campaign=signup-redirect): sign up
# (https://stackoverflow.com/users/login?ssrc=head): log in
# (/tour): tour
# (#):  help
# (/tour):  Tour
# (/help):  Help Center
# (//meta.stackoverflow.com):  Meta
# (http://stackoverflow.com/company/about):  About Us
# (http://business.stackoverflow.com/?ref=topbar_help):  Business
# (/):  Stack Overflow
# (/questions):  Questions
# (/jobs?med=site-ui&ref=jobs-tab):  Jobs
# (/documentation):  Documentation
# (/tags):  Tags
# (/users):  Users
# (/help/badges):  Badges
# (/questions/ask): Ask Question
# (/users/login?ssrc=head&returnurl=http%3a%2f%2fstackoverflow.com%2f): Log in
# (/users/signup?ssrc=head&returnurl=http%3a%2f%2fstackoverflow.com%2f): Sign up
# (//stackexchange.com/sites): communities
# (/users/account-recovery): forgot
# (None): more login options
# (http://openid.net/what/): more about OpenId
# (http://openid.net/get/): how to get an OpenID enabled account
# (/users/signup?ssrc=head&returnurl=http%3a%2f%2fstackoverflow.com%2f): Sign up
# (https://careers.stackoverflow.com/employer/login): Log in on Talent
# (http://stackoverflow.com/company/about): about us
# (/tour): tour
# (/help): help
# (http://stackoverflow.blog?blb=1): blog
# (http://chat.stackoverflow.com): chat
# (http://data.stackexchange.com): data
# (http://stackexchange.com/legal): legal
# (http://stackexchange.com/legal/privacy-policy): privacy policy
# (http://stackoverflow.com/company/work-here): work here
# (http://stackexchange.com/mediakit): advertising info
# (None): mobile
# (/contact): contact us
# (http://meta.stackoverflow.com): feedback
# (//stackoverflow.com): Stack Overflow
# (//serverfault.com): Server Fault
# (//superuser.com): Super User
# (//webapps.stackexchange.com): Web Applications
# (//askubuntu.com): Ask Ubuntu
# (//webmasters.stackexchange.com): Webmasters
# (//gamedev.stackexchange.com): Game Development
# (//tex.stackexchange.com): TeX LaTeX
# (//softwareengineering.stackexchange.com): Software Engineering
# (//unix.stackexchange.com): Unix Linux
# (//apple.stackexchange.com): Ask Different Apple
# (//wordpress.stackexchange.com): WordPress Development
# (//gis.stackexchange.com): Geographic Information Systems
# (//electronics.stackexchange.com): Electrical Engineering
# (//android.stackexchange.com): Android Enthusiasts
# (//security.stackexchange.com): Information Security
# (//dba.stackexchange.com): Database Administrators
# (//drupal.stackexchange.com): Drupal Answers
# (//sharepoint.stackexchange.com): SharePoint
# (//ux.stackexchange.com): User Experience
# (//mathematica.stackexchange.com): Mathematica
# (//salesforce.stackexchange.com): Salesforce
# (//expressionengine.stackexchange.com): ExpressionEngine Answers
# (//crypto.stackexchange.com): Cryptography
# (//codereview.stackexchange.com): Code Review
# (//magento.stackexchange.com): Magento
# (//dsp.stackexchange.com): Signal Processing
# (//raspberrypi.stackexchange.com): Raspberry Pi
# (//codegolf.stackexchange.com): Programming Puzzles Code Golf
# (http://stackexchange.com/sites#technology):  more 7
# (//photo.stackexchange.com): Photography
# (//scifi.stackexchange.com): Science Fiction Fantasy
# (//graphicdesign.stackexchange.com): Graphic Design
# (//movies.stackexchange.com): Movies TV
# (//music.stackexchange.com): Music Practice Theory
# (//cooking.stackexchange.com): Seasoned Advice cooking
# (//diy.stackexchange.com): Home Improvement
# (//money.stackexchange.com): Personal Finance Money
# (//academia.stackexchange.com): Academia
# (http://stackexchange.com/sites#lifearts):  more 8
# (//english.stackexchange.com): English Language Usage
# (//skeptics.stackexchange.com): Skeptics
# (//judaism.stackexchange.com): Mi Yodeya Judaism
# (//travel.stackexchange.com): Travel
# (//christianity.stackexchange.com): Christianity
# (//ell.stackexchange.com): English Language Learners
# (//japanese.stackexchange.com): Japanese Language
# (//gaming.stackexchange.com): Arqade gaming
# (//bicycles.stackexchange.com): Bicycles
# (//rpg.stackexchange.com): Role playing Games
# (//anime.stackexchange.com): Anime Manga
# (//mechanics.stackexchange.com): Motor Vehicle Maintenance Repair
# (http://stackexchange.com/sites#culturerecreation):  more 17
# (//mathoverflow.net): MathOverflow
# (//math.stackexchange.com): Mathematics
# (//stats.stackexchange.com): Cross Validated stats
# (//cstheory.stackexchange.com): Theoretical Computer Science
# (//physics.stackexchange.com): Physics
# (//chemistry.stackexchange.com): Chemistry
# (//biology.stackexchange.com): Biology
# (//cs.stackexchange.com): Computer Science
# (//philosophy.stackexchange.com): Philosophy
# (http://stackexchange.com/sites#science):  more 3
# (//meta.stackexchange.com): Meta Stack Exchange
# (//stackapps.com): Stack Apps
# (//area51.stackexchange.com): Area 51
# (//talent.stackoverflow.com): Stack Overflow Talent
# (https://creativecommons.org/licenses/by-sa/3.0/): cc by sa 3 0
# (http://blog.stackoverflow.com/2009/06/attribution-required/): attribution required
# �
# �
# �
# �
# 7
# (//stackoverflow.com): current community
# (http://chat.stackoverflow.com): chat
# (https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent&amp;utm_source=stackoverflow.com&amp;utm_medium=dev-story&amp;utm_campaign=signup-redirect): Sign up
# (https://stackoverflow.com/users/login?ssrc=site_switcher&returnurl=http%3a%2f%2fstackoverflow.com%2ftour): log in
# (//stackexchange.com/sites): more stack exchange communities
# (http://stackoverflow.blog): company blog
# (https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent&utm_source=stackoverflow.com&utm_medium=dev-story&utm_campaign=signup-redirect): sign up
# (https://stackoverflow.com/users/login?ssrc=head&returnurl=http%3a%2f%2fstackoverflow.com%2ftour): log in
# (/tour): tour
# (#):  help
# (/tour):  Tour
# (/help):  Help Center
# (//meta.stackoverflow.com):  Meta
# (http://stackoverflow.com/company/about):  About Us
# (http://business.stackoverflow.com/?ref=topbar_help):  Business
# (/):  Stack Overflow
# (/questions):  Questions
# (/jobs?med=site-ui&ref=jobs-tab):  Jobs
# (/documentation):  Documentation
# (/tags):  Tags
# (/users):  Users
# (/help/badges):  Badges
# (/questions/ask): Ask Question
# (http://stackexchange.com): Stack Exchange
# (http://en.wikipedia.org/wiki/OS_X_Mavericks): OS X 10 9
# (http://en.wikipedia.org/wiki/OS_X_Mountain_Lion): OS X 10 8
# (/questions/tagged/ios): ios
# (/questions/tagged/osx): osx
# (/questions/tagged/swift): swift
# (/tags): tag list
# (http://en.wikipedia.org/wiki/OS_X_Mavericks): OS X 10 9
# (http://en.wikipedia.org/wiki/OS_X_Mountain_Lion): OS X 10 8
# (/questions/tagged/ios): ios
# (/questions/tagged/osx): osx
# (/questions/tagged/swift): swift
# (/help/privileges): unlock new privileges
# (/users?tab=moderators): community moderators
# (/help/privileges): see all privileges
# (None): edit
# (None): add a comment
# (http://stackoverflow.com/tour): tour
# (/help/badges): see all badges
# (/users/signup?ssrc=about&returnurl=http%3a%2f%2fstackoverflow.com%2ftour%23cta): Sign up
# (/help): Visit the Help Center
# (http://stackexchange.com/sites): full list of sites
# (http://stackoverflow.com/company/about): about us
# (/tour): tour
# (/help): help
# (http://stackoverflow.blog?blb=1): blog
# (http://chat.stackoverflow.com): chat
# (http://data.stackexchange.com): data
# (http://stackexchange.com/legal): legal
# (http://stackexchange.com/legal/privacy-policy): privacy policy
# (http://stackoverflow.com/company/work-here): work here
# (http://stackexchange.com/mediakit): advertising info
# (None): mobile
# (/contact): contact us
# (http://meta.stackoverflow.com): feedback
# (//stackoverflow.com): Stack Overflow
# (//serverfault.com): Server Fault
# (//superuser.com): Super User
# (//webapps.stackexchange.com): Web Applications
# (//askubuntu.com): Ask Ubuntu
# (//webmasters.stackexchange.com): Webmasters
# (//gamedev.stackexchange.com): Game Development
# (//tex.stackexchange.com): TeX LaTeX
# (//softwareengineering.stackexchange.com): Software Engineering
# (//unix.stackexchange.com): Unix Linux
# (//apple.stackexchange.com): Ask Different Apple
# (//wordpress.stackexchange.com): WordPress Development
# (//gis.stackexchange.com): Geographic Information Systems
# (//electronics.stackexchange.com): Electrical Engineering
# (//android.stackexchange.com): Android Enthusiasts
# (//security.stackexchange.com): Information Security
# (//dba.stackexchange.com): Database Administrators
# (//drupal.stackexchange.com): Drupal Answers
# (//sharepoint.stackexchange.com): SharePoint
# (//ux.stackexchange.com): User Experience
# (//mathematica.stackexchange.com): Mathematica
# (//salesforce.stackexchange.com): Salesforce
# (//expressionengine.stackexchange.com): ExpressionEngine Answers
# (//crypto.stackexchange.com): Cryptography
# (//codereview.stackexchange.com): Code Review
# (//magento.stackexchange.com): Magento
# (//dsp.stackexchange.com): Signal Processing
# (//raspberrypi.stackexchange.com): Raspberry Pi
# (//codegolf.stackexchange.com): Programming Puzzles Code Golf
# (http://stackexchange.com/sites#technology):  more 7
# (//photo.stackexchange.com): Photography
# (//scifi.stackexchange.com): Science Fiction Fantasy
# (//graphicdesign.stackexchange.com): Graphic Design
# (//movies.stackexchange.com): Movies TV
# (//music.stackexchange.com): Music Practice Theory
# (//cooking.stackexchange.com): Seasoned Advice cooking
# (//diy.stackexchange.com): Home Improvement
# (//money.stackexchange.com): Personal Finance Money
# (//academia.stackexchange.com): Academia
# (http://stackexchange.com/sites#lifearts):  more 8
# (//english.stackexchange.com): English Language Usage
# (//skeptics.stackexchange.com): Skeptics
# (//judaism.stackexchange.com): Mi Yodeya Judaism
# (//travel.stackexchange.com): Travel
# (//christianity.stackexchange.com): Christianity
# (//ell.stackexchange.com): English Language Learners
# (//japanese.stackexchange.com): Japanese Language
# (//gaming.stackexchange.com): Arqade gaming
# (//bicycles.stackexchange.com): Bicycles
# (//rpg.stackexchange.com): Role playing Games
# (//anime.stackexchange.com): Anime Manga
# (//mechanics.stackexchange.com): Motor Vehicle Maintenance Repair
# (http://stackexchange.com/sites#culturerecreation):  more 17
# (//mathoverflow.net): MathOverflow
# (//math.stackexchange.com): Mathematics
# (//stats.stackexchange.com): Cross Validated stats
# (//cstheory.stackexchange.com): Theoretical Computer Science
# (//physics.stackexchange.com): Physics
# (//chemistry.stackexchange.com): Chemistry
# (//biology.stackexchange.com): Biology
# (//cs.stackexchange.com): Computer Science
# (//philosophy.stackexchange.com): Philosophy
# (http://stackexchange.com/sites#science):  more 3
# (//meta.stackexchange.com): Meta Stack Exchange
# (//stackapps.com): Stack Apps
# (//area51.stackexchange.com): Area 51
# (//talent.stackoverflow.com): Stack Overflow Talent
# (https://creativecommons.org/licenses/by-sa/3.0/): cc by sa 3 0
# (http://blog.stackoverflow.com/2009/06/attribution-required/): attribution required
# �
# �
# �
# 8
# (//stackoverflow.com): current community
# (http://chat.stackoverflow.com): chat
# (https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent&amp;utm_source=stackoverflow.com&amp;utm_medium=dev-story&amp;utm_campaign=signup-redirect): Sign up
# (https://stackoverflow.com/users/login?ssrc=site_switcher&returnurl=http%3a%2f%2fstackoverflow.com%2fhelp): log in
# (//stackexchange.com/sites): more stack exchange communities
# (http://stackoverflow.blog): company blog
# (https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent&utm_source=stackoverflow.com&utm_medium=dev-story&utm_campaign=signup-redirect): sign up
# (https://stackoverflow.com/users/login?ssrc=head&returnurl=http%3a%2f%2fstackoverflow.com%2fhelp): log in
# (/tour): tour
# (#):  help
# (/tour):  Tour
# (/help):  Help Center
# (//meta.stackoverflow.com):  Meta
# (http://stackoverflow.com/company/about):  About Us
# (http://business.stackoverflow.com/?ref=topbar_help):  Business
# (/):  Stack Overflow
# (/questions):  Questions
# (/jobs?med=site-ui&ref=jobs-tab):  Jobs
# (/documentation):  Documentation
# (/tags):  Tags
# (/users):  Users
# (/help/badges):  Badges
# (/questions/ask): Ask Question
# (/tour): Take the 2 minute tour
# (/help/duplicates):  Why are some questions marked as duplicate
# (/help/reopen-questions):  What if I disagree with the closure of a question How can I reopen it
# (/help/asking):  View more
# (/help/advertising):  How do I advertise on Stack Overflow
# (/help/advanced-search-parameters-jobs):  What are advanced search query parameters
# (/help/stackexchange):  View more
# (/help/bounty):  What is a bounty How can I start one
# (/help/serial-voting-reversed):  Why do I have a reputation change on my reputation page that says voting corrected
# (/help/reputation):  View more
# (/help/referencing):  How to reference material written by others
# (/help/answer-bans):  Why are answers no longer being accepted from my account
# (/help/deleted-answers):  Why and how are some answers deleted
# (/help/how-to-answer):  How do I write a good answer
# (/help/answering):  View more
# (/help/badges): View a full list of badges you can earn
# (/help/privileges): View a full list of privileges you can earn
# (/help/contact-by-recruiters):  Im not looking for a job Will I be contacted by recruiters
# (/help/how-to-find-jobs):  How can I find jobs Im interested in
# (/help/advanced-search-jobs):  What is an advanced search query
# (/help/jobs):  View more
# (/help/question-limited):  Why have I been limited to one question per week
# (/help/account):  View more
# (/help/documentation-add-tags):  Adding Documentation To Tags
# (/help/documentation-proposed-changes):  Proposed Changes
# (/help/documentation-notifications):  Notifications
# (/help/documentation-drafts):  Edit Drafts
# (/help/documentation-topic-requests):  Topic Requests
# (/help/documentation):  View more
# (http://stackoverflow.com/company/about): about us
# (/tour): tour
# (/help): help
# (http://stackoverflow.blog?blb=1): blog
# (http://chat.stackoverflow.com): chat
# (http://data.stackexchange.com): data
# (http://stackexchange.com/legal): legal
# (http://stackexchange.com/legal/privacy-policy): privacy policy
# (http://stackoverflow.com/company/work-here): work here
# (http://stackexchange.com/mediakit): advertising info
# (None): mobile
# (/contact): contact us
# (http://meta.stackoverflow.com): feedback
# (//stackoverflow.com): Stack Overflow
# (//serverfault.com): Server Fault
# (//superuser.com): Super User
# (//webapps.stackexchange.com): Web Applications
# (//askubuntu.com): Ask Ubuntu
# (//webmasters.stackexchange.com): Webmasters
# (//gamedev.stackexchange.com): Game Development
# (//tex.stackexchange.com): TeX LaTeX
# (//softwareengineering.stackexchange.com): Software Engineering
# (//unix.stackexchange.com): Unix Linux
# (//apple.stackexchange.com): Ask Different Apple
# (//wordpress.stackexchange.com): WordPress Development
# (//gis.stackexchange.com): Geographic Information Systems
# (//electronics.stackexchange.com): Electrical Engineering
# (//android.stackexchange.com): Android Enthusiasts
# (//security.stackexchange.com): Information Security
# (//dba.stackexchange.com): Database Administrators
# (//drupal.stackexchange.com): Drupal Answers
# (//sharepoint.stackexchange.com): SharePoint
# (//ux.stackexchange.com): User Experience
# (//mathematica.stackexchange.com): Mathematica
# (//salesforce.stackexchange.com): Salesforce
# (//expressionengine.stackexchange.com): ExpressionEngine Answers
# (//crypto.stackexchange.com): Cryptography
# (//codereview.stackexchange.com): Code Review
# (//magento.stackexchange.com): Magento
# (//dsp.stackexchange.com): Signal Processing
# (//raspberrypi.stackexchange.com): Raspberry Pi
# (//codegolf.stackexchange.com): Programming Puzzles Code Golf
# (http://stackexchange.com/sites#technology):  more 7
# (//photo.stackexchange.com): Photography
# (//scifi.stackexchange.com): Science Fiction Fantasy
# (//graphicdesign.stackexchange.com): Graphic Design
# (//movies.stackexchange.com): Movies TV
# (//music.stackexchange.com): Music Practice Theory
# (//cooking.stackexchange.com): Seasoned Advice cooking
# (//diy.stackexchange.com): Home Improvement
# (//money.stackexchange.com): Personal Finance Money
# (//academia.stackexchange.com): Academia
# (http://stackexchange.com/sites#lifearts):  more 8
# (//english.stackexchange.com): English Language Usage
# (//skeptics.stackexchange.com): Skeptics
# (//judaism.stackexchange.com): Mi Yodeya Judaism
# (//travel.stackexchange.com): Travel
# (//christianity.stackexchange.com): Christianity
# (//ell.stackexchange.com): English Language Learners
# (//japanese.stackexchange.com): Japanese Language
# (//gaming.stackexchange.com): Arqade gaming
# (//bicycles.stackexchange.com): Bicycles
# (//rpg.stackexchange.com): Role playing Games
# (//anime.stackexchange.com): Anime Manga
# (//mechanics.stackexchange.com): Motor Vehicle Maintenance Repair
# (http://stackexchange.com/sites#culturerecreation):  more 17
# (//mathoverflow.net): MathOverflow
# (//math.stackexchange.com): Mathematics
# (//stats.stackexchange.com): Cross Validated stats
# (//cstheory.stackexchange.com): Theoretical Computer Science
# (//physics.stackexchange.com): Physics
# (//chemistry.stackexchange.com): Chemistry
# (//biology.stackexchange.com): Biology
# (//cs.stackexchange.com): Computer Science
# (//philosophy.stackexchange.com): Philosophy
# (http://stackexchange.com/sites#science):  more 3
# (//meta.stackexchange.com): Meta Stack Exchange
# (//stackapps.com): Stack Apps
# (//area51.stackexchange.com): Area 51
# (//talent.stackoverflow.com): Stack Overflow Talent
# (https://creativecommons.org/licenses/by-sa/3.0/): cc by sa 3 0
# (http://blog.stackoverflow.com/2009/06/attribution-required/): attribution required
# �
# �
# �
# �
# 9
# (//stackoverflow.com): current community
# (http://chat.stackoverflow.com): chat
# (https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent&amp;utm_source=stackoverflow.com&amp;utm_medium=dev-story&amp;utm_campaign=signup-redirect): Sign up
# (https://stackoverflow.com/users/login?ssrc=site_switcher&returnurl=http%3a%2f%2fstackoverflow.com%2fcompany%2fabout): log in
# (//stackexchange.com/sites): more stack exchange communities
# (http://stackoverflow.blog): company blog
# (https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent&utm_source=stackoverflow.com&utm_medium=dev-story&utm_campaign=signup-redirect): sign up
# (https://stackoverflow.com/users/login?ssrc=head&returnurl=http%3a%2f%2fstackoverflow.com%2fcompany%2fabout): log in
# (/tour): tour
# (#):  help
# (/tour):  Tour
# (/help):  Help Center
# (//meta.stackoverflow.com):  Meta
# (http://stackoverflow.com/company/about):  About Us
# (http://business.stackoverflow.com/?ref=topbar_help):  Business
# (/):  Stack Overflow
# (/questions):  Questions
# (/jobs?med=site-ui&ref=jobs-tab):  Jobs
# (/documentation):  Documentation
# (/tags):  Tags
# (/users):  Users
# (/help/badges):  Badges
# (/questions/ask): Ask Question
# (/company/about): about
# (/company/team): team
# (/company/management): management
# (/company/contact): contact us
# (/company/work-here): work here
# (https://stackoverflow.com/company/salary): salary
# (/company/logos): logos
# (/company/work-here): hiring
# (/company/logos): Download Logos
# (http://stackoverflow.blog): Read the Latest Release
# (http://stackoverflow.com/company/about): about us
# (/tour): tour
# (/help): help
# (http://stackoverflow.blog?blb=1): blog
# (http://chat.stackoverflow.com): chat
# (http://data.stackexchange.com): data
# (http://stackexchange.com/legal): legal
# (http://stackexchange.com/legal/privacy-policy): privacy policy
# (http://stackoverflow.com/company/work-here): work here
# (http://stackexchange.com/mediakit): advertising info
# (None): mobile
# (/contact): contact us
# (http://meta.stackoverflow.com): feedback
# (//stackoverflow.com): Stack Overflow
# (//serverfault.com): Server Fault
# (//superuser.com): Super User
# (//webapps.stackexchange.com): Web Applications
# (//askubuntu.com): Ask Ubuntu
# (//webmasters.stackexchange.com): Webmasters
# (//gamedev.stackexchange.com): Game Development
# (//tex.stackexchange.com): TeX LaTeX
# (//softwareengineering.stackexchange.com): Software Engineering
# (//unix.stackexchange.com): Unix Linux
# (//apple.stackexchange.com): Ask Different Apple
# (//wordpress.stackexchange.com): WordPress Development
# (//gis.stackexchange.com): Geographic Information Systems
# (//electronics.stackexchange.com): Electrical Engineering
# (//android.stackexchange.com): Android Enthusiasts
# (//security.stackexchange.com): Information Security
# (//dba.stackexchange.com): Database Administrators
# (//drupal.stackexchange.com): Drupal Answers
# (//sharepoint.stackexchange.com): SharePoint
# (//ux.stackexchange.com): User Experience
# (//mathematica.stackexchange.com): Mathematica
# (//salesforce.stackexchange.com): Salesforce
# (//expressionengine.stackexchange.com): ExpressionEngine Answers
# (//crypto.stackexchange.com): Cryptography
# (//codereview.stackexchange.com): Code Review
# (//magento.stackexchange.com): Magento
# (//dsp.stackexchange.com): Signal Processing
# (//raspberrypi.stackexchange.com): Raspberry Pi
# (//codegolf.stackexchange.com): Programming Puzzles Code Golf
# (http://stackexchange.com/sites#technology):  more 7
# (//photo.stackexchange.com): Photography
# (//scifi.stackexchange.com): Science Fiction Fantasy
# (//graphicdesign.stackexchange.com): Graphic Design
# (//movies.stackexchange.com): Movies TV
# (//music.stackexchange.com): Music Practice Theory
# (//cooking.stackexchange.com): Seasoned Advice cooking
# (//diy.stackexchange.com): Home Improvement
# (//money.stackexchange.com): Personal Finance Money
# (//academia.stackexchange.com): Academia
# (http://stackexchange.com/sites#lifearts):  more 8
# (//english.stackexchange.com): English Language Usage
# (//skeptics.stackexchange.com): Skeptics
# (//judaism.stackexchange.com): Mi Yodeya Judaism
# (//travel.stackexchange.com): Travel
# (//christianity.stackexchange.com): Christianity
# (//ell.stackexchange.com): English Language Learners
# (//japanese.stackexchange.com): Japanese Language
# (//gaming.stackexchange.com): Arqade gaming
# (//bicycles.stackexchange.com): Bicycles
# (//rpg.stackexchange.com): Role playing Games
# (//anime.stackexchange.com): Anime Manga
# (//mechanics.stackexchange.com): Motor Vehicle Maintenance Repair
# (http://stackexchange.com/sites#culturerecreation):  more 17
# (//mathoverflow.net): MathOverflow
# (//math.stackexchange.com): Mathematics
# (//stats.stackexchange.com): Cross Validated stats
# (//cstheory.stackexchange.com): Theoretical Computer Science
# (//physics.stackexchange.com): Physics
# (//chemistry.stackexchange.com): Chemistry
# (//biology.stackexchange.com): Biology
# (//cs.stackexchange.com): Computer Science
# (//philosophy.stackexchange.com): Philosophy
# (http://stackexchange.com/sites#science):  more 3
# (//meta.stackexchange.com): Meta Stack Exchange
# (//stackapps.com): Stack Apps
# (//area51.stackexchange.com): Area 51
# (//talent.stackoverflow.com): Stack Overflow Talent
# (https://creativecommons.org/licenses/by-sa/3.0/): cc by sa 3 0
# (http://blog.stackoverflow.com/2009/06/attribution-required/): attribution required
# �
# ��
# ��
# 10
# (//business.stackoverflow.com/talent/route): Source attract and recruit technical talent on the platform 40 million developers trust to solve their coding problems
# (https://business.stackoverflow.com/talent?modal=false): United States
# (//business.stackoverflow.com/uk/talent?modal=false): United Kingdom
# (https://business.stackoverflow.com/de/talent?modal=false): Deutschland
# (https://business.stackoverflow.com/fr/talent?modal=false): France
# (//business.stackoverflow.com/talent/route): Learn More
# (//business.stackoverflow.com/advertise/): Learn More
# (//business.stackoverflow.com/enterprise): Learn More
# (http://stackoverflow.com/jobs): Visit our jobs page
# (http://stackoverflow.com/): stackoverflow com
# (http://stackexchange.com/legal/privacy-policy): Privacy Policy
# (http://stackexchange.com/legal): Legal
# ��
# ��
# �
# 11
# (//stackoverflow.com): current community
# (http://chat.stackoverflow.com): chat
# (https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent&amp;utm_source=stackoverflow.com&amp;utm_medium=dev-story&amp;utm_campaign=signup-redirect): Sign up
# (https://stackoverflow.com/users/login?ssrc=site_switcher&returnurl=http%3a%2f%2fstackoverflow.com%2fquestions): log in
# (//stackexchange.com/sites): more stack exchange communities
# (http://stackoverflow.blog): company blog
# (https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent&utm_source=stackoverflow.com&utm_medium=dev-story&utm_campaign=signup-redirect): sign up
# (https://stackoverflow.com/users/login?ssrc=head&returnurl=http%3a%2f%2fstackoverflow.com%2fquestions): log in
# (/tour): tour
# (#):  help
# (/tour):  Tour
# (/help):  Help Center
# (//meta.stackoverflow.com):  Meta
# (http://stackoverflow.com/company/about):  About Us
# (http://business.stackoverflow.com/?ref=topbar_help):  Business
# (/):  Stack Overflow
# (/questions):  Questions
# (/jobs?med=site-ui&ref=jobs-tab):  Jobs
# (/documentation):  Documentation
# (/tags):  Tags
# (/users):  Users
# (/help/badges):  Badges
# (/questions/ask): Ask Question
# (/users/story/join): Check out Developer Story
# (/questions?sort=newest):  newest
# (/questions?sort=frequent):  frequent
# (/questions?sort=votes):  votes
# (/questions?sort=active):  active
# (/unanswered):  unanswered
# (/questions/40868015/use-set-1-of-a-database-to-get-set-2-of-a-different-database-in-combination): Use set 1 of a database to get set 2 of a different database in combination
# (/questions/tagged/mysql): mysql
# (/questions/tagged/sql): sql
# (/users/1435176/wouter): Wouter
# (/questions/40868014/how-to-remove-blank-lines-and-duplicate-lines-from-a-text-file-and-save-the-resu): How to remove blank lines and duplicate lines from a text file and save the result in other text file
# (/questions/tagged/python-3.x): python 3 x
# (/users/7222444/robert-szabo): Robert Szabo
# (/questions/40868010/error-reading-csv-file-in-rr): Error Reading CSV file in Rr
# (/questions/tagged/r): r
# (/questions/tagged/csv): csv
# (/questions/tagged/rstudio): rstudio
# (/users/7220615/nats): NATS
# (/questions/40868009/how-to-fetch-user-manager-details-from-sharepint-site-using-asp-net-webapi): how to fetch user manager details from sharepint site using asp net webapi
# (/questions/tagged/c%23): c
# (/questions/tagged/jquery): jquery
# (/questions/tagged/asp.net-web-api): asp net web api
# (/users/6655747/abhijeet-kumar): Abhijeet Kumar
# (/questions/40868006/filtering-the-detectsurffeatures-and-converting-the-array-back-to-its-own-type-o): Filtering the DetectSURFfeatures and converting the array back to its own type on MATLAB
# (/questions/tagged/matlab): matlab
# (/questions/tagged/surf): surf
# (/users/7150999/can-demir): Can Demir
# (/questions/40868003/redirect-every-subpage-to-parent-page): Redirect every subpage to parent page
# (/questions/tagged/.htaccess):  htaccess
# (/questions/tagged/redirect): redirect
# (/questions/tagged/http-status-code-301): http status code 301
# (/users/5300067/marco-jacobs): Marco Jacobs
# (/questions/40868000/sparklyr-working-only-for-root-user-under-debian): sparklyr working only for root user under Debian
# (/questions/tagged/r): r
# (/questions/tagged/sparklyr): sparklyr
# (/users/6290607/mhaddad): mhaddad
# (/questions/40867999/justmock-lite-mocking-sqlconnection): JustMock Lite Mocking SqlConnection
# (/questions/tagged/unit-testing): unit testing
# (/questions/tagged/justmock): justmock
# (/users/285409/limey): Limey
# (/questions/40867992/memento-pattern-in-java-serialization-of-inner-class): Memento pattern in Java serialization of inner class
# (/questions/tagged/java): java
# (/questions/tagged/serialization): serialization
# (/questions/tagged/memento): memento
# (/users/428173/martin-melka): Martin Melka
# (/questions/40867989/express-cant-set-headers-after-they-are-sent-error): Express can t set headers after they are sent error
# (/questions/tagged/javascript): javascript
# (/questions/tagged/node.js): node js
# (/questions/tagged/mongodb): mongodb
# (/questions/tagged/express): express
# (/questions/tagged/mongoose): mongoose
# (/users/818700/dean-gibson): Dean Gibson
# (/questions/40867988/how-to-recreate-reinstantiate-an-object-in-python-2-7): How to recreate reinstantiate an object in python 2 7
# (/questions/tagged/python): python
# (/questions/tagged/oop): oop
# (/users/6598386/kinto-d): kinto d
# (/questions/40867987/mongoose-add-expires-attribute-for-a-specific-field): Mongoose add expires attribute for a specific field
# (/questions/tagged/node.js): node js
# (/questions/tagged/mongodb): mongodb
# (/questions/tagged/mongoose): mongoose
# (/users/2984653/sadrzadehsina): sadrzadehsina
# (/questions/40867986/dividing-frequency-spectrum-in-3-smaller-spectrums): Dividing frequency spectrum in 3 smaller spectrums
# (/questions/tagged/matlab): matlab
# (/questions/tagged/audio): audio
# (/questions/tagged/spectrum): spectrum
# (/users/6281035/jack): Jack
# (/questions/40867985/is-it-possible-to-create-keyboard-events-when-a-certain-key-is-pressed): Is it possible to create keyboard events when a certain key is pressed
# (/questions/tagged/python): python
# (/questions/tagged/python-3.x): python 3 x
# (/users/7116175/percy-shey): Percy Shey
# (/questions/40867984/michelson-interferometer-destructive-interference-due-to-reflection-phase-chan): Michelson interferometer destructive interference due to reflection phase change
# (/questions/tagged/reflection): reflection
# (/questions/tagged/physics): physics
# (/users/1927395/user1927395): user1927395
# (/questions/40867981/multiple-queries-in-model-file-codeigniter): multiple queries in model file codeigniter
# (/questions/tagged/php): php
# (/questions/tagged/mysql): mysql
# (/questions/tagged/codeigniter): codeigniter
# (/users/5273221/harris-khan): Harris Khan
# (/questions/40867979/which-product-or-platform-should-i-use-to-produce-pdf-files-on-the-server-side): Which Product or Platform should I use to produce pdf files on the server side based on templates defined by the user
# (/questions/tagged/pdf): pdf
# (/questions/tagged/pdf-generation): pdf generation
# (/questions/tagged/acrobat): acrobat
# (/users/5699993/picci): Picci
# (/questions/40867977/pandas-drop-certain-values-from-a-column-with-a-string-title): Pandas drop certain values from a column with a string title
# (/questions/tagged/python): python
# (/questions/tagged/string): string
# (/questions/tagged/pandas): pandas
# (/questions/tagged/dataframe): dataframe
# (/users/5110870/cf84): CF84
# (/questions/40867974/rxjs-subscription-in-a-service-does-not-fire): rxjs subscription in a service does not fire
# (/questions/tagged/angular2): angular2
# (/users/2393347/michael-wilson): Michael Wilson
# (/questions/40867973/date-format-in-java-when-9999-12-31-23-59-59-999999): Date format in Java when 9999 12 31 23 59 59 999999
# (/questions/tagged/java): java
# (/questions/tagged/simpledateformat): simpledateformat
# ...
# (http://sqa.stackexchange.com/questions/23932/do-we-use-need-test-cases-in-agile):  Do we use need test cases in Agile
# (http://unix.stackexchange.com/questions/326707/vim-what-are-all-the-possible-swapfile-extensions):  Vim what are all the possible swapfile extensions
# (http://gaming.stackexchange.com/questions/292734/who-performs-the-scene-in-the-instance-of-a-tie):  Who performs the scene in the instance of a tie
# (http://worldbuilding.stackexchange.com/questions/62572/truth-stone-effects-on-the-justice-system-and-criminal-world):  Truth Stone Effects on the justice system and criminal world
# (http://politics.stackexchange.com/questions/13718/why-is-cuba-still-leasing-guantanamo-bay-to-the-us):  Why is Cuba still leasing Guantanamo Bay to the US
# (http://ell.stackexchange.com/questions/110723/can-we-say-hour-11-instead-of-11-hour):  can we say hour 11 instead of 11 hour
# (http://travel.stackexchange.com/questions/83401/after-being-refused-entry-and-removed-from-heathrow-can-i-visit-england):  After being refused entry and removed from Heathrow can I visit England
# (http://physics.stackexchange.com/questions/294966/what-does-antimatter-look-like):  What does antimatter look like
# (http://ham.stackexchange.com/questions/6887/can-my-neighbors-ham-radio-antenna-be-interfering-with-my-internet-signal-or-is):  Can my neighbor s ham radio antenna be interfering with my internet signal or is my internet provider just throwing blame elsewhere
# (http://matheducators.stackexchange.com/questions/11678/why-do-we-care-about-multiple-proofs-of-the-same-theorem):  Why do we care about multiple proofs of the same theorem
# (http://space.stackexchange.com/questions/19191/why-arent-we-sending-quadcopters-to-mars):  Why aren t we sending quadcopters to mars
# (http://aviation.stackexchange.com/questions/33482/why-is-water-contaminated-fuel-bad-but-water-injection-is-not):  Why is water contaminated fuel bad but water injection is not
# (http://sharepoint.stackexchange.com/questions/200865/people-search-core-results-web-part-prompting-credentials-for-each-user-in-the-r):  People Search Core results Web Part prompting credentials for each user in the result
# (http://worldbuilding.stackexchange.com/questions/62429/in-an-era-of-instantaneous-travel-would-more-mundane-methods-still-be-used):  In an era of instantaneous travel would more mundane methods still be used
# (#):  more hot questions
# (http://stackoverflow.com/company/about): about us
# (/tour): tour
# (/help): help
# (http://stackoverflow.blog?blb=1): blog
# (http://chat.stackoverflow.com): chat
# (http://data.stackexchange.com): data
# (http://stackexchange.com/legal): legal
# (http://stackexchange.com/legal/privacy-policy): privacy policy
# (http://stackoverflow.com/company/work-here): work here
# (http://stackexchange.com/mediakit): advertising info
# (None): mobile
# (/contact): contact us
# (http://meta.stackoverflow.com): feedback
# (//stackoverflow.com): Stack Overflow
# (//serverfault.com): Server Fault
# (//superuser.com): Super User
# (//webapps.stackexchange.com): Web Applications
# (//askubuntu.com): Ask Ubuntu
# (//webmasters.stackexchange.com): Webmasters
# (//gamedev.stackexchange.com): Game Development
# (//tex.stackexchange.com): TeX LaTeX
# (//softwareengineering.stackexchange.com): Software Engineering
# (//unix.stackexchange.com): Unix Linux
# (//apple.stackexchange.com): Ask Different Apple
# (//wordpress.stackexchange.com): WordPress Development
# (//gis.stackexchange.com): Geographic Information Systems
# (//electronics.stackexchange.com): Electrical Engineering
# (//android.stackexchange.com): Android Enthusiasts
# (//security.stackexchange.com): Information Security
# (//dba.stackexchange.com): Database Administrators
# (//drupal.stackexchange.com): Drupal Answers
# (//sharepoint.stackexchange.com): SharePoint
# (//ux.stackexchange.com): User Experience
# (//mathematica.stackexchange.com): Mathematica
# (//salesforce.stackexchange.com): Salesforce
# (//expressionengine.stackexchange.com): ExpressionEngine Answers
# (//crypto.stackexchange.com): Cryptography
# (//codereview.stackexchange.com): Code Review
# (//magento.stackexchange.com): Magento
# (//dsp.stackexchange.com): Signal Processing
# (//raspberrypi.stackexchange.com): Raspberry Pi
# (//codegolf.stackexchange.com): Programming Puzzles Code Golf
# (http://stackexchange.com/sites#technology):  more 7
# (//photo.stackexchange.com): Photography
# (//scifi.stackexchange.com): Science Fiction Fantasy
# (//graphicdesign.stackexchange.com): Graphic Design
# (//movies.stackexchange.com): Movies TV
# (//music.stackexchange.com): Music Practice Theory
# (//cooking.stackexchange.com): Seasoned Advice cooking
# (//diy.stackexchange.com): Home Improvement
# (//money.stackexchange.com): Personal Finance Money
# (//academia.stackexchange.com): Academia
# (http://stackexchange.com/sites#lifearts):  more 8
# (//english.stackexchange.com): English Language Usage
# (//skeptics.stackexchange.com): Skeptics
# (//judaism.stackexchange.com): Mi Yodeya Judaism
# (//travel.stackexchange.com): Travel
# (//christianity.stackexchange.com): Christianity
# (//ell.stackexchange.com): English Language Learners
# (//japanese.stackexchange.com): Japanese Language
# (//gaming.stackexchange.com): Arqade gaming
# (//bicycles.stackexchange.com): Bicycles
# (//rpg.stackexchange.com): Role playing Games
# (//anime.stackexchange.com): Anime Manga
# (//mechanics.stackexchange.com): Motor Vehicle Maintenance Repair
# (http://stackexchange.com/sites#culturerecreation):  more 17
# (//mathoverflow.net): MathOverflow
# (//math.stackexchange.com): Mathematics
# (//stats.stackexchange.com): Cross Validated stats
# (//cstheory.stackexchange.com): Theoretical Computer Science
# (//physics.stackexchange.com): Physics
# (//chemistry.stackexchange.com): Chemistry
# (//biology.stackexchange.com): Biology
# (//cs.stackexchange.com): Computer Science
# (//philosophy.stackexchange.com): Philosophy
# (http://stackexchange.com/sites#science):  more 3
# (//meta.stackexchange.com): Meta Stack Exchange
# (//stackapps.com): Stack Apps
# (//area51.stackexchange.com): Area 51
# (//talent.stackoverflow.com): Stack Overflow Talent
# (https://creativecommons.org/licenses/by-sa/3.0/): cc by sa 3 0
# (http://blog.stackoverflow.com/2009/06/attribution-required/): attribution required
# �
# �
# �
# �
# �
# 21
# (//stackoverflow.com): current community
# (http://chat.stackoverflow.com): chat
# (https://stackoverflow.com/users/signup?ssrc=site_switcher&returnurl=%2fusers%2fstory%2fcurrent&amp;utm_source=stackoverflow.com&amp;utm_medium=dev-story&amp;utm_campaign=signup-redirect): Sign up
# (https://stackoverflow.com/users/login?ssrc=site_switcher&returnurl=http%3a%2f%2fstackoverflow.com%2f%3ftab%3dweek): log in
# (//stackexchange.com/sites): more stack exchange communities
# (http://stackoverflow.blog): company blog
# (https://stackoverflow.com/users/signup?ssrc=head&returnurl=%2fusers%2fstory%2fcurrent&utm_source=stackoverflow.com&utm_medium=dev-story&utm_campaign=signup-redirect): sign up
# (https://stackoverflow.com/users/login?ssrc=head&returnurl=http%3a%2f%2fstackoverflow.com%2f%3ftab%3dweek): log in
# (/tour): tour
# (#):  help
# (/tour):  Tour
# (/help):  Help Center
# (//meta.stackoverflow.com):  Meta
# (http://stackoverflow.com/company/about):  About Us
# (http://business.stackoverflow.com/?ref=topbar_help):  Business
# (/):  Stack Overflow
# (/questions):  Questions
# (/jobs?med=site-ui&ref=jobs-tab):  Jobs
# (/documentation):  Documentation
# (/tags):  Tags
# (/users):  Users
# (/help/badges):  Badges
# (/questions/ask): Ask Question
# (/users/story/join): Check out Developer Story
# (?tab=interesting):  interesting
# (?tab=hot):  hot
# (?tab=week):  week
# (?tab=month):  month
# (/questions/40751662/is-a-b-255-255-the-same-as-a-b-255): Is a b 255 255 the same as a b 255
# (/questions/tagged/c%2b%2b): c
# (/questions/tagged/binary): binary
# (/questions/tagged/logic): logic
# (/questions/40751662/is-a-b-255-255-the-same-as-a-b-255/?lastactivity): modified
# (/users/1681985/arhak): arhak
# (/questions/40848551/how-does-adding-string-with-integer-work-in-javascript): How does adding String with Integer work in JavaScript
# (/questions/tagged/javascript): javascript
# (/questions/tagged/string): string
# (/questions/40848551/how-does-adding-string-with-integer-work-in-javascript/?lastactivity): modified
# (/users/1104402/ahmad): Ahmad
# (/questions/40809985/are-functors-actually-faster-than-pointers-to-functions): Are functors actually faster than pointers to functions
# (/questions/tagged/c%2b%2b): c
# (/questions/tagged/function-pointers): function pointers
# (/questions/tagged/function-object): function object
# (/questions/tagged/inlining): inlining
# (/questions/40809985/are-functors-actually-faster-than-pointers-to-functions/?lastactivity): modified
# (/users/366904/cody-gray): Cody Gray
# (/questions/40766653/understanding-complex-typedef-expressions): Understanding complex typedef expressions on hold
# (/questions/tagged/c%2b%2b): c
# (/questions/tagged/c%2b%2b11): c 11
# (/questions/40766653/understanding-complex-typedef-expressions/?lastactivity): modified
# (/users/3620305/k-messaoudi): k messaoudi
# (/questions/40773259/declaring-arrays-in-c): Declaring arrays in C
# (/questions/tagged/c%2b%2b): c
# (/questions/tagged/arrays): arrays
# (/questions/tagged/c%2b%2b11): c 11
# (/questions/tagged/stl): stl
# (/questions/40773259/declaring-arrays-in-c/?lastactivity): modified
# (/users/1067624/max-raskin): Max Raskin
# (/questions/40837371/simplification-of-successive-if-statements-in-java): Simplification of successive if statements in Java on hold
# (/questions/tagged/java): java
# (/questions/tagged/if-statement): if statement
# (/questions/tagged/multidimensional-array): multidimensional array
# (/questions/40837371/simplification-of-successive-if-statements-in-java/?lastactivity): modified
# (/users/1044603/jimmycarr): jimmycarr
# (/questions/40807404/does-the-c-standard-specify-that-for-some-cases-the-compiling-should-fail-with): Does the C standard specify that for some cases the compiling should fail with an error
# (/questions/tagged/c%2b%2b): c
# (/questions/tagged/type-conversion): type conversion
# (/questions/tagged/language-lawyer): language lawyer
# (/questions/tagged/iso): iso
# (/questions/40807404/does-the-c-standard-specify-that-for-some-cases-the-compiling-should-fail-with/?lastactivity): modified
# (/users/3309790/songyuanyao): songyuanyao
# (/questions/40793038/why-css-selector-with-sign-direct-child-overrides-default-styles): Why CSS selector with sign direct child overrides default styles
# (/questions/tagged/html): html
# (/questions/tagged/css): css
# (/questions/tagged/css-selectors): css selectors
# (/questions/40793038/why-css-selector-with-sign-direct-child-overrides-default-styles/?lastactivity): modified
# (/users/3597276/michael-b): Michael B
# (/questions/40791235/error-with-ranged-for-inside-function): Error with ranged for inside function
# (/questions/tagged/c%2b%2b): c
# (/questions/tagged/arrays): arrays
# (/questions/tagged/ranged-loops): ranged loops
# (/questions/40791235/error-with-ranged-for-inside-function/?lastactivity): modified
# (/users/3495074/lemko): Lemko
# (/questions/40759800/in-special-cases-is-faster-than): In special cases Is faster than
# (/questions/tagged/c%2b%2b): c
# (/questions/tagged/c): c
# (/questions/tagged/performance): performance
# (/questions/40759800/in-special-cases-is-faster-than/?lastactivity): modified
# (/users/1788806/willi-mentzel): Willi Mentzel
# (/questions/40765232/why-can-constructor-syntax-not-be-used-with-the-unsigned-int-type): Why can constructor syntax not be used with the unsigned int type
# (/questions/tagged/c%2b%2b): c
# (/questions/tagged/type-conversion): type conversion
# (/questions/tagged/language-lawyer): language lawyer
# (/questions/40765232/why-can-constructor-syntax-not-be-used-with-the-unsigned-int-type/?lastactivity): modified
# (/users/3309790/songyuanyao): songyuanyao
# (/questions/40820787/is-there-a-difference-between-and-list-when-using-id): Is there a difference between and list when using id
# (/questions/tagged/python): python
# (/questions/tagged/list): list
# (/questions/tagged/python-internals): python internals
# (/questions/40820787/is-there-a-difference-between-and-list-when-using-id/?lastactivity): modified
# (/users/100297/martijn-pieters): Martijn Pieters
# (/questions/40842277/create-line-numbers-on-pre-with-css-only): Create line numbers on pre with CSS only
# (/questions/tagged/html): html
# (/questions/tagged/css): css
# (/questions/tagged/css-counter): css counter
# (/questions/40842277/create-line-numbers-on-pre-with-css-only/?lastactivity): modified
# (/users/2606013/harry): Harry
# (/questions/40782381/is-there-a-way-to-have-pi-in-a-css-calc): Is there a way to have pi in a CSS calc
# (/questions/tagged/css): css
# (/questions/tagged/css3): css3
# (/questions/tagged/svg): svg
# (/questions/tagged/css-animations): css animations
# (/questions/40782381/is-there-a-way-to-have-pi-in-a-css-calc/?lastactivity): modified
# (/users/6512469/philip-eagles): Philip Eagles
# (/questions/40767681/absence-of-compilation-error-when-using-parametrized-constructor): Absence of compilation error when using parametrized constructor
# (/questions/tagged/c%2b%2b): c
# (/questions/tagged/most-vexing-parse): most vexing parse
# (/questions/40767681/absence-of-compilation-error-when-using-parametrized-constructor/?lastactivity): answered
# (/users/2692339/black): black
# (/questions/40746309/want-kind-of-constexpr-switch-case-on-type): Want kind of constexpr switch case on type
# (/questions/tagged/c%2b%2b): c
# (/questions/tagged/templates): templates
# (/questions/tagged/metaprogramming): metaprogramming
# (/questions/40746309/want-kind-of-constexpr-switch-case-on-type/?lastactivity): modified
# (/users/4324224/w-f): W F
# (/questions/40842008/subset-a-file-by-row-and-column-numbers): Subset a file by row and column numbers
# (/questions/tagged/bash): bash
# (/questions/tagged/awk): awk
# (/questions/tagged/subset): subset
# (/questions/tagged/bioinformatics): bioinformatics
# (/questions/tagged/cut): cut
# (/questions/40842008/subset-a-file-by-row-and-column-numbers/?lastactivity): modified
# (/users/1543618/ronjohn): RonJohn
# (/questions/40853501/whats-the-substitute-for-jquerys-each-function-in-javascript): What s the substitute for jQuery s each function in JavaScript
# (/questions/tagged/javascript): javascript
# (/questions/tagged/jquery): jquery
# (/questions/40853501/whats-the-substitute-for-jquerys-each-function-in-javascript/?lastactivity): modified
# (/users/1106925/squint): squint
# (/questions/40823526/error-validate-default-type-an-options-default-must-match-its-type-argume): Error Validate default type An option s default must match its type ArgumentError when running Ruby on Rails generate on Windows
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-13-1fc795a1130d> in <module>()
#      11     sorter.sort()
#      12
# ---> 13 iterate()
#
# <ipython-input-13-1fc795a1130d> in iterate()
#       7         print(i)
#       8         crawler.run(i)
# ----> 9         parser.run(i)
#      10     urlresolver.run()
#      11     sorter.sort()
#
# /Users/noahziems/Desktop/SadFuntimes/src/indexer/Parser.pyc in run(docID)
#     100
#     101 def run(docID):
# --> 102     return parseFancyHits(docID)
#
# /Users/noahziems/Desktop/SadFuntimes/src/indexer/Parser.pyc in parseFancyHits(docID, print_data)
#      86         text, link = i
#      87         print "(%s): %s"%(link, text)
# ---> 88         anchorHandler.addAnchor(docID, link, text)
#      89     document_status = 1
#      90     position, url_length, title_length = docIndex.setDocInfo(url, title)
#
# /Users/noahziems/Desktop/SadFuntimes/src/anchors/Anchors.py in addAnchor(docID, link, text)
#      30             link.encode('ascii')
#      31         with open('anchors/anchors.bin', 'r+b') as fp:
# ---> 32             packet = struct.pack('IHH', docID, len(link), len(text)) + link + text
#      33             fp.seek(0, 2)
#      34             position = fp.tell()
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0x80 in position 6: ordinal not in range(128)

# %%
searcher.search('business')
