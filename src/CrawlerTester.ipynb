# %%
import crawlers.Crawlers as crawler

crawler.run(0)
# Out:
# http://www.ibm.com/http://www.ibm.com/http://www.ibm.com//IBM Website/IBM Website/IBM Websitesite
# <!DOCTYPE html>
# <html lang="en-ZZ">
# 	<head>
# 		<meta charset="UTF-8">
#
# 		<meta name="viewport" content="width=device-width, initial-scale=1">
#
# 		<meta name="robots" content="noindex,follow">
# 		<meta name="description" content="The page you requested cannot be displayed (HTTP response code 404)">
# 		<meta name="keywords" content="The page you requested cannot be displayed (HTTP response code 404)">
#
# 		<meta name="geo.country" content="ZZ">
# 		<meta name="dcterms.date" content="2016-05-21">
# 		<meta name="dcterms.rights" content=" Copyright IBM Corp. 2016">
#
# 		<script>
# 			digitalData = {
# 				page: {
# 					category: {
# 						primaryCategory: 'error'
# 					},
# 					pageInfo: {
# 						effectiveDate: '2016-05-21',
# 						expiryDate: '2026-05-21',
# 						language: 'en-ZZ',
# 						publishDate: '2016-05-21',
# 						publisher: 'IBM Corporation',
# ...
